# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# y_test.shape, y_val.shape, y_train.shape
# X_train.shape, X_train.dtype, X_val.shape, X_val.dtype, X_test.shape, X_test.dtype
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # number of layers or depth
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        # The adaptive/learnable/updatable random feedforward
        self.model = []
        self.W_fixed = []
        self.grads = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad = []
        for layer in range(self.L):
            grad.append({key: np.zeros_like(val) for key, val in self.model[1][layer].items()})
        self.grads.append(grad)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Outout layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        # dX = dout @ W.T # Backprop
        dX = dout @ W_fixed.T # fb alignment

        return dX, dW, db

    def train_forward(self, X):
        caches = []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
        y = l.sigmoid(X=y)
        X = y.copy() # pass to the next layer
        caches.append(fc_cache) # caches[0]
        
        # Hidden layers
        fc_caches = []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
            y = l.sigmoid(X=y)
            X = y.copy() # pass to next layer
            fc_caches.append(fc_cache)
        caches.append(fc_caches) # caches[1]
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        caches.append(fc_cache) # caches[2]

        return y, caches

    def loss_function(self, y, y_train):
        
        loss = cross_entropy(y, y_train) # softmax is included
        dy = dcross_entropy(y, y_train) # dsoftmax is included
        
        return loss, dy
    
    def train_backward(self, dy, caches):
        # Output layer
        fc_cache = caches[2]
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy() # pass to the previous layer
        self.grads[2]['W'] = dW
        self.grads[2]['b'] = db

        # Hidden layer
        fc_caches = caches[1]
        for layer in reversed(range(self.L)):
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
            self.grads[1][layer]['W'] = dW
            self.grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache = caches[0]
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        self.grads[0]['W'] = dW
        self.grads[0]['b'] = db

        return dX
    
    def test(self, X):
        y_logit, _ = self.train_forward(X)
        
        # if self.mode == 'classification':
        y_prob = l.softmax(y_logit) # for accuracy== acc
        y_pred = np.argmax(y_prob, axis=1) # for loss==err
        
        return y_pred, y_logit
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            y, caches = self.train_forward(X_mini)
            loss, dy = self.loss_function(y, y_mini)
            _ = self.train_backward(dy, caches)
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in self.grads[0].keys():
                self.model[0][key] -= alpha * self.grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in self.grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * self.grads[1][layer][key]

            # Update the model for output layer
            for key in self.grads[2].keys():
                self.model[2][key] -= alpha * self.grads[2][key]
                
            # Validate the updated model
            y_pred, y_logit = self.test(X_val)
            valid_loss, _ = self.loss_function(y_logit, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val)
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_logit = nn.test(X_test)
        loss, _ = self.loss_function(y_logit, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 10000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 64 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 100 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 1 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-100 train loss: 2.3086 valid loss: 2.3342, valid accuracy: 0.0958
# Iter-200 train loss: 2.3508 valid loss: 2.3283, valid accuracy: 0.0958
# Iter-300 train loss: 2.2495 valid loss: 2.3238, valid accuracy: 0.0958
# Iter-400 train loss: 2.3646 valid loss: 2.3198, valid accuracy: 0.0956
# Iter-500 train loss: 2.3336 valid loss: 2.3160, valid accuracy: 0.0958
# Iter-600 train loss: 2.3233 valid loss: 2.3129, valid accuracy: 0.0958
# Iter-700 train loss: 2.2885 valid loss: 2.3106, valid accuracy: 0.0958
# Iter-800 train loss: 2.3061 valid loss: 2.3084, valid accuracy: 0.0960
# Iter-900 train loss: 2.3410 valid loss: 2.3065, valid accuracy: 0.0984
# Iter-1000 train loss: 2.3094 valid loss: 2.3049, valid accuracy: 0.0988
# Iter-1100 train loss: 2.2962 valid loss: 2.3035, valid accuracy: 0.1038
# Iter-1200 train loss: 2.3179 valid loss: 2.3024, valid accuracy: 0.1328
# Iter-1300 train loss: 2.3029 valid loss: 2.3012, valid accuracy: 0.1510
# Iter-1400 train loss: 2.3030 valid loss: 2.3001, valid accuracy: 0.1342
# Iter-1500 train loss: 2.2976 valid loss: 2.2992, valid accuracy: 0.1732
# Iter-1600 train loss: 2.2963 valid loss: 2.2985, valid accuracy: 0.1894
# Iter-1700 train loss: 2.2783 valid loss: 2.2977, valid accuracy: 0.1862
# Iter-1800 train loss: 2.3054 valid loss: 2.2969, valid accuracy: 0.1766
# Iter-1900 train loss: 2.2916 valid loss: 2.2963, valid accuracy: 0.1672
# Iter-2000 train loss: 2.3028 valid loss: 2.2957, valid accuracy: 0.1642
# Iter-2100 train loss: 2.2995 valid loss: 2.2951, valid accuracy: 0.1606
# Iter-2200 train loss: 2.2857 valid loss: 2.2945, valid accuracy: 0.1512
# Iter-2300 train loss: 2.3062 valid loss: 2.2939, valid accuracy: 0.1596
# Iter-2400 train loss: 2.2914 valid loss: 2.2935, valid accuracy: 0.1550
# Iter-2500 train loss: 2.2806 valid loss: 2.2929, valid accuracy: 0.1512
# Iter-2600 train loss: 2.2942 valid loss: 2.2925, valid accuracy: 0.1448
# Iter-2700 train loss: 2.2828 valid loss: 2.2921, valid accuracy: 0.1458
# Iter-2800 train loss: 2.2870 valid loss: 2.2917, valid accuracy: 0.1444
# Iter-2900 train loss: 2.2922 valid loss: 2.2911, valid accuracy: 0.1472
# Iter-3000 train loss: 2.2935 valid loss: 2.2906, valid accuracy: 0.1540
# Iter-3100 train loss: 2.2919 valid loss: 2.2901, valid accuracy: 0.1576
# Iter-3200 train loss: 2.3016 valid loss: 2.2896, valid accuracy: 0.1706
# Iter-3300 train loss: 2.2854 valid loss: 2.2891, valid accuracy: 0.1712
# Iter-3400 train loss: 2.2858 valid loss: 2.2885, valid accuracy: 0.1658
# Iter-3500 train loss: 2.2798 valid loss: 2.2880, valid accuracy: 0.1686
# Iter-3600 train loss: 2.2909 valid loss: 2.2875, valid accuracy: 0.1740
# Iter-3700 train loss: 2.2887 valid loss: 2.2870, valid accuracy: 0.1702
# Iter-3800 train loss: 2.2957 valid loss: 2.2865, valid accuracy: 0.1604
# Iter-3900 train loss: 2.2833 valid loss: 2.2861, valid accuracy: 0.1494
# Iter-4000 train loss: 2.2843 valid loss: 2.2856, valid accuracy: 0.1552
# Iter-4100 train loss: 2.2854 valid loss: 2.2852, valid accuracy: 0.1496
# Iter-4200 train loss: 2.2754 valid loss: 2.2847, valid accuracy: 0.1540
# Iter-4300 train loss: 2.2706 valid loss: 2.2842, valid accuracy: 0.1602
# Iter-4400 train loss: 2.2862 valid loss: 2.2838, valid accuracy: 0.1636
# Iter-4500 train loss: 2.3118 valid loss: 2.2831, valid accuracy: 0.1762
# Iter-4600 train loss: 2.2950 valid loss: 2.2826, valid accuracy: 0.1764
# Iter-4700 train loss: 2.2717 valid loss: 2.2820, valid accuracy: 0.1898
# Iter-4800 train loss: 2.2684 valid loss: 2.2814, valid accuracy: 0.1836
# Iter-4900 train loss: 2.2645 valid loss: 2.2808, valid accuracy: 0.1948
# Iter-5000 train loss: 2.2819 valid loss: 2.2801, valid accuracy: 0.1972
# Iter-5100 train loss: 2.2742 valid loss: 2.2795, valid accuracy: 0.1960
# Iter-5200 train loss: 2.2868 valid loss: 2.2790, valid accuracy: 0.1932
# Iter-5300 train loss: 2.2662 valid loss: 2.2783, valid accuracy: 0.1906
# Iter-5400 train loss: 2.2807 valid loss: 2.2776, valid accuracy: 0.1916
# Iter-5500 train loss: 2.2798 valid loss: 2.2769, valid accuracy: 0.1978
# Iter-5600 train loss: 2.2946 valid loss: 2.2763, valid accuracy: 0.1976
# Iter-5700 train loss: 2.2669 valid loss: 2.2756, valid accuracy: 0.1938
# Iter-5800 train loss: 2.2942 valid loss: 2.2749, valid accuracy: 0.1832
# Iter-5900 train loss: 2.2688 valid loss: 2.2742, valid accuracy: 0.1880
# Iter-6000 train loss: 2.2639 valid loss: 2.2735, valid accuracy: 0.1916
# Iter-6100 train loss: 2.2709 valid loss: 2.2729, valid accuracy: 0.1906
# Iter-6200 train loss: 2.2741 valid loss: 2.2722, valid accuracy: 0.1912
# Iter-6300 train loss: 2.2951 valid loss: 2.2713, valid accuracy: 0.1948
# Iter-6400 train loss: 2.2607 valid loss: 2.2706, valid accuracy: 0.1984
# Iter-6500 train loss: 2.2722 valid loss: 2.2699, valid accuracy: 0.1952
# Iter-6600 train loss: 2.2699 valid loss: 2.2690, valid accuracy: 0.1986
# Iter-6700 train loss: 2.2538 valid loss: 2.2682, valid accuracy: 0.2036
# Iter-6800 train loss: 2.2534 valid loss: 2.2672, valid accuracy: 0.2084
# Iter-6900 train loss: 2.2708 valid loss: 2.2663, valid accuracy: 0.2146
# Iter-7000 train loss: 2.2667 valid loss: 2.2655, valid accuracy: 0.2162
# Iter-7100 train loss: 2.2544 valid loss: 2.2647, valid accuracy: 0.2130
# Iter-7200 train loss: 2.2637 valid loss: 2.2637, valid accuracy: 0.2190
# Iter-7300 train loss: 2.2574 valid loss: 2.2628, valid accuracy: 0.2174
# Iter-7400 train loss: 2.2500 valid loss: 2.2618, valid accuracy: 0.2236
# Iter-7500 train loss: 2.2360 valid loss: 2.2607, valid accuracy: 0.2296
# Iter-7600 train loss: 2.2561 valid loss: 2.2596, valid accuracy: 0.2332
# Iter-7700 train loss: 2.2648 valid loss: 2.2586, valid accuracy: 0.2306
# Iter-7800 train loss: 2.2470 valid loss: 2.2574, valid accuracy: 0.2334
# Iter-7900 train loss: 2.2730 valid loss: 2.2563, valid accuracy: 0.2354
# Iter-8000 train loss: 2.2260 valid loss: 2.2551, valid accuracy: 0.2374
# Iter-8100 train loss: 2.2578 valid loss: 2.2539, valid accuracy: 0.2386
# Iter-8200 train loss: 2.2685 valid loss: 2.2527, valid accuracy: 0.2356
# Iter-8300 train loss: 2.2622 valid loss: 2.2514, valid accuracy: 0.2356
# Iter-8400 train loss: 2.2686 valid loss: 2.2502, valid accuracy: 0.2356
# Iter-8500 train loss: 2.2718 valid loss: 2.2489, valid accuracy: 0.2378
# Iter-8600 train loss: 2.2609 valid loss: 2.2475, valid accuracy: 0.2422
# Iter-8700 train loss: 2.2475 valid loss: 2.2461, valid accuracy: 0.2428
# Iter-8800 train loss: 2.2718 valid loss: 2.2447, valid accuracy: 0.2456
# Iter-8900 train loss: 2.2383 valid loss: 2.2433, valid accuracy: 0.2480
# Iter-9000 train loss: 2.2520 valid loss: 2.2419, valid accuracy: 0.2444
# Iter-9100 train loss: 2.2359 valid loss: 2.2405, valid accuracy: 0.2446
# Iter-9200 train loss: 2.2447 valid loss: 2.2389, valid accuracy: 0.2450
# Iter-9300 train loss: 2.2240 valid loss: 2.2373, valid accuracy: 0.2446
# Iter-9400 train loss: 2.2613 valid loss: 2.2357, valid accuracy: 0.2460
# Iter-9500 train loss: 2.2359 valid loss: 2.2341, valid accuracy: 0.2476
# Iter-9600 train loss: 2.2020 valid loss: 2.2324, valid accuracy: 0.2486
# Iter-9700 train loss: 2.2357 valid loss: 2.2307, valid accuracy: 0.2494
# Iter-9800 train loss: 2.2708 valid loss: 2.2291, valid accuracy: 0.2512
# Iter-9900 train loss: 2.2154 valid loss: 2.2274, valid accuracy: 0.2550
# Iter-10000 train loss: 2.2393 valid loss: 2.2255, valid accuracy: 0.2576
# Last iteration - Test accuracy mean: 0.2571, std: 0.0000, loss: 2.2247

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
# plt.plot(nn.losses['smooth train'], label='Train smooth loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
