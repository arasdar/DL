# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
y_test.shape, y_val.shape, y_train.shape
X_train.shape, X_train.dtype, X_val.shape, X_val.dtype, X_test.shape, X_test.dtype
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz
# ((55000, 784),
#  dtype('float32'),
#  (5000, 784),
#  dtype('float32'),
#  (10000, 784),
#  dtype('float32'))

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# sample = np.random.uniform(high=10, low=0, size=(1,10))
# sample.shape, sample.dtype, sample

# %%
# # np.exp(sample)/np.exp(sample).sum(axis=1)
# # # sample.shape, sample.dtype
# np.exp(sample)/ np.exp(sample).sum(axis=1).reshape(-1, 1)

# %%
# def softmax(X):
# #     eX = np.exp((X.T - np.max(X, axis=1)).T)
#     eX = np.exp(X.T)
#     return (eX.T / eX.sum(axis=1)).T

# %%
# softmax(X=sample), np.exp(sample.T)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # number of layers or depth
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        # The adaptive/learnable/updatable random feedforward
        self.model = []
        self.W_fixed = []
        self.grads = []
        self.ys_prev = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})
        # Previous output layer
        self.ys_prev.append(0.0)

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad_L = []
        for _ in range(L):
            grad_L.append({key: np.zeros_like(val) for key, val in self.model[1][0].items()})
        self.grads.append(grad_L)
        # Previous output layer
        ys_prev_L = []
        for _ in range(L):
            ys_prev_L.append(0.0)
        self.ys_prev.append(ys_prev_L)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Outout layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        # Previous output layer
        self.ys_prev.append(0.0)
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
        # dX = dout @ W.T # Backprop
        dX = dout @ W_fixed.T # fb alignment

        return dX, dW, db

    def train_forward(self, X):
        caches, ys = [], []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
        y, nl_cache = l.selu_forward(X=y)
#         y = np.exp(y) #/ np.exp(y).sum(axis=1).reshape(-1, 1) # txn
        X = y.copy() # pass to the next layer
        caches.append((fc_cache, nl_cache)) # caches[0]
        ys.append(y) # ys[0]
        
        # Hidden layers
        fc_caches, nl_caches, ys_L = [], [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
            y, nl_cache = l.selu_forward(X=y)
#             y = np.exp(y) #/ np.exp(y).sum(axis=1).reshape(-1, 1) # txn
            X = y.copy() # pass to next layer
            fc_caches.append(fc_cache)
            nl_caches.append(nl_cache)
            ys_L.append(y) # ys[1][layer]
        caches.append((fc_caches, nl_caches)) # caches[1]
        ys.append(ys_L) # ys[1]
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        caches.append(fc_cache) # caches[2]
        ys.append(y) # ys[2]

        return ys, caches

    def loss_function(self, y, y_train):
        
        loss = cross_entropy(y, y_train) # softmax is included
        dy = dcross_entropy(y, y_train) # dsoftmax is included
        
        return loss, dy
        
    def train_backward(self, dy, caches):
        grads = self.grads # initialized by Zero in every iteration/epoch
        
        # Output layer
        fc_cache = caches[2]
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
        grads[2]['W'] = dW
        grads[2]['b'] = db

        # Hidden layer
        fc_caches, nl_caches = caches[1]
        for layer in reversed(range(self.L)):
#             dy = l.selu_backward(cache=nl_caches[layer], dout=dy)
#             dy = np.exp(dy) #/ np.exp(dy).sum(axis=1).reshape(-1, 1) # txn
            dy *= self.ys[1][layer] - self.ys_prev[1][layer] # function derivative or dfunc
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
            grads[1][layer]['W'] = dW
            grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache, nl_cache = caches[0]
#         dy = l.selu_backward(cache=nl_cache, dout=dy)
#         dy = np.exp(dy) #/ np.exp(dy).sum(axis=1).reshape(-1, 1) # txn
        dy *= self.ys[0] - self.ys_prev[0]
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        # dy = dX.copy()
        grads[0]['W'] = dW
        grads[0]['b'] = db

        return dX, grads
    
    def test(self, X):
        ys_logit, _ = self.train_forward(X)
        y_logit = ys_logit[2] # last layer
        
        # if self.mode == 'classification':
        y_prob = l.softmax(y_logit) # for accuracy == acc
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_logit
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            self.ys, caches = self.train_forward(X_mini)
#             print(self.ys[2].shape)
            loss, dy = self.loss_function(self.ys[2], y_mini)
            _, grads = self.train_backward(dy, caches) # self.ys_prev is used here for dfunc/ diff
            self.ys_prev = self.ys # for next iteration or epoch
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in grads[0].keys():
                self.model[0][key] -= alpha * grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * grads[1][layer][key]

            # Update the model for output layer
            for key in grads[2].keys():
                self.model[2][key] -= alpha * grads[2][key]
                
            # Validate the updated model
            y_pred, y_logit = self.test(X_val)
            valid_loss, _ = self.loss_function(y_logit, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val) # confusion matrix
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_logit = nn.test(X_test)
        loss, _ = self.loss_function(y_logit, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 1000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 50 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 10 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 10 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-10 train loss: 2.3564 valid loss: 2.3113, valid accuracy: 0.0996
# Iter-20 train loss: 2.3556 valid loss: 2.3110, valid accuracy: 0.0998
# Iter-30 train loss: 2.3389 valid loss: 2.3107, valid accuracy: 0.1006
# Iter-40 train loss: 2.3297 valid loss: 2.3104, valid accuracy: 0.1008
# Iter-50 train loss: 2.3008 valid loss: 2.3100, valid accuracy: 0.1016
# Iter-60 train loss: 2.2921 valid loss: 2.3097, valid accuracy: 0.1022
# Iter-70 train loss: 2.2988 valid loss: 2.3094, valid accuracy: 0.1026
# Iter-80 train loss: 2.2610 valid loss: 2.3091, valid accuracy: 0.1028
# Iter-90 train loss: 2.3133 valid loss: 2.3088, valid accuracy: 0.1036
# Iter-100 train loss: 2.3162 valid loss: 2.3084, valid accuracy: 0.1040
# Iter-110 train loss: 2.2306 valid loss: 2.3081, valid accuracy: 0.1042
# Iter-120 train loss: 2.3251 valid loss: 2.3078, valid accuracy: 0.1040
# Iter-130 train loss: 2.2778 valid loss: 2.3075, valid accuracy: 0.1042
# Iter-140 train loss: 2.2833 valid loss: 2.3071, valid accuracy: 0.1046
# Iter-150 train loss: 2.2908 valid loss: 2.3068, valid accuracy: 0.1052
# Iter-160 train loss: 2.3417 valid loss: 2.3065, valid accuracy: 0.1054
# Iter-170 train loss: 2.2941 valid loss: 2.3061, valid accuracy: 0.1058
# Iter-180 train loss: 2.3246 valid loss: 2.3058, valid accuracy: 0.1062
# Iter-190 train loss: 2.3009 valid loss: 2.3055, valid accuracy: 0.1066
# Iter-200 train loss: 2.2920 valid loss: 2.3052, valid accuracy: 0.1068
# Iter-210 train loss: 2.2934 valid loss: 2.3049, valid accuracy: 0.1072
# Iter-220 train loss: 2.2904 valid loss: 2.3045, valid accuracy: 0.1070
# Iter-230 train loss: 2.2977 valid loss: 2.3042, valid accuracy: 0.1074
# Iter-240 train loss: 2.2666 valid loss: 2.3039, valid accuracy: 0.1080
# Iter-250 train loss: 2.3071 valid loss: 2.3035, valid accuracy: 0.1084
# Iter-260 train loss: 2.2765 valid loss: 2.3032, valid accuracy: 0.1092
# Iter-270 train loss: 2.3181 valid loss: 2.3029, valid accuracy: 0.1096
# Iter-280 train loss: 2.3336 valid loss: 2.3025, valid accuracy: 0.1106
# Iter-290 train loss: 2.2892 valid loss: 2.3022, valid accuracy: 0.1104
# Iter-300 train loss: 2.2769 valid loss: 2.3019, valid accuracy: 0.1106
# Iter-310 train loss: 2.2959 valid loss: 2.3016, valid accuracy: 0.1106
# Iter-320 train loss: 2.2881 valid loss: 2.3012, valid accuracy: 0.1110
# Iter-330 train loss: 2.3296 valid loss: 2.3009, valid accuracy: 0.1114
# Iter-340 train loss: 2.3140 valid loss: 2.3006, valid accuracy: 0.1120
# Iter-350 train loss: 2.3141 valid loss: 2.3003, valid accuracy: 0.1124
# Iter-360 train loss: 2.2836 valid loss: 2.3000, valid accuracy: 0.1128
# Iter-370 train loss: 2.3189 valid loss: 2.2996, valid accuracy: 0.1132
# Iter-380 train loss: 2.2814 valid loss: 2.2993, valid accuracy: 0.1134
# Iter-390 train loss: 2.3008 valid loss: 2.2990, valid accuracy: 0.1136
# Iter-400 train loss: 2.3001 valid loss: 2.2987, valid accuracy: 0.1138
# Iter-410 train loss: 2.2865 valid loss: 2.2984, valid accuracy: 0.1142
# Iter-420 train loss: 2.3466 valid loss: 2.2981, valid accuracy: 0.1148
# Iter-430 train loss: 2.3064 valid loss: 2.2978, valid accuracy: 0.1150
# Iter-440 train loss: 2.2614 valid loss: 2.2975, valid accuracy: 0.1150
# Iter-450 train loss: 2.2880 valid loss: 2.2972, valid accuracy: 0.1152
# Iter-460 train loss: 2.3063 valid loss: 2.2968, valid accuracy: 0.1160
# Iter-470 train loss: 2.2813 valid loss: 2.2965, valid accuracy: 0.1166
# Iter-480 train loss: 2.2424 valid loss: 2.2962, valid accuracy: 0.1168
# Iter-490 train loss: 2.3323 valid loss: 2.2959, valid accuracy: 0.1168
# Iter-500 train loss: 2.2369 valid loss: 2.2956, valid accuracy: 0.1170
# Iter-510 train loss: 2.3104 valid loss: 2.2953, valid accuracy: 0.1172
# Iter-520 train loss: 2.2951 valid loss: 2.2950, valid accuracy: 0.1176
# Iter-530 train loss: 2.2646 valid loss: 2.2946, valid accuracy: 0.1178
# Iter-540 train loss: 2.3672 valid loss: 2.2943, valid accuracy: 0.1178
# Iter-550 train loss: 2.3065 valid loss: 2.2940, valid accuracy: 0.1180
# Iter-560 train loss: 2.3062 valid loss: 2.2937, valid accuracy: 0.1184
# Iter-570 train loss: 2.3117 valid loss: 2.2934, valid accuracy: 0.1192
# Iter-580 train loss: 2.3438 valid loss: 2.2931, valid accuracy: 0.1198
# Iter-590 train loss: 2.2972 valid loss: 2.2927, valid accuracy: 0.1196
# Iter-600 train loss: 2.2709 valid loss: 2.2925, valid accuracy: 0.1204
# Iter-610 train loss: 2.2864 valid loss: 2.2921, valid accuracy: 0.1204
# Iter-620 train loss: 2.2666 valid loss: 2.2918, valid accuracy: 0.1208
# Iter-630 train loss: 2.2924 valid loss: 2.2915, valid accuracy: 0.1216
# Iter-640 train loss: 2.2942 valid loss: 2.2913, valid accuracy: 0.1222
# Iter-650 train loss: 2.2798 valid loss: 2.2909, valid accuracy: 0.1224
# Iter-660 train loss: 2.2930 valid loss: 2.2906, valid accuracy: 0.1226
# Iter-670 train loss: 2.3424 valid loss: 2.2903, valid accuracy: 0.1236
# Iter-680 train loss: 2.2531 valid loss: 2.2900, valid accuracy: 0.1244
# Iter-690 train loss: 2.2862 valid loss: 2.2897, valid accuracy: 0.1244
# Iter-700 train loss: 2.2858 valid loss: 2.2894, valid accuracy: 0.1244
# Iter-710 train loss: 2.2939 valid loss: 2.2891, valid accuracy: 0.1250
# Iter-720 train loss: 2.2847 valid loss: 2.2888, valid accuracy: 0.1252
# Iter-730 train loss: 2.3044 valid loss: 2.2885, valid accuracy: 0.1256
# Iter-740 train loss: 2.2460 valid loss: 2.2882, valid accuracy: 0.1258
# Iter-750 train loss: 2.2846 valid loss: 2.2880, valid accuracy: 0.1262
# Iter-760 train loss: 2.2613 valid loss: 2.2877, valid accuracy: 0.1268
# Iter-770 train loss: 2.3114 valid loss: 2.2873, valid accuracy: 0.1274
# Iter-780 train loss: 2.2487 valid loss: 2.2870, valid accuracy: 0.1276
# Iter-790 train loss: 2.2879 valid loss: 2.2867, valid accuracy: 0.1284
# Iter-800 train loss: 2.3037 valid loss: 2.2864, valid accuracy: 0.1290
# Iter-810 train loss: 2.2709 valid loss: 2.2861, valid accuracy: 0.1296
# Iter-820 train loss: 2.2921 valid loss: 2.2859, valid accuracy: 0.1298
# Iter-830 train loss: 2.2694 valid loss: 2.2856, valid accuracy: 0.1308
# Iter-840 train loss: 2.3108 valid loss: 2.2853, valid accuracy: 0.1310
# Iter-850 train loss: 2.3044 valid loss: 2.2850, valid accuracy: 0.1310
# Iter-860 train loss: 2.2942 valid loss: 2.2847, valid accuracy: 0.1314
# Iter-870 train loss: 2.2446 valid loss: 2.2843, valid accuracy: 0.1320
# Iter-880 train loss: 2.3068 valid loss: 2.2840, valid accuracy: 0.1326
# Iter-890 train loss: 2.2828 valid loss: 2.2837, valid accuracy: 0.1330
# Iter-900 train loss: 2.2988 valid loss: 2.2834, valid accuracy: 0.1338
# Iter-910 train loss: 2.2715 valid loss: 2.2830, valid accuracy: 0.1356
# Iter-920 train loss: 2.2452 valid loss: 2.2827, valid accuracy: 0.1358
# Iter-930 train loss: 2.3168 valid loss: 2.2825, valid accuracy: 0.1368
# Iter-940 train loss: 2.3124 valid loss: 2.2821, valid accuracy: 0.1364
# Iter-950 train loss: 2.2498 valid loss: 2.2818, valid accuracy: 0.1372
# Iter-960 train loss: 2.2524 valid loss: 2.2815, valid accuracy: 0.1374
# Iter-970 train loss: 2.3036 valid loss: 2.2812, valid accuracy: 0.1376
# Iter-980 train loss: 2.2317 valid loss: 2.2810, valid accuracy: 0.1380
# Iter-990 train loss: 2.2555 valid loss: 2.2806, valid accuracy: 0.1386
# Iter-1000 train loss: 2.2772 valid loss: 2.2803, valid accuracy: 0.1388
# Last iteration - Test accuracy mean: 0.1423, std: 0.0000, loss: 2.2787

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
