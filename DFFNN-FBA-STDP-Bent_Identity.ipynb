# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# y_test.shape, y_val.shape, y_train.shape
# X_train.shape, X_train.dtype, X_val.shape, X_val.dtype, X_test.shape, X_test.dtype
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # number of layers or depth
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        # The adaptive/learnable/updatable random feedforward
        self.model = []
        self.W_fixed = []
        self.grads = []
        self.ys_prev = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})
        # Previous output layer
        self.ys_prev.append(0.0)

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad_L = []
        for _ in range(L):
            grad_L.append({key: np.zeros_like(val) for key, val in self.model[1][0].items()})
        self.grads.append(grad_L)
        # Previous output layer
        ys_prev_L = []
        for _ in range(L):
            ys_prev_L.append(0.0)
        self.ys_prev.append(ys_prev_L)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Outout layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        # Previous output layer
        self.ys_prev.append(0.0)
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
        # dX = dout @ W.T # Backprop
        dX = dout @ W_fixed.T # fb alignment

        return dX, dW, db

    def train_forward(self, X, train):
        caches, ys = [], []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
#         y, _ = l.selu_forward(X=y)
#         y = l.elu_fwd(X=y)
#         y = l.sigmoid(X=y)
#         y = np.tanh(y)
#         a, b = 1.7519, 2/3
#         y = a * np.tanh(b*y) # LeCun Tanh
#         y = np.arctan(y)
#         y = y / (1 + np.absolute(y)) # softsign
        y = ((((y**2) + 1)**0.5 + 1)/ 2) + y # bent identity
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[0]
        X = y.copy() # pass to the next layer
        
        # Hidden layers
        fc_caches, ys_L, do_caches = [], [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
#             y, _ = l.selu_forward(X=y)
#             y = l.elu_fwd(X=y)
#             y = l.sigmoid(X=y)
#             y = np.tanh(y)
#             a, b = 1.7519, 2/3
#             y = a * np.tanh(b*y)
#             y = np.arctan(y)
#             y = y / (1 + np.absolute(y)) # softsign
            y = ((((y**2) + 1)**0.5 + 1)/ 2) + y # bent identity
            fc_caches.append(fc_cache)
            ys_L.append(y) # ys[1][layer]
            X = y.copy() # pass to next layer
        if train:
            caches.append(fc_caches) # caches[1]
        ys.append(ys_L) # ys[1]            
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[2]

        return ys, caches # for backpropating the error

    def loss_function(self, y, y_train):
        
        loss = cross_entropy(y, y_train) # softmax is included
        dy = dcross_entropy(y, y_train) # dsoftmax is included
        
        return loss, dy
        
    def train_backward(self, dy, caches):
        grads = self.grads # initialized by Zero in every iteration/epoch
        ys, ys_prev = self.ys, self.ys_prev # temporal diff instead of differentiable function
        
        # Output layer
        fc_cache = caches[2]
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
        grads[2]['W'] = dW
        grads[2]['b'] = db

        # Hidden layer
        fc_caches = caches[1]
        for layer in reversed(range(self.L)):
            dy *= ys[1][layer] - ys_prev[1][layer] # temporal diff instead of differentiable function
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
            grads[1][layer]['W'] = dW
            grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache = caches[0]
        dy *= ys[0] - ys_prev[0] # temporal diff instead of differentiable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        grads[0]['W'] = dW
        grads[0]['b'] = db

        return dX, grads
    
    def test(self, X):
        ys_logit, _ = self.train_forward(X, train=False)
        y_logit = ys_logit[2] # last layer
        
        # if self.mode == 'classification':
        y_prob = l.softmax(y_logit) # for accuracy == acc
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_logit
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            self.ys, caches = self.train_forward(X_mini, train=True)
            loss, dy = self.loss_function(self.ys[2], y_mini)
            _, grads = self.train_backward(dy, caches) # self.ys_prev is used here for dfunc/ diff
            self.ys_prev = self.ys # for next iteration or epoch
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in grads[0].keys():
                self.model[0][key] -= alpha * grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * grads[1][layer][key]

            # Update the model for output layer
            for key in grads[2].keys():
                self.model[2][key] -= alpha * grads[2][key]
                
            # Validate the updated model
            y_pred, y_logit = self.test(X_val)
            valid_loss, _ = self.loss_function(y_logit, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val) # confusion matrix
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_logit = nn.test(X_test)
        loss, _ = self.loss_function(y_logit, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 10000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 50 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 100 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 2 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-100 train loss: 2.4704 valid loss: 2.4659, valid accuracy: 0.0392
# Iter-200 train loss: 2.3586 valid loss: 2.3634, valid accuracy: 0.0562
# Iter-300 train loss: 2.3285 valid loss: 2.3505, valid accuracy: 0.0518
# Iter-400 train loss: 2.3697 valid loss: 2.3494, valid accuracy: 0.0588
# Iter-500 train loss: 2.3541 valid loss: 2.3471, valid accuracy: 0.0638
# Iter-600 train loss: 2.3979 valid loss: 2.3438, valid accuracy: 0.0572
# Iter-700 train loss: 2.3358 valid loss: 2.3435, valid accuracy: 0.0594
# Iter-800 train loss: 2.3413 valid loss: 2.3405, valid accuracy: 0.0608
# Iter-900 train loss: 2.3343 valid loss: 2.3382, valid accuracy: 0.0616
# Iter-1000 train loss: 2.3645 valid loss: 2.3356, valid accuracy: 0.0630
# Iter-1100 train loss: 2.3124 valid loss: 2.3347, valid accuracy: 0.0800
# Iter-1200 train loss: 2.3371 valid loss: 2.3316, valid accuracy: 0.0770
# Iter-1300 train loss: 2.2889 valid loss: 2.3298, valid accuracy: 0.0596
# Iter-1400 train loss: 2.3612 valid loss: 2.3275, valid accuracy: 0.0852
# Iter-1500 train loss: 2.3212 valid loss: 2.3251, valid accuracy: 0.0748
# Iter-1600 train loss: 2.2892 valid loss: 2.3227, valid accuracy: 0.0858
# Iter-1700 train loss: 2.3342 valid loss: 2.3208, valid accuracy: 0.0666
# Iter-1800 train loss: 2.2967 valid loss: 2.3201, valid accuracy: 0.0740
# Iter-1900 train loss: 2.3368 valid loss: 2.3171, valid accuracy: 0.0812
# Iter-2000 train loss: 2.3013 valid loss: 2.3153, valid accuracy: 0.0860
# Iter-2100 train loss: 2.2930 valid loss: 2.3137, valid accuracy: 0.0930
# Iter-2200 train loss: 2.3224 valid loss: 2.3096, valid accuracy: 0.1060
# Iter-2300 train loss: 2.3446 valid loss: 2.3077, valid accuracy: 0.0944
# Iter-2400 train loss: 2.3057 valid loss: 2.3064, valid accuracy: 0.0920
# Iter-2500 train loss: 2.3226 valid loss: 2.3033, valid accuracy: 0.0804
# Iter-2600 train loss: 2.3006 valid loss: 2.3006, valid accuracy: 0.0806
# Iter-2700 train loss: 2.3007 valid loss: 2.3009, valid accuracy: 0.0894
# Iter-2800 train loss: 2.3181 valid loss: 2.2976, valid accuracy: 0.0970
# Iter-2900 train loss: 2.3120 valid loss: 2.2952, valid accuracy: 0.0992
# Iter-3000 train loss: 2.2612 valid loss: 2.2939, valid accuracy: 0.1060
# Iter-3100 train loss: 2.2868 valid loss: 2.2910, valid accuracy: 0.0908
# Iter-3200 train loss: 2.3128 valid loss: 2.2890, valid accuracy: 0.1338
# Iter-3300 train loss: 2.2853 valid loss: 2.2879, valid accuracy: 0.1176
# Iter-3400 train loss: 2.2552 valid loss: 2.2855, valid accuracy: 0.1600
# Iter-3500 train loss: 2.2856 valid loss: 2.2846, valid accuracy: 0.1598
# Iter-3600 train loss: 2.2606 valid loss: 2.2809, valid accuracy: 0.1610
# Iter-3700 train loss: 2.2875 valid loss: 2.2785, valid accuracy: 0.1404
# Iter-3800 train loss: 2.2612 valid loss: 2.2786, valid accuracy: 0.1096
# Iter-3900 train loss: 2.2612 valid loss: 2.2748, valid accuracy: 0.1616
# Iter-4000 train loss: 2.2894 valid loss: 2.2733, valid accuracy: 0.1188
# Iter-4100 train loss: 2.3014 valid loss: 2.2722, valid accuracy: 0.1358
# Iter-4200 train loss: 2.2820 valid loss: 2.2700, valid accuracy: 0.1110
# Iter-4300 train loss: 2.2583 valid loss: 2.2691, valid accuracy: 0.1682
# Iter-4400 train loss: 2.2449 valid loss: 2.2677, valid accuracy: 0.1756
# Iter-4500 train loss: 2.2453 valid loss: 2.2638, valid accuracy: 0.2002
# Iter-4600 train loss: 2.2774 valid loss: 2.2609, valid accuracy: 0.1798
# Iter-4700 train loss: 2.2689 valid loss: 2.2605, valid accuracy: 0.1640
# Iter-4800 train loss: 2.2783 valid loss: 2.2585, valid accuracy: 0.1714
# Iter-4900 train loss: 2.3005 valid loss: 2.2558, valid accuracy: 0.2038
# Iter-5000 train loss: 2.2496 valid loss: 2.2551, valid accuracy: 0.2026
# Iter-5100 train loss: 2.2859 valid loss: 2.2531, valid accuracy: 0.2190
# Iter-5200 train loss: 2.2496 valid loss: 2.2531, valid accuracy: 0.2302
# Iter-5300 train loss: 2.2453 valid loss: 2.2502, valid accuracy: 0.1898
# Iter-5400 train loss: 2.2841 valid loss: 2.2482, valid accuracy: 0.2168
# Iter-5500 train loss: 2.2368 valid loss: 2.2470, valid accuracy: 0.1614
# Iter-5600 train loss: 2.2671 valid loss: 2.2432, valid accuracy: 0.2138
# Iter-5700 train loss: 2.2132 valid loss: 2.2423, valid accuracy: 0.1926
# Iter-5800 train loss: 2.2667 valid loss: 2.2403, valid accuracy: 0.2160
# Iter-5900 train loss: 2.2035 valid loss: 2.2385, valid accuracy: 0.1900
# Iter-6000 train loss: 2.2337 valid loss: 2.2376, valid accuracy: 0.2030
# Iter-6100 train loss: 2.2064 valid loss: 2.2370, valid accuracy: 0.2240
# Iter-6200 train loss: 2.1921 valid loss: 2.2351, valid accuracy: 0.2400
# Iter-6300 train loss: 2.2219 valid loss: 2.2312, valid accuracy: 0.2320
# Iter-6400 train loss: 2.2385 valid loss: 2.2314, valid accuracy: 0.2302
# Iter-6500 train loss: 2.2366 valid loss: 2.2312, valid accuracy: 0.2456
# Iter-6600 train loss: 2.2496 valid loss: 2.2262, valid accuracy: 0.2484
# Iter-6700 train loss: 2.2264 valid loss: 2.2263, valid accuracy: 0.2510
# Iter-6800 train loss: 2.1820 valid loss: 2.2244, valid accuracy: 0.2552
# Iter-6900 train loss: 2.2304 valid loss: 2.2217, valid accuracy: 0.2528
# Iter-7000 train loss: 2.2280 valid loss: 2.2210, valid accuracy: 0.2404
# Iter-7100 train loss: 2.2201 valid loss: 2.2183, valid accuracy: 0.2578
# Iter-7200 train loss: 2.2231 valid loss: 2.2189, valid accuracy: 0.2456
# Iter-7300 train loss: 2.2454 valid loss: 2.2155, valid accuracy: 0.2632
# Iter-7400 train loss: 2.1943 valid loss: 2.2136, valid accuracy: 0.2478
# Iter-7500 train loss: 2.2470 valid loss: 2.2151, valid accuracy: 0.2298
# Iter-7600 train loss: 2.2343 valid loss: 2.2114, valid accuracy: 0.2654
# Iter-7700 train loss: 2.2132 valid loss: 2.2079, valid accuracy: 0.2852
# Iter-7800 train loss: 2.2209 valid loss: 2.2077, valid accuracy: 0.2466
# Iter-7900 train loss: 2.2199 valid loss: 2.2066, valid accuracy: 0.2578
# Iter-8000 train loss: 2.1911 valid loss: 2.2037, valid accuracy: 0.2576
# Iter-8100 train loss: 2.2268 valid loss: 2.2030, valid accuracy: 0.2776
# Iter-8200 train loss: 2.2294 valid loss: 2.2013, valid accuracy: 0.2812
# Iter-8300 train loss: 2.1981 valid loss: 2.2009, valid accuracy: 0.2818
# Iter-8400 train loss: 2.1610 valid loss: 2.1974, valid accuracy: 0.2772
# Iter-8500 train loss: 2.1667 valid loss: 2.1986, valid accuracy: 0.2690
# Iter-8600 train loss: 2.1705 valid loss: 2.1985, valid accuracy: 0.2038
# Iter-8700 train loss: 2.1664 valid loss: 2.1984, valid accuracy: 0.2628
# Iter-8800 train loss: 2.2554 valid loss: 2.1944, valid accuracy: 0.2934
# Iter-8900 train loss: 2.1646 valid loss: 2.1912, valid accuracy: 0.2840
# Iter-9000 train loss: 2.2017 valid loss: 2.1898, valid accuracy: 0.2898
# Iter-9100 train loss: 2.1807 valid loss: 2.1886, valid accuracy: 0.3004
# Iter-9200 train loss: 2.1698 valid loss: 2.1860, valid accuracy: 0.3114
# Iter-9300 train loss: 2.1986 valid loss: 2.1860, valid accuracy: 0.2724
# Iter-9400 train loss: 2.1842 valid loss: 2.1844, valid accuracy: 0.2834
# Iter-9500 train loss: 2.2372 valid loss: 2.1821, valid accuracy: 0.2962
# Iter-9600 train loss: 2.1533 valid loss: 2.1829, valid accuracy: 0.2734
# Iter-9700 train loss: 2.1821 valid loss: 2.1809, valid accuracy: 0.2880
# Iter-9800 train loss: 2.1949 valid loss: 2.1766, valid accuracy: 0.2886
# Iter-9900 train loss: 2.1330 valid loss: 2.1781, valid accuracy: 0.2466
# Iter-10000 train loss: 2.1783 valid loss: 2.1755, valid accuracy: 0.3128
# Last iteration - Test accuracy mean: 0.2995, std: 0.0000, loss: 2.1747

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
