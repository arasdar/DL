# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# y_test.shape, y_val.shape, y_train.shape
# X_train.shape, X_train.dtype, X_val.shape, X_val.dtype, X_test.shape, X_test.dtype
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # number of layers or depth
        self.C = C
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        # The adaptive/learnable/updatable random feedforward
        self.model = []
        self.W_fixed = []
        self.grads = []
        self.ys_prev = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})
        # Previous output layer
        self.ys_prev.append(0.0)

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad_L = []
        for _ in range(L):
            grad_L.append({key: np.zeros_like(val) for key, val in self.model[1][0].items()})
        self.grads.append(grad_L)
        # Previous output layer
        ys_prev_L = []
        for _ in range(L):
            ys_prev_L.append(0.0)
        self.ys_prev.append(ys_prev_L)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Outout layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        # Previous output layer
        self.ys_prev.append(0.0)
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
#         dX = dout @ W.T # Backprop
        dX = dout @ W_fixed.T # fb alignment

        return dX, dW, db

    def train_forward(self, X, train):
        caches, ys = [], []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
        y, nl_cache = l.tanh_forward(X=y)
        if train:
            caches.append((fc_cache, nl_cache))
        ys.append(y) # ys[0]
        X = y.copy() # pass to the next layer
        
        # Hidden layers
        fc_caches, nl_caches, ys_L = [], [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
            y, nl_cache = l.tanh_forward(X=y)
            ys_L.append(y) # ys[1][layer]
            X = y.copy() # pass to next layer
            if train:
                fc_caches.append(fc_cache)
                nl_caches.append(nl_cache)
        if train:
            caches.append((fc_caches, nl_caches)) # caches[1]            
        ys.append(ys_L) # ys[1]            
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        y_prob = l.softmax(X=y)
        if train:
            caches.append(fc_cache)
        ys.append(y_prob) # ys[2]

        return ys, caches # for backpropating the error

    def onehot(self, y_train):
#         y = np.zeros([y_train.size, np.max(y_train) + 1])
        y = np.zeros([y_train.size, self.C])
        y[range(y_train.size), y_train] = 1.
        return y

    def squared_loss(self, y_prob, y_train):
        m = y_prob.shape[0]

        data_loss = 0.5 * np.sum(y_prob - (self.onehot(y_train))**2)/ m
#         print(y_prob.shape, l.onehot(y_train).shape)

        return data_loss

    def dsquared_loss(self, y_prob, y_train):
        m = y_prob.shape[0]

        grad_y = (y_prob - l.onehot(y_train))/ m
#         print(y_pred.shape, l.onehot(y_train).shape)
        
        return grad_y

    def cross_entropy(self, y_prob, y_train):
        m = y_prob.shape[0]

#         prob = l.softmax(y_pred)
        log_like = -np.log(y_prob[range(m), y_train] + l.eps) # to avoid the devision by zero
        data_loss = np.sum(log_like) / m

        return data_loss

    def dcross_entropy(self, y_prob, y_train): # this is equal for both since the reg_loss (noise) derivative is ZERO.
        m = y_prob.shape[0]

#         grad_y = l.softmax(y_pred)
        grad_y = y_prob
        grad_y[range(m), y_train] -= 1.
        grad_y /= m

        return grad_y

    def loss_function(self, y_prob, y_train):
        
        loss = self.cross_entropy(y_prob, y_train) # softmax is included
        dy = self.dcross_entropy(y_prob, y_train) # dsoftmax is included

#         loss = self.squared_loss(y_prob, y_train)
#         dy = self.dsquared_loss(y_prob, y_train)
# #         print(dy.shape)

        return loss, dy
        
    def train_backward(self, dy, caches, ys):
        grads, ys_prev = self.grads, self.ys_prev # initialized by Zero in every iteration/epoch
        
        # Output layer
        fc_cache = caches[2]
        # softmax_backward
#         dy *= ys[2] - ys_prev[2] # temporal diff instead of differentiable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
        grads[2]['W'] = dW

        grads[2]['b'] = db

        # Hidden layer
        fc_caches, nl_caches = caches[1]
        for layer in reversed(range(self.L)):
            dy *= ys[1][layer] - ys_prev[1][layer] # temporal diff instead of differentiable function
#             dy = l.tanh_backward(cache=nl_caches[layer], dout=dy) # diffable function
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
            grads[1][layer]['W'] = dW
            grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache, nl_cache = caches[0]
        dy *= ys[0] - ys_prev[0] # temporal diff instead of differentiable function
#         dy = l.tanh_backward(cache=nl_cache, dout=dy) # diffable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        grads[0]['W'] = dW
        grads[0]['b'] = db

        return dX, grads
    
    def test(self, X):
        ys, _ = self.train_forward(X, train=False)
        y_prob = ys[2] # last layer
        
        # if self.mode == 'classification':
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_prob
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            ys, caches = self.train_forward(X_mini, train=True)
            loss, dy = self.loss_function(ys[2], y_mini)
            _, grads = self.train_backward(dy, caches, ys) # ys[0], ys[1] and ys_prev are used for backprop
            self.ys_prev = ys # for next iteration or epoch learning dW and db
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in grads[0].keys():
                self.model[0][key] -= alpha * grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * grads[1][layer][key]

            # Update the model for output layer
            for key in grads[2].keys():
                self.model[2][key] -= alpha * grads[2][key]
                
            # Validate the updated model
            y_pred, y_prob = self.test(X_val)
            valid_loss, _ = self.loss_function(y_prob, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val) # confusion matrix
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_prob = nn.test(X_test)
        loss, _ = self.loss_function(y_prob, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 1000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 50 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 10 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 2 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-10 train loss: 2.3008 valid loss: 2.3086, valid accuracy: 0.0730
# Iter-20 train loss: 2.3310 valid loss: 2.3085, valid accuracy: 0.0730
# Iter-30 train loss: 2.3025 valid loss: 2.3084, valid accuracy: 0.0732
# Iter-40 train loss: 2.3108 valid loss: 2.3083, valid accuracy: 0.0736
# Iter-50 train loss: 2.3253 valid loss: 2.3083, valid accuracy: 0.0738
# Iter-60 train loss: 2.3275 valid loss: 2.3082, valid accuracy: 0.0744
# Iter-70 train loss: 2.3190 valid loss: 2.3081, valid accuracy: 0.0742
# Iter-80 train loss: 2.3284 valid loss: 2.3080, valid accuracy: 0.0742
# Iter-90 train loss: 2.3153 valid loss: 2.3079, valid accuracy: 0.0744
# Iter-100 train loss: 2.3008 valid loss: 2.3078, valid accuracy: 0.0748
# Iter-110 train loss: 2.2912 valid loss: 2.3077, valid accuracy: 0.0748
# Iter-120 train loss: 2.3143 valid loss: 2.3076, valid accuracy: 0.0750
# Iter-130 train loss: 2.2898 valid loss: 2.3075, valid accuracy: 0.0756
# Iter-140 train loss: 2.3181 valid loss: 2.3074, valid accuracy: 0.0760
# Iter-150 train loss: 2.3071 valid loss: 2.3073, valid accuracy: 0.0760
# Iter-160 train loss: 2.3036 valid loss: 2.3072, valid accuracy: 0.0760
# Iter-170 train loss: 2.3199 valid loss: 2.3071, valid accuracy: 0.0762
# Iter-180 train loss: 2.3209 valid loss: 2.3070, valid accuracy: 0.0766
# Iter-190 train loss: 2.3060 valid loss: 2.3070, valid accuracy: 0.0770
# Iter-200 train loss: 2.3154 valid loss: 2.3069, valid accuracy: 0.0770
# Iter-210 train loss: 2.2978 valid loss: 2.3068, valid accuracy: 0.0772
# Iter-220 train loss: 2.2884 valid loss: 2.3067, valid accuracy: 0.0772
# Iter-230 train loss: 2.2933 valid loss: 2.3066, valid accuracy: 0.0772
# Iter-240 train loss: 2.3129 valid loss: 2.3065, valid accuracy: 0.0774
# Iter-250 train loss: 2.3045 valid loss: 2.3064, valid accuracy: 0.0774
# Iter-260 train loss: 2.3184 valid loss: 2.3063, valid accuracy: 0.0774
# Iter-270 train loss: 2.3203 valid loss: 2.3062, valid accuracy: 0.0776
# Iter-280 train loss: 2.3063 valid loss: 2.3061, valid accuracy: 0.0776
# Iter-290 train loss: 2.3170 valid loss: 2.3060, valid accuracy: 0.0780
# Iter-300 train loss: 2.3008 valid loss: 2.3059, valid accuracy: 0.0780
# Iter-310 train loss: 2.3135 valid loss: 2.3058, valid accuracy: 0.0782
# Iter-320 train loss: 2.3111 valid loss: 2.3057, valid accuracy: 0.0782
# Iter-330 train loss: 2.2873 valid loss: 2.3056, valid accuracy: 0.0780
# Iter-340 train loss: 2.3154 valid loss: 2.3055, valid accuracy: 0.0782
# Iter-350 train loss: 2.3107 valid loss: 2.3054, valid accuracy: 0.0780
# Iter-360 train loss: 2.2995 valid loss: 2.3054, valid accuracy: 0.0782
# Iter-370 train loss: 2.2892 valid loss: 2.3053, valid accuracy: 0.0782
# Iter-380 train loss: 2.2719 valid loss: 2.3052, valid accuracy: 0.0782
# Iter-390 train loss: 2.2886 valid loss: 2.3051, valid accuracy: 0.0780
# Iter-400 train loss: 2.3157 valid loss: 2.3050, valid accuracy: 0.0784
# Iter-410 train loss: 2.3114 valid loss: 2.3049, valid accuracy: 0.0784
# Iter-420 train loss: 2.2793 valid loss: 2.3048, valid accuracy: 0.0792
# Iter-430 train loss: 2.3150 valid loss: 2.3047, valid accuracy: 0.0794
# Iter-440 train loss: 2.3017 valid loss: 2.3046, valid accuracy: 0.0800
# Iter-450 train loss: 2.3237 valid loss: 2.3045, valid accuracy: 0.0802
# Iter-460 train loss: 2.3087 valid loss: 2.3045, valid accuracy: 0.0800
# Iter-470 train loss: 2.2879 valid loss: 2.3044, valid accuracy: 0.0802
# Iter-480 train loss: 2.2880 valid loss: 2.3043, valid accuracy: 0.0794
# Iter-490 train loss: 2.3044 valid loss: 2.3042, valid accuracy: 0.0802
# Iter-500 train loss: 2.2974 valid loss: 2.3041, valid accuracy: 0.0802
# Iter-510 train loss: 2.2887 valid loss: 2.3040, valid accuracy: 0.0804
# Iter-520 train loss: 2.2990 valid loss: 2.3039, valid accuracy: 0.0806
# Iter-530 train loss: 2.3099 valid loss: 2.3038, valid accuracy: 0.0804
# Iter-540 train loss: 2.3244 valid loss: 2.3037, valid accuracy: 0.0806
# Iter-550 train loss: 2.2755 valid loss: 2.3036, valid accuracy: 0.0808
# Iter-560 train loss: 2.3075 valid loss: 2.3035, valid accuracy: 0.0808
# Iter-570 train loss: 2.3194 valid loss: 2.3034, valid accuracy: 0.0808
# Iter-580 train loss: 2.2819 valid loss: 2.3034, valid accuracy: 0.0808
# Iter-590 train loss: 2.3208 valid loss: 2.3033, valid accuracy: 0.0810
# Iter-600 train loss: 2.3060 valid loss: 2.3032, valid accuracy: 0.0812
# Iter-610 train loss: 2.3193 valid loss: 2.3031, valid accuracy: 0.0814
# Iter-620 train loss: 2.2978 valid loss: 2.3030, valid accuracy: 0.0816
# Iter-630 train loss: 2.3051 valid loss: 2.3029, valid accuracy: 0.0818
# Iter-640 train loss: 2.2914 valid loss: 2.3028, valid accuracy: 0.0822
# Iter-650 train loss: 2.3231 valid loss: 2.3027, valid accuracy: 0.0822
# Iter-660 train loss: 2.3070 valid loss: 2.3026, valid accuracy: 0.0826
# Iter-670 train loss: 2.2959 valid loss: 2.3025, valid accuracy: 0.0826
# Iter-680 train loss: 2.3284 valid loss: 2.3024, valid accuracy: 0.0828
# Iter-690 train loss: 2.2999 valid loss: 2.3023, valid accuracy: 0.0826
# Iter-700 train loss: 2.3090 valid loss: 2.3022, valid accuracy: 0.0832
# Iter-710 train loss: 2.3226 valid loss: 2.3021, valid accuracy: 0.0834
# Iter-720 train loss: 2.3085 valid loss: 2.3020, valid accuracy: 0.0842
# Iter-730 train loss: 2.2991 valid loss: 2.3020, valid accuracy: 0.0846
# Iter-740 train loss: 2.2851 valid loss: 2.3018, valid accuracy: 0.0846
# Iter-750 train loss: 2.3162 valid loss: 2.3018, valid accuracy: 0.0848
# Iter-760 train loss: 2.2912 valid loss: 2.3017, valid accuracy: 0.0850
# Iter-770 train loss: 2.2796 valid loss: 2.3016, valid accuracy: 0.0852
# Iter-780 train loss: 2.3089 valid loss: 2.3015, valid accuracy: 0.0856
# Iter-790 train loss: 2.3000 valid loss: 2.3014, valid accuracy: 0.0858
# Iter-800 train loss: 2.2819 valid loss: 2.3013, valid accuracy: 0.0856
# Iter-810 train loss: 2.2931 valid loss: 2.3012, valid accuracy: 0.0862
# Iter-820 train loss: 2.2950 valid loss: 2.3011, valid accuracy: 0.0868
# Iter-830 train loss: 2.2985 valid loss: 2.3010, valid accuracy: 0.0874
# Iter-840 train loss: 2.3166 valid loss: 2.3009, valid accuracy: 0.0876
# Iter-850 train loss: 2.3020 valid loss: 2.3009, valid accuracy: 0.0878
# Iter-860 train loss: 2.2957 valid loss: 2.3008, valid accuracy: 0.0876
# Iter-870 train loss: 2.2849 valid loss: 2.3007, valid accuracy: 0.0880
# Iter-880 train loss: 2.3068 valid loss: 2.3006, valid accuracy: 0.0882
# Iter-890 train loss: 2.2747 valid loss: 2.3005, valid accuracy: 0.0888
# Iter-900 train loss: 2.2984 valid loss: 2.3004, valid accuracy: 0.0894
# Iter-910 train loss: 2.3104 valid loss: 2.3003, valid accuracy: 0.0900
# Iter-920 train loss: 2.3008 valid loss: 2.3002, valid accuracy: 0.0900
# Iter-930 train loss: 2.2877 valid loss: 2.3001, valid accuracy: 0.0908
# Iter-940 train loss: 2.2822 valid loss: 2.3001, valid accuracy: 0.0914
# Iter-950 train loss: 2.2971 valid loss: 2.3000, valid accuracy: 0.0914
# Iter-960 train loss: 2.2967 valid loss: 2.2999, valid accuracy: 0.0916
# Iter-970 train loss: 2.3004 valid loss: 2.2998, valid accuracy: 0.0922
# Iter-980 train loss: 2.3269 valid loss: 2.2997, valid accuracy: 0.0930
# Iter-990 train loss: 2.2921 valid loss: 2.2996, valid accuracy: 0.0928
# Iter-1000 train loss: 2.2933 valid loss: 2.2995, valid accuracy: 0.0928
# Last iteration - Test accuracy mean: 0.0883, std: 0.0000, loss: 2.3005

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
