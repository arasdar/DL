# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # layers
        self.C = C # classes
        self.losses = {'train':[], 'train_acc':[], 
                       'valid':[], 'valid_acc':[], 
                       'test':[], 'test_acc':[]}
        
        self.model = []
        self.W_fixed = []
        self.grads = []
        self.dy_prev = np.zeros((1, C))
        self.y_prev = np.zeros((1, C))
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad_L = []
        for _ in range(L):
            grad_L.append({key: np.zeros_like(val) for key, val in self.model[1][0].items()})
        self.grads.append(grad_L)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Output layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
        dX = dout @ W.T # vanilla Backprop
#         dX = dout @ W_fixed.T # fba backprop

        return dX, dW, db

    def train_forward(self, X, train):
        caches, ys = [], []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
        y, nl_cache = l.tanh_forward(X=y)
#         y, nl_cache = l.sigmoid_forward(X=y)
        if train:
            caches.append((fc_cache, nl_cache))
        X = y.copy() # pass to the next layer
        
        # Hidden layers
        fc_caches, nl_caches = [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
            y, nl_cache = l.tanh_forward(X=y)
#             y, nl_cache = l.sigmoid_forward(X=y)
            X = y.copy() # pass to next layer
            if train:
                fc_caches.append(fc_cache)
                nl_caches.append(nl_cache)
        if train:
            caches.append((fc_caches, nl_caches)) # caches[1]            
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        y_prob = l.softmax(X=y)
        if train:
            caches.append(fc_cache)

        return y_prob, caches # for backpropating the error

    def cross_entropy(self, y_prob, y_train):
        m = y_prob.shape[0]

        #         prob = l.softmax(y_pred)
        log_like = -np.log(y_prob[range(m), y_train] + l.eps) # to avoid the devision by zero
        data_loss = np.sum(log_like) / m

        return data_loss

    def dcross_entropy(self, y_prob, y_train): # this is equal for both since the reg_loss (noise) derivative is ZERO.
        m = y_prob.shape[0]

        #         grad_y = l.softmax(y_pred)
        grad_y = y_prob
        grad_y[range(m), y_train] -= 1.
        grad_y /= m

        return grad_y

    def loss_function(self, y_prob, y_train):
        
        loss = self.cross_entropy(y_prob, y_train) # softmax is included
        dy = self.dcross_entropy(y_prob, y_train) # dsoftmax is included

        return loss, dy
        
    def train_backward(self, dy, caches, y):
        grads = self.grads.copy() # initialized by Zero in every iteration/epoch
#         dy_prev = self.dy_prev.copy() # for temporal differencing
#         self.dy_prev = dy.copy() # next iteration/ epoch
#         y_prev = self.y_prev.copy() # for temporal differencing
#         self.y_prev = y.copy() # next iteration/ epoch
        
        # Output layer
        fc_cache = caches[2]
        # softmax_backward is included in dcross_entropy.
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
# #         dy =  dy @ self.W_fixed[2].T # done
#         dy_prev =  dy_prev @ self.W_fixed[2].T
#         y =  y @ self.W_fixed[2].T # done
#         y_prev =  y_prev @ self.W_fixed[2].T
        grads[2]['W'] = dW
        grads[2]['b'] = db

        # Hidden layer
        fc_caches, nl_caches = caches[1]
        for layer in reversed(range(self.L)):
            dy = l.tanh_backward(cache=nl_caches[layer], dout=dy) # diffable function
#             dy = l.sigmoid_backward(cache=nl_caches[layer], dout=dy) # diffable function
#             dy *= dy - dy_prev # temporal diff instead of differentiable function
#             dy *= y - y_prev # temporal diff instead of differentiable function
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
# #             dy =  dy @ self.W_fixed[2].T # done
#             dy_prev =  dy_prev @ self.W_fixed[1][layer].T
#             y =  y @ self.W_fixed[1][layer].T # done
#             y_prev =  y_prev @ self.W_fixed[1][layer].T
            grads[1][layer]['W'] = dW
            grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache, nl_cache = caches[0]
        dy = l.tanh_backward(cache=nl_cache, dout=dy) # diffable function
#         dy = l.sigmoid_backward(cache=nl_caches[layer], dout=dy) # diffable function
#         dy *= dy - dy_prev # temporal diff instead of differentiable function
#         dy *= y - y_prev # temporal diff instead of differentiable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        grads[0]['W'] = dW
        grads[0]['b'] = db

        return dX, grads
    
    def test(self, X):
        y_prob, _ = self.train_forward(X, train=False)
        
        # if self.mode == 'classification':
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_prob
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            y_prob, caches = self.train_forward(X_mini, train=True)
            _, dy = self.loss_function(y_prob, y_mini)
            _, grads = self.train_backward(dy, caches, y_prob)
            
            # Update the model for input layer
            for key in grads[0].keys():
                self.model[0][key] -= alpha * grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * grads[1][layer][key]

            # Update the model for output layer
            for key in grads[2].keys():
                self.model[2][key] -= alpha * grads[2][key]
            
            # Training accuracy
            y_pred, y_prob = self.test(X_mini)
            loss, _ = self.loss_function(y_prob, y_mini) # softmax is included in entropy loss function
            self.losses['train'].append(loss)
            acc = np.mean(y_pred == y_mini) # confusion matrix
            self.losses['train_acc'].append(acc)

            # Validate the updated model
            y_pred, y_prob = self.test(X_val)
            valid_loss, _ = self.loss_function(y_prob, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val) # confusion matrix
            self.losses['valid_acc'].append(valid_acc)
            
            # Test the final model
            y_pred, y_prob = nn.test(X_test)
            test_loss, _ = self.loss_function(y_prob, y_test) # softmax is included in entropy loss function
            self.losses['test'].append(test_loss)
            test_acc = np.mean(y_pred == y_test)
            self.losses['test_acc'].append(test_acc)
#             print('Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.
#             format(acc.mean(), acc.std(), loss))
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{}, train loss-{:.4f}, acc-{:.4f}, valid loss-{:.4f}, acc-{:.4f}, test loss-{:.4f}, acc-{:.4f}'.format(
                   iter, loss, acc, valid_loss, valid_acc, test_loss, test_acc))

# %%
# Hyper-parameters
n_iter = 1000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 50 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 10 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 2 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-10, train loss-2.3398, acc-0.0600, valid loss-2.3290, acc-0.0898, test loss-2.3258, acc-0.0961
# Iter-20, train loss-2.3212, acc-0.1200, valid loss-2.3242, acc-0.0954, test loss-2.3210, acc-0.1036
# Iter-30, train loss-2.3227, acc-0.0600, valid loss-2.3193, acc-0.1012, test loss-2.3161, acc-0.1104
# Iter-40, train loss-2.2953, acc-0.1000, valid loss-2.3146, acc-0.1068, test loss-2.3113, acc-0.1174
# Iter-50, train loss-2.2979, acc-0.0800, valid loss-2.3099, acc-0.1112, test loss-2.3066, acc-0.1241
# Iter-60, train loss-2.2968, acc-0.1800, valid loss-2.3054, acc-0.1178, test loss-2.3021, acc-0.1332
# Iter-70, train loss-2.3131, acc-0.1000, valid loss-2.3009, acc-0.1262, test loss-2.2974, acc-0.1412
# Iter-80, train loss-2.3344, acc-0.0400, valid loss-2.2961, acc-0.1338, test loss-2.2926, acc-0.1489
# Iter-90, train loss-2.2586, acc-0.2400, valid loss-2.2914, acc-0.1420, test loss-2.2879, acc-0.1579
# Iter-100, train loss-2.2933, acc-0.1200, valid loss-2.2870, acc-0.1514, test loss-2.2835, acc-0.1666
# Iter-110, train loss-2.3002, acc-0.1200, valid loss-2.2825, acc-0.1610, test loss-2.2789, acc-0.1751
# Iter-120, train loss-2.2564, acc-0.1800, valid loss-2.2778, acc-0.1680, test loss-2.2742, acc-0.1849
# Iter-130, train loss-2.2857, acc-0.1600, valid loss-2.2733, acc-0.1762, test loss-2.2697, acc-0.1932
# Iter-140, train loss-2.2750, acc-0.1400, valid loss-2.2685, acc-0.1876, test loss-2.2649, acc-0.2027
# Iter-150, train loss-2.2658, acc-0.2000, valid loss-2.2641, acc-0.1970, test loss-2.2604, acc-0.2124
# Iter-160, train loss-2.2534, acc-0.1800, valid loss-2.2597, acc-0.2056, test loss-2.2560, acc-0.2215
# Iter-170, train loss-2.2629, acc-0.2000, valid loss-2.2552, acc-0.2150, test loss-2.2515, acc-0.2324
# Iter-180, train loss-2.2311, acc-0.3600, valid loss-2.2511, acc-0.2226, test loss-2.2473, acc-0.2400
# Iter-190, train loss-2.2639, acc-0.1600, valid loss-2.2469, acc-0.2324, test loss-2.2431, acc-0.2500
# Iter-200, train loss-2.2602, acc-0.2400, valid loss-2.2428, acc-0.2400, test loss-2.2390, acc-0.2584
# Iter-210, train loss-2.2416, acc-0.3000, valid loss-2.2385, acc-0.2478, test loss-2.2347, acc-0.2678
# Iter-220, train loss-2.2403, acc-0.2400, valid loss-2.2340, acc-0.2562, test loss-2.2303, acc-0.2776
# Iter-230, train loss-2.2328, acc-0.2400, valid loss-2.2296, acc-0.2648, test loss-2.2257, acc-0.2870
# Iter-240, train loss-2.2202, acc-0.3600, valid loss-2.2256, acc-0.2714, test loss-2.2217, acc-0.2939
# Iter-250, train loss-2.2264, acc-0.2800, valid loss-2.2211, acc-0.2834, test loss-2.2173, acc-0.3013
# Iter-260, train loss-2.1818, acc-0.4200, valid loss-2.2169, acc-0.2920, test loss-2.2131, acc-0.3096
# Iter-270, train loss-2.2137, acc-0.3200, valid loss-2.2129, acc-0.3002, test loss-2.2091, acc-0.3162
# Iter-280, train loss-2.2254, acc-0.2800, valid loss-2.2088, acc-0.3072, test loss-2.2050, acc-0.3247
# Iter-290, train loss-2.2042, acc-0.3800, valid loss-2.2046, acc-0.3146, test loss-2.2008, acc-0.3324
# Iter-300, train loss-2.2221, acc-0.2800, valid loss-2.2003, acc-0.3228, test loss-2.1964, acc-0.3409
# Iter-310, train loss-2.2155, acc-0.2800, valid loss-2.1963, acc-0.3296, test loss-2.1924, acc-0.3483
# Iter-320, train loss-2.1913, acc-0.3200, valid loss-2.1922, acc-0.3370, test loss-2.1883, acc-0.3574
# Iter-330, train loss-2.1948, acc-0.2600, valid loss-2.1881, acc-0.3454, test loss-2.1842, acc-0.3657
# Iter-340, train loss-2.1427, acc-0.4000, valid loss-2.1841, acc-0.3548, test loss-2.1802, acc-0.3719
# Iter-350, train loss-2.1830, acc-0.3400, valid loss-2.1800, acc-0.3624, test loss-2.1762, acc-0.3778
# Iter-360, train loss-2.1790, acc-0.3800, valid loss-2.1760, acc-0.3700, test loss-2.1721, acc-0.3828
# Iter-370, train loss-2.1511, acc-0.3400, valid loss-2.1719, acc-0.3764, test loss-2.1680, acc-0.3894
# Iter-380, train loss-2.1610, acc-0.4800, valid loss-2.1682, acc-0.3832, test loss-2.1642, acc-0.3943
# Iter-390, train loss-2.1698, acc-0.4800, valid loss-2.1644, acc-0.3892, test loss-2.1605, acc-0.3993
# Iter-400, train loss-2.2033, acc-0.3200, valid loss-2.1605, acc-0.3936, test loss-2.1566, acc-0.4044
# Iter-410, train loss-2.1399, acc-0.4400, valid loss-2.1564, acc-0.3986, test loss-2.1525, acc-0.4113
# Iter-420, train loss-2.1427, acc-0.4800, valid loss-2.1527, acc-0.4032, test loss-2.1488, acc-0.4154
# Iter-430, train loss-2.1506, acc-0.4600, valid loss-2.1488, acc-0.4096, test loss-2.1449, acc-0.4192
# Iter-440, train loss-2.1135, acc-0.4400, valid loss-2.1450, acc-0.4152, test loss-2.1412, acc-0.4251
# Iter-450, train loss-2.1613, acc-0.3200, valid loss-2.1412, acc-0.4202, test loss-2.1373, acc-0.4301
# Iter-460, train loss-2.1133, acc-0.5600, valid loss-2.1373, acc-0.4254, test loss-2.1334, acc-0.4344
# Iter-470, train loss-2.1174, acc-0.4400, valid loss-2.1333, acc-0.4308, test loss-2.1295, acc-0.4389
# Iter-480, train loss-2.1449, acc-0.2800, valid loss-2.1295, acc-0.4358, test loss-2.1257, acc-0.4432
# Iter-490, train loss-2.1303, acc-0.4800, valid loss-2.1257, acc-0.4408, test loss-2.1218, acc-0.4479
# Iter-500, train loss-2.1183, acc-0.4200, valid loss-2.1217, acc-0.4448, test loss-2.1179, acc-0.4521
# Iter-510, train loss-2.1325, acc-0.4800, valid loss-2.1180, acc-0.4502, test loss-2.1141, acc-0.4555
# Iter-520, train loss-2.0837, acc-0.5000, valid loss-2.1140, acc-0.4558, test loss-2.1102, acc-0.4590
# Iter-530, train loss-2.1306, acc-0.4000, valid loss-2.1102, acc-0.4604, test loss-2.1065, acc-0.4633
# Iter-540, train loss-2.0707, acc-0.5600, valid loss-2.1062, acc-0.4634, test loss-2.1024, acc-0.4671
# Iter-550, train loss-2.1362, acc-0.3400, valid loss-2.1025, acc-0.4676, test loss-2.0987, acc-0.4705
# Iter-560, train loss-2.0605, acc-0.5200, valid loss-2.0987, acc-0.4722, test loss-2.0949, acc-0.4732
# Iter-570, train loss-2.0774, acc-0.4400, valid loss-2.0949, acc-0.4766, test loss-2.0911, acc-0.4767
# Iter-580, train loss-2.0820, acc-0.5000, valid loss-2.0913, acc-0.4804, test loss-2.0876, acc-0.4803
# Iter-590, train loss-2.0629, acc-0.6400, valid loss-2.0875, acc-0.4828, test loss-2.0838, acc-0.4827
# Iter-600, train loss-2.0744, acc-0.4400, valid loss-2.0838, acc-0.4870, test loss-2.0800, acc-0.4868
# Iter-610, train loss-2.0910, acc-0.4800, valid loss-2.0801, acc-0.4884, test loss-2.0763, acc-0.4893
# Iter-620, train loss-2.0842, acc-0.5200, valid loss-2.0765, acc-0.4932, test loss-2.0727, acc-0.4919
# Iter-630, train loss-2.0885, acc-0.4800, valid loss-2.0730, acc-0.4958, test loss-2.0692, acc-0.4947
# Iter-640, train loss-2.0796, acc-0.5000, valid loss-2.0693, acc-0.4988, test loss-2.0656, acc-0.4968
# Iter-650, train loss-2.0981, acc-0.4600, valid loss-2.0657, acc-0.5014, test loss-2.0621, acc-0.5007
# Iter-660, train loss-2.0715, acc-0.5000, valid loss-2.0622, acc-0.5044, test loss-2.0585, acc-0.5030
# Iter-670, train loss-2.0356, acc-0.5200, valid loss-2.0585, acc-0.5070, test loss-2.0549, acc-0.5059
# Iter-680, train loss-2.0354, acc-0.5200, valid loss-2.0547, acc-0.5108, test loss-2.0511, acc-0.5082
# Iter-690, train loss-2.0746, acc-0.4600, valid loss-2.0512, acc-0.5144, test loss-2.0476, acc-0.5096
# Iter-700, train loss-2.0515, acc-0.4800, valid loss-2.0476, acc-0.5174, test loss-2.0441, acc-0.5120
# Iter-710, train loss-2.0166, acc-0.5800, valid loss-2.0440, acc-0.5206, test loss-2.0405, acc-0.5146
# Iter-720, train loss-2.0273, acc-0.5600, valid loss-2.0404, acc-0.5230, test loss-2.0369, acc-0.5175
# Iter-730, train loss-2.0358, acc-0.5200, valid loss-2.0368, acc-0.5250, test loss-2.0334, acc-0.5193
# Iter-740, train loss-1.9795, acc-0.7000, valid loss-2.0333, acc-0.5274, test loss-2.0299, acc-0.5206
# Iter-750, train loss-2.0438, acc-0.5200, valid loss-2.0300, acc-0.5284, test loss-2.0266, acc-0.5237
# Iter-760, train loss-2.0509, acc-0.4200, valid loss-2.0265, acc-0.5300, test loss-2.0232, acc-0.5264
# Iter-770, train loss-2.0085, acc-0.6000, valid loss-2.0229, acc-0.5324, test loss-2.0196, acc-0.5285
# Iter-780, train loss-1.9903, acc-0.6200, valid loss-2.0194, acc-0.5334, test loss-2.0160, acc-0.5301
# Iter-790, train loss-2.0033, acc-0.5600, valid loss-2.0159, acc-0.5328, test loss-2.0125, acc-0.5309
# Iter-800, train loss-1.9823, acc-0.5200, valid loss-2.0124, acc-0.5342, test loss-2.0090, acc-0.5320
# Iter-810, train loss-2.0531, acc-0.4000, valid loss-2.0090, acc-0.5368, test loss-2.0056, acc-0.5335
# Iter-820, train loss-2.0448, acc-0.5400, valid loss-2.0055, acc-0.5382, test loss-2.0022, acc-0.5356
# Iter-830, train loss-1.9959, acc-0.6200, valid loss-2.0021, acc-0.5392, test loss-1.9988, acc-0.5367
# Iter-840, train loss-2.0637, acc-0.4200, valid loss-1.9987, acc-0.5422, test loss-1.9955, acc-0.5384
# Iter-850, train loss-2.0183, acc-0.4800, valid loss-1.9951, acc-0.5436, test loss-1.9919, acc-0.5398
# Iter-860, train loss-1.9855, acc-0.6200, valid loss-1.9917, acc-0.5468, test loss-1.9885, acc-0.5417
# Iter-870, train loss-1.9804, acc-0.6000, valid loss-1.9883, acc-0.5466, test loss-1.9851, acc-0.5436
# Iter-880, train loss-1.9622, acc-0.5600, valid loss-1.9849, acc-0.5480, test loss-1.9817, acc-0.5454
# Iter-890, train loss-2.0000, acc-0.5400, valid loss-1.9815, acc-0.5496, test loss-1.9783, acc-0.5471
# Iter-900, train loss-2.0098, acc-0.5200, valid loss-1.9781, acc-0.5508, test loss-1.9749, acc-0.5487
# Iter-910, train loss-1.9972, acc-0.4600, valid loss-1.9747, acc-0.5530, test loss-1.9716, acc-0.5496
# Iter-920, train loss-2.0128, acc-0.5800, valid loss-1.9713, acc-0.5534, test loss-1.9683, acc-0.5503
# Iter-930, train loss-1.9935, acc-0.4800, valid loss-1.9680, acc-0.5558, test loss-1.9650, acc-0.5513
# Iter-940, train loss-1.9610, acc-0.5400, valid loss-1.9647, acc-0.5572, test loss-1.9618, acc-0.5529
# Iter-950, train loss-1.9812, acc-0.5800, valid loss-1.9614, acc-0.5588, test loss-1.9584, acc-0.5540
# Iter-960, train loss-1.9291, acc-0.5800, valid loss-1.9580, acc-0.5596, test loss-1.9550, acc-0.5548
# Iter-970, train loss-2.0363, acc-0.4600, valid loss-1.9546, acc-0.5614, test loss-1.9518, acc-0.5559
# Iter-980, train loss-1.9521, acc-0.5400, valid loss-1.9514, acc-0.5616, test loss-1.9485, acc-0.5571
# Iter-990, train loss-1.9326, acc-0.5800, valid loss-1.9480, acc-0.5626, test loss-1.9451, acc-0.5577
# Iter-1000, train loss-1.8924, acc-0.6000, valid loss-1.9446, acc-0.5654, test loss-1.9418, acc-0.5593

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.plot(nn.losses['test'], label='Test loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['train_acc'], label='Train accuracy')
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.plot(nn.losses['test_acc'], label='Test accuracy')
plt.legend()
plt.show()
