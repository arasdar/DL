# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# y_test.shape, y_val.shape, y_train.shape
# X_train.shape, X_train.dtype, X_val.shape, X_val.dtype, X_test.shape, X_test.dtype
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # number of layers or depth
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        # The adaptive/learnable/updatable random feedforward
        self.model = []
        self.W_fixed = []
        self.grads = []
        self.ys_prev = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})
        # Previous output layer
        self.ys_prev.append(0.0)

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad_L = []
        for _ in range(L):
            grad_L.append({key: np.zeros_like(val) for key, val in self.model[1][0].items()})
        self.grads.append(grad_L)
        # Previous output layer
        ys_prev_L = []
        for _ in range(L):
            ys_prev_L.append(0.0)
        self.ys_prev.append(ys_prev_L)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Outout layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        # Previous output layer
        self.ys_prev.append(0.0)
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
        # dX = dout @ W.T # Backprop
        dX = dout @ W_fixed.T # fb alignment

        return dX, dW, db

    def train_forward(self, X, train):
        caches, ys = [], []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
#         y, _ = l.selu_forward(X=y)
#         y = l.elu_fwd(X=y)
#         y = l.sigmoid(X=y)
#         y = np.tanh(y)
        a, b = 1.7519, 2/3
        y = a * np.tanh(b*y)
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[0]
        X = y.copy() # pass to the next layer
        
        # Hidden layers
        fc_caches, ys_L, do_caches = [], [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
#             y, _ = l.selu_forward(X=y)
#             y = l.elu_fwd(X=y)
#             y = l.sigmoid(X=y)
#             y = np.tanh(y)
            a, b = 1.7519, 2/3
            y = a * np.tanh(b*y)
            fc_caches.append(fc_cache)
            ys_L.append(y) # ys[1][layer]
            X = y.copy() # pass to next layer
        if train:
            caches.append(fc_caches) # caches[1]
        ys.append(ys_L) # ys[1]            
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[2]

        return ys, caches # for backpropating the error

    def loss_function(self, y, y_train):
        
        loss = cross_entropy(y, y_train) # softmax is included
        dy = dcross_entropy(y, y_train) # dsoftmax is included
        
        return loss, dy
        
    def train_backward(self, dy, caches):
        grads = self.grads # initialized by Zero in every iteration/epoch
        ys, ys_prev = self.ys, self.ys_prev # temporal diff instead of differentiable function
        
        # Output layer
        fc_cache = caches[2]
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
        grads[2]['W'] = dW
        grads[2]['b'] = db

        # Hidden layer
        fc_caches = caches[1]
        for layer in reversed(range(self.L)):
            dy *= ys[1][layer] - ys_prev[1][layer] # temporal diff instead of differentiable function
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
            grads[1][layer]['W'] = dW
            grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache = caches[0]
        dy *= ys[0] - ys_prev[0] # temporal diff instead of differentiable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        grads[0]['W'] = dW
        grads[0]['b'] = db

        return dX, grads
    
    def test(self, X):
        ys_logit, _ = self.train_forward(X, train=False)
        y_logit = ys_logit[2] # last layer
        
        # if self.mode == 'classification':
        y_prob = l.softmax(y_logit) # for accuracy == acc
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_logit
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            self.ys, caches = self.train_forward(X_mini, train=True)
            loss, dy = self.loss_function(self.ys[2], y_mini)
            _, grads = self.train_backward(dy, caches) # self.ys_prev is used here for dfunc/ diff
            self.ys_prev = self.ys # for next iteration or epoch
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in grads[0].keys():
                self.model[0][key] -= alpha * grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * grads[1][layer][key]

            # Update the model for output layer
            for key in grads[2].keys():
                self.model[2][key] -= alpha * grads[2][key]
                
            # Validate the updated model
            y_pred, y_logit = self.test(X_val)
            valid_loss, _ = self.loss_function(y_logit, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val) # confusion matrix
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_logit = nn.test(X_test)
        loss, _ = self.loss_function(y_logit, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 10000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 50 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 100 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 2 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-100 train loss: 2.2953 valid loss: 2.3037, valid accuracy: 0.0970
# Iter-200 train loss: 2.2891 valid loss: 2.3012, valid accuracy: 0.0984
# Iter-300 train loss: 2.3061 valid loss: 2.2987, valid accuracy: 0.1022
# Iter-400 train loss: 2.2709 valid loss: 2.2962, valid accuracy: 0.1042
# Iter-500 train loss: 2.2936 valid loss: 2.2937, valid accuracy: 0.1072
# Iter-600 train loss: 2.2813 valid loss: 2.2913, valid accuracy: 0.1080
# Iter-700 train loss: 2.2792 valid loss: 2.2887, valid accuracy: 0.1108
# Iter-800 train loss: 2.3013 valid loss: 2.2863, valid accuracy: 0.1136
# Iter-900 train loss: 2.2528 valid loss: 2.2839, valid accuracy: 0.1164
# Iter-1000 train loss: 2.2684 valid loss: 2.2814, valid accuracy: 0.1198
# Iter-1100 train loss: 2.3058 valid loss: 2.2790, valid accuracy: 0.1238
# Iter-1200 train loss: 2.2583 valid loss: 2.2766, valid accuracy: 0.1264
# Iter-1300 train loss: 2.2631 valid loss: 2.2742, valid accuracy: 0.1304
# Iter-1400 train loss: 2.2809 valid loss: 2.2718, valid accuracy: 0.1338
# Iter-1500 train loss: 2.2629 valid loss: 2.2695, valid accuracy: 0.1366
# Iter-1600 train loss: 2.3022 valid loss: 2.2671, valid accuracy: 0.1398
# Iter-1700 train loss: 2.2422 valid loss: 2.2647, valid accuracy: 0.1430
# Iter-1800 train loss: 2.2620 valid loss: 2.2623, valid accuracy: 0.1484
# Iter-1900 train loss: 2.2893 valid loss: 2.2600, valid accuracy: 0.1530
# Iter-2000 train loss: 2.2484 valid loss: 2.2576, valid accuracy: 0.1584
# Iter-2100 train loss: 2.2271 valid loss: 2.2553, valid accuracy: 0.1614
# Iter-2200 train loss: 2.2532 valid loss: 2.2529, valid accuracy: 0.1672
# Iter-2300 train loss: 2.2766 valid loss: 2.2506, valid accuracy: 0.1728
# Iter-2400 train loss: 2.2581 valid loss: 2.2483, valid accuracy: 0.1768
# Iter-2500 train loss: 2.2925 valid loss: 2.2460, valid accuracy: 0.1834
# Iter-2600 train loss: 2.2474 valid loss: 2.2436, valid accuracy: 0.1878
# Iter-2700 train loss: 2.2304 valid loss: 2.2413, valid accuracy: 0.1918
# Iter-2800 train loss: 2.2328 valid loss: 2.2390, valid accuracy: 0.1960
# Iter-2900 train loss: 2.2287 valid loss: 2.2367, valid accuracy: 0.2012
# Iter-3000 train loss: 2.2300 valid loss: 2.2344, valid accuracy: 0.2034
# Iter-3100 train loss: 2.2019 valid loss: 2.2321, valid accuracy: 0.2068
# Iter-3200 train loss: 2.2181 valid loss: 2.2299, valid accuracy: 0.2100
# Iter-3300 train loss: 2.2209 valid loss: 2.2276, valid accuracy: 0.2134
# Iter-3400 train loss: 2.2111 valid loss: 2.2254, valid accuracy: 0.2166
# Iter-3500 train loss: 2.2514 valid loss: 2.2231, valid accuracy: 0.2206
# Iter-3600 train loss: 2.1998 valid loss: 2.2209, valid accuracy: 0.2240
# Iter-3700 train loss: 2.2621 valid loss: 2.2186, valid accuracy: 0.2264
# Iter-3800 train loss: 2.2209 valid loss: 2.2164, valid accuracy: 0.2300
# Iter-3900 train loss: 2.1560 valid loss: 2.2142, valid accuracy: 0.2318
# Iter-4000 train loss: 2.2177 valid loss: 2.2120, valid accuracy: 0.2344
# Iter-4100 train loss: 2.2525 valid loss: 2.2098, valid accuracy: 0.2378
# Iter-4200 train loss: 2.1945 valid loss: 2.2075, valid accuracy: 0.2400
# Iter-4300 train loss: 2.1933 valid loss: 2.2054, valid accuracy: 0.2426
# Iter-4400 train loss: 2.2255 valid loss: 2.2032, valid accuracy: 0.2438
# Iter-4500 train loss: 2.1975 valid loss: 2.2010, valid accuracy: 0.2474
# Iter-4600 train loss: 2.1961 valid loss: 2.1988, valid accuracy: 0.2502
# Iter-4700 train loss: 2.2095 valid loss: 2.1967, valid accuracy: 0.2534
# Iter-4800 train loss: 2.1948 valid loss: 2.1945, valid accuracy: 0.2552
# Iter-4900 train loss: 2.2079 valid loss: 2.1924, valid accuracy: 0.2576
# Iter-5000 train loss: 2.1767 valid loss: 2.1903, valid accuracy: 0.2612
# Iter-5100 train loss: 2.2188 valid loss: 2.1881, valid accuracy: 0.2636
# Iter-5200 train loss: 2.1719 valid loss: 2.1860, valid accuracy: 0.2668
# Iter-5300 train loss: 2.1724 valid loss: 2.1839, valid accuracy: 0.2682
# Iter-5400 train loss: 2.1996 valid loss: 2.1817, valid accuracy: 0.2706
# Iter-5500 train loss: 2.2031 valid loss: 2.1796, valid accuracy: 0.2730
# Iter-5600 train loss: 2.1583 valid loss: 2.1776, valid accuracy: 0.2754
# Iter-5700 train loss: 2.1528 valid loss: 2.1755, valid accuracy: 0.2778
# Iter-5800 train loss: 2.1852 valid loss: 2.1734, valid accuracy: 0.2794
# Iter-5900 train loss: 2.1420 valid loss: 2.1713, valid accuracy: 0.2812
# Iter-6000 train loss: 2.1545 valid loss: 2.1692, valid accuracy: 0.2838
# Iter-6100 train loss: 2.1426 valid loss: 2.1671, valid accuracy: 0.2858
# Iter-6200 train loss: 2.2215 valid loss: 2.1650, valid accuracy: 0.2880
# Iter-6300 train loss: 2.1298 valid loss: 2.1630, valid accuracy: 0.2900
# Iter-6400 train loss: 2.1593 valid loss: 2.1609, valid accuracy: 0.2942
# Iter-6500 train loss: 2.1551 valid loss: 2.1589, valid accuracy: 0.2962
# Iter-6600 train loss: 2.1571 valid loss: 2.1569, valid accuracy: 0.2986
# Iter-6700 train loss: 2.1130 valid loss: 2.1549, valid accuracy: 0.3002
# Iter-6800 train loss: 2.1263 valid loss: 2.1529, valid accuracy: 0.3020
# Iter-6900 train loss: 2.1261 valid loss: 2.1508, valid accuracy: 0.3038
# Iter-7000 train loss: 2.1670 valid loss: 2.1489, valid accuracy: 0.3058
# Iter-7100 train loss: 2.1928 valid loss: 2.1469, valid accuracy: 0.3094
# Iter-7200 train loss: 2.1274 valid loss: 2.1449, valid accuracy: 0.3124
# Iter-7300 train loss: 2.1498 valid loss: 2.1429, valid accuracy: 0.3136
# Iter-7400 train loss: 2.1416 valid loss: 2.1409, valid accuracy: 0.3166
# Iter-7500 train loss: 2.0900 valid loss: 2.1389, valid accuracy: 0.3186
# Iter-7600 train loss: 2.1694 valid loss: 2.1369, valid accuracy: 0.3210
# Iter-7700 train loss: 2.0723 valid loss: 2.1349, valid accuracy: 0.3222
# Iter-7800 train loss: 2.1455 valid loss: 2.1330, valid accuracy: 0.3244
# Iter-7900 train loss: 2.1148 valid loss: 2.1310, valid accuracy: 0.3270
# Iter-8000 train loss: 2.0729 valid loss: 2.1290, valid accuracy: 0.3312
# Iter-8100 train loss: 2.1559 valid loss: 2.1271, valid accuracy: 0.3330
# Iter-8200 train loss: 2.1375 valid loss: 2.1252, valid accuracy: 0.3360
# Iter-8300 train loss: 2.1371 valid loss: 2.1233, valid accuracy: 0.3374
# Iter-8400 train loss: 2.1523 valid loss: 2.1214, valid accuracy: 0.3394
# Iter-8500 train loss: 2.1337 valid loss: 2.1194, valid accuracy: 0.3412
# Iter-8600 train loss: 2.1239 valid loss: 2.1175, valid accuracy: 0.3436
# Iter-8700 train loss: 2.0664 valid loss: 2.1156, valid accuracy: 0.3460
# Iter-8800 train loss: 2.0787 valid loss: 2.1138, valid accuracy: 0.3472
# Iter-8900 train loss: 2.0876 valid loss: 2.1119, valid accuracy: 0.3488
# Iter-9000 train loss: 2.1687 valid loss: 2.1100, valid accuracy: 0.3510
# Iter-9100 train loss: 2.0950 valid loss: 2.1081, valid accuracy: 0.3534
# Iter-9200 train loss: 2.0970 valid loss: 2.1062, valid accuracy: 0.3548
# Iter-9300 train loss: 2.1144 valid loss: 2.1043, valid accuracy: 0.3580
# Iter-9400 train loss: 2.1190 valid loss: 2.1024, valid accuracy: 0.3606
# Iter-9500 train loss: 2.1261 valid loss: 2.1005, valid accuracy: 0.3632
# Iter-9600 train loss: 2.1500 valid loss: 2.0987, valid accuracy: 0.3646
# Iter-9700 train loss: 2.0448 valid loss: 2.0968, valid accuracy: 0.3664
# Iter-9800 train loss: 2.1106 valid loss: 2.0950, valid accuracy: 0.3690
# Iter-9900 train loss: 2.1003 valid loss: 2.0931, valid accuracy: 0.3704
# Iter-10000 train loss: 2.0819 valid loss: 2.0913, valid accuracy: 0.3726
# Last iteration - Test accuracy mean: 0.3689, std: 0.0000, loss: 2.0869

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
