# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# y_test.shape, y_val.shape, y_train.shape
# X_train.shape, X_train.dtype, X_val.shape, X_val.dtype, X_test.shape, X_test.dtype
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # number of layers or depth
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        # The adaptive/learnable/updatable random feedforward
        self.model = []
        self.W_fixed = []
        self.grads = []
        self.ys_prev = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})
        # Previous output layer
        self.ys_prev.append(0.0)

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad_L = []
        for _ in range(L):
            grad_L.append({key: np.zeros_like(val) for key, val in self.model[1][0].items()})
        self.grads.append(grad_L)
        # Previous output layer
        ys_prev_L = []
        for _ in range(L):
            ys_prev_L.append(0.0)
        self.ys_prev.append(ys_prev_L)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Outout layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        # Previous output layer
        self.ys_prev.append(0.0)
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
        # dX = dout @ W.T # Backprop
        dX = dout @ W_fixed.T # fb alignment

        return dX, dW, db

    def train_forward(self, X, train):
        caches, ys = [], []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
#         y, _ = l.selu_forward(X=y)
        y = l.elu_fwd(X=y)
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[0]
        X = y.copy() # pass to the next layer
        
        # Hidden layers
        fc_caches, ys_L, do_caches = [], [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
#             y, _ = l.selu_forward(X=y)
            y = l.elu_fwd(X=y)
            fc_caches.append(fc_cache)
            ys_L.append(y) # ys[1][layer]
            X = y.copy() # pass to next layer
        if train:
            caches.append(fc_caches) # caches[1]
        ys.append(ys_L) # ys[1]            
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[2]

        return ys, caches # for backpropating the error

    def loss_function(self, y, y_train):
        
        loss = cross_entropy(y, y_train) # softmax is included
        dy = dcross_entropy(y, y_train) # dsoftmax is included
        
        return loss, dy
        
    def train_backward(self, dy, caches):
        grads = self.grads # initialized by Zero in every iteration/epoch
        ys, ys_prev = self.ys, self.ys_prev # temporal diff instead of differentiable function
        
        # Output layer
        fc_cache = caches[2]
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
        grads[2]['W'] = dW
        grads[2]['b'] = db

        # Hidden layer
        fc_caches = caches[1]
        for layer in reversed(range(self.L)):
            dy *= ys[1][layer] - ys_prev[1][layer] # temporal diff instead of differentiable function
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
            grads[1][layer]['W'] = dW
            grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache = caches[0]
        dy *= ys[0] - ys_prev[0] # temporal diff instead of differentiable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        grads[0]['W'] = dW
        grads[0]['b'] = db

        return dX, grads
    
    def test(self, X):
        ys_logit, _ = self.train_forward(X, train=False)
        y_logit = ys_logit[2] # last layer
        
        # if self.mode == 'classification':
        y_prob = l.softmax(y_logit) # for accuracy == acc
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_logit
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            self.ys, caches = self.train_forward(X_mini, train=True)
            loss, dy = self.loss_function(self.ys[2], y_mini)
            _, grads = self.train_backward(dy, caches) # self.ys_prev is used here for dfunc/ diff
            self.ys_prev = self.ys # for next iteration or epoch
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in grads[0].keys():
                self.model[0][key] -= alpha * grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * grads[1][layer][key]

            # Update the model for output layer
            for key in grads[2].keys():
                self.model[2][key] -= alpha * grads[2][key]
                
            # Validate the updated model
            y_pred, y_logit = self.test(X_val)
            valid_loss, _ = self.loss_function(y_logit, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val) # confusion matrix
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_logit = nn.test(X_test)
        loss, _ = self.loss_function(y_logit, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 10000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 50 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 100 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 2 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-100 train loss: 2.2989 valid loss: 2.2926, valid accuracy: 0.1070
# Iter-200 train loss: 2.3090 valid loss: 2.2917, valid accuracy: 0.1090
# Iter-300 train loss: 2.2940 valid loss: 2.2909, valid accuracy: 0.1112
# Iter-400 train loss: 2.2749 valid loss: 2.2900, valid accuracy: 0.1130
# Iter-500 train loss: 2.2995 valid loss: 2.2891, valid accuracy: 0.1164
# Iter-600 train loss: 2.2929 valid loss: 2.2883, valid accuracy: 0.1182
# Iter-700 train loss: 2.2850 valid loss: 2.2875, valid accuracy: 0.1190
# Iter-800 train loss: 2.2820 valid loss: 2.2866, valid accuracy: 0.1218
# Iter-900 train loss: 2.3005 valid loss: 2.2857, valid accuracy: 0.1240
# Iter-1000 train loss: 2.2698 valid loss: 2.2849, valid accuracy: 0.1262
# Iter-1100 train loss: 2.2670 valid loss: 2.2840, valid accuracy: 0.1272
# Iter-1200 train loss: 2.2821 valid loss: 2.2831, valid accuracy: 0.1294
# Iter-1300 train loss: 2.2890 valid loss: 2.2823, valid accuracy: 0.1318
# Iter-1400 train loss: 2.2809 valid loss: 2.2815, valid accuracy: 0.1330
# Iter-1500 train loss: 2.2738 valid loss: 2.2806, valid accuracy: 0.1366
# Iter-1600 train loss: 2.2737 valid loss: 2.2798, valid accuracy: 0.1378
# Iter-1700 train loss: 2.2791 valid loss: 2.2789, valid accuracy: 0.1400
# Iter-1800 train loss: 2.2989 valid loss: 2.2781, valid accuracy: 0.1414
# Iter-1900 train loss: 2.2837 valid loss: 2.2773, valid accuracy: 0.1438
# Iter-2000 train loss: 2.2781 valid loss: 2.2764, valid accuracy: 0.1466
# Iter-2100 train loss: 2.2950 valid loss: 2.2756, valid accuracy: 0.1492
# Iter-2200 train loss: 2.2820 valid loss: 2.2748, valid accuracy: 0.1518
# Iter-2300 train loss: 2.2816 valid loss: 2.2739, valid accuracy: 0.1540
# Iter-2400 train loss: 2.2752 valid loss: 2.2731, valid accuracy: 0.1560
# Iter-2500 train loss: 2.2792 valid loss: 2.2723, valid accuracy: 0.1588
# Iter-2600 train loss: 2.2812 valid loss: 2.2715, valid accuracy: 0.1602
# Iter-2700 train loss: 2.2736 valid loss: 2.2706, valid accuracy: 0.1640
# Iter-2800 train loss: 2.2738 valid loss: 2.2698, valid accuracy: 0.1670
# Iter-2900 train loss: 2.2624 valid loss: 2.2690, valid accuracy: 0.1690
# Iter-3000 train loss: 2.2592 valid loss: 2.2682, valid accuracy: 0.1730
# Iter-3100 train loss: 2.2852 valid loss: 2.2674, valid accuracy: 0.1738
# Iter-3200 train loss: 2.2743 valid loss: 2.2665, valid accuracy: 0.1760
# Iter-3300 train loss: 2.2650 valid loss: 2.2657, valid accuracy: 0.1784
# Iter-3400 train loss: 2.2765 valid loss: 2.2649, valid accuracy: 0.1812
# Iter-3500 train loss: 2.2907 valid loss: 2.2641, valid accuracy: 0.1834
# Iter-3600 train loss: 2.2780 valid loss: 2.2633, valid accuracy: 0.1870
# Iter-3700 train loss: 2.2754 valid loss: 2.2625, valid accuracy: 0.1888
# Iter-3800 train loss: 2.2551 valid loss: 2.2617, valid accuracy: 0.1918
# Iter-3900 train loss: 2.2516 valid loss: 2.2609, valid accuracy: 0.1936
# Iter-4000 train loss: 2.2322 valid loss: 2.2600, valid accuracy: 0.1958
# Iter-4100 train loss: 2.2464 valid loss: 2.2592, valid accuracy: 0.1978
# Iter-4200 train loss: 2.2559 valid loss: 2.2585, valid accuracy: 0.1998
# Iter-4300 train loss: 2.2771 valid loss: 2.2577, valid accuracy: 0.2048
# Iter-4400 train loss: 2.2692 valid loss: 2.2568, valid accuracy: 0.2096
# Iter-4500 train loss: 2.2794 valid loss: 2.2560, valid accuracy: 0.2110
# Iter-4600 train loss: 2.2780 valid loss: 2.2552, valid accuracy: 0.2138
# Iter-4700 train loss: 2.2566 valid loss: 2.2544, valid accuracy: 0.2156
# Iter-4800 train loss: 2.2563 valid loss: 2.2536, valid accuracy: 0.2168
# Iter-4900 train loss: 2.2657 valid loss: 2.2529, valid accuracy: 0.2192
# Iter-5000 train loss: 2.2695 valid loss: 2.2521, valid accuracy: 0.2216
# Iter-5100 train loss: 2.2773 valid loss: 2.2513, valid accuracy: 0.2224
# Iter-5200 train loss: 2.2521 valid loss: 2.2505, valid accuracy: 0.2244
# Iter-5300 train loss: 2.2520 valid loss: 2.2497, valid accuracy: 0.2268
# Iter-5400 train loss: 2.2305 valid loss: 2.2490, valid accuracy: 0.2286
# Iter-5500 train loss: 2.2261 valid loss: 2.2482, valid accuracy: 0.2308
# Iter-5600 train loss: 2.2854 valid loss: 2.2474, valid accuracy: 0.2326
# Iter-5700 train loss: 2.2668 valid loss: 2.2466, valid accuracy: 0.2338
# Iter-5800 train loss: 2.2627 valid loss: 2.2458, valid accuracy: 0.2364
# Iter-5900 train loss: 2.2301 valid loss: 2.2450, valid accuracy: 0.2404
# Iter-6000 train loss: 2.2373 valid loss: 2.2443, valid accuracy: 0.2416
# Iter-6100 train loss: 2.2617 valid loss: 2.2435, valid accuracy: 0.2446
# Iter-6200 train loss: 2.2788 valid loss: 2.2427, valid accuracy: 0.2464
# Iter-6300 train loss: 2.2351 valid loss: 2.2419, valid accuracy: 0.2502
# Iter-6400 train loss: 2.2377 valid loss: 2.2412, valid accuracy: 0.2514
# Iter-6500 train loss: 2.2430 valid loss: 2.2404, valid accuracy: 0.2540
# Iter-6600 train loss: 2.2554 valid loss: 2.2396, valid accuracy: 0.2568
# Iter-6700 train loss: 2.2672 valid loss: 2.2389, valid accuracy: 0.2590
# Iter-6800 train loss: 2.2535 valid loss: 2.2381, valid accuracy: 0.2608
# Iter-6900 train loss: 2.2374 valid loss: 2.2373, valid accuracy: 0.2620
# Iter-7000 train loss: 2.2331 valid loss: 2.2366, valid accuracy: 0.2626
# Iter-7100 train loss: 2.2225 valid loss: 2.2358, valid accuracy: 0.2660
# Iter-7200 train loss: 2.2284 valid loss: 2.2350, valid accuracy: 0.2680
# Iter-7300 train loss: 2.2545 valid loss: 2.2343, valid accuracy: 0.2708
# Iter-7400 train loss: 2.2370 valid loss: 2.2335, valid accuracy: 0.2716
# Iter-7500 train loss: 2.2328 valid loss: 2.2327, valid accuracy: 0.2738
# Iter-7600 train loss: 2.2578 valid loss: 2.2320, valid accuracy: 0.2758
# Iter-7700 train loss: 2.2452 valid loss: 2.2312, valid accuracy: 0.2784
# Iter-7800 train loss: 2.2369 valid loss: 2.2304, valid accuracy: 0.2802
# Iter-7900 train loss: 2.2308 valid loss: 2.2297, valid accuracy: 0.2828
# Iter-8000 train loss: 2.2275 valid loss: 2.2289, valid accuracy: 0.2844
# Iter-8100 train loss: 2.2466 valid loss: 2.2282, valid accuracy: 0.2856
# Iter-8200 train loss: 2.2128 valid loss: 2.2274, valid accuracy: 0.2868
# Iter-8300 train loss: 2.2215 valid loss: 2.2267, valid accuracy: 0.2868
# Iter-8400 train loss: 2.2264 valid loss: 2.2259, valid accuracy: 0.2888
# Iter-8500 train loss: 2.2345 valid loss: 2.2251, valid accuracy: 0.2900
# Iter-8600 train loss: 2.2230 valid loss: 2.2244, valid accuracy: 0.2918
# Iter-8700 train loss: 2.2467 valid loss: 2.2236, valid accuracy: 0.2936
# Iter-8800 train loss: 2.2090 valid loss: 2.2229, valid accuracy: 0.2946
# Iter-8900 train loss: 2.2417 valid loss: 2.2221, valid accuracy: 0.2970
# Iter-9000 train loss: 2.2088 valid loss: 2.2214, valid accuracy: 0.2974
# Iter-9100 train loss: 2.2246 valid loss: 2.2207, valid accuracy: 0.2998
# Iter-9200 train loss: 2.2375 valid loss: 2.2199, valid accuracy: 0.3006
# Iter-9300 train loss: 2.2086 valid loss: 2.2192, valid accuracy: 0.3018
# Iter-9400 train loss: 2.2312 valid loss: 2.2184, valid accuracy: 0.3022
# Iter-9500 train loss: 2.2084 valid loss: 2.2177, valid accuracy: 0.3034
# Iter-9600 train loss: 2.2359 valid loss: 2.2169, valid accuracy: 0.3050
# Iter-9700 train loss: 2.2394 valid loss: 2.2162, valid accuracy: 0.3086
# Iter-9800 train loss: 2.1967 valid loss: 2.2155, valid accuracy: 0.3102
# Iter-9900 train loss: 2.2283 valid loss: 2.2147, valid accuracy: 0.3112
# Iter-10000 train loss: 2.2237 valid loss: 2.2140, valid accuracy: 0.3130
# Last iteration - Test accuracy mean: 0.3027, std: 0.0000, loss: 2.2153

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
