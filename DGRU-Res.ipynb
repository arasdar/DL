# %%
import numpy as np

with open('data/text_data/japan.txt', 'r') as f:
    txt = f.read()

    X = []
    y = []

    char_to_idx = {char: i for i, char in enumerate(set(txt))}
    idx_to_char = {i: char for i, char in enumerate(set(txt))}

    X = np.array([char_to_idx[x] for x in txt])
    y = [char_to_idx[x] for x in txt[1:]]
    y.append(char_to_idx['.'])
    y = np.array(y)

# %%
import impl.layer as l

class GRU:

    def __init__(self, D, H, L, char2idx, idx2char, p_dropout):
        self.D = D
        self.H = H
        self.L = L
        self.char2idx = char2idx
        self.idx2char = idx2char
        self.vocab_size = len(char2idx)
        self.losses = {'train':[], 'smooth train':[]}
        self.p_dropout = p_dropout
        
        # Model parameters
        Z = H + D
        m = dict(
            Wz=np.random.randn(Z, H) / np.sqrt(Z / 2.),
            Wh=np.random.randn(Z, H) / np.sqrt(Z / 2.),
            Wy=np.random.randn(H, D) / np.sqrt(H / 2.),
            bz=np.zeros((1, H)),
            bh=np.zeros((1, H)),
            by=np.zeros((1, D))
        )
        
        self.model = []
        for _ in range(self.L):
            self.model.append(m)
            
    def initial_state(self):
        return np.zeros((1, self.H))

    def dropout_forward(self, X, p_dropout):
        u = np.random.binomial(1, p_dropout, size=X.shape) / p_dropout
        # q = 1-p_dropout
        # u = np.random.binomial(1, q, size=X.shape)
        out = X * u
        cache = u
        return out, cache

    def dropout_backward(self, dout, cache):
        dX = dout * cache
        return dX
    
    def selu_forward(self, X):
        alpha = 1.6732632423543772848170429916717
        scale = 1.0507009873554804934193349852946
        out = scale * np.where(X>=0.0, X, alpha * (np.exp(X)-1))
        cache = X
        return out, cache

    def selu_backward(self, dout, cache):
        alpha = 1.6732632423543772848170429916717
        scale = 1.0507009873554804934193349852946
        X = cache
        dX_pos = dout.copy()
        dX_pos[X<0] = 0
        dX_neg = dout.copy()
        dX_neg[X>0] = 0
        dX = scale * np.where(X>=0.0, dX_pos, dX_neg * alpha * np.exp(X))
        return dX

    # p_dropout = keep_prob in this case! 
    # Is this true in other cases as well?
    def alpha_dropout_fwd(self, h, q):
        '''h is activation, q is keep probability: q=1-p, p=p_dropout, and q=keep_prob'''
        alpha = 1.6732632423543772848170429916717
        scale = 1.0507009873554804934193349852946
        alpha_p = -scale * alpha
        mask = np.random.binomial(1, q, size=h.shape)
        dropped = (mask * h) + ((1 - mask) * alpha_p)
        a = 1. / np.sqrt(q + (alpha_p ** 2 * q  * (1 - q)))
        b = -a * (1 - q) * alpha_p
        out = (a * dropped) + b
        cache = (a, mask)
        return out, cache

    def alpha_dropout_bwd(self, dout, cache):
        a, mask = cache
        d_dropped = dout * a
        dh = d_dropped * mask
        return dh
    
    def forward(self, X, h, m, train):
        Wz, Wh, Wy = m['Wz'], m['Wh'], m['Wy']
        bz, bh, by = m['bz'], m['bh'], m['by']

        X_in = X.copy()
        h_in = h.copy()

        X = np.column_stack((h_in, X_in))

        hz, hz_cache = l.fc_forward(X, Wz, bz)
        hz, hz_sigm_cache = l.sigmoid_forward(hz)

        hh, hh_cache = l.fc_forward(X, Wh, bh)
        hh, hh_tanh_cache = l.tanh_forward(hh)

        h = h_in + (hz * (hh - h_in))
        # equal to
        # h = (1.0 - hz) * h_in + hz * hh
        # or
        # h = h_in + (hz * hh)
        # or
        # h = h_in + hz
        # or
        # h = h_in + hh

        ## SELU + SELU-Dropout
        #         y, y_cache = l.fc_forward(h, Wy, by)
        #         y, y_selu_cache = self.selu_forward(y)
        #         y = X_in + y
        #         if train: # with Dropout
        #             y, y_do_cache = self.alpha_dropout_fwd(y, self.p_dropout)
        #             cache = (h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache, y_selu_cache, y_do_cache)
        #         else: # no Dropout: testing or validation
        #             cache = (h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache, y_selu_cache)
        
        y, y_cache = l.fc_forward(h, Wy, by)
        y = X_in + y
        
        if train: # with Dropout
            y, y_do_cache = self.dropout_forward(y, self.p_dropout)
            cache = (h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache, y_do_cache)
        else: # no Dropout: testing or validation
            cache = (h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache)

        return y, h, cache

    def backward(self, dy, dh, cache, train):
        if train:
            h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache, y_do_cache = cache
            dy = self.dropout_backward(dout=dy, cache=y_do_cache)
        else:
            h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache = cache
        
        dy_out = dy.copy()
        dh_out = dh.copy()
        
        dh, dWy, dby = l.fc_backward(dy, y_cache)
        
        dh += dh_out
        dh_in1 = dh * (1.0 - hz) # res

        dhh =  dh * hz
        dhh = l.tanh_backward(dhh, hh_tanh_cache)
        dXh, dWh, dbh = l.fc_backward(dhh, hh_cache)
        
        dhz = dh * (hh - h_in)
        dhz = l.sigmoid_backward(dhz, hz_sigm_cache)
        dXz, dWz, dbz = l.fc_backward(dhz, hz_cache)
        
        dX = dXz + dXh
        
        dh_in2 = dX[:, :self.H]
        dh = dh_in1 + dh_in2 # res cells
        
        dX = dX[:, self.H:]
        dX += dy_out # res layers

        grad = dict(Wz=dWz, Wh=dWh, Wy=dWy, bz=dbz, bh=dbh, by=dby)
        
        return dX, dh, grad
    
    def train_forward(self, X_train, h):
        ys, caches = [], []
        h_init = h.copy()
        h = []
        for _ in range(self.L):
            h.append(h_init.copy())
            caches.append([])
            
        for X in X_train:
            X_one_hot = np.zeros(self.D)
            X_one_hot[X] = 1.
            X = X_one_hot.reshape(1, -1)
            for layer in range(self.L):
                y, h[layer], cache = self.forward(X, h[layer], self.model[layer], train=True)
                caches[layer].append(cache)
                X = y.copy()
            ys.append(y)
            
        return ys, caches

    def cross_entropy(self, y_pred, y_train):
        m = y_pred.shape[0]

        prob = l.softmax(y_pred)
        log_like = -np.log(prob[range(m), y_train])
        data_loss = np.sum(log_like) / m

        return data_loss

    def dcross_entropy(self, y_pred, y_train):
        m = y_pred.shape[0]

        grad_y = l.softmax(y_pred)
        grad_y[range(m), y_train] -= 1.0
        grad_y /= m

        return grad_y
    
    def loss_function(self, y_train, ys):
        loss, dys = 0.0, []

        for y_pred, y in zip(ys, y_train):
            loss += self.cross_entropy(y_pred, y)
            dy = self.dcross_entropy(y_pred, y)
            dys.append(dy)
            
        return loss, dys

    def train_backward(self, dys, caches):
        dh, grad, grads = [], [], []
        for layer in range(self.L):
            dh.append(np.zeros((1, self.H)))
            grad.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
            grads.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
            
        dXs = []
        for t in reversed(range(len(dys))):
            dy = dys[t]
            for layer in reversed(range(self.L)):
                dX, dh[layer], grad[layer] = self.backward(dy, dh[layer], caches[layer][t], train=True)                
                for key in grad[layer].keys():
                    grads[layer][key] += grad[layer][key]
                dy = dX.copy()
            dXs.append(dX)
                
        return dXs, grads
    
    def test(self, X_seed, h, size):
        chars = [self.idx2char[X_seed]]
        idx_list = list(range(self.vocab_size))
        X = X_seed
        h_init = h.copy()
        h = []
        for _ in range(self.L):
            h.append(h_init.copy())

        for _ in range(size):
            X_one_hot = np.zeros(self.D)
            X_one_hot[X] = 1.0
            X = X_one_hot.reshape(1, -1)
            for layer in range(self.L):
                y, h[layer], _ = self.forward(X, h[layer], self.model[layer], train=False)
                X = y.copy()
                
            prob = l.softmax(y)
            idx = np.random.choice(idx_list, p=prob.ravel())
            chars.append(self.idx2char[idx])
            X = idx

        return ''.join(chars)

    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        # for i in range(0, X.shape[0] - minibatch_size +1, 1):
        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def adam_rnn(self, X_train, y_train, alpha, mb_size, n_iter, print_after):
        M, R = [], []
         
        # Hidden layers
        for layer in range(nn.L):
            M.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
            R.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
         
        beta1 = .99
        beta2 = .999
        eps = 1e-8
        state = self.initial_state()
        smooth_loss = 1.0
        minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=False)

        # Epochs
        for iter in range(1, n_iter + 1):
            # Minibacthes
            for idx in range(len(minibatches)):
                X_mini, y_mini = minibatches[idx]
                ys, caches = self.train_forward(X_mini, state)
                loss, dys = self.loss_function(y_train=y_mini, ys=ys)
                _, grads = self.train_backward(dys, caches)
                self.losses['train'].append(loss)
                smooth_loss = (0.999 * smooth_loss) + (0.001 * loss)
                self.losses['smooth train'].append(smooth_loss)

                for layer in range(nn.L):
                    for key in grads[layer].keys(): #key, value: items
                        M[layer][key] = l.exp_running_avg(M[layer][key], grads[layer][key], beta1)
                        R[layer][key] = l.exp_running_avg(R[layer][key], grads[layer][key]**2, beta2)

                        m_k_hat = M[layer][key] / (1. - (beta1**(iter)))
                        r_k_hat = R[layer][key] / (1. - (beta2**(iter)))

                        self.model[layer][key] -= alpha * m_k_hat / (np.sqrt(r_k_hat) + eps)

            # Print loss and test sample
            if iter % print_after == 0:
                print('Iter-{} loss: {:.4f}'.format(iter, loss))
                sample = self.test(X_mini[0], state, size=100)
                print(sample)

# %%
# Hyper-parameters
time_step = 100 # width, minibatch size and test sample size as well
num_layers = 1 # depth
n_iter = 10000 # epochs
alpha = 1e-4 # learning_rate
p_dropout = 0.95 # q=1-p, q=keep_prob and p=dropout.
print_after = 10 # n_iter//100 # print training loss, valid, and test
num_hidden_units = 64 # num_hidden_units in hidden layer
num_input_units = len(char_to_idx) # vocab_size = len(char_to_idx)

# Build the network and learning it or optimizing it using SGD
nn = GRU(D=num_input_units, H=num_hidden_units, L=num_layers, p_dropout=p_dropout, char2idx=char_to_idx, idx2char=idx_to_char)

# Start learning using BP-SGD-ADAM
nn.adam_rnn(X_train=X, y_train=y, alpha=alpha, mb_size=time_step, n_iter=n_iter, print_after=print_after)

# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['smooth train'], label='Train smooth loss')
plt.legend()
plt.show()
# Out:
# Iter-10 loss: 108.6161
# e p"E%ulptgat.oef ,shooiTig,ai:,eeRTieCheheti A1da,wiluo8t ftefrt poorid La  oy mooai auhlaeu ii me
# Iter-20 loss: 104.6498
# eLu
# tanay mcaa  tr v  ox iehmh1morn  ssnd)utchmtSiixn ep .f iihern reeyl va-, aheegRpe  ey se pwd oee
# Iter-30 loss: 102.6231
# eywvo w1an wneAel2 uHexry UaC9iLam4etIpP-nidakehdr tan.hs a pR ttAscsu ooni. s2 eea ie  shad onn bnob
# Iter-40 loss: 102.7918
# eexSSkarhWrrtu06  rrfnntiiont E"rettonrs. tiinr(nJdl ip ia  ohca il dahi eJ  ,pcanOa  heuirT  Infrofp
# Iter-50 loss: 99.3490
# eAAipk  irf4Idnnes thereeJPhop fnnth lngrsri uureadct. hn8 anTolnr  mP i.ne ir w mi he ysiaR  aokan
# Iter-60 loss: 97.9766
# e% 30eero,roiSd Eayta  ohsI sfe ofduSy nes dar aketay t i ienrwco  hr fore t27cAws  ats sso ibRgodWsc
# Iter-70 loss: 95.8533
# esmcdnnv iies ioeASnlnf d1lge cinm'ieh-mu cynta re lnpy osrcchar atw ulitcaxz a1up fi5aW foshapa dii
# Iter-80 loss: 93.1826
# e.myeGe isdJGhnpnnwire Ind caitey3 haswot ef pnmT ehee kon leph , tt–e oue
# TdFinscolt cpirnd本dspoaalc
# Iter-90 loss: 93.4884
# e;ajdyopn a2tdnt8-d woiin cnrnrhe oloepeasdn ei. ch"obcyrlit ti es an wohi rrcnll.ogest ae dasikin ,s
# Iter-100 loss: 93.9453
# e'iey nwtent aminro 5-1Tf t. 9ttkf eoT3 9mfothe fLith, he C;ilres6rba gan thAs ontyn 5 hiEgs arO eees
# Iter-110 loss: 91.8265
# eTwhyueros FakmtrW eueewo4. HodinnuOsnah  hupal Joduow nf of.nbe.peitNlarnral Dum6n th .nie aod bApEa
# Iter-120 loss: 92.0684
# e)RaPdJ LDuhin ;,,tingf aresty ha msht;e wCdda pd gugitndu N.lioind taC sGJema h1lsG rniTinjof ttecge
# Iter-130 loss: 90.0524
# eh lnlc
# e本 is N1ranggg ofiG0DWGat h6elula, Japanoo Smuh hres tpe phlagge  et esye'e tapmero. be  hpri
# Iter-140 loss: 87.8865
# e5rsa eetulted Aliri thr .iare wes iol ind of  hhi,aEmcsttt rireds iott -coponls Wratgor lerols supIn
# Iter-150 loss: 90.9266
# ehwema n eheoe Thesrlldmirn esdAtd in oshiro.cAith iusourisn,i latdngdgNa ;oha z;uliogotgsc harth ont
# Iter-160 loss: 89.3151
# e%y tunrpor1 Lasd ewente bhras rwrai as an an s
# Win 3striren olwtfyian tm"ahGede fapa sn srhhrs othrn
# Iter-170 loss: 89.1272
# es
# s horacDtef osrdhxanA)ctcerere go ion iis Nohinc arany SkJIeetiistn tpn 4ftl Nhipan5 moeropor marW
# Iter-180 loss: 88.6662
# eR iossthe the Wihel ofNJe
# the tde  hh  SoorddsK :mh5Px"5h lasL ,aaae Hantwt lrltel EedtlepplinehI GN
# Iter-190 loss: 86.6830
# e3bAnp2d iemian ingesind Jaap1n tee t'rth N'llialatt in fase fotegcans'l nEcmend fhinst–Dhanf cmi8ole
# Iter-200 loss: 88.0851
# eun,, Janal wipes on E.rf inne, this outoe Jappth lof tJvptn ind io iinc chiou dd wioo JernitotWl Gft
# Iter-210 loss: 84.4246
# euinh cie teie fot mike l8ki",. os froba re Gnn,rpandk ohton 1mTeh an -h
# u.l-ee Werios wWl th pfptibe
# Iter-220 loss: 86.1092
# ezTe innc ooir ican T, analgand wmpa5e rante tan cte to cdrrlor, ,taly tooicoitgk2ast iusta covtLasl
# Iter-230 loss: 82.6378
# eAxt iias puSfo4 h7 toe thunlisg oi. whunamee AupcthelRls aP tuanes insthel1the thestenleteen  the wy
# Iter-240 loss: 81.7482
# e%naa6 noindschcDtlrea s anxase aa ciak'iwh ahes arlarlay..I.  perreyof ths 1calos Duexlar5d ferte te
# Iter-250 loss: 83.1432
# eu1dgg targt te the auL.n1, ne Japao wan La-tyznnusd Japal ras, anes metd Haka 1o. Rdminhtc ilia,-vba
# Iter-260 loss: 86.6378
# et–ia, Tokan pourone wep. To6gd. Ial rexthe coxhsd eatke tie Janat my po fe heveB phhtpGJauan Kinesit
# Iter-270 loss: 82.1019
# eeh "oares af oiteo oo. Krohea Ja tar2s avurisenicyilee Irdestotan se to dr'e Gf -ai9es an ehe warhe
# Iter-280 loss: 82.6769
# e%. Thn capet cponi ceCvered Gag chiaa am. Fan oa1diwe wir9des onia. Lisa wittoe0re tog Ilon 6I5wv0I
# Iter-290 loss: 76.8119
# ea,d Sfrshh ceathe SGuroty of the 19ntee fanwo, the Sap oEcivhnxs pirhrste inucchytirezt. ywvrri ko6e
# Iter-300 loss: 82.2119
# ex, Wwriis ourrythe hglcsicecered lhe t pee 1of cHoktiremWci2d comgitt od thakI xhe 10o5d thecyLbovec
# Iter-310 loss: 76.3010
# e. ioino-y. th ceasukewi2g Japan pe la'j sa atitro'f wgrcmletertd int ii l0ayMwoTon aies nnxpard Rito
# Iter-320 loss: 80.5703
# es 4n, thh or lod teeed got telyroh. Thh varlh Plltio, inty orghedicn turiog sit eird iac oh eneFpite
# Iter-330 loss: 77.5069
# estana eo Po4led ia .e pe Cared ind ateo in ti0thon f-snt kfy touch-ed thf wspad sif Nburhy 本tan of
# Iter-340 loss: 79.6001
# e1zWpwg pore.sbC lhJyla89o  anolas . Wy Jatae;,G in selieaticing stihe wovt Japin1u, icarer svwate ca
# Iter-350 loss: 74.0499
# e, thin..z
# rgathe rirrtinffcm, terxarg.tIt' an liwint llopetd uvItilgeste Cobet vint ind io foTry'st
# Iter-360 loss: 76.3421
# eLL9eapar inntI inh c9tglithl ac Nngs ro3nzeR,d,pirporespingoalar, Whrlgboted. he mane ile 0e6es, tre
# Iter-370 loss: 73.1350
# e2 Sjally whtthe -fiom lfyinosTen Rame filmtareo to nofged th  o
# untiin Fsed Japan is asicoreiNere pa
# Iter-380 loss: 75.8376
# e-winserea 2eiWIrgosu em1ercan, ohaparth us Kesthin folme taro ap 1fol eedWr's vard Serg pored iwoctb
# Iter-390 loss: 74.9023
# elP Japan Knd aheow iu cherha11,":) Japanas the I26ly', Sethip'aowtin wantsa vist Nolliosd fulih. mhe
# Iter-400 loss: 76.2055
# ee fers thell'pent igoat")ie teeg of irs Ea t-ppon oN Japan crjanceevkracturiggatNe laperlakg'is cura
# Iter-410 loss: 71.4047
# eGT2e Anplun tooe. nrpangge th nopled lhe ward hn worlhd Aagges mmpnl Sonen Bhole9Fi thi-iexnus ealy
# Iter-420 loss: 73.9640
# efciod iny siraRess feJruared1G. In an mvputtelin wil ce-levete tar rossi. The feruog (r ha,e font wn
# Iter-430 loss: 71.5623
# erbHnoftJ taneint ynd warthin the wrd cyming are c2un,'smvorolcJapan, ama thedaLan wascx"cm tapon in,
# Iter-440 loss: 72.2962
# ew"ldrrl thilalyymw oWya ind paralgwics skrlatsoustth chalisis. Jamaue is latoh te ins is theteandein
# Iter-450 loss: 70.4812
# e3x Japancoeg nf urconnys Ja. thitres cresthr as. Fpsl rlothe Thkl ined Aita aclsuou. Jheandith ate a
# Iter-460 loss: 65.6224
# emilola9d Thexciontdesteet ed oonte-lard Is aal Jamand cis thust ainod The eurhid I IndevGalesie thra
# Iter-470 loss: 66.0055
# eabiry win, iestor. ind Horaex Erpan,d thc oNcnthey Wpos an or ind Jaryd;st muiicnts ter west ed 103-
# Iter-480 loss: 74.7212
# e. Tve wered ucor-got oninch1 Che f本,nd Sareler.T, ame at ouns a0ghaly. The eapest. Troxti asg ofooll
# Iter-490 loss: 65.9602
# en, .fur. The Eagie Is cient. thr anpNcf r8dkaked waics firon iuste wior risyekoit te liinn-elek6n ms
# Iter-500 loss: 68.6634
# ejicl hisW indha  ho%liOs thes Fiutt sole burA. of cNoulaody wata charthes Tht onureds. Japan war sWo
# Iter-510 loss: 71.1379
# edNnarve 1fom lnkenly- oas of Japac)Cest perut18d wenth lake i8 they matee tf6the ca as. TLennorf ist
# Iter-520 loss: 64.5032
# e skan Inmekenft thon roule1, wi aeci'ies reased romcAEwit meleatd an enlllxbypiked xay tas os ropes
# Iter-530 loss: 67.9968
# e– bivane Kasy 2micn remedest tiinea mn thkr. The 1ep is uec7pwrse Japan in, tuclelitsia CodeWpcitit
# Iter-540 loss: 63.4472
# eabutc oalyowtrcar mo't,tien if.is the herdaE"sicantin an core tarel. Japan Ispi ardeGte aas an catee
# Iter-550 loss: 66.3868
# en and the ;ftirtde (e iiiit, oanleater woved se the The Saug of Japanghon wNikitarow Jaagxa15Laghura
# Iter-560 loss: 69.2635
# ea ae wof I7y io2Rbd , th cestif ci1st ond peri5 T3unef 1nd exsuagerEy pande 1fvh ares ou Japan,sta t
# Iter-570 loss: 66.1264
# eby parmint ohst. bn thean-wHred 1xcolea, th rad tho Utce msstardon Hrthha Sea520lIkincsth intte ben"
# Iter-580 loss: 63.8391
# event Win U's dar3p Aaken, 60sundJ1pan, ward-theg Nsaled ist rored ate inec mouutar g2 tthin thliBend
# Iter-590 loss: 60.3155
# ew.sTce colat as tevene ma ifar Tyhan poru 5are sd nof ury sgast ejoed s ef theren ury, Fan the the l
# Iter-600 loss: 59.6558
# en at iand Japano5 as tapeity "sta cedKer andendf stturake ih isechitg la, exth pareaa, aska 's thest
# Iter-610 loss: 58.9934
# ex livitoped init Hyvirtind Win sm erono, Japang at enporven, weld Japae byp tepenm tha wtpre parlmyt
# Iter-620 loss: 58.4163
# e pfoun r9emolinc of Sclore Fedit o fitirias in the Cirstivoded. Japan insu f本strtdeccnrise ULcandlig
# Iter-630 loss: 62.7355
# edes ir the teetorl conth y mekey at Thea, Cy ofel-tper enpon oaf ofulary thl Tof hsot mofo lace teri
# Iter-640 loss: 62.5129
# ea modpang ia 1sst rnd thind of it the io1f,. Jhaan or 7are essren libh  inded Wint ginth- atoI andd
# Iter-650 loss: 65.0427
# ed ind1 th lavioun. The conut the"-Japec iiti, bf the Empire va meglen and atmeed co-leropith. The Oa
# Iter-660 loss: 63.6725
# e"e ard wacciled cofen Ly tio ce tovs of tree mnint in logith lamtlt ansp furfhus mand wErrjpontt-tew
# Iter-670 loss: 60.1091
# ex crnsergerlar ou and hanley ad acpes angy panie of ural Japan by iEgS as andstanceace gh vagand Kof
# Iter-680 loss: 63.6160
# e–Wir des rurel inets as nous thred wris Ghelad insox.j iterolleworu ...D: ta as ofelopperea uthe whr
# Iter-690 loss: 55.1097
# eins and povukewoW 9ogth capardiccalnict oe:b2  punnnoky non  opresto fed itea an , is th-catwers tae
# Iter-700 loss: 60.7561
# e Redis fe ri6erys. If bor miun fk5ring. mpirate ir khes1 Haeentry it ood tery P1nond reos HereshareC
# Iter-710 loss: 55.9879
# eT, ooked East bate the :OmR2日r Lopand wh sg-phuroo onL6o-oaiteky Brangas ands of Japan4s wes cerral
# Iter-720 loss: 57.2089
# erina whilc. Japan Im,es. Worthe "actes on maturiast Hy as s0 andeSallowyith is thevh rl6hsst iranarc
# Iter-730 loss: 55.7592
# elsacgoithe wofth regbyms com7t liparih the wan cf Chgint eme cound Dorudi47, 3 hacenciustarly figh t
# Iter-740 loss: 66.3093
# e" alin wh the woCticeunbit mncittr cppreg as expan  sfedEprrxeala. in thethetis thr arlaese te cagao
# Iter-750 loss: 56.7762
# ek oru" ihut H4hingu, thica and at enth lopno td Isino fo6lctbyl gut1rcy wes es andinc chorlo. cofco
# Iter-760 loss: 58.2289
# eFy pins ceand preled at . of thry tpan cijount viciopes povukobnt , fost Aurapye 1n The and dimet pi
# Iter-770 loss: 65.6505
# eas ofwithe pimalet gcstcentr undriOed Holasy Nhtl ison.
# 4w;A koith thtuncrew1d Ja.8T, an tmbitexes l
# Iter-780 loss: 54.7531
# e olat onJatany why MEramivsted insta te accewes in woris whes destres whir. lmtirEas on eo Jopponox.
# Iter-790 loss: 49.8038
# ed War e91Sur ins farching ls of Japlnnsi torudJapacina, Chmameliat higeompes lalithe Ou–ress suced i
# Iter-800 loss: 53.3293
# ed ith rast ountrd inst ru ian, whxlalgeet bime oi1d., Wirgart ts andenenen icent ped prisind au es i
# Iter-810 loss: 52.5738
# eou engsitao eoge the Eareliti7 es urethin wanki warly inase bIunwr% giond is tholi. AEes pencales lo
# Iter-820 loss: 52.6774
# eT;oin hosuwha Togeann of Komersa ty ressof the E-ralen ol the Nefilstao- anos penhe thlanomy an sae
# Iter-830 loss: 54.3609
# ey hicgari isina, louth-tarcsigance is in th lerer se poonlorf par asben en es-untroloponn uatvaHalas
# Iter-840 loss: 59.0204
# evinal wulioktey suurgssicand pe Uoked macreapicstan estarucctaite an In exeunu fia the the wocurilgP
# Iter-850 loss: 47.8966
# e; follapelotken ur 7awrs RuseallyoketeNy patereE Empeanor ao maale, fivhepolitat toren. Japan t si a
# Iter-860 loss: 48.7239
# e lesolevedke riche th in tareo an hea and Nau thilet, ig hiasea. Anes he papeise To0nlvrlati in durt
# Iter-870 loss: 48.8988
# e 9f the Cinn ogble of Dbvlofno Azehlsparc alefotity Seugiss ar hithe woku, ti6ar sin the rarlory vhk
# Iter-880 loss: 52.0384
# e Sexed penEmp ronte inoteo Iea, che turaG soula,, 25Mhisilgat he Nian he OoNgghazz,0y. DPGAshiraliwa
# Iter-890 loss: 45.2876
# eh te the forl Wirtere en imy micl iast f,th larbest siit orhe Stymy co stom ingeopen East Copen re s
# Iter-900 loss: 54.0439
# e7 by pirotin aid, Shat C2alird sa de weot of dlithd nomst pesititenu tu open west titt ind orutiHinx
# Iter-910 loss: 49.8537
# e Easi rnd O8ge is Easty. The soumtirglin wak ous rike indla dat in mantren. Itpthe torede. The Saure
# Iter-920 loss: 49.6950
# ecoliro N9hh and onok8,, Japancanse worthi ntam onte ingthi atainan, forit milatimithe ao se pocitar-
# Iter-930 loss: 43.6757
# e日. 9paparop tory wits ipethe nant onecoun as raplofrom. Empt pereoper ist oxporlen2 featerld in an e
# Iter-940 loss: 51.6010
# el rokf is the tinily iost tisy cruper bs toryd rthst. of the rea Os 3meen y smanlean maplowonte went
# Iter-950 loss: 54.4644
# e emlloulotan es lopen arpertand wintutinges ter du1ttu ar conith s hares wonj th-tariy, whint winula
# Iter-960 loss: 46.9033
# elmiotitomy East irinsta th iU ti, hinctiis aodl Gace toen1ut tolJapangDai tho et meEpkesC tisi and p
# Iter-970 loss: 58.5938
# ed conul mreapersis ay she lape owa, KNthemallind vionde, winjs chan(uclameent en encryy. Af irttilte
# Iter-980 loss: 46.2837
# ea ory ,fted auth te tora1d'y Japan tixthe and SeamointGkenInd P on porbd Japan we tovat ins aol Eubt
# Iter-990 loss: 47.9852
# eWin Ce mertele6ol 1868 enebtit .iTt an podnlaplpar-tar R"st tins uubl ceenfeJ paokeovet anarof the c
# Iter-1000 loss: 40.6316
# e8" want Japan,) thta weut rolatbent cuntl Japan Was lcicatbes Houmalapiy aisy and bomt. pal Eas a ci
# Iter-1010 loss: 48.8919
# ea, Resio" argiit ande wari maen" wed Sictaouogof fnithe fodo, phevered, fioh aclargy Wange pare 28-r
# Iter-1020 loss: 40.7946
# enn Sfabor cry th an thind carkoI he Siaa eas of Nnhed Warges wopt prates. er isited arcesof eclare N
# Iter-1030 loss: 42.3335
# es frrhe World Wprtfein th the tititure octlolyo ea an Ease westhe ap Coindmy boma es Emst rinta. Tof
# Iter-1040 loss: 47.8291
# epon Eastaipents intk the wersrlboffi, thr asticoundN milatinl coflomy th des puretep ogFith r pareec
# Iter-1050 loss: 42.9679
# exBurako, War licinnthe Wonku, thoy  mamelerly. IJmea. Japan in the aidso ulbur ons, fiontury .. 1I 日
# Iter-1060 loss: 52.0489
# es of hrmalitnd se ghe tukatue tode cald thr hiuntred eagi iny, woth laggers mepalthy caglocinseded r
# Iter-1070 loss: 42.9349
# ea seokurit oolatweite unsty. Epppof tot opoeceupes Tyeoconnt t tein og pounouunowcouuttryd choxt the
# Iter-1080 loss: 38.7675
# e; momperpenge malcporgest Aithe of then rolupin tapor East Spandect todor. Japan "a an mirilotojn 38
# Iter-1090 loss: 40.2904
# eze's cren;om-larink a 1s wonl fitl ufres and forla . peonnav waini s mestios. Japan is a ffits bnmpe
# Iter-1100 loss: 44.6182
# ey The Nof rokeG, the the Sulolledentl inttonin The "onat is aslored taty 1ntm uritaly ghe "h as 9mIk
# Iter-1110 loss: 37.1736
# e fopurewed sthe thrrandroclithr aith is tedin fort thity ingmict atte ofes urythectirnd. Toun pore W
# Iter-1120 loss: 47.5481
# ekea icakionth lamamlithe Gas and5s ionorlend of arith ang an shar. Ofunnt25-dennI y Weve ea as ko is
# Iter-1130 loss: 36.9592
# ejinctare cands. Japan ts in the fuletden an is andeopen is thereater and ourth the eatl catlend rarg
# Iter-1140 loss: 41.8771
# elopulathe the Nin8da nte' of oob la sed ing( ilelorlivinex Gfkinl the wonl miulalo bor.
# Ljt chas ing
# Iter-1150 loss: 36.4507
# eveve tegoof es the atmeito, thi arcithe "atse whr hxparband Tomon in by pongest ifatt resio mhis tak
# Iter-1160 loss: 35.6557
# e7 Chuta le on m9ed ug tary pits ncptilithe 12td enponle, inbo pento inand is merth temtie fhic aseat
# Iter-1170 loss: 36.7845
# e penila lof the wxxlatrentu's iact ry's vinsom bonnd iI nom tho" 日d hissivenwer puwa. Japana oG etor
# Iter-1180 loss: 39.1869
# e Resicgnturicg, the Rpristhen ceofod Re Nthe mint an N20u7de, fes ardesturea Upin ty canden mlabanc
# Iter-1190 loss: 43.1755
# ecy ip oxpOk;etFi th car 9i1, wand thend .red of the Unte Wertom nisy athe Uflirg, thoc tion Japan1)I
# Iter-1200 loss: 43.5504
# ej as aslurarn. The fokntry Torkog aidi, wentiry Cow1d, the arest mard wand ihed Hmmare Buka, 5y 1853
# Iter-1210 loss: 34.9739
# e" pores SeaAl euporlengestar wacto the ficctary whed , Jatan by surgest Chicheces mtevenntind winth
# Iter-1220 loss: 41.2071
# ed borlast chistrmeititeve es ar Nihond aninkEm58 esia a. Japan iso gabed iE ban eI olg's canle Peleo
# Iter-1230 loss: 37.9465
# e fols Hurlak2 depfop tara  hicntye to ire H8g, ghes argestomy asth carthe whct onthe fearonmanarithh
# Iter-1240 loss: 41.6129
# exha troUntiin easco atthin mf aithe Thken, thi aicc inst enenS sea eobed boxs cutre se Ffrse 2ulurlo
# Iter-1250 loss: 47.5134
# eje thit torly Bf the Japan h stareof ath caland Hhichules The devin bolalomy th theteonl 4d penceaer
# Iter-1260 loss: 40.5848
# e, ite tre oumt ou ting tte of 18h la asly woth ly fod tool rinnoryaWar inha. Ey the wext claroni. JS
# Iter-1270 loss: 38.3133
# e. The fanc persar indriost ry the nomake In A iast rof iorth tertat wictrod Ea. 193menoun 5mempareIn
# Iter-1280 loss: 41.1309
# en im fict ans andsTaconalatirnty in 1967, wond,  riuregJalan's Hatat "ofatsty strethe Emme engulin O
# Iter-1290 loss: 32.3983
# e Seired focrtar cots tomai, thea The cotd cits cobet in ting ot lion Wirman ind perore diinonkky lit
# Iter-1300 loss: 38.7093
# ex and Sola, Japan by wand Nhanawey consed urthliof nnky irowoct lopprettencrlanc Japan's The aulitue
# Iter-1310 loss: 36.5255
# eccensuve. Icford sared's lago upala, wath cala, Kotihllenuld. Arenf-5umel-Jaknncping of mrily. I,Oth
# Iter-1320 loss: 45.5779
# en args.. Jppanourt th marlemio ba, shicanamal hing日: ditat in apjistu angartheng chas rapel pinrese
# Iter-1330 loss: 35.4976
# e asd wormpJapand the EAstpergest ury fa s maole. Area of 1941, Em exdrsiteving vnor fi1nts in 194y w
# Iter-1340 loss: 38.6828
# eE storeoped f ortl bod dmit tucand d intaL ev dopit liculatie the wLes Nrgpor logive onsirentury. Ni
# Iter-1350 loss: 31.3522
# eina an Asinnau wand aced 19th lnvularil tonn ineryos thes relolapee tho wand Asihed mest or pintemoe
# Iter-1360 loss: 39.7248
# es lef mppore we ile Ware Japan Pe aa the four Eurblobu it 18is and chulethe eag tevon1 the world 2ml
# Iter-1370 loss: 38.0938
# e ef J8eknanby antithe thor1m7imlingowwoky. TAAlotlentud of jo Nidod Jafan's micexth tamelest rintuti
# Iter-1380 loss: 35.1905
# ed bomtirste the aily inp1ediind is arecetil thit roncelsm ented enobo penme perceaked of Japan se eo
# Iter-1390 loss: 30.2487
# ed bar antrowet in the lapise anucballowa, the hipbealed foret trsu tuot rnget.win an the foummil tha
# Iter-1400 loss: 35.0199
# exta limgeat in moulios lith lllifesig Eas as atsed bipalacitch 9git-wenkI itse "rinttyis ates werore
# Iter-1410 loss: 37.0833
# e fed cpundertinn uuprrin the dento nnllIlititowe ar sfonerounl. Deparde wod leked the "open as argit
# Iter-1420 loss: 31.6311
# e Japan (exs urinhe InolyCuAcon mhitalyeita of Japan  irses. Japan is tha aras wot1 Japan's u ath whl
# Iter-1430 loss: 31.6636
# eTEm onent-lewel pande wers whire ligesite eas seicrealith. Tived co lesiraliko, thich args ping, mar
# Iter-1440 loss: 33.5647
# ed in the Fount Dynred Japan wod sthire whicm inge mby tand sionthe worl bokukok , ol pirinix8, kkolo
# Iter-1450 loss: 30.7939
# e the Sean EhefPonncS st chith nl the eowed par mapenalesun h cexprlathe ShanU,.Wanwccporoteinamy he
# Iter-1460 loss: 29.1131
# ecwint wrod Eonj ap rster atid Oins Wereled.ict otprited of irest-tiriond th cand's iand. The worud's
# Iter-1470 loss: 30.0250
# el of Ali2kelonn o fhith un G853 ance pepprceas- frkenis a arga tien om the seured ind Hupatyenee uvo
# Iter-1480 loss: 36.2709
# ese of remiolio 17t8 Jaaan") Nst of isewhr espand Iponte ofof the es. ef ute nogistte the fonrlpurerr
# Iter-1490 loss: 28.5628
# eInd ox hrtarlyy9. the fpureloupin Se marlecWes. Jupandec tal Japan ts aresuvend chere ti ofe ntsi ed
# Iter-1500 loss: 31.5650
# evext piniloubea  hicanila andila, mhitertas ax hat suled mamlid the turation. Thy M60o5  lbconledicl
# Iter-1510 loss: 32.7370
# e, the Sipandec of 126 linae ea cepolits cfrfrrinsky. of Nhastro fist ofebo beth cs ases prestveres a
# Iter-1520 loss: 34.7894
# ex Nistorloean D hmured'sorawored..%. LIthtired. in fourtthe es in-lite to the nury Warly in8, , hire
# Iter-1530 loss: 30.1975
# e" and ivet of Japan's tama mpun loral taclof.in thr aimeres an maian Ky1ss-keorlokuJap6LanOlamaleved
# Iter-1540 loss: 31.0796
# e senfer feurl Nhe Houlaly"In, mhes aldmian Nimitentar of the siciay in kion Wim den fo stiry st orom
# Iter-1550 loss: 33.3067
# en righarge the wors ropuonled intr  citoe thes tury CEupokgo Inden aa te lenporin thed Wurtulicy an
# Iter-1560 loss: 34.7813
# e Wors Chith p9pate. Gpentroy cotstreteulivinins Ermeinity cefira  adinand AnllW15–7SiconarcT1y.. Tow
# Iter-1570 loss: 29.2040
# e" ured Rm lala lsuhe bokukeit7 y  oured Wftke in marin bu cond of romtet on milopurd inthx anghar Wa
# Iter-1580 loss: 37.3240
# ed Risth ccmales Wes copee ta sea as heving ase then mpurald an the wors in Ch6 nommked th u parisl.
# Iter-1590 loss: 34.2222
# ed tiin Cian und nhral Cofno, y945–20ce off1 3 the worg cflore maoky. Ap the frd tiringe wo mhin aful
# Iter-1600 loss: 32.6698
# e5toliwont myes ry shorea the Mupbe ef is Worellbutce ommicinaty Honath Rsseare malioun Jaman tirias
# Iter-1610 loss: 26.3518
# e of. Thi alano chintoplestive ios tain rountse Wergent arom tasi Panly wotbo-nate 1ha "a In eckiog t
# Iter-1620 loss: 33.1221
# e-darinas ecitlatitowict1ed tomal tury. LPnures weod Tof of logJapand as asloxtar and xparanaea. fin
# Iter-1630 loss: 34.9760
# exPa Takio ne Japanein Sen. Toked is lare Uatto nant. Jepand cf ithir make lo 1ndlomelaty inomKa medi
# Iter-1640 loss: 43.2476
# e worl Diran, whl atdid nonI Wart Ja.an Fire parlaturigenty sorcatcinan eame.wit beapeob re niss inct
# Iter-1650 loss: 31.0569
# ed 2ish armhev.oA the areestome ba ty Henlop0urmal tas of ithexsu hexhisteenno of enjins anf calttoma
# Iter-1660 loss: 32.8913
# ed fores pDebpreater fich ig the was i. 18te andy be togest. Japan ous andev Japan ha 1 thh an, Dhe w
# Iter-1670 loss: 24.7606
# el of Japan, was mestitivinh 19gKmeetioge
# th an ather. As inand ffrit wichils and Jaran was land Warg
# Iter-1680 loss: 33.5121
# e-siven mpee ox the and lioina, "anar"y aggint old EarthG G;Pankunke, Sacandexa. Japan war sepandeate
# Iter-1690 loss: 30.1057
# el ffist nrgitowed se thica arisa. Japancease Fint Issmatein ga to the fouf Hikkorcetity focst Cightr
# Iter-1700 loss: 25.7825
# everec. wistreand fored Ka hs anenkowIn If Japand an smounttol lomet in Count. Te an of Copol ted ous
# Iter-1710 loss: 24.4107
# e's Copural milnty. Axoc homeor andepponante fentt en Japan's tina as a. Jfpan sivanery. Japan sucita
# Iter-1720 loss: 33.0008
# e filet om intired owow hu hru3len. ns asererea urth in 12, Homa, ha, hhanlym-eatbe Se ofoc lohaectul
# Iter-1730 loss: 30.5414
# e ficstion of Japan, the Emmite es ar sipon kokuliD . Aroan Chhestoryo, fJasasa ai h, ismaleind Afont
# Iter-1740 loss: 28.7900
# e mintion indrane andy ward Wandmeopan siven ursex. Jppaneint efits the an er laton wan, Wargest cofr
# Iter-1750 loss: 28.6408
# e Sea, Chion unkedrdina Sma an hisotel moret ond. The Gake tr dopon ered Japan ) is rind pas ixtarlet
# Iter-1760 loss: 23.4581
# eje th raplidic whv mollound apaa-ked-sov Gleftar and Nigapet testowt th vesbam- cpan "s an by forl t
# Iter-1770 loss: 31.4444
# e foul the namped the cEure Frr"s ofdic the tira  xup rollis the Worts. The Aanje furthe Inden me tot
# Iter-1780 loss: 27.6484
# epFcorges the Grcationde wald chubel Pa as thenwon dmin poridarecchin, 17th cen-ulak8,d Fatst Wat's v
# Iter-1790 loss: 30.6132
# e7 West op rs the Ring pmein fo sty bopel prm inwe lu andeswon haseatulate na mellinstily.rof asty be
# Iter-1800 loss: 23.2570
# ed livith the GEmst on tienaroy Bhar, 9akulith, whod Hokkkhim1,, KKyyy O–-Japakonkk016 SR smuuullonll
# Iter-1810 loss: 27.6995
# eine 1fil wing ant opertarlega we 1st roltionti the worl bion ggDl-dneunar. APeat my ator fed dofe pr
# Iter-1820 loss: 30.7114
# e bouloC, pyrctarecstivine I. Tse naBgal inste an milatarcy winthe .o no Aligeji malthin minsiardint.
# Iter-1830 loss: 30.6037
# e meobul esTa pouplrogntary, whic aightit ceanick ind ruby anty cond porrligina as an in the Ctirgaso
# Iter-1840 loss: 26.0325
# er and WorldCp rat andevveufa. T. of tntire on lioJapanas aastho ard ipenough m8kan ss an the noled,
# Iter-1850 loss: 26.8083
# e Tfky bo thed The conte isma by peopod an ar mofbo, an zes inklogesulan Dfilatity an red ingurs lari
# Iter-1860 loss: 35.3190
# e 9igelurgest refioptrel Wir col lors atestiol aided in ax mmpininonan Japan pesicanas hesIryeded rep
# Iter-1870 loss: 29.5508
# expeclare Che founs vhenane S. Pan ofloty rtyinand is athe womh ly foukfkoC ty us miog or-klopmestend
# Iter-1880 loss: 25.3970
# ergaction Japan has the dintrouy wath rambor nof d"pte ty tn p riantyy so Atimpenon miebolicb is minn
# Iter-1890 loss: 33.3160
# e3 mecrount ive ornd in East eslar cabon in the Hobud "a,gh chast ldenor es intexparopat meatha U8,th
# Iter-1900 loss: 26.2765
# e Smnexpepense f res destrty taty catee whit en urmeloind. Inceborg tity 1ftiy  ens ceahed Taken fict
# Iter-1910 loss: 25.2633
# e-largest redilots it timist on-uralkhiy cofis thes lalaro stion is aroled ligowathe fargest ertirlao
# Iter-1920 loss: 36.4356
# emiletiot ares . Japan wes sularigith an miobtoly. Ir maklins Wardest ceailothe gambe sece og the lat
# Iter-1930 loss: 21.6004
# e' lianty ino1 Pmyyat wis ofind Japan sud the d peroly. Ip lipare Hovmaeas vesed Woute cparte the wic
# Iter-1940 loss: 24.5454
# erecconusithe on bo-kowel ti tornag 9. In fn mbeleoperwad se popproninge tore fert lasiceteis teunt a
# Iter-1950 loss: 23.7983
# e fios teU or the Gast Asia.e" a th wxtttren is fica, capal tres rnur d86t. co th ts an Japanece War
# Iter-1960 loss: 24.9411
# eclomettry ko ul hi. Japan ins anjcape. Nsmpmeiniondecepem the sourlc, ins r hefount Sof o. "repar an
# Iter-1970 loss: 20.9269
# e Pealowat onor ants inp. lpproponved an Cs andeige worod Taofed wogh uR S"5355I8koke" an in maulita
# Iter-1980 loss: 27.6792
# es of Nasile and Hemst ked cald WargeI goct ergestoe of Japanc8, wand the Rusolu,ga 1yth yalad Sontao
# Iter-1990 loss: 22.5397
# eincreciinty in wor1d 37 und wor6d'sPWlithix. Japan suralaia a. Japan'suvind hrs coted Japan in Dareo
# Iter-2000 loss: 20.3923
# eD anded ofetre lake ch thicheal Is ose Caite nupat on porata ie 35 meilargT tored fome talite fed Eu
# Iter-2010 loss: 24.1808
# evbo an1y The goprorea, m3y inkel Warkeo an hiconnred 9acd atylount hininas Inin mait endiperanded mh
# Iter-2020 loss: 23.2240
# e; fobmel bompent ye fors  arhes urgas, the Cound-ras, in tho nand inuthe Rissowexth thet urilatiry 9
# Iter-2030 loss: 20.1507
# ed finst ertatien Inita ind ial tirisinl Siaice is f ome East warthe worm lrlurokk. In par copet occ0
# Iter-2040 loss: 33.6716
# ed romeicethe mald anm liinounde920Gme-narty wund the coflory Warsh meles romelorly whit hingutst in
# Iter-2050 loss: 25.4317
# er otateon in the Emperore wosu ex aring,and inath , athe G9.garon ha asd grondesrolyo preateont fofr
# Iter-2060 loss: 20.0066
# etlono the 37 pef-ofine Snange to topuncensu lobuliandin wand Htesthe worg sturlomIldea, mand the Upp
# Iter-2070 loss: 29.0331
# es ares ofec presirom ar "span a sex.ropparty in th- andel pexporel. Appupeeotol ofoit tieanomy by te
# Iter-2080 loss: 22.2546
# e forst rofitary po lithilolinom the G2mbereas . LPapan tas in Ohess fais reked Japan is a gromelitiv
# Iter-2090 loss: 18.0433
# e worth. Wart Cowan 5 hesocound Thh-aan", an wwod ward . Inglod ffer Epperer ithe "Lant. Jfpan is a.
# Iter-2100 loss: 26.0875
# expan ardix hingoptte nesi Chintry lith iccliog and ounlarisea Ookealitogcoro sh maxlrcanded of oroby
# Iter-2110 loss: 25.1331
# e Worla, van superomes. Wveporperth ias, gh the four mist on Wof-ngba a cy wad sower istar an encunts
# Iter-2120 loss: 22.7898
# e Japan is anor ofina sec and Spannand Japan tiven. Sl afdit nncenur ankewis tacatecnarWai, the Emper
# Iter-2130 loss: 22.6251
# eMei a are wond Arithen, garixc, Kofokst-ked of tf-dat enges ares worceanerea,, maithl armhepond Warg
# Iter-2140 loss: 22.9420
# es ioper arased nomal tadicanded Japan thist ande world fint in mamilat mialald f mhe woludesicen of
# Iter-2150 loss: 18.7338
# eJapan (DUranes wos rollowerthe Pacl isterofe ca tho eage Nhe nokand The Sandexumat-enpingeand if iti
# Iter-2160 loss: 21.0631
# er of Hiodchandasa, hhas18,h, mhkiisla,, aigto-nary, a, chulatininga ly Nistor. no freat Risin meared
# Iter-2170 loss: 18.3412
# e fersuta dentivino Impenoly uhan DIikoko. ATy3 Sranovod maice aris a.nd por mplthr apleinigicanam-wa
# Iter-2180 loss: 22.3278
# eTdenicof opper and Wargedte df the louistreby tyry Ward Ntinthe G7, the Grlynan Sly forlari1ed Konsa
# Iter-2190 loss: 25.5804
# empinie: Ospandectury cal liof. Japan as a werd pandentece tese poreslupar ha an highins o lotb d ont
# Iter-2200 loss: 24.9550
# ex an rokloris. gAsharesternoma eint aleropledesta and if tht teded imperter "fnicin mambin melederta
# Iter-2210 loss: 29.1048
# ef in the xowetrenthe wed isef ucetumy tity in the wofld' Othe Sebnd conom ilhea iogghas Wan Eusllurs
# Iter-2220 loss: 21.8637
# es of the ceuned Nitht andisen in milarom Tan of thiche E s-sereith owett ofel pursta. e tio wed sura
# Iter-2230 loss: 21.6601
# ef Sea arcsedJatae ias tha dpar coted noper asssivenally irgarty in islowas and Hurans inlecwist Inde
# Iter-2240 loss: 21.6848
# e Wored War II as o nised in the world's Token"mpirg it micand tecenom is eath canth l. Tre dearwes w
# Iter-2250 loss: 22.0023
# eto fove pugenar mearog thice and wechored in Isd of Jakan, Itecofitht hiasore ized Janan, in higatut
# Iter-2260 loss: 33.8944
# e liof Ochlepled aves prof the Gliponked saveo parcsuncathithe foull"20e tica wish chust Chentopu, ts
# Iter-2270 loss: 17.8175
# e ficetoupal worl the Emppropen uroGakght atestarn of Japan as feccad seinl forloturo aslar mionend W
# Iter-2280 loss: 25.7182
# eJapan (omearenic karwit wase malconnthe worrd fbonl Nih5–20r5 209enkeng pponeofeace urelopplc inpprp
# Iter-2290 loss: 25.7569
# ed fire War sesed lath at 12til. of uraNa, was ed ind it owod, an expunternd conte pargeste laresth a
# Iter-2300 loss: 24.4109
# ex and Worgio ,ect endexmellourel opertetter hom1d, tara ceastor.en ture teriat Sintowin wicu ard ihe
# Iter-2310 loss: 21.2505
# eceuliti ings fvintwen in whid Hollkisid thon. Nntrorl. In epenow ivyman ecst ener la, erlabl couitan
# Iter-2320 loss: 21.8023
# eteo of the GskanecI aid of 6thin me8ling ar is.re tive exgl. Japan in ta Un. I pentin Gomex. atisn b
# Iter-2330 loss: 16.5361
# es ares Worf cEppepenty copill iest Cogntry siog arcauge the Fofrl bim-ler,7 EmDeiontiwof interlicano
# Iter-2340 loss: 17.5303
# eUNin as inond perientby ind Tth rented Stan of Japanese gcotiestica iesticenilaticctar the Gs inc"2i
# Iter-2350 loss: 17.7920
# elcofritited wis thic1my by wat me porleloofeowel ha axsh of Jfeaned iancha Ooggeamby Rass me torthe
# Iter-2360 loss: 17.3112
# es of the nad end reandef cotare l.umber and anome mhe er.d-konnc mambin and the hommelerty in bhe co
# Iter-2370 loss: 20.2012
# ea in 1868. Japan hicathe whrs ralored of or Nebtor angs unren'm iana3d Gantha arghingeclalesthe form
# Iter-2380 loss: 15.7776
# e Homes, mauinan mestoro un hi, Eom-dest. Ntalnor 9gimerere thithe nome tpti onerd Jakan s orla thit
# Iter-2390 loss: 17.6874
# exparea Wivg at lowor porel opmel. Srat onom oanloukDomaL, hh as ponlof4n pareatheceate Japan") ia Ol
# Iter-2400 loss: 31.5777
# expopal hichare who hisNundes, in homeres anes haparas andid in the Japan is coled inter ounto nertop
# Iter-2410 loss: 21.5809
# erow the depeo ilankeInd countit tino an y fnal meality ar, iomai, ank opectan os ffectarly io the St
# Iter-2420 loss: 30.1535
# ed War sop lored in Connowco iote nertaicancc the atoin. Thuunath in Ease north- atbe poniwI  irlicun
# Iter-2430 loss: 29.0955
# e kiom or mek2ins an s inte lestor apal thomal pedsicgapa in ma bo atet oretsty rast of-Japan, the wa
# Iter-2440 loss: 20.1386
# exvectored of ory. Wit  oured Nrupanged Teg ounary mantea, haidex. Nipexo ro-nokekeing andes theth pa
# Iter-2450 loss: 16.9707
# es frest ofrist Simhary. In is andipe thess. Arealititine In ed ints reation. The fomest tint olid'.
# Iter-2460 loss: 19.3819
# el of fry5s of 126 milater fict in N8m55 od Nobod Oanish anden uf Japan's Wan, aspenparcedeath .aCP a
# Iter-2470 loss: 25.2698
# ed in the worud Winge the wogurct-ondgB. of in a2llonude Emserell siration "nnxtslalimi andety st rol
# Iter-2480 loss: 26.8581
# ejFist erep rimea we Pixan fo mallry ar,y the Gumbol-kols uratory'v nouth ancctainy. ANistthe tivg of
# Iter-2490 loss: 18.9625
# eked sitt on tured in the woul 180–2015–woit . ortor. Aich. Japan "s a tivibalt minhowf icttory cots
# Iter-2500 loss: 27.2624
# e of 6, Che fogs th the calge cokune U. Japan in a8d ondioghar Koumallounthe anlygukf osl roreteonle
# Iter-2510 loss: 18.5505
# e Japan Ko Japan1)1 siond Japal tasican maitenty sastiman ind merlalitan so mmlrrand cony hustry mest
# Iter-2520 loss: 18.7467
# e9wor hessuly restirxtin. Th  cabto neg omper is marlithe Warmylitan s iste te the Firs urethe Witf a
# Iter-2530 loss: 15.7285
# er aid ounth Japan (mpinalfonst. Japan tr and in to thobnf estal fo todidesig harcichand it the Soud
# Iter-2540 loss: 28.7031
# es in the sorl-mer-bepon ge sofelopy ba tioa. ca ase lopurald.iF tetircal fristono f thiternar "oviti
# Iter-2550 loss: 22.4782
# es frest fral purindesil thic. Epperert mionty ts teron it tolentuliwan mulara, 18hi, hand the aogid.
# Iter-2560 loss: 15.5005
# e pioteoly unstameintar sial of taty ty as ly ond oupel argstaneccano h8. S
# . outho foulatgentry cogs
# Iter-2570 loss: 19.3299
# ed Sar 9. Japan wnd sures urid bits nttite tn estro fi1th ullarlymdento mhe Empenor an melextat endin
# Iter-2580 loss: 15.7926
# en romeor aigha the anes lyAdeved ardeitece fest fxcr and in ed Aset. I ped proand form irenn2015, hi
# Iter-2590 loss: 25.2523
# ed aiwto nereabit "thi tred itmin pand whess mimbertuciwat myeby Emsiy penge the worgd ty ce ised ofu
# Iter-2600 loss: 18.7837
# etory Asth copolariech. In Em5iral mpinanc ferso meceber iggha, hasasu andes. Japan in the atred itin
# Iter-2610 loss: 20.6191
# ex ably. Tfe coprod tound Wardec isith cas ad t ond-rargest cctiothe with en the Wargest econxry 3han
# Iter-2620 loss: 15.2358
# ex arly, pref arctubio cons ctrithe wobto and desttore th mhithenaly and carenot mionfod ina, a cothe
# Iter-2630 loss: 23.3013
# ed roves tas ov the Napledil ther mpition bo torlang War IIisoveconalltuea. lited of urits unclyrr fi
# Iter-2640 loss: 14.9357
# es in the Japan es ino an to andinge East Japan has andar. atereand in wint rndelarly frchl Cog1ttr n
# Iter-2650 loss: 17.1195
# ecliom ition. Inpund connt's lonnme-lenowdive hi thend comest tid arcminary. Anircband Ghe G8GGPlcand
# Iter-2660 loss: 25.6450
# ecincexsmporngbt tont fiol fomel ef th the acan eckionty chegest gint-intby pext rtand es ite tilnd J
# Iter-2670 loss: 18.5944
# emecelag iconnty wontr ind uured CTofghtvll.kederccof opel bambca the wots cicnthe whorlallerimsitaty
# Iter-2680 loss: 19.2104
# epecicalith and the Nourligonigg un sd Japan, whet ty Bstox. Cowno"Japanail Wargest es int rolod.7TTy
# Iter-2690 loss: 22.2073
# ey 9ouras ercedety deio o thiparcesia meIhisin. NAsprepelith c.pred Japan is at Cower Wextar wEs tunt
# Iter-2700 loss: 13.2977
# e War of Japan, 1hh ce rediowd worthe Tok lopol tnonof. or thety. Topon and if Hasis. The Copand sham
# Iter-2710 loss: 20.6240
# e moltronlowinc efentrpy bu tigu, Has canalacardes arexpand ofrealy, the atred ate o9 any shanan moul
# Iter-2720 loss: 18.1447
# e loverrad oh c. Japan ind astio aigh uarlymMentrty foptr asiand fofloty ioltin thig cound Wargest ce
# Iter-2730 loss: 16.2657
# ed romexpatWeanse an pxpandentulalecco toly 20th anly ats andathe RECCCumaanke is the semmelit. Japan
# Iter-2740 loss: 23.2966
# ed first contrmintuy high cackedis arest roftarthic whis, marl 194t. Tnkeonithe GTOconatio .AAA iand
# Iter-2750 loss: 26.2653
# ewol moprral 1945, finke wsith cesis arasian, the Eart rinnthy cEgceante fict in silulargeatee th in
# Iter-2760 loss: 15.2570
# e giottered,iwad iaper and in-woud Gicheancates ofeN prust on. Jrpan, the whuth- lrkaod ofy N hariegh
# Iter-2770 loss: 14.4436
# e poflimpor latD atarea d oan ty nsulary whist radionded inttr povilat Cowlrtionly in the G7vinan Inc
# Iter-2780 loss: 18.0582
# el history ba d th c. Japan in the wors uring, th angEmpeasto of ar3se Wand comate the G,umat in lion
# Iter-2790 loss: 17.1459
# ed of the lame ci saont fodicalis thin mecliWat wolac. Is expar and feared wrogh. "Eapna the ator anl
# Iter-2800 loss: 17.1299
# ec-largest chtuttendeded Japan tsia tint porred ompes lates tares wares linano fram ins ures. Th an p
# Iter-2810 loss: 14.0885
# e Homeor an hounilh- lathec ar, 12ty in the sargestory stuth reslarith an malein bo porclited finctan
# Iter-2820 loss: 16.8149
# e fiot and of Aso Nhakand whe the ficston the aresea. Japan is a. Japanoso. 日本本本Jppppppoperol iombo p
# Iter-2830 loss: 17.2639
# es of riveliti na I wed in the suriss wort rinted Tiondeconce th uraliti, cotit tith in ligJapand at
# Iter-2840 loss: 18.0704
# es of Japan, it tionlous raresid fed opprcalliter owet h urationd coftor al the worg staro atekowic h
# Iter-2850 loss: 23.7595
# exty toryd pof Nry s-ofrom inanh anmedpante fouttred of che aal the Hokud's lumeove it dinctarea. A i
# Iter-2860 loss: 20.5990
# es if the mepperol.Df ofor mibbtenty copia ty ismporo spofand ateanar homal taticnkin the Horth' weln
# Iter-2870 loss: 13.6541
# e fed ragesuve Asta on mher aggsar Paanbou, whiot enoked, Wargint Indin hichiseme bith Wiv alis eauba
# Iter-2880 loss: 21.5161
# eBly rostin.nt proped trte cous rureh mbll urgy EurullowIF t the of is anesed inte porne's pindturcen
# Iter-2890 loss: 21.1028
# er of "Sean "siadein dma in the fors ureCdi, tarins andex lhkunath inscaud axth alatiwe  meitorn esol
# Iter-2900 loss: 19.2913
# e tored bompen in 1hh Cal omiliey. Ohichland Rasss area andmy in histownin thit e fi tho estakio wiog
# Iter-2910 loss: 29.8508
# e meol ored Honted of tho Narloku, Rivhtbon mad's vean, Infed ase torea. The cince irmed'inn eppelone
# Iter-2920 loss: 16.1545
# ed Wirth ca th un the 1s, Japan (Japan's eamia licincthe th unst eod oful hecrunl oJmpan, 125 olilali
# Iter-2930 loss: 22.3252
# ec ored,, the wour mbelloulliggburlatee whis drand asprepornind Wountr an toked ceteopiccan ss enfud
# Iter-2940 loss: 19.1834
# es in the fourtly Tigen pout the GsPa and STakecnnted inithe Wort NrWlitho and Hurendund Nngunt ofld
# Iter-2950 loss: 14.8315
# e War lopen un tokon, the Russd Russo-Japanny in Chuns chares tyounccuterth and inga wh perded romed
# Iter-2960 loss: 27.1136
# ed meith ceressu, Japan tulite igst wort foll prepprfind Worlulit5 Dertong of-floked-kotl iveG. paban
# Iter-2970 loss: 22.2568
# e of 1sty onandec ontut 9unbr Inte Jala. Ja angha tha melh bo turndesived ofuma ty isurof is aneres o
# Iter-2980 loss: 17.7585
# e roked catien Asia ao sopeppred ogptre Easinccandst robe rols itsticatecn as ialar este in the Warg
# Iter-2990 loss: 21.5948
# e cogulat  nclnunles Holofkile 205kk-denty s fors lured's lin9tht vediond ffrlatelcturth cucin Cighet
# Iter-3000 loss: 16.3013
# e-metbon mombiran Nistor aided me tarioghich untrleitikinicot kyocs and prmainound Wardecpurea dita o
# Iter-3010 loss: 17.2338
# e ficstand atertwtivine f-ompored Taf copnopes as impirind and fecmtore bolede tho Mount-ry powti tan
# Iter-3020 loss: 20.5487
# en membite of the Nation .iot pricededithe coure perig. Japan (ndexpopperod. Th an andenfeceant if no
# Iter-3030 loss: 13.4775
# elliomattoy. Toey fend per an the noun Chineng suras then wirs . Ard9r. of dnomil ande esdund cented
# Iter-3040 loss: 12.7968
# ercinteoted ofithp mest or 9..Jrpan ins anpornal in the Rusad oI 9od1, The wordd tive ond Wergerugesu
# Iter-3050 loss: 21.1006
# ecWare I. In ecenore liof bxprealisst orlituringlats ncutar enttoinety ssoute the eoum luser. Apentur
# Iter-3060 loss: 17.8743
# e Japan wes oxperpard ismlitina Seacendwith ank destowy te pare worg Cpin te poncoun the Homperting,
# Iter-3070 loss: 17.2371
# el of pobole Iaves, hhesom mbolital fipeteen aiUntres arded are malade:, the the wored Wfrnd Nlofour9
# Iter-3080 loss: 26.5932
# es ares porat ofof prenter ntsi wand The fod poper ant Wesoles ares pemailin. Napesoin kior cote titi
# Iter-3090 loss: 20.0559
# ed Wor srits. Ipperedwio fictront teonomy ie tho worldCginctures doficatein hasjicctared 17ty land ma
# Iter-3100 loss: 21.9197
# ed War wopll ind17, lredeity in the wol divith ng Japan in mpat on 1rel.e to fropet ex Japan, the Upa
# Iter-3110 loss: 21.1397
# ex arlyupin Un the firsty pevite focan es a tht enorlghin tuen tion. I peviles, ca Unci. Tof d's ties
# Iter-3120 loss: 15.3242
# ed Ease catn of papanceakkintwo me tiontion fod reace wor. A then counory intm ircandic khento lapal
# Iter-3130 loss: 12.0611
# expaclarem920 houmempily 2nsm irl1935 Japancin tade as ia ned in the Chome Chernethe In Ind itona pio
# Iter-3140 loss: 12.4371
# e ficatyen miut tres arglitatity and of N, tos enttd lopeopte to to-pard cha , Asiand feast rrest. Th
# Iter-3150 loss: 13.0490
# e fourth a, the chare Parnn th copltro Wive es ar hesarcemyev an ef ural dican en wom Japan hica, hal
# Iter-3160 loss: 15.2979
# ed in th lopulat ostar cese Cures it kidster of ittin ande War ced of8, varaiand inglsgicctare ea. en
# Iter-3170 loss: 15.9948
# ed in the coun remalep om anin wes, in highing and 1mped Tate cant y frolythrce loge popledin raklinc
# Iter-3180 loss: 12.8253
# ed in th Tnkedes of itiontinithy caty Tofan medecor hs ares ofrc-batby puca, caty cand Was fopl pease
# Iter-3190 loss: 11.9013
# e rediowes meationti mokedos . Ar6 lokulivinin Gs conne sareofiom anare andis venkal Japal the the so
# Iter-3200 loss: 16.4898
# e finst fristand istion liti utren the figrtalland chast mopnstu tacn. S ea io Aioaty ty niob a loth
# Iter-3210 loss: 12.1227
# ek orstronth insth percerimil. Indes preantreadestien of rctlepilxtard Thend Wil mils arcmainea, Khic
# Iter-3220 loss: 17.1261
# ecinal whitho an NiSand-din Io od antso Anth rentud ef is canst porth the GRul Eb5t ixeatcendes ofAol
# Iter-3230 loss: 12.6097
# e8 anes. Areatuty. ToAu6tectir G85% of nstirinat my anthiceand facctaenest cintrin miobel mamb the wa
# Iter-3240 loss: 16.0236
# ef ar has of chest to nsmal ped rogs rsmeit ed ixporgen. Is ofou, the aslal cofularisthe chistimnarit
# Iter-3250 loss: 13.2420
# e porlory. Sracaeatc nors meation by perse thirge nuls wirth res arcs iotttron himhivingss ar hivy. I
# Iter-3260 loss: 18.2918
# esly mpprponowo th Nheulati"cnac des wrcd roxsa thun 20ullowit kolerea, the fouldrectiondecowod Japan
# Iter-3270 loss: 18.0370
# e4 wes Erperomy vint ofon fichacan Che forl corndes ealofo Th-Panladas whitelithithe woth cltratitony
# Iter-3280 loss: 16.0756
# e porlitind Brol ofed. on parcetion "ounir Isand conftitte ntst. Trea of hivesh cofrdmparilithic ares
# Iter-3290 loss: 11.4581
# ed fins aretto of the Gl eand in ea dithenc maiban Deveand in maulithe mhip .untar onth on the 1rtinn
# Iter-3300 loss: 16.8390
# en frust. Neproleties dictored an silaromst hinteolare sh make uppen aga and Warth ce tiot innd ig an
# Iter-3310 loss: 18.1355
# e of 1s3y . of 193ty fectorlgban re the ou, thid coule iregha, the Rucsorlobal coflopF rt the ngrta i
# Iter-3320 loss: 15.4263
# es of the Sabned Tof crand is a, woin"an tinntitiwent in bint ofod Fiates Tof eopan Dy founto-keoplop
# Iter-3330 loss: 20.0080
# ered inti teront miintein wand thothe meobol eate louponper mpinind andin re tio woxt rpreniogepand o
# Iter-3340 loss: 21.4028
# el of Asored ing imsestury sliced th Gn paleedectare warc ofela, has Hakakes wes drcetiotthecetsi lov
# Iter-3350 loss: 27.4548
# ed fore thesto lobainy has wof lopen by bo bed Eas ancEmperest China esman wes refas y fed rollalilat
# Iter-3360 loss: 17.7889
# e2 The Ooban y crgodtw-inht orid noustr. of the lith it thes frestary in Cigatun Emse tol worcd in th
# Iter-3370 loss: 14.4859
# e first en thendentf copan ms andrun 98Ch in thin Eurto NnopI pexpoponane Nspepondof as periogler ast
# Iter-3380 loss: 11.2720
# ely pef urstopul trop loredsine GNoband The worid Siny 1m4in wasd the Grlaturil 1868, andat tory. I t
# Iter-3390 loss: 14.1484
# ed Sea ap poral io and ipand Istor onte par inme bint 1ot tan edlititity undtre noll. intbon wfil mye
# Iter-3400 loss: 10.9299
# ex anlyuipong(Japanain wasd chure .7, tho woridg, Kaghhs-sarly's Japan's then mame tity poreant tye o
# Iter-3410 loss: 20.9067
# e ferse mfelropiogen ma bard nf Japan is if nam in thith  as d's liliginsty coulltD rearin O8IInowa,
# Iter-3420 loss: 14.9394
# e Grestof frcaty ct-kand War host. popar askuvionton tofy pate nfrr Cfintry sity an radeinf us the at
# Iter-3430 loss: 14.0091
# e porlomith an bounins as omper arsexpecllomio-kanke parth War, coulith rs the hesicofela, hat hamal
# Iter-3440 loss: 17.2742
# el in tollomile foulatoen en the G20theconst icanoly secture divind f orlititinnce sedine fice etsiwe
# Iter-3450 loss: 10.6909
# eularisiven the wors .iof ur ansy no flompestar ha, "atal thmper anded nnla bpanolify ct frodtatiwed
# Iter-3460 loss: 17.0111
# e Inderedenwur atdina amala i. Nitateen. A tary cinuth the world's thistronlubar ceadligh th the Glce
# Iter-3470 loss: 17.5170
# e pored War Inowan is axins xfontredeind whe highic alasd and Senou, hovesevenOu, Kath percount. The
# Iter-3480 loss: 12.1453
# ex arly.20 Ty hoparae wa, sates army pen en bo purolygsor. Aitto foper and owotok. Tivacents of ane t
# Iter-3490 loss: 16.1706
# eGre and imalatin 18, iccand it cnnsud efompolana an handexvestand charestrensto and insexppppono fip
# Iter-3500 loss: 26.1716
# el fiultrro ea, ithican7the wirt on mound Nuunknku, wo, ho eroby. In usean sured itumite wor ary and
# Iter-3510 loss: 13.4125
# erog thicer anl wintserentof omyes th the thite of urea 20ited of itetn tse Warlo u7th revidese me bo
# Iter-3520 loss: 17.5359
# e-sares if 1ot ia aite Wor Olital count. The "anns fficata des derac towe Wertiry ante tory Astivent
# Iter-3530 loss: 13.1972
# el of Worllcbunty 17th cand ans oruct DearolItiod ithe the meubxlint an sifan ma and ilstony istr the
# Iter-3540 loss: 17.3559
# ef lopacatal whic, imintiol eining andio andin arlith the mporlobure Chingec nosth ccoplorldmar, ih c
# Iter-3550 loss: 25.9130
# e Hogesula. Coutato noryo, thic areod efon percand if country it 1igit wins f ditory wa, s fecolat ex
# Iter-3560 loss: 21.6070
# ed of the lation mRureatisn. Ianand chare Japanna tha ai lasi. hivesp ealigu and in ates anccanestart
# Iter-3570 loss: 13.9631
# e rinted of frymbyn mal hassmaf inta igit Sndexcolaluts cerlomilate Nasand is licodentulite living li
# Iter-3580 loss: 14.4760
# eKorea and in a. Japan sice arth tarly Br hachta enCting and parcCowort oxsistrongula ar with in Chin
# Iter-3590 loss: 10.6032
# ed War soulargbotean whsive lame Wirg on tho F7orlll-ofod, Japannsthe aimed in the solcedictuen. Ao a
# Iter-3600 loss: 14.1157
# ed of the wate ch an th ccuntry Sing stlrofrcearesived as trenstxte ndendrpendice heseromeivinga an l
# Iter-3610 loss: 9.7286
# e Wored Taty 1868, malaratio hich and cunily Und the foullaristh ictarlyghef urea by penied of isolar
# Iter-3620 loss: 10.1488
# ecincedsivese fe Japan's nath asladest roflares, thithe ailed ioted loggettin thiv largectary catietw
# Iter-3630 loss: 14.1122
# e figsture soularisex ananediinn", usia tios ompir ass of Un, (ha arly wind malal melitan omcitint in
# Iter-3640 loss: 21.1864
# e; War omplety ul Countr inat cicand if comeltitcenombiveans aa an Japan, it himares ofeicat cinata d
# Iter-3650 loss: 21.1190
# ed in th lartent ofof cbe the warl chala, wand chakod mhive ald bendon the crtetof in the aal micanan
# Iter-3660 loss: 10.0284
# ed in th l. puliran to copan ts antu ingEas ancsoana asmalain 1h4m anle:pinge Il of. Nopata westicuni
# Iter-3670 loss: 9.9320
# en ures uper Nitsencofed poth ar Emprror and he striter. Itwece the worgd the Guvean" and tura cald o
# Iter-3680 loss: 11.1693
# e War of Ja.an, thh satesul the woresl pirtorlaggorpan in hightand ot molateon. Achartithenccouter To
# Iter-3690 loss: 9.5874
# es of mbilalcin the whort-l-kkkiod Sinke:-sofed, Saa an hipand Wante peoper as .fota an hasicac Japan
# Iter-3700 loss: 13.1553
# erecflom caber and of ghicalalisa, molalita ic biCg oxth pargest reditured Noty teron. J'panare thots
# Iter-3710 loss: 18.5060
# e tiotoC ofed Nchtimnliphoplalicad ompirinl1 Imionty in larisnt oflictbo tory Btat-mellioll.worlarlyi
# Iter-3720 loss: 11.5048
# epercenturla. of angin ande who  arlingeand fhast 20okulle 1rokowit hicetare whe P8v5Slinoly se tiote
# Iter-3730 loss: 11.5920
# e pored War I. Japan is a mombe pedisa a Upining ins  ulitolll and iflan se forl mientury d. As arand
# Iter-3740 loss: 11.3411
# es of the couner mase noby pont redofod tyore thor 94. of Ok35 I5kiol of itilatio tint olitiry, th  c
# Iter-3750 loss: 12.3329
# ely. The cand of rapar wed be tolledila, is andit enf1dsteco estuty no mint in male of NiSpen lowiowe
# Iter-3760 loss: 16.7076
# e wed revedent of is pecctorengu tste to tertedintr the nome eatio Gd Ninntan ande ward chusat melito
# Iter-3770 loss: 13.4998
# ed firs ares tired in tes ansi parcinheccongN ha and Iloof.dA the fourtrly inth ternalithe th cepredi
# Iter-3780 loss: 13.2914
# e fros the os probth lats ct the tores a7 histolythith cerid 17ir owan, the tored bargest ertintre fi
# Iter-3790 loss: 12.5442
# ed of the Gall ghst ond . oppernaty ia Okghic and iagcound intnd inathe Thky co fort roked The coulic
# Iter-3800 loss: 19.0372
# e world's largest metropoe topan andr efon, Sha and of 6, Kohesarlichastad exth parucnand Oa6,athe wh
# Iter-3810 loss: 13.6748
# ex and oupninI Wivg cto n raronth icht an huponded in Gistronod Wores. F prthin. I fictryns wfricatel
# Iter-3820 loss: 22.7309
# ...
# Iter-8740 loss: 6.4149
# ed first in the numbe porle firy in ty and in the County-lowedss mantinied itomeinteind Af rst rodigg
# Iter-8750 loss: 5.9402
# ed ficht as preand of Japan's 185, ha andEiclaig at m inand, anuna, winsearlycand arcetil eomed Wnon;
# Iter-8760 loss: 4.5637
# ery Br Coine, war ea, China, wad iapes in the Global in aa, Houknd's landea, mbal wor Elithe ea ty no
# Iter-8770 loss: 7.6450
# er and Winter Olympic Gauts. Japan has Rchast miob Nnpen lobeso fhas whcliccthest vefrolst oxpponter
# Iter-8780 loss: 3.7982
# ed first in the number of Nobec laudext meandey Toky cote Wa denclarey h7 hisican mailan Komapapancea
# Iter-8790 loss: 7.0438
# expaclicinsexsk tory. As aresttyo fice ind rulito, nathe ward cogunt 2018ty nn thi anom in Che nagd c
# Iter-8800 loss: 5.4798
# eNearly. fourltrenin. Rl otiod in colltorll1mione. AP arlyis. Thurco-Japand in the sory Asian e melio
# Iter-8810 loss: 7.1991
# ed in the wand Warg 1ti cenmeis .an the aad rinity of Tailnc arly. The espuralo focmpareec-pand Shako
# Iter-8820 loss: 10.3555
# e boulor ay y of Ol6 ismby pevilate Seao-sokfkiotetyepent Reslity in daricn, stry ht dirtowor O bote
# Iter-8830 loss: 5.5927
# ed in the warl chenouga aral whicealiginithic and itented fo sicane then of the nas  of1lty in 9ighec
# Iter-8840 loss: 5.0298
# e wod rulid in the Global es pheptounaryIN 3inh canded ibula ligs morlithe wan kulicl ess rofid boula
# Iter-8850 loss: 9.6748
# e of 6, Japan") is an illinilithe marth. T"AA the cexporland of as ind Huend's ianth cennd indun, Ind
# Iter-8860 loss: 8.4872
# e forst tof o, the G2s andeity un limerext hixas whist country in Chi engu, ardI tho and urulowom lai
# Iter-8870 loss: 3.5379
# ed first in the number of Nored Paacea. Japan wer surind ilslopor an the nots ompre the wits Worthe F
# Iter-8880 loss: 7.7410
# er and Winter Olympic Games.
# . Japan in tas anct. en unured Palos ic the couled ba an'pmeind ith an t
# Iter-8890 loss: 3.4429
# ed first in the woulde. The cenpericturea, in th as the Risstoun rc nomal in Aemporiedea, med redsily
# Iter-8900 loss: 5.8005
# exte toredes of Nibate novuna sio ad Chirn the G7o nalg, 1ste wntthe woth lfrumete ne sorcowec tar es
# Iter-8910 loss: 5.5621
# e dintrof in the caulec tyea. Theane mellity isul riintroI 9hict onit. The nag tol cilat in tato Nakk
# Iter-8920 loss: 14.7510
# e wod rulid in the Glorags of Hheanch indtiry wond Warthe wand afey Asiwe Ch raChi and Stakiog flilit
# Iter-8930 loss: 10.6767
# ed War soulalion ed Aned no the War s. irlar med inflima lighertulall ofita, at lowai hares and1twel
# Iter-8940 loss: 9.8532
# ed Sta ap-Japan wes omaititcenceled inuno Warly pso tare th mest tinn aogeaten ar ofolstareech. miob
# Iter-8950 loss: 3.3829
# er of 1937 hapana, Garla. The of gionde ed nan e porilitigint esd itrondm.on the nokid litowon Japan
# Iter-8960 loss: 8.8579
# er of 1937 malandect. Inin eontert contr lhe torld ant in otirn. Nepend rente nf urpare chun". Japan
# Iter-8970 loss: 3.4745
# e world's largest metropolitan area with over 35 million redsofy s alart wint ofeit meiteanevun n fis
# Iter-8980 loss: 14.2138
# er and Winter Olympic Games.
# . Japan in tas andth  esaire io towed batt 2 uNtarne the na th cowtir as
# Iter-8990 loss: 5.8143
# expaclaringhan and anula asun wisto no the poritso Ind rmpenturigglite f rmper in Nighet on minb and
# Iter-9000 loss: 10.4061
# er and Wint oullo eret or. ,Tith ar porev of nse forst ered in the couter ceutori", in h mhivenowfo J
# Iter-9010 loss: 7.3850
# e porlicilumok'ind-sand ofrea and its owed Japan in te-parisha foureas ingestie hist of asd nts narl
# Iter-9020 loss: 6.0925
# ered into a long period of isolation in the early 17th centurig9Sna and ofillhic toknd sf-conte pevin
# Iter-9030 loss: 9.4127
# e fercolakiont ieanory anty s virilcbIndeve ul tory. TE Deatorigunat towext the bomulat in han1ea low
# Iter-9040 loss: 10.3437
# erel ofed, the soultry ihok Cbund ctbinevwol gilithe coureasire hichlccont. 2runallEmperowit hinst mo
# Iter-9050 loss: 3.6404
# e first wollrpaital wsf ioped by ponced Index. laporth WAstal ofithe mbin akbin Eoulare cauted bx asl
# Iter-9060 loss: 5.1799
# e forst toby wod pexplrtarigh. War sobnd cogittred inth cealogsopparese frar aslionthy boul ligina wo
# Iter-9070 loss: 3.3734
# ed first ir the nmmkionof countrotyitho aod foult. Inwecepof The cann dst thh mppepornglotoentitaed c
# Iter-9080 loss: 11.9869
# ed first in the number of Nobel laureates of chese tory Ctony suruthe Rigsom") is a totliclarlymind f
# Iter-9090 loss: 3.0971
# e fors urced in the ward coght tury cunned find af lsty untro hertolal citand contod Wirlh in the Glc
# Iter-9100 loss: 10.0280
# ed country in the wits y pr poratal io thulas wed suparly of The eagbed as ivenar as irtas woct. the
# Iter-9110 loss: 3.3224
# ery Br iso Worllignda, hmest ofithe nog tod Eas rncearly 12d Japan tiry Asia by surit. Tof nmai wod P
# Iter-9120 loss: 3.4387
# e Worl billoboltrty irunig il find wnd supal wed redes cr Oisind f orlir.vined ipin re Jana, wod Etse
# Iter-9130 loss: 5.8274
# eted forth plobld's renkind in the sourto une2, , ind1, ty nnest pedpic liguter Inteo and porateon ul
# Iter-9140 loss: 3.2963
# er and Winter Olympic Games.
# . Japan in tomeeatin a lidectyes tfel pprritor wolid and Homath on kabis
# Iter-9150 loss: 4.9548
# e wedd tfre mpir OECpmant tesexce torinility of and 1, an bicenne mailan 1mtic and perconked mion onl
# Iter-9160 loss: 5.2739
# e Japan was incabulats iretit licu,aglic ariha, wath ceast mornd SJapan's dintrel maintal eatioghit h
# Iter-9170 loss: 3.4328
# e world's largest metropolitan area with over 35 million residents and the Emperor and the coured the
# Iter-9180 loss: 5.1122
# ered into a long period of isolation in the early st. Jaean wste ffrctuked Inted Wen deutal wett ond
# Iter-9190 loss: 12.8890
# ed first in the number of Nobel lauperteving is as impenind aint imsiran Infexofe turas ande whith cp
# Iter-9200 loss: 4.6713
# ery Br Cowy. The coufopat te onked pond pores tee world ingCh realde flcitate Ehs- unber no the calis
# Iter-9210 loss: 3.1507
# e toruds the EAsial Asila-keigoC wan Empexpir and the world's ifudth llcofe, T kane whigh rlain")nim
# Iter-9220 loss: 3.2678
# ed in the wand The nogutat cenco Ind of Japanese Wan ar and in torns. The copJapaldpo preterne the Em
# Iter-9230 loss: 3.1677
# evered in os esornd in the world's largest meintryn whul lfras meuliog pios. Ar alored andy Deacon th
# Iter-9240 loss: 9.2009
# er and ofrom and Standa, whic lithe tobes an hamain aiwed an hapan tho worg itwed Japan is and ianaic
# Iter-9250 loss: 7.4955
# e world's largest mbintron Easimes an the ados wfol mpkrons arunst molrorithes veredoflich anest. nat
# Iter-9260 loss: 7.1634
# e world's largest metropoliga a at'ras intexparcea, bandec, mby 20asuncEas and the hostrrtailed is as
# Iter-9270 loss: 3.2083
# expaclare mhe porulithicliontex whfres lfessutaricinea wed ionth the wort wond Japan wardecthor count
# Iter-9280 loss: 7.6662
# e Peadent of rotityeng Aslal cofrlopt it tins Wfresl ferereake con maulaty of cticed com eted ivingr
# Iter-9290 loss: 8.3217
# ery Br Co6 itbin ay hingwal d ind rill. Is andin aiunarcmonity woth lapmeleilininu aroin boural thest
# Iter-9300 loss: 5.8430
# e Peleoper as hison Japan in ty nopala a cedicte nfrlallecttrearly and tho apper as sapor Olhy westic
# Iter-9310 loss: 7.8111
# ed ficht as uraglitne wos d's thes 1mtlipirins. In or and ofula, hy ssulexpmelednof. utprreciged fors
# Iter-9320 loss: 3.3712
# es of the ncabed Wd nor ainst cofntte eitivin tilo wat  ofro, papana an's inm16 The and rurog Wir lec
# Iter-9330 loss: 3.6095
# e fors Wered cease counter aint. In endin ry ison. The coustrytit exet of in porelatie fors alasivice
# Iter-9340 loss: 8.1846
# es of the ceabin O, molilion, imilary un loupor e7 the world's Warmy bu nd's Indenwd prec assurcltein
# Iter-9350 loss: 6.9123
# e of 1, 3te nnnter dobyd coullrDby and percokeopor an of orely tno westre thit. Tof omeit by pornd 18
# Iter-9360 loss: 9.6430
# ed first in the number of Nobel laureates of any country in Asia. Japan is ranked first in the Countr
# Iter-9370 loss: 13.3498
# e wod Horud, in the Fitst forto-nalis. Tof Olcatsen of the watd nf uns and the GE pan ed Nater Olgety
# Iter-9380 loss: 6.0780
# e wiod rir niny and copropat oi inely asd of omper coutar wit wind the wouth. The G7ertceunod hinhe m
# Iter-9390 loss: 7.5044
# e-s.vere tion ompre trets  of the ecSnaed RIgstaiont in the Countor ogitivides. o t. trennals wort li
# Iter-9400 loss: 6.0762
# ed Wir sura de rof ponot Dy arop4. Japan is a stroened Unith caple pore ligith the Emperoc. ncteriant
# Iter-9410 loss: 8.4521
# ed coutht to udsires al ten thir Collower Japan tas chas Empeasirga the Risstre of the Gl an Counog h
# Iter-9420 loss: 8.8453
# ed first in the nmail o8. Tho Seate conomy ty Dalainengulateo hich and rofidan, the wotl cirntrIndec
# Iter-9430 loss: 6.4582
# e world's largest metropolitan area with over 35 million residents and the world's largest urban aggl
# Iter-9440 loss: 6.8493
# e wint ofobur aise at the nthe fo tred first woftrupal is atonowe deator of in the wirg strcobet wrig
# Iter-9450 loss: 3.1806
# er in tionwer llofoont Iibeteco of ur lnond-sunwed proan cupar in the wonld bad indserty tyd Eas mett
# Iter-9460 loss: 6.6714
# ed first in the number of Nobel laureates of atey wost rictened d orth tnr hestor ealit in th and Sea
# Iter-9470 loss: 3.1865
# e Pevero mint orlithendesif Nithe anluman. an maullowed pedicalis virtion in the nast of counesR Wand
# Iter-9480 loss: 3.2247
# ered into a long period of isolation in the early 17th centurced inud ard itsan of the sioted bf the
# Iter-9490 loss: 7.5214
# e world's largest metropolitan arta Wor heatilitint orilivinty Tolyc. Sha asor. itois and Spa andgiti
# Iter-9500 loss: 9.4827
# e toros. The cearoontronest-rentin ef in landexty and is endmilared a deiniry athi Japan the Riss rog
# Iter-9510 loss: 13.6549
# ed first io the nsured foust mailituent. Japan was enwesimeteny ay ir hostor anais and the OECDO Ocba
# Iter-9520 loss: 7.8811
# er of 1937 halaine war wctlicland pora, Napares. Tio of enty in nder ol the Ceitory 9ogurnd SiatoCn.
# Iter-9530 loss: 9.7842
# e wint of Japan, itea ar Indexron ane1 heland Sta and ionth s oragly sed forme rente Jfean "s ancturi
# Iter-9540 loss: 3.2166
# ercand fights prontmy ne coreatst cofrtrtio aidine China, is ardictiot in the ward iggat Ded ofod app
# Iter-9550 loss: 7.8721
# es of Nive2e elod porlebolt the world iathe wand War of land band chgmest melopolygloulabi es enstina
# Iter-9560 loss: 3.2272
# er and Winter Olympic Gamese
# . liAstan tottirunt ce io Isden liconturthe wiun 1,tinced obl picdtins a
# Iter-9570 loss: 10.2862
# ed first in the number of ,bit  narty 2n ma no's iontury wind ited it tionwered ange tareas tein by t
# Iter-9580 loss: 4.9319
# er and Winter Olyt, the world Wir Od Snand conth te tnop limand ne edar the Wornd Won e pereng t oeri
# Iter-9590 loss: 7.0493
# er and Wint oJapincbas an Eiso nte nict. In exe atdin Okusaity in lomeice Emsial care tity wan  foumH
# Iter-9600 loss: 3.0577
# ed first in the number of Nobel laureates of any country in Asia. Japan is ranked first in the Counto
# Iter-9610 loss: 9.9020
# ed first in the number of loAsea ard itelngvite Is and conse Japan porea "h as the dfrthe estunive in
# Iter-9620 loss: 14.1006
# ered into a long piredin micena dithe was wan rupal witt ond Werad in the Emmelerenweo sepereat o fro
# Iter-9630 loss: 12.1379
# ed first ir the nmmildente un th on rbe toA the Count.2 Tye world's mand rugan, 17t moin wofd cates w
# Iter-9640 loss: 6.9551
# expaclare the of'Jacan, th the nas of the OcSaa, wande ward the Emokro stred isoles The or poppritsex
# Iter-9650 loss: 8.9166
# emel in the nomulity is larioglit indarghes of Jamanesy. Nopatt onorounto Ay Werened f irlalReowad ry
# Iter-9660 loss: 10.5432
# e world's largest metropolitan area with over 35 million resident meint in limint and Human") is efti
# Iter-9670 loss: 3.0673
# ed in the wand The nomina isd itisivengm ia es ivenevwin  iost. the nas  ofllthe th testal thit re ti
# Iter-9680 loss: 2.8904
# evelof inteare worg stres intirtan wor mballcegltor hian, Indent in tountro enCeins of tienne imea, w
# Iter-9690 loss: 3.1461
# ed ficht as preand of 6veand anunal conntoryene fisitaticatelt inhtupal is lapon poro apal wes the su
# Iter-9700 loss: 2.8993
# erea lo younteryeso fodmprrakain. f orth ponumban koullou, thh caletained if nte rented rf asiar of i
# Iter-9710 loss: 6.3054
# e wored llunituty by usul ompinine alopola. The country historyec and Warth parc ahemeice an e lictey
# Iter-9720 loss: 14.1502
# e ficctung wing properleid cighe torlmburty gh mbol Japan, atemnat makan wed resicltempitity untry le
# Iter-9730 loss: 3.1900
# ered inte perlare shend oulallromy ancha and in thy Worth ty Asowad Japan's Eusextcona, th kas im isi
# Iter-9740 loss: 5.3996
# ery Br Cod itbin cand comulitivinithi main aigetan has mecelrtaturnwes ir fish porumat, the worlhC2 r
# Iter-9750 loss: 5.6143
# ed first in the number of Nobel laureates of any country in Asia. Japan is ranked first in the Firlto
# Iter-9760 loss: 3.2193
# e fors Wered ceare ipente inan, malic.ns treacand it tio wirth in the Oc"San, il tith proped iluted e
# Iter-9770 loss: 9.2140
# ered into a long period of isolation in the early 17th centuryes.. Titer in the Seagdccnnth rectony A
# Iter-9780 loss: 8.2995
# e torlom isita wendicitith and the Empino teren 1mainan mearogntity ind urled The eopeted The dornd s
# Iter-9790 loss: 7.8513
# ed fors apand is matekene Is tonto para ceunory indty who udbes. Totoky, wh ch rediligd War 98. mbor
# Iter-9800 loss: 5.4910
# er of 6,8h7 arlagd.d, Japac ios the diparo atwed itan uc tomor, the on. oreas, the Eapeser akain 1ete
# Iter-9810 loss: 10.5967
# ed first in the number of Nobel mailityky 1Atoled ar mpinwerldganty sed reses tt the ngetre nort licl
# Iter-9820 loss: 7.8659
# elof inter onitureas in the dirst lowar pore whit Japanopal mapar wed rupen in tak io the ast 1rcotee
# Iter-9830 loss: 10.1407
# ed first in the number of Nobel lauleaper Odast word stran yutol ented nf the nati nf s onthe Worg lt
# Iter-9840 loss: 6.5751
# ed first in the number of Nobel laureates of any country in Asian c inse ro usfent ofed ty tspal mipr
# Iter-9850 loss: 8.5551
# er and Winter Olympic Games.
# . Jaea ent hichapar asor. The ciastrot in. I flre coket. n pares. werl t
# Iter-9860 loss: 10.2614
# e world's largest meth tf nomper ess ffrlationte tan wos mecll of Ni'nden ange tas andit indarty dfou
# Iter-9870 loss: 3.4917
# ed Sta ap Japan is a th tul thith  cogatupy. Th uest rcltef of the Grlain, has ad itlin by ponter an
# Iter-9880 loss: 5.8913
# ed first in the number of Nobel laureates of o22 haslowso prresed font tural Divonaple ndeted forth a
# Iter-9890 loss: 2.9275
# e world's largest metropolitaian taricl im the nas rolidatety wasd thet o ol miobr. ly uns ofol mobnd
# Iter-9900 loss: 3.2489
# ed country in the witi nf Nes lfgs ralye woll lire orithe Asia., A Taleecila. Japan histhe as inuth n
# Iter-9910 loss: 5.9632
# er and Winter Olympic laposara. Tovec po fod tete pore four 9hulange nessow othe 1rth nar hat o parin
# Iter-9920 loss: 11.7632
# ed fors apalitivinas whith c gimts peetor O9w5s mioneowUrine1 Krectand ighat Co notulivithe Rursove n
# Iter-9930 loss: 6.4247
# er. The ciuntr ieatiny ward iteCtineal coOl. 1st revenwes Rens vertiealicina at inect oi houNia ,ist.
# Iter-9940 loss: 7.0771
# evened f ist tren uping s pr'p tioted The donto portertering is lf isppron Glucanded lof istar hesicc
# Iter-9950 loss: 5.4694
# ed first in the Wurly lomfob ea3e mbaa wod lofil's lata nted nind it the purnglRuged, micl aros fored
# Iter-9960 loss: 11.2489
# e world's largest metropol tof torla, woth largest and frrst weitiry of. Toty by ss f prmaired atiena
# Iter-9970 loss: 12.8611
# e porimal ey Asoand theghupallImiea an Japan was sapal tosto paited ar Niontron an of liviniman insta
# Iter-9980 loss: 9.0895
# e world's largest metropolitan area with over 35 million residents and the world's largest Areanicin
# Iter-9990 loss: 10.1881
# er and Winter Olympic Games.
# . Japan in tasa at ho9tonn larlycty in the woby b then of Janan, the war
# Iter-10000 loss: 13.3601
# ed first in the number of Nobel laureates of any country in Asia. Japan is ranked first in the Countr
