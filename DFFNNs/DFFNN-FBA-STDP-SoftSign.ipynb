# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# y_test.shape, y_val.shape, y_train.shape
# X_train.shape, X_train.dtype, X_val.shape, X_val.dtype, X_test.shape, X_test.dtype
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # number of layers or depth
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        # The adaptive/learnable/updatable random feedforward
        self.model = []
        self.W_fixed = []
        self.grads = []
        self.ys_prev = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})
        # Previous output layer
        self.ys_prev.append(0.0)

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad_L = []
        for _ in range(L):
            grad_L.append({key: np.zeros_like(val) for key, val in self.model[1][0].items()})
        self.grads.append(grad_L)
        # Previous output layer
        ys_prev_L = []
        for _ in range(L):
            ys_prev_L.append(0.0)
        self.ys_prev.append(ys_prev_L)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Outout layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        # Previous output layer
        self.ys_prev.append(0.0)
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
        # dX = dout @ W.T # Backprop
        dX = dout @ W_fixed.T # fb alignment

        return dX, dW, db

    def train_forward(self, X, train):
        caches, ys = [], []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
#         y, _ = l.selu_forward(X=y)
#         y = l.elu_fwd(X=y)
#         y = l.sigmoid(X=y)
#         y = np.tanh(y)
#         a, b = 1.7519, 2/3
#         y = a * np.tanh(b*y) # LeCun Tanh
#         y = np.arctan(y)
        y = y / (1 + np.absolute(y)) # softsign
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[0]
        X = y.copy() # pass to the next layer
        
        # Hidden layers
        fc_caches, ys_L, do_caches = [], [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
#             y, _ = l.selu_forward(X=y)
#             y = l.elu_fwd(X=y)
#             y = l.sigmoid(X=y)
#             y = np.tanh(y)
#             a, b = 1.7519, 2/3
#             y = a * np.tanh(b*y)
#             y = np.arctan(y)
            y = y / (1 + np.absolute(y)) # softsign
            fc_caches.append(fc_cache)
            ys_L.append(y) # ys[1][layer]
            X = y.copy() # pass to next layer
        if train:
            caches.append(fc_caches) # caches[1]
        ys.append(ys_L) # ys[1]            
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[2]

        return ys, caches # for backpropating the error

    def loss_function(self, y, y_train):
        
        loss = cross_entropy(y, y_train) # softmax is included
        dy = dcross_entropy(y, y_train) # dsoftmax is included
        
        return loss, dy
        
    def train_backward(self, dy, caches):
        grads = self.grads # initialized by Zero in every iteration/epoch
        ys, ys_prev = self.ys, self.ys_prev # temporal diff instead of differentiable function
        
        # Output layer
        fc_cache = caches[2]
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
        grads[2]['W'] = dW
        grads[2]['b'] = db

        # Hidden layer
        fc_caches = caches[1]
        for layer in reversed(range(self.L)):
            dy *= ys[1][layer] - ys_prev[1][layer] # temporal diff instead of differentiable function
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
            grads[1][layer]['W'] = dW
            grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache = caches[0]
        dy *= ys[0] - ys_prev[0] # temporal diff instead of differentiable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        grads[0]['W'] = dW
        grads[0]['b'] = db

        return dX, grads
    
    def test(self, X):
        ys_logit, _ = self.train_forward(X, train=False)
        y_logit = ys_logit[2] # last layer
        
        # if self.mode == 'classification':
        y_prob = l.softmax(y_logit) # for accuracy == acc
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_logit
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            self.ys, caches = self.train_forward(X_mini, train=True)
            loss, dy = self.loss_function(self.ys[2], y_mini)
            _, grads = self.train_backward(dy, caches) # self.ys_prev is used here for dfunc/ diff
            self.ys_prev = self.ys # for next iteration or epoch
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in grads[0].keys():
                self.model[0][key] -= alpha * grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * grads[1][layer][key]

            # Update the model for output layer
            for key in grads[2].keys():
                self.model[2][key] -= alpha * grads[2][key]
                
            # Validate the updated model
            y_pred, y_logit = self.test(X_val)
            valid_loss, _ = self.loss_function(y_logit, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val) # confusion matrix
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_logit = nn.test(X_test)
        loss, _ = self.loss_function(y_logit, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 10000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 50 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 100 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 2 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-100 train loss: 2.3101 valid loss: 2.3068, valid accuracy: 0.1024
# Iter-200 train loss: 2.3123 valid loss: 2.3064, valid accuracy: 0.1036
# Iter-300 train loss: 2.3127 valid loss: 2.3061, valid accuracy: 0.1052
# Iter-400 train loss: 2.3149 valid loss: 2.3057, valid accuracy: 0.1054
# Iter-500 train loss: 2.2990 valid loss: 2.3053, valid accuracy: 0.1068
# Iter-600 train loss: 2.3035 valid loss: 2.3049, valid accuracy: 0.1068
# Iter-700 train loss: 2.3064 valid loss: 2.3045, valid accuracy: 0.1082
# Iter-800 train loss: 2.2995 valid loss: 2.3041, valid accuracy: 0.1088
# Iter-900 train loss: 2.3148 valid loss: 2.3037, valid accuracy: 0.1128
# Iter-1000 train loss: 2.3045 valid loss: 2.3033, valid accuracy: 0.1142
# Iter-1100 train loss: 2.2969 valid loss: 2.3029, valid accuracy: 0.1156
# Iter-1200 train loss: 2.3123 valid loss: 2.3026, valid accuracy: 0.1162
# Iter-1300 train loss: 2.2973 valid loss: 2.3022, valid accuracy: 0.1174
# Iter-1400 train loss: 2.2910 valid loss: 2.3018, valid accuracy: 0.1182
# Iter-1500 train loss: 2.2963 valid loss: 2.3014, valid accuracy: 0.1194
# Iter-1600 train loss: 2.3042 valid loss: 2.3010, valid accuracy: 0.1212
# Iter-1700 train loss: 2.2898 valid loss: 2.3007, valid accuracy: 0.1220
# Iter-1800 train loss: 2.2916 valid loss: 2.3003, valid accuracy: 0.1234
# Iter-1900 train loss: 2.3078 valid loss: 2.2999, valid accuracy: 0.1246
# Iter-2000 train loss: 2.2906 valid loss: 2.2995, valid accuracy: 0.1260
# Iter-2100 train loss: 2.3104 valid loss: 2.2992, valid accuracy: 0.1274
# Iter-2200 train loss: 2.2951 valid loss: 2.2988, valid accuracy: 0.1284
# Iter-2300 train loss: 2.2979 valid loss: 2.2984, valid accuracy: 0.1298
# Iter-2400 train loss: 2.3087 valid loss: 2.2980, valid accuracy: 0.1302
# Iter-2500 train loss: 2.2991 valid loss: 2.2977, valid accuracy: 0.1312
# Iter-2600 train loss: 2.3055 valid loss: 2.2973, valid accuracy: 0.1344
# Iter-2700 train loss: 2.2946 valid loss: 2.2969, valid accuracy: 0.1354
# Iter-2800 train loss: 2.3012 valid loss: 2.2965, valid accuracy: 0.1364
# Iter-2900 train loss: 2.2940 valid loss: 2.2962, valid accuracy: 0.1386
# Iter-3000 train loss: 2.3008 valid loss: 2.2958, valid accuracy: 0.1392
# Iter-3100 train loss: 2.2930 valid loss: 2.2954, valid accuracy: 0.1404
# Iter-3200 train loss: 2.2922 valid loss: 2.2950, valid accuracy: 0.1420
# Iter-3300 train loss: 2.3013 valid loss: 2.2947, valid accuracy: 0.1438
# Iter-3400 train loss: 2.3097 valid loss: 2.2943, valid accuracy: 0.1446
# Iter-3500 train loss: 2.2914 valid loss: 2.2940, valid accuracy: 0.1460
# Iter-3600 train loss: 2.2779 valid loss: 2.2936, valid accuracy: 0.1472
# Iter-3700 train loss: 2.3099 valid loss: 2.2932, valid accuracy: 0.1486
# Iter-3800 train loss: 2.3015 valid loss: 2.2928, valid accuracy: 0.1506
# Iter-3900 train loss: 2.2766 valid loss: 2.2925, valid accuracy: 0.1520
# Iter-4000 train loss: 2.2888 valid loss: 2.2921, valid accuracy: 0.1534
# Iter-4100 train loss: 2.2954 valid loss: 2.2917, valid accuracy: 0.1552
# Iter-4200 train loss: 2.2774 valid loss: 2.2913, valid accuracy: 0.1558
# Iter-4300 train loss: 2.2903 valid loss: 2.2910, valid accuracy: 0.1574
# Iter-4400 train loss: 2.2914 valid loss: 2.2906, valid accuracy: 0.1572
# Iter-4500 train loss: 2.3023 valid loss: 2.2902, valid accuracy: 0.1592
# Iter-4600 train loss: 2.2787 valid loss: 2.2898, valid accuracy: 0.1618
# Iter-4700 train loss: 2.2899 valid loss: 2.2895, valid accuracy: 0.1628
# Iter-4800 train loss: 2.2844 valid loss: 2.2891, valid accuracy: 0.1640
# Iter-4900 train loss: 2.2879 valid loss: 2.2887, valid accuracy: 0.1654
# Iter-5000 train loss: 2.2878 valid loss: 2.2884, valid accuracy: 0.1662
# Iter-5100 train loss: 2.2855 valid loss: 2.2880, valid accuracy: 0.1676
# Iter-5200 train loss: 2.2883 valid loss: 2.2876, valid accuracy: 0.1690
# Iter-5300 train loss: 2.2830 valid loss: 2.2873, valid accuracy: 0.1698
# Iter-5400 train loss: 2.2972 valid loss: 2.2869, valid accuracy: 0.1720
# Iter-5500 train loss: 2.2956 valid loss: 2.2866, valid accuracy: 0.1726
# Iter-5600 train loss: 2.2796 valid loss: 2.2862, valid accuracy: 0.1728
# Iter-5700 train loss: 2.2916 valid loss: 2.2859, valid accuracy: 0.1732
# Iter-5800 train loss: 2.2787 valid loss: 2.2855, valid accuracy: 0.1750
# Iter-5900 train loss: 2.2997 valid loss: 2.2852, valid accuracy: 0.1762
# Iter-6000 train loss: 2.2909 valid loss: 2.2848, valid accuracy: 0.1784
# Iter-6100 train loss: 2.3012 valid loss: 2.2844, valid accuracy: 0.1794
# Iter-6200 train loss: 2.2718 valid loss: 2.2841, valid accuracy: 0.1802
# Iter-6300 train loss: 2.2839 valid loss: 2.2837, valid accuracy: 0.1812
# Iter-6400 train loss: 2.2870 valid loss: 2.2834, valid accuracy: 0.1822
# Iter-6500 train loss: 2.2944 valid loss: 2.2830, valid accuracy: 0.1828
# Iter-6600 train loss: 2.2744 valid loss: 2.2826, valid accuracy: 0.1836
# Iter-6700 train loss: 2.2898 valid loss: 2.2823, valid accuracy: 0.1846
# Iter-6800 train loss: 2.2771 valid loss: 2.2819, valid accuracy: 0.1856
# Iter-6900 train loss: 2.2765 valid loss: 2.2816, valid accuracy: 0.1868
# Iter-7000 train loss: 2.2915 valid loss: 2.2812, valid accuracy: 0.1876
# Iter-7100 train loss: 2.2808 valid loss: 2.2809, valid accuracy: 0.1890
# Iter-7200 train loss: 2.2603 valid loss: 2.2805, valid accuracy: 0.1908
# Iter-7300 train loss: 2.2787 valid loss: 2.2801, valid accuracy: 0.1916
# Iter-7400 train loss: 2.2684 valid loss: 2.2798, valid accuracy: 0.1924
# Iter-7500 train loss: 2.2641 valid loss: 2.2794, valid accuracy: 0.1940
# Iter-7600 train loss: 2.3045 valid loss: 2.2791, valid accuracy: 0.1946
# Iter-7700 train loss: 2.3009 valid loss: 2.2787, valid accuracy: 0.1962
# Iter-7800 train loss: 2.2896 valid loss: 2.2784, valid accuracy: 0.1968
# Iter-7900 train loss: 2.2806 valid loss: 2.2780, valid accuracy: 0.1984
# Iter-8000 train loss: 2.2737 valid loss: 2.2777, valid accuracy: 0.1988
# Iter-8100 train loss: 2.2916 valid loss: 2.2774, valid accuracy: 0.2012
# Iter-8200 train loss: 2.2839 valid loss: 2.2770, valid accuracy: 0.2012
# Iter-8300 train loss: 2.2735 valid loss: 2.2766, valid accuracy: 0.2034
# Iter-8400 train loss: 2.2844 valid loss: 2.2763, valid accuracy: 0.2040
# Iter-8500 train loss: 2.2880 valid loss: 2.2759, valid accuracy: 0.2054
# Iter-8600 train loss: 2.2862 valid loss: 2.2756, valid accuracy: 0.2066
# Iter-8700 train loss: 2.2676 valid loss: 2.2752, valid accuracy: 0.2088
# Iter-8800 train loss: 2.2766 valid loss: 2.2749, valid accuracy: 0.2106
# Iter-8900 train loss: 2.2940 valid loss: 2.2745, valid accuracy: 0.2128
# Iter-9000 train loss: 2.2684 valid loss: 2.2742, valid accuracy: 0.2132
# Iter-9100 train loss: 2.2732 valid loss: 2.2739, valid accuracy: 0.2140
# Iter-9200 train loss: 2.2598 valid loss: 2.2735, valid accuracy: 0.2150
# Iter-9300 train loss: 2.2785 valid loss: 2.2732, valid accuracy: 0.2156
# Iter-9400 train loss: 2.2661 valid loss: 2.2728, valid accuracy: 0.2178
# Iter-9500 train loss: 2.2837 valid loss: 2.2725, valid accuracy: 0.2182
# Iter-9600 train loss: 2.2827 valid loss: 2.2721, valid accuracy: 0.2190
# Iter-9700 train loss: 2.2474 valid loss: 2.2718, valid accuracy: 0.2208
# Iter-9800 train loss: 2.2716 valid loss: 2.2714, valid accuracy: 0.2224
# Iter-9900 train loss: 2.2642 valid loss: 2.2711, valid accuracy: 0.2232
# Iter-10000 train loss: 2.2804 valid loss: 2.2708, valid accuracy: 0.2236
# Last iteration - Test accuracy mean: 0.2189, std: 0.0000, loss: 2.2707

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
