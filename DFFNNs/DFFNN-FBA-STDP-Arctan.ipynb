# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# y_test.shape, y_val.shape, y_train.shape
# X_train.shape, X_train.dtype, X_val.shape, X_val.dtype, X_test.shape, X_test.dtype
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # number of layers or depth
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        # The adaptive/learnable/updatable random feedforward
        self.model = []
        self.W_fixed = []
        self.grads = []
        self.ys_prev = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})
        # Previous output layer
        self.ys_prev.append(0.0)

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad_L = []
        for _ in range(L):
            grad_L.append({key: np.zeros_like(val) for key, val in self.model[1][0].items()})
        self.grads.append(grad_L)
        # Previous output layer
        ys_prev_L = []
        for _ in range(L):
            ys_prev_L.append(0.0)
        self.ys_prev.append(ys_prev_L)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Outout layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        # Previous output layer
        self.ys_prev.append(0.0)
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
        # dX = dout @ W.T # Backprop
        dX = dout @ W_fixed.T # fb alignment

        return dX, dW, db

    def train_forward(self, X, train):
        caches, ys = [], []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
#         y, _ = l.selu_forward(X=y)
#         y = l.elu_fwd(X=y)
#         y = l.sigmoid(X=y)
#         y = np.tanh(y)
#         a, b = 1.7519, 2/3
#         y = a * np.tanh(b*y)
        y = np.arctan(y)
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[0]
        X = y.copy() # pass to the next layer
        
        # Hidden layers
        fc_caches, ys_L, do_caches = [], [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
#             y, _ = l.selu_forward(X=y)
#             y = l.elu_fwd(X=y)
#             y = l.sigmoid(X=y)
#             y = np.tanh(y)
#             a, b = 1.7519, 2/3
#             y = a * np.tanh(b*y)
            y = np.arctan(y)
            fc_caches.append(fc_cache)
            ys_L.append(y) # ys[1][layer]
            X = y.copy() # pass to next layer
        if train:
            caches.append(fc_caches) # caches[1]
        ys.append(ys_L) # ys[1]            
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[2]

        return ys, caches # for backpropating the error

    def loss_function(self, y, y_train):
        
        loss = cross_entropy(y, y_train) # softmax is included
        dy = dcross_entropy(y, y_train) # dsoftmax is included
        
        return loss, dy
        
    def train_backward(self, dy, caches):
        grads = self.grads # initialized by Zero in every iteration/epoch
        ys, ys_prev = self.ys, self.ys_prev # temporal diff instead of differentiable function
        
        # Output layer
        fc_cache = caches[2]
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
        grads[2]['W'] = dW
        grads[2]['b'] = db

        # Hidden layer
        fc_caches = caches[1]
        for layer in reversed(range(self.L)):
            dy *= ys[1][layer] - ys_prev[1][layer] # temporal diff instead of differentiable function
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
            grads[1][layer]['W'] = dW
            grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache = caches[0]
        dy *= ys[0] - ys_prev[0] # temporal diff instead of differentiable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        grads[0]['W'] = dW
        grads[0]['b'] = db

        return dX, grads
    
    def test(self, X):
        ys_logit, _ = self.train_forward(X, train=False)
        y_logit = ys_logit[2] # last layer
        
        # if self.mode == 'classification':
        y_prob = l.softmax(y_logit) # for accuracy == acc
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_logit
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            self.ys, caches = self.train_forward(X_mini, train=True)
            loss, dy = self.loss_function(self.ys[2], y_mini)
            _, grads = self.train_backward(dy, caches) # self.ys_prev is used here for dfunc/ diff
            self.ys_prev = self.ys # for next iteration or epoch
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in grads[0].keys():
                self.model[0][key] -= alpha * grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * grads[1][layer][key]

            # Update the model for output layer
            for key in grads[2].keys():
                self.model[2][key] -= alpha * grads[2][key]
                
            # Validate the updated model
            y_pred, y_logit = self.test(X_val)
            valid_loss, _ = self.loss_function(y_logit, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val) # confusion matrix
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_logit = nn.test(X_test)
        loss, _ = self.loss_function(y_logit, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 10000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 50 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 100 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 2 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-100 train loss: 2.3249 valid loss: 2.3209, valid accuracy: 0.0890
# Iter-200 train loss: 2.3001 valid loss: 2.3192, valid accuracy: 0.0934
# Iter-300 train loss: 2.3081 valid loss: 2.3176, valid accuracy: 0.0980
# Iter-400 train loss: 2.3012 valid loss: 2.3160, valid accuracy: 0.1018
# Iter-500 train loss: 2.3295 valid loss: 2.3144, valid accuracy: 0.1050
# Iter-600 train loss: 2.2954 valid loss: 2.3128, valid accuracy: 0.1086
# Iter-700 train loss: 2.2974 valid loss: 2.3112, valid accuracy: 0.1144
# Iter-800 train loss: 2.3042 valid loss: 2.3096, valid accuracy: 0.1166
# Iter-900 train loss: 2.3080 valid loss: 2.3080, valid accuracy: 0.1202
# Iter-1000 train loss: 2.3088 valid loss: 2.3064, valid accuracy: 0.1244
# Iter-1100 train loss: 2.2926 valid loss: 2.3048, valid accuracy: 0.1300
# Iter-1200 train loss: 2.2976 valid loss: 2.3032, valid accuracy: 0.1336
# Iter-1300 train loss: 2.2728 valid loss: 2.3017, valid accuracy: 0.1366
# Iter-1400 train loss: 2.2792 valid loss: 2.3001, valid accuracy: 0.1400
# Iter-1500 train loss: 2.2993 valid loss: 2.2985, valid accuracy: 0.1432
# Iter-1600 train loss: 2.2919 valid loss: 2.2970, valid accuracy: 0.1464
# Iter-1700 train loss: 2.2907 valid loss: 2.2954, valid accuracy: 0.1518
# Iter-1800 train loss: 2.2903 valid loss: 2.2938, valid accuracy: 0.1552
# Iter-1900 train loss: 2.3080 valid loss: 2.2923, valid accuracy: 0.1584
# Iter-2000 train loss: 2.2673 valid loss: 2.2907, valid accuracy: 0.1614
# Iter-2100 train loss: 2.3034 valid loss: 2.2891, valid accuracy: 0.1646
# Iter-2200 train loss: 2.2726 valid loss: 2.2876, valid accuracy: 0.1682
# Iter-2300 train loss: 2.2726 valid loss: 2.2861, valid accuracy: 0.1724
# Iter-2400 train loss: 2.3053 valid loss: 2.2845, valid accuracy: 0.1780
# Iter-2500 train loss: 2.2813 valid loss: 2.2829, valid accuracy: 0.1806
# Iter-2600 train loss: 2.3094 valid loss: 2.2813, valid accuracy: 0.1836
# Iter-2700 train loss: 2.2913 valid loss: 2.2798, valid accuracy: 0.1860
# Iter-2800 train loss: 2.2602 valid loss: 2.2783, valid accuracy: 0.1876
# Iter-2900 train loss: 2.2853 valid loss: 2.2767, valid accuracy: 0.1892
# Iter-3000 train loss: 2.2769 valid loss: 2.2752, valid accuracy: 0.1926
# Iter-3100 train loss: 2.2904 valid loss: 2.2737, valid accuracy: 0.1952
# Iter-3200 train loss: 2.2873 valid loss: 2.2723, valid accuracy: 0.1968
# Iter-3300 train loss: 2.2443 valid loss: 2.2708, valid accuracy: 0.1990
# Iter-3400 train loss: 2.3095 valid loss: 2.2693, valid accuracy: 0.2022
# Iter-3500 train loss: 2.2822 valid loss: 2.2677, valid accuracy: 0.2038
# Iter-3600 train loss: 2.2592 valid loss: 2.2662, valid accuracy: 0.2060
# Iter-3700 train loss: 2.2703 valid loss: 2.2647, valid accuracy: 0.2098
# Iter-3800 train loss: 2.2342 valid loss: 2.2633, valid accuracy: 0.2114
# Iter-3900 train loss: 2.2832 valid loss: 2.2617, valid accuracy: 0.2130
# Iter-4000 train loss: 2.2465 valid loss: 2.2603, valid accuracy: 0.2154
# Iter-4100 train loss: 2.2690 valid loss: 2.2588, valid accuracy: 0.2176
# Iter-4200 train loss: 2.2494 valid loss: 2.2573, valid accuracy: 0.2194
# Iter-4300 train loss: 2.2791 valid loss: 2.2558, valid accuracy: 0.2212
# Iter-4400 train loss: 2.2729 valid loss: 2.2544, valid accuracy: 0.2216
# Iter-4500 train loss: 2.2519 valid loss: 2.2530, valid accuracy: 0.2228
# Iter-4600 train loss: 2.2522 valid loss: 2.2515, valid accuracy: 0.2236
# Iter-4700 train loss: 2.2275 valid loss: 2.2501, valid accuracy: 0.2248
# Iter-4800 train loss: 2.2421 valid loss: 2.2486, valid accuracy: 0.2250
# Iter-4900 train loss: 2.2256 valid loss: 2.2472, valid accuracy: 0.2272
# Iter-5000 train loss: 2.2679 valid loss: 2.2457, valid accuracy: 0.2280
# Iter-5100 train loss: 2.2463 valid loss: 2.2443, valid accuracy: 0.2294
# Iter-5200 train loss: 2.2309 valid loss: 2.2429, valid accuracy: 0.2300
# Iter-5300 train loss: 2.2616 valid loss: 2.2414, valid accuracy: 0.2320
# Iter-5400 train loss: 2.2401 valid loss: 2.2400, valid accuracy: 0.2324
# Iter-5500 train loss: 2.2469 valid loss: 2.2386, valid accuracy: 0.2352
# Iter-5600 train loss: 2.2042 valid loss: 2.2371, valid accuracy: 0.2356
# Iter-5700 train loss: 2.2091 valid loss: 2.2357, valid accuracy: 0.2372
# Iter-5800 train loss: 2.2170 valid loss: 2.2343, valid accuracy: 0.2382
# Iter-5900 train loss: 2.2332 valid loss: 2.2329, valid accuracy: 0.2384
# Iter-6000 train loss: 2.2350 valid loss: 2.2315, valid accuracy: 0.2406
# Iter-6100 train loss: 2.2303 valid loss: 2.2302, valid accuracy: 0.2424
# Iter-6200 train loss: 2.2267 valid loss: 2.2288, valid accuracy: 0.2430
# Iter-6300 train loss: 2.2369 valid loss: 2.2274, valid accuracy: 0.2438
# Iter-6400 train loss: 2.2486 valid loss: 2.2260, valid accuracy: 0.2454
# Iter-6500 train loss: 2.2105 valid loss: 2.2246, valid accuracy: 0.2462
# Iter-6600 train loss: 2.2534 valid loss: 2.2232, valid accuracy: 0.2470
# Iter-6700 train loss: 2.2187 valid loss: 2.2219, valid accuracy: 0.2486
# Iter-6800 train loss: 2.2294 valid loss: 2.2205, valid accuracy: 0.2502
# Iter-6900 train loss: 2.2182 valid loss: 2.2191, valid accuracy: 0.2512
# Iter-7000 train loss: 2.2124 valid loss: 2.2177, valid accuracy: 0.2526
# Iter-7100 train loss: 2.1996 valid loss: 2.2164, valid accuracy: 0.2532
# Iter-7200 train loss: 2.2314 valid loss: 2.2150, valid accuracy: 0.2544
# Iter-7300 train loss: 2.2413 valid loss: 2.2137, valid accuracy: 0.2548
# Iter-7400 train loss: 2.2219 valid loss: 2.2124, valid accuracy: 0.2558
# Iter-7500 train loss: 2.1677 valid loss: 2.2110, valid accuracy: 0.2558
# Iter-7600 train loss: 2.2153 valid loss: 2.2097, valid accuracy: 0.2566
# Iter-7700 train loss: 2.1701 valid loss: 2.2083, valid accuracy: 0.2580
# Iter-7800 train loss: 2.1789 valid loss: 2.2070, valid accuracy: 0.2578
# Iter-7900 train loss: 2.2203 valid loss: 2.2057, valid accuracy: 0.2588
# Iter-8000 train loss: 2.1856 valid loss: 2.2044, valid accuracy: 0.2590
# Iter-8100 train loss: 2.2098 valid loss: 2.2030, valid accuracy: 0.2596
# Iter-8200 train loss: 2.2189 valid loss: 2.2017, valid accuracy: 0.2610
# Iter-8300 train loss: 2.1578 valid loss: 2.2004, valid accuracy: 0.2616
# Iter-8400 train loss: 2.1664 valid loss: 2.1991, valid accuracy: 0.2630
# Iter-8500 train loss: 2.1835 valid loss: 2.1977, valid accuracy: 0.2634
# Iter-8600 train loss: 2.1718 valid loss: 2.1964, valid accuracy: 0.2648
# Iter-8700 train loss: 2.2227 valid loss: 2.1952, valid accuracy: 0.2660
# Iter-8800 train loss: 2.1466 valid loss: 2.1938, valid accuracy: 0.2668
# Iter-8900 train loss: 2.1564 valid loss: 2.1925, valid accuracy: 0.2670
# Iter-9000 train loss: 2.1854 valid loss: 2.1912, valid accuracy: 0.2694
# Iter-9100 train loss: 2.1937 valid loss: 2.1899, valid accuracy: 0.2700
# Iter-9200 train loss: 2.2012 valid loss: 2.1886, valid accuracy: 0.2700
# Iter-9300 train loss: 2.1771 valid loss: 2.1873, valid accuracy: 0.2716
# Iter-9400 train loss: 2.1917 valid loss: 2.1860, valid accuracy: 0.2722
# Iter-9500 train loss: 2.1548 valid loss: 2.1847, valid accuracy: 0.2730
# Iter-9600 train loss: 2.1711 valid loss: 2.1834, valid accuracy: 0.2738
# Iter-9700 train loss: 2.1585 valid loss: 2.1822, valid accuracy: 0.2746
# Iter-9800 train loss: 2.1509 valid loss: 2.1809, valid accuracy: 0.2756
# Iter-9900 train loss: 2.1822 valid loss: 2.1796, valid accuracy: 0.2766
# Iter-10000 train loss: 2.1696 valid loss: 2.1783, valid accuracy: 0.2770
# Last iteration - Test accuracy mean: 0.2842, std: 0.0000, loss: 2.1692

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
