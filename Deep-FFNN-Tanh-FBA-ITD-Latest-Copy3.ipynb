# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # layers
        self.C = C # classes
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        self.model = []
        self.W_fixed = []
        self.grads = []
        self.dy_prev = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad_L = []
        for _ in range(L):
            grad_L.append({key: np.zeros_like(val) for key, val in self.model[1][0].items()})
        self.grads.append(grad_L)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Output layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
#         dX = dout @ W.T # vanilla Backprop
        dX = dout @ W_fixed.T # fba backprop
#         dX = dout @ np.linalg.inv(W_fixed) # my backprop

        return dX, dW, db

    def train_forward(self, X, train):
        caches, ys = [], []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
        y, nl_cache = l.tanh_forward(X=y)
        if train:
            caches.append((fc_cache, nl_cache))
        X = y.copy() # pass to the next layer
        
        # Hidden layers
        fc_caches, nl_caches = [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
            y, nl_cache = l.tanh_forward(X=y)
            X = y.copy() # pass to next layer
            if train:
                fc_caches.append(fc_cache)
                nl_caches.append(nl_cache)
        if train:
            caches.append((fc_caches, nl_caches)) # caches[1]            
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        y_prob = l.softmax(X=y)
        if train:
            caches.append(fc_cache)

        return y_prob, caches # for backpropating the error

    def cross_entropy(self, y_prob, y_train):
        m = y_prob.shape[0]

        #         prob = l.softmax(y_pred)
        log_like = -np.log(y_prob[range(m), y_train] + l.eps) # to avoid the devision by zero
        data_loss = np.sum(log_like) / m

        return data_loss

    def dcross_entropy(self, y_prob, y_train): # this is equal for both since the reg_loss (noise) derivative is ZERO.
        m = y_prob.shape[0]

        #         grad_y = l.softmax(y_pred)
        grad_y = y_prob
        grad_y[range(m), y_train] -= 1.
        grad_y /= m

        return grad_y

    def loss_function(self, y_prob, y_train):
        
        loss = self.cross_entropy(y_prob, y_train) # softmax is included
        dy = self.dcross_entropy(y_prob, y_train) # dsoftmax is included

        return loss, dy
        
    def train_backward(self, dy, caches):
        grads = self.grads.copy() # initialized by Zero in every iteration/epoch
        dy_prev = self.dy_prev.copy() # for temporal differencing
        self.dy_prev = dy.copy() # next iteration/ epoch
        
        # Output layer
        fc_cache = caches[2]
        # softmax_backward include in dcross_entropy
#         dy *= ys[2] - ys_prev[2] # temporal diff instead of differentiable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
        grads[2]['W'] = dW
        grads[2]['b'] = db

        # Hidden layer
        fc_caches, nl_caches = caches[1]
        for layer in reversed(range(self.L)):
#             dy *= ys[1][layer] - ys_prev[1][layer] # temporal diff instead of differentiable function
            dy = l.tanh_backward(cache=nl_caches[layer], dout=dy) # diffable function
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
            grads[1][layer]['W'] = dW
            grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache, nl_cache = caches[0]
        dy = l.tanh_backward(cache=nl_cache, dout=dy) # diffable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        grads[0]['W'] = dW
        grads[0]['b'] = db

        return dX, grads
    
    def test(self, X):
        y_prob, _ = self.train_forward(X, train=False)
        
        # if self.mode == 'classification':
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_prob
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            y_prob, caches = self.train_forward(X_mini, train=True)
            loss, dy = self.loss_function(y_prob, y_mini)
            _, grads = self.train_backward(dy, caches)
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in grads[0].keys():
                self.model[0][key] -= alpha * grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * grads[1][layer][key]

            # Update the model for output layer
            for key in grads[2].keys():
                self.model[2][key] -= alpha * grads[2][key]
                
            # Validate the updated model
            y_pred, y_prob = self.test(X_val)
            valid_loss, _ = self.loss_function(y_prob, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val) # confusion matrix
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_prob = nn.test(X_test)
        loss, _ = self.loss_function(y_prob, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 1000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 64 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 10 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 2 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-10 train loss: 2.3310 valid loss: 2.3216, valid accuracy: 0.0844
# Iter-20 train loss: 2.3348 valid loss: 2.3214, valid accuracy: 0.0844
# Iter-30 train loss: 2.3489 valid loss: 2.3213, valid accuracy: 0.0844
# Iter-40 train loss: 2.3339 valid loss: 2.3212, valid accuracy: 0.0854
# Iter-50 train loss: 2.3245 valid loss: 2.3210, valid accuracy: 0.0848
# Iter-60 train loss: 2.3222 valid loss: 2.3209, valid accuracy: 0.0850
# Iter-70 train loss: 2.3270 valid loss: 2.3207, valid accuracy: 0.0848
# Iter-80 train loss: 2.3364 valid loss: 2.3205, valid accuracy: 0.0852
# Iter-90 train loss: 2.2995 valid loss: 2.3203, valid accuracy: 0.0858
# Iter-100 train loss: 2.3184 valid loss: 2.3201, valid accuracy: 0.0856
# Iter-110 train loss: 2.3009 valid loss: 2.3200, valid accuracy: 0.0856
# Iter-120 train loss: 2.3066 valid loss: 2.3198, valid accuracy: 0.0860
# Iter-130 train loss: 2.3284 valid loss: 2.3197, valid accuracy: 0.0862
# Iter-140 train loss: 2.3180 valid loss: 2.3195, valid accuracy: 0.0856
# Iter-150 train loss: 2.3358 valid loss: 2.3193, valid accuracy: 0.0858
# Iter-160 train loss: 2.3274 valid loss: 2.3191, valid accuracy: 0.0870
# Iter-170 train loss: 2.3085 valid loss: 2.3189, valid accuracy: 0.0874
# Iter-180 train loss: 2.3142 valid loss: 2.3187, valid accuracy: 0.0876
# Iter-190 train loss: 2.3203 valid loss: 2.3185, valid accuracy: 0.0878
# Iter-200 train loss: 2.3191 valid loss: 2.3184, valid accuracy: 0.0876
# Iter-210 train loss: 2.3221 valid loss: 2.3182, valid accuracy: 0.0880
# Iter-220 train loss: 2.3286 valid loss: 2.3180, valid accuracy: 0.0880
# Iter-230 train loss: 2.3223 valid loss: 2.3178, valid accuracy: 0.0884
# Iter-240 train loss: 2.3221 valid loss: 2.3176, valid accuracy: 0.0888
# Iter-250 train loss: 2.3162 valid loss: 2.3175, valid accuracy: 0.0892
# Iter-260 train loss: 2.3284 valid loss: 2.3173, valid accuracy: 0.0898
# Iter-270 train loss: 2.3238 valid loss: 2.3170, valid accuracy: 0.0906
# Iter-280 train loss: 2.3211 valid loss: 2.3169, valid accuracy: 0.0912
# Iter-290 train loss: 2.3016 valid loss: 2.3167, valid accuracy: 0.0914
# Iter-300 train loss: 2.3219 valid loss: 2.3166, valid accuracy: 0.0922
# Iter-310 train loss: 2.3110 valid loss: 2.3164, valid accuracy: 0.0930
# Iter-320 train loss: 2.3125 valid loss: 2.3163, valid accuracy: 0.0920
# Iter-330 train loss: 2.3177 valid loss: 2.3160, valid accuracy: 0.0920
# Iter-340 train loss: 2.3311 valid loss: 2.3158, valid accuracy: 0.0920
# Iter-350 train loss: 2.3167 valid loss: 2.3156, valid accuracy: 0.0918
# Iter-360 train loss: 2.3170 valid loss: 2.3154, valid accuracy: 0.0918
# Iter-370 train loss: 2.3021 valid loss: 2.3152, valid accuracy: 0.0932
# Iter-380 train loss: 2.3088 valid loss: 2.3150, valid accuracy: 0.0930
# Iter-390 train loss: 2.3046 valid loss: 2.3148, valid accuracy: 0.0930
# Iter-400 train loss: 2.3159 valid loss: 2.3146, valid accuracy: 0.0930
# Iter-410 train loss: 2.3072 valid loss: 2.3144, valid accuracy: 0.0938
# Iter-420 train loss: 2.3207 valid loss: 2.3142, valid accuracy: 0.0936
# Iter-430 train loss: 2.2974 valid loss: 2.3141, valid accuracy: 0.0952
# Iter-440 train loss: 2.3236 valid loss: 2.3138, valid accuracy: 0.0966
# Iter-450 train loss: 2.3113 valid loss: 2.3136, valid accuracy: 0.0968
# Iter-460 train loss: 2.3328 valid loss: 2.3134, valid accuracy: 0.0962
# Iter-470 train loss: 2.3127 valid loss: 2.3131, valid accuracy: 0.0964
# Iter-480 train loss: 2.3077 valid loss: 2.3129, valid accuracy: 0.0972
# Iter-490 train loss: 2.3315 valid loss: 2.3127, valid accuracy: 0.0966
# Iter-500 train loss: 2.3125 valid loss: 2.3125, valid accuracy: 0.0968
# Iter-510 train loss: 2.3319 valid loss: 2.3123, valid accuracy: 0.0968
# Iter-520 train loss: 2.3155 valid loss: 2.3121, valid accuracy: 0.0968
# Iter-530 train loss: 2.3005 valid loss: 2.3118, valid accuracy: 0.0970
# Iter-540 train loss: 2.3038 valid loss: 2.3115, valid accuracy: 0.0970
# Iter-550 train loss: 2.2978 valid loss: 2.3113, valid accuracy: 0.0974
# Iter-560 train loss: 2.3016 valid loss: 2.3110, valid accuracy: 0.0976
# Iter-570 train loss: 2.3066 valid loss: 2.3108, valid accuracy: 0.0988
# Iter-580 train loss: 2.3185 valid loss: 2.3106, valid accuracy: 0.0992
# Iter-590 train loss: 2.2994 valid loss: 2.3104, valid accuracy: 0.0998
# Iter-600 train loss: 2.3115 valid loss: 2.3101, valid accuracy: 0.1000
# Iter-610 train loss: 2.3314 valid loss: 2.3099, valid accuracy: 0.1006
# Iter-620 train loss: 2.3173 valid loss: 2.3097, valid accuracy: 0.1014
# Iter-630 train loss: 2.3060 valid loss: 2.3094, valid accuracy: 0.1018
# Iter-640 train loss: 2.3304 valid loss: 2.3092, valid accuracy: 0.1026
# Iter-650 train loss: 2.3189 valid loss: 2.3090, valid accuracy: 0.1034
# Iter-660 train loss: 2.3003 valid loss: 2.3087, valid accuracy: 0.1034
# Iter-670 train loss: 2.2902 valid loss: 2.3084, valid accuracy: 0.1034
# Iter-680 train loss: 2.3011 valid loss: 2.3081, valid accuracy: 0.1036
# Iter-690 train loss: 2.3002 valid loss: 2.3079, valid accuracy: 0.1040
# Iter-700 train loss: 2.2867 valid loss: 2.3077, valid accuracy: 0.1034
# Iter-710 train loss: 2.3086 valid loss: 2.3073, valid accuracy: 0.1050
# Iter-720 train loss: 2.3044 valid loss: 2.3071, valid accuracy: 0.1046
# Iter-730 train loss: 2.3146 valid loss: 2.3069, valid accuracy: 0.1058
# Iter-740 train loss: 2.2971 valid loss: 2.3066, valid accuracy: 0.1078
# Iter-750 train loss: 2.3110 valid loss: 2.3063, valid accuracy: 0.1086
# Iter-760 train loss: 2.3128 valid loss: 2.3061, valid accuracy: 0.1106
# Iter-770 train loss: 2.3012 valid loss: 2.3058, valid accuracy: 0.1118
# Iter-780 train loss: 2.3073 valid loss: 2.3055, valid accuracy: 0.1122
# Iter-790 train loss: 2.2929 valid loss: 2.3051, valid accuracy: 0.1136
# Iter-800 train loss: 2.2970 valid loss: 2.3048, valid accuracy: 0.1152
# Iter-810 train loss: 2.2923 valid loss: 2.3045, valid accuracy: 0.1164
# Iter-820 train loss: 2.3157 valid loss: 2.3042, valid accuracy: 0.1168
# Iter-830 train loss: 2.2988 valid loss: 2.3038, valid accuracy: 0.1184
# Iter-840 train loss: 2.3108 valid loss: 2.3035, valid accuracy: 0.1208
# Iter-850 train loss: 2.3057 valid loss: 2.3032, valid accuracy: 0.1224
# Iter-860 train loss: 2.2940 valid loss: 2.3029, valid accuracy: 0.1242
# Iter-870 train loss: 2.2940 valid loss: 2.3026, valid accuracy: 0.1246
# Iter-880 train loss: 2.2947 valid loss: 2.3024, valid accuracy: 0.1258
# Iter-890 train loss: 2.2982 valid loss: 2.3021, valid accuracy: 0.1270
# Iter-900 train loss: 2.3366 valid loss: 2.3018, valid accuracy: 0.1280
# Iter-910 train loss: 2.2981 valid loss: 2.3015, valid accuracy: 0.1298
# Iter-920 train loss: 2.3278 valid loss: 2.3012, valid accuracy: 0.1312
# Iter-930 train loss: 2.2974 valid loss: 2.3009, valid accuracy: 0.1324
# Iter-940 train loss: 2.2935 valid loss: 2.3006, valid accuracy: 0.1330
# Iter-950 train loss: 2.3063 valid loss: 2.3003, valid accuracy: 0.1338
# Iter-960 train loss: 2.2988 valid loss: 2.2999, valid accuracy: 0.1366
# Iter-970 train loss: 2.3104 valid loss: 2.2996, valid accuracy: 0.1380
# Iter-980 train loss: 2.3088 valid loss: 2.2993, valid accuracy: 0.1400
# Iter-990 train loss: 2.2993 valid loss: 2.2989, valid accuracy: 0.1422
# Iter-1000 train loss: 2.2905 valid loss: 2.2986, valid accuracy: 0.1434
# Last iteration - Test accuracy mean: 0.1375, std: 0.0000, loss: 2.2987

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
