# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# y_test.shape, y_val.shape, y_train.shape
# X_train.shape, X_train.dtype, X_val.shape, X_val.dtype, X_test.shape, X_test.dtype
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # number of layers or depth
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        # The adaptive/learnable/updatable random feedforward
        self.model = []
        self.W_fixed = []
        self.grads = []
        self.ys_prev = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})
        # Previous output layer
        self.ys_prev.append(0.0)

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad_L = []
        for _ in range(L):
            grad_L.append({key: np.zeros_like(val) for key, val in self.model[1][0].items()})
        self.grads.append(grad_L)
        # Previous output layer
        ys_prev_L = []
        for _ in range(L):
            ys_prev_L.append(0.0)
        self.ys_prev.append(ys_prev_L)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Outout layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        # Previous output layer
        self.ys_prev.append(0.0)
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
        # dX = dout @ W.T # Backprop
        dX = dout @ W_fixed.T # fb alignment

        return dX, dW, db

    def train_forward(self, X, train):
        caches, ys = [], []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
        y, _ = l.selu_forward(X=y)
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[0]
        X = y.copy() # pass to the next layer
        
        # Hidden layers
        fc_caches, ys_L, do_caches = [], [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
            y, _ = l.selu_forward(X=y)
            fc_caches.append(fc_cache)
            ys_L.append(y) # ys[1][layer]
            X = y.copy() # pass to next layer
        if train:
            caches.append(fc_caches) # caches[1]
        ys.append(ys_L) # ys[1]            
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[2]

        return ys, caches # for backpropating the error

    def loss_function(self, y, y_train):
        
        loss = cross_entropy(y, y_train) # softmax is included
        dy = dcross_entropy(y, y_train) # dsoftmax is included
        
        return loss, dy
        
    def train_backward(self, dy, caches):
        grads = self.grads # initialized by Zero in every iteration/epoch
        ys, ys_prev = self.ys, self.ys_prev # temporal diff instead of differentiable function
        
        # Output layer
        fc_cache = caches[2]
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
        grads[2]['W'] = dW
        grads[2]['b'] = db

        # Hidden layer
        fc_caches = caches[1]
        for layer in reversed(range(self.L)):
            dy *= ys[1][layer] - ys_prev[1][layer] # temporal diff instead of differentiable function
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
            grads[1][layer]['W'] = dW
            grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache = caches[0]
        dy *= ys[0] - ys_prev[0] # temporal diff instead of differentiable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        grads[0]['W'] = dW
        grads[0]['b'] = db

        return dX, grads
    
    def test(self, X):
        ys_logit, _ = self.train_forward(X, train=False)
        y_logit = ys_logit[2] # last layer
        
        # if self.mode == 'classification':
        y_prob = l.softmax(y_logit) # for accuracy == acc
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_logit
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            self.ys, caches = self.train_forward(X_mini, train=True)
            loss, dy = self.loss_function(self.ys[2], y_mini)
            _, grads = self.train_backward(dy, caches) # self.ys_prev is used here for dfunc/ diff
            self.ys_prev = self.ys # for next iteration or epoch
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in grads[0].keys():
                self.model[0][key] -= alpha * grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * grads[1][layer][key]

            # Update the model for output layer
            for key in grads[2].keys():
                self.model[2][key] -= alpha * grads[2][key]
                
            # Validate the updated model
            y_pred, y_logit = self.test(X_val)
            valid_loss, _ = self.loss_function(y_logit, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val) # confusion matrix
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_logit = nn.test(X_test)
        loss, _ = self.loss_function(y_logit, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 1000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 50 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 10 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 10 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-10 train loss: 2.3399 valid loss: 2.3523, valid accuracy: 0.0576
# Iter-20 train loss: 2.2776 valid loss: 2.3510, valid accuracy: 0.0578
# Iter-30 train loss: 2.3241 valid loss: 2.3495, valid accuracy: 0.0598
# Iter-40 train loss: 2.3584 valid loss: 2.3481, valid accuracy: 0.0604
# Iter-50 train loss: 2.3216 valid loss: 2.3468, valid accuracy: 0.0618
# Iter-60 train loss: 2.3538 valid loss: 2.3454, valid accuracy: 0.0618
# Iter-70 train loss: 2.3139 valid loss: 2.3440, valid accuracy: 0.0626
# Iter-80 train loss: 2.2818 valid loss: 2.3425, valid accuracy: 0.0630
# Iter-90 train loss: 2.3342 valid loss: 2.3411, valid accuracy: 0.0634
# Iter-100 train loss: 2.3453 valid loss: 2.3398, valid accuracy: 0.0642
# Iter-110 train loss: 2.2910 valid loss: 2.3383, valid accuracy: 0.0652
# Iter-120 train loss: 2.3076 valid loss: 2.3370, valid accuracy: 0.0662
# Iter-130 train loss: 2.3276 valid loss: 2.3357, valid accuracy: 0.0666
# Iter-140 train loss: 2.3237 valid loss: 2.3344, valid accuracy: 0.0684
# Iter-150 train loss: 2.3478 valid loss: 2.3332, valid accuracy: 0.0688
# Iter-160 train loss: 2.3795 valid loss: 2.3319, valid accuracy: 0.0700
# Iter-170 train loss: 2.3143 valid loss: 2.3306, valid accuracy: 0.0710
# Iter-180 train loss: 2.2910 valid loss: 2.3292, valid accuracy: 0.0712
# Iter-190 train loss: 2.3314 valid loss: 2.3280, valid accuracy: 0.0730
# Iter-200 train loss: 2.3687 valid loss: 2.3267, valid accuracy: 0.0734
# Iter-210 train loss: 2.3485 valid loss: 2.3254, valid accuracy: 0.0748
# Iter-220 train loss: 2.3026 valid loss: 2.3241, valid accuracy: 0.0754
# Iter-230 train loss: 2.3435 valid loss: 2.3229, valid accuracy: 0.0770
# Iter-240 train loss: 2.3428 valid loss: 2.3216, valid accuracy: 0.0786
# Iter-250 train loss: 2.2854 valid loss: 2.3203, valid accuracy: 0.0790
# Iter-260 train loss: 2.2809 valid loss: 2.3191, valid accuracy: 0.0794
# Iter-270 train loss: 2.3625 valid loss: 2.3179, valid accuracy: 0.0802
# Iter-280 train loss: 2.3116 valid loss: 2.3167, valid accuracy: 0.0806
# Iter-290 train loss: 2.3136 valid loss: 2.3154, valid accuracy: 0.0814
# Iter-300 train loss: 2.3122 valid loss: 2.3142, valid accuracy: 0.0826
# Iter-310 train loss: 2.3540 valid loss: 2.3129, valid accuracy: 0.0834
# Iter-320 train loss: 2.3169 valid loss: 2.3119, valid accuracy: 0.0834
# Iter-330 train loss: 2.2777 valid loss: 2.3106, valid accuracy: 0.0842
# Iter-340 train loss: 2.2797 valid loss: 2.3094, valid accuracy: 0.0854
# Iter-350 train loss: 2.3075 valid loss: 2.3082, valid accuracy: 0.0856
# Iter-360 train loss: 2.2996 valid loss: 2.3068, valid accuracy: 0.0884
# Iter-370 train loss: 2.3086 valid loss: 2.3057, valid accuracy: 0.0892
# Iter-380 train loss: 2.3211 valid loss: 2.3046, valid accuracy: 0.0914
# Iter-390 train loss: 2.2747 valid loss: 2.3034, valid accuracy: 0.0922
# Iter-400 train loss: 2.2913 valid loss: 2.3023, valid accuracy: 0.0932
# Iter-410 train loss: 2.2829 valid loss: 2.3012, valid accuracy: 0.0924
# Iter-420 train loss: 2.2759 valid loss: 2.3001, valid accuracy: 0.0934
# Iter-430 train loss: 2.2775 valid loss: 2.2989, valid accuracy: 0.0954
# Iter-440 train loss: 2.2783 valid loss: 2.2978, valid accuracy: 0.0950
# Iter-450 train loss: 2.2696 valid loss: 2.2966, valid accuracy: 0.0952
# Iter-460 train loss: 2.3064 valid loss: 2.2955, valid accuracy: 0.0956
# Iter-470 train loss: 2.2734 valid loss: 2.2944, valid accuracy: 0.0970
# Iter-480 train loss: 2.3113 valid loss: 2.2932, valid accuracy: 0.0976
# Iter-490 train loss: 2.2906 valid loss: 2.2921, valid accuracy: 0.0988
# Iter-500 train loss: 2.3393 valid loss: 2.2910, valid accuracy: 0.0984
# Iter-510 train loss: 2.3170 valid loss: 2.2899, valid accuracy: 0.0992
# Iter-520 train loss: 2.2830 valid loss: 2.2887, valid accuracy: 0.0998
# Iter-530 train loss: 2.3301 valid loss: 2.2876, valid accuracy: 0.0998
# Iter-540 train loss: 2.2780 valid loss: 2.2865, valid accuracy: 0.1012
# Iter-550 train loss: 2.2413 valid loss: 2.2854, valid accuracy: 0.1014
# Iter-560 train loss: 2.3073 valid loss: 2.2843, valid accuracy: 0.1018
# Iter-570 train loss: 2.2570 valid loss: 2.2832, valid accuracy: 0.1026
# Iter-580 train loss: 2.2633 valid loss: 2.2822, valid accuracy: 0.1036
# Iter-590 train loss: 2.2635 valid loss: 2.2811, valid accuracy: 0.1040
# Iter-600 train loss: 2.3104 valid loss: 2.2800, valid accuracy: 0.1044
# Iter-610 train loss: 2.2479 valid loss: 2.2788, valid accuracy: 0.1062
# Iter-620 train loss: 2.2608 valid loss: 2.2777, valid accuracy: 0.1072
# Iter-630 train loss: 2.2683 valid loss: 2.2768, valid accuracy: 0.1076
# Iter-640 train loss: 2.2552 valid loss: 2.2756, valid accuracy: 0.1088
# Iter-650 train loss: 2.3113 valid loss: 2.2746, valid accuracy: 0.1092
# Iter-660 train loss: 2.2962 valid loss: 2.2736, valid accuracy: 0.1102
# Iter-670 train loss: 2.2654 valid loss: 2.2724, valid accuracy: 0.1106
# Iter-680 train loss: 2.2633 valid loss: 2.2713, valid accuracy: 0.1112
# Iter-690 train loss: 2.2441 valid loss: 2.2704, valid accuracy: 0.1120
# Iter-700 train loss: 2.2312 valid loss: 2.2694, valid accuracy: 0.1122
# Iter-710 train loss: 2.3243 valid loss: 2.2682, valid accuracy: 0.1122
# Iter-720 train loss: 2.2624 valid loss: 2.2672, valid accuracy: 0.1124
# Iter-730 train loss: 2.3084 valid loss: 2.2661, valid accuracy: 0.1140
# Iter-740 train loss: 2.2749 valid loss: 2.2652, valid accuracy: 0.1154
# Iter-750 train loss: 2.2372 valid loss: 2.2641, valid accuracy: 0.1160
# Iter-760 train loss: 2.2788 valid loss: 2.2630, valid accuracy: 0.1168
# Iter-770 train loss: 2.2376 valid loss: 2.2620, valid accuracy: 0.1176
# Iter-780 train loss: 2.2599 valid loss: 2.2610, valid accuracy: 0.1188
# Iter-790 train loss: 2.2387 valid loss: 2.2601, valid accuracy: 0.1188
# Iter-800 train loss: 2.3086 valid loss: 2.2590, valid accuracy: 0.1194
# Iter-810 train loss: 2.3036 valid loss: 2.2580, valid accuracy: 0.1198
# Iter-820 train loss: 2.2762 valid loss: 2.2571, valid accuracy: 0.1198
# Iter-830 train loss: 2.2712 valid loss: 2.2562, valid accuracy: 0.1206
# Iter-840 train loss: 2.2731 valid loss: 2.2552, valid accuracy: 0.1206
# Iter-850 train loss: 2.2471 valid loss: 2.2542, valid accuracy: 0.1218
# Iter-860 train loss: 2.2274 valid loss: 2.2534, valid accuracy: 0.1224
# Iter-870 train loss: 2.2291 valid loss: 2.2523, valid accuracy: 0.1236
# Iter-880 train loss: 2.2740 valid loss: 2.2515, valid accuracy: 0.1248
# Iter-890 train loss: 2.2337 valid loss: 2.2505, valid accuracy: 0.1252
# Iter-900 train loss: 2.2509 valid loss: 2.2496, valid accuracy: 0.1252
# Iter-910 train loss: 2.2568 valid loss: 2.2486, valid accuracy: 0.1260
# Iter-920 train loss: 2.1943 valid loss: 2.2477, valid accuracy: 0.1268
# Iter-930 train loss: 2.2337 valid loss: 2.2468, valid accuracy: 0.1270
# Iter-940 train loss: 2.2200 valid loss: 2.2459, valid accuracy: 0.1274
# Iter-950 train loss: 2.2103 valid loss: 2.2448, valid accuracy: 0.1286
# Iter-960 train loss: 2.2458 valid loss: 2.2440, valid accuracy: 0.1290
# Iter-970 train loss: 2.2218 valid loss: 2.2430, valid accuracy: 0.1304
# Iter-980 train loss: 2.3098 valid loss: 2.2421, valid accuracy: 0.1316
# Iter-990 train loss: 2.2264 valid loss: 2.2412, valid accuracy: 0.1326
# Iter-1000 train loss: 2.2552 valid loss: 2.2403, valid accuracy: 0.1328
# Last iteration - Test accuracy mean: 0.1355, std: 0.0000, loss: 2.2401

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
