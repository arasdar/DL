# %%
# import scipy.io as spio
import pandas as pd
import numpy as np

# %%
ls /home/arasdar/datasets/bci/
# Out:
# bci-project-data-RAW/  csp4.csv  hw3/  sampleEEGdata.mat*  y.mat
# bci-project-final/     hw1/      hw4/  x.mat

# %%
csp4_csv = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/bci/csp4.csv')

# %%
csp4_csv.head()
# Out:
#    0.13504  4.1039e+05    0.9192  -0.20251  -0.7784  -8.7575e+05  63.488  \
# 0 -0.36907  -2580400.0   0.67863   0.26801  0.28788    -226040.0  17.218
# 1  1.66670  40120000.0 -13.48600  -4.68940  3.72150     153070.0 -11.076
# 2  0.53092  40058000.0 -10.16800  -4.28450  3.86370    -536530.0  40.258
# 3  0.79339   4424600.0  -2.24940   0.15076 -0.28500    1035300.0 -76.536
# 4 -0.44330  -6210900.0   1.32340   0.71040 -0.11454   -1169000.0  84.962
#
#     1451.9   190.37  -915.31   30.212  0
# 0   374.72   49.337  -236.53   8.5765  0
# 1  -253.80  -34.454   158.49  -4.5551  1
# 2   886.63  114.210  -561.75  19.9670  1
# 3 -1716.10 -229.200  1081.40 -35.1390  0
# 4  1936.90  255.320 -1221.10  39.9430  0

# %%
import matplotlib.pyplot as mplot

csp4_csv.hist()
mplot.show()
