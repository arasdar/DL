# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# y_test.shape, y_val.shape, y_train.shape
# X_train.shape, X_train.dtype, X_val.shape, X_val.dtype, X_test.shape, X_test.dtype
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # number of layers or depth
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        # The adaptive/learnable/updatable random feedforward
        self.model = []
        self.W_fixed = []
        self.grads = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad = []
        for layer in range(L):
            grad.append({key: np.zeros_like(val) for key, val in self.model[1][layer].items()})
        self.grads.append(grad)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Outout layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
        # dX = dout @ W.T # Backprop
        dX = dout @ W_fixed.T # fb alignment

        return dX, dW, db

    def train_forward(self, X):
        caches = []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
        y, nl_cache = l.selu_forward(X=y)
        X = y.copy() # pass to the next layer
        caches.append((fc_cache, nl_cache)) # caches[0]
        
        # Hidden layers
        fc_caches, nl_caches = [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
            y, nl_cache = l.selu_forward(X=y)
            X = y.copy() # pass to next layer
            fc_caches.append(fc_cache)
            nl_caches.append(nl_cache)
        caches.append((fc_caches, nl_caches)) # caches[1]
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        caches.append(fc_cache) # caches[2]

        return y, caches

    def loss_function(self, y, y_train):
        
        loss = cross_entropy(y, y_train) # softmax is included
        dy = dcross_entropy(y, y_train) # dsoftmax is included
        
        return loss, dy
        
    def train_backward(self, dy, caches):
        
        # Output layer
        fc_cache = caches[2]
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
        self.grads[2]['W'] = dW
        self.grads[2]['b'] = db

        # Hidden layer
        fc_caches, nl_caches = caches[1]
        for layer in reversed(range(self.L)):
            dy = l.selu_backward(cache=nl_caches[layer], dout=dy)
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
            self.grads[1][layer]['W'] = dW
            self.grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache, nl_cache = caches[0]
        dy = l.selu_backward(cache=nl_cache, dout=dy)
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        # dy = dX.copy()
        self.grads[0]['W'] = dW
        self.grads[0]['b'] = db

        return dX
    
    def test(self, X):
        y_logit, _ = self.train_forward(X)
        
        # if self.mode == 'classification':
        y_prob = l.softmax(y_logit) # for accuracy == acc
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_logit
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            y, caches = self.train_forward(X_mini)
            loss, dy = self.loss_function(y, y_mini)
            _ = self.train_backward(dy, caches)
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in self.grads[0].keys():
                self.model[0][key] -= alpha * self.grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in self.grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * self.grads[1][layer][key]

            # Update the model for output layer
            for key in self.grads[2].keys():
                self.model[2][key] -= alpha * self.grads[2][key]
                
            # Validate the updated model
            y_pred, y_logit = self.test(X_val)
            valid_loss, _ = self.loss_function(y_logit, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val)
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_logit = nn.test(X_test)
        loss, _ = self.loss_function(y_logit, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 10000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 64 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 100 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 10 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-100 train loss: 2.4200 valid loss: 2.3823, valid accuracy: 0.0700
# Iter-200 train loss: 2.4427 valid loss: 2.3740, valid accuracy: 0.0878
# Iter-300 train loss: 2.3955 valid loss: 2.3579, valid accuracy: 0.1156
# Iter-400 train loss: 2.3279 valid loss: 2.3397, valid accuracy: 0.1382
# Iter-500 train loss: 2.3242 valid loss: 2.3225, valid accuracy: 0.1532
# Iter-600 train loss: 2.3106 valid loss: 2.3055, valid accuracy: 0.1644
# Iter-700 train loss: 2.2622 valid loss: 2.2869, valid accuracy: 0.1732
# Iter-800 train loss: 2.2558 valid loss: 2.2684, valid accuracy: 0.1806
# Iter-900 train loss: 2.2361 valid loss: 2.2503, valid accuracy: 0.1850
# Iter-1000 train loss: 2.2236 valid loss: 2.2336, valid accuracy: 0.1918
# Iter-1100 train loss: 2.2387 valid loss: 2.2179, valid accuracy: 0.1980
# Iter-1200 train loss: 2.1760 valid loss: 2.2042, valid accuracy: 0.2036
# Iter-1300 train loss: 2.1944 valid loss: 2.1912, valid accuracy: 0.2068
# Iter-1400 train loss: 2.1681 valid loss: 2.1787, valid accuracy: 0.2068
# Iter-1500 train loss: 2.1408 valid loss: 2.1661, valid accuracy: 0.2008
# Iter-1600 train loss: 2.1576 valid loss: 2.1544, valid accuracy: 0.1928
# Iter-1700 train loss: 2.1613 valid loss: 2.1445, valid accuracy: 0.1858
# Iter-1800 train loss: 2.1139 valid loss: 2.1352, valid accuracy: 0.1806
# Iter-1900 train loss: 2.1282 valid loss: 2.1267, valid accuracy: 0.1778
# Iter-2000 train loss: 2.1547 valid loss: 2.1178, valid accuracy: 0.1728
# Iter-2100 train loss: 2.1173 valid loss: 2.1086, valid accuracy: 0.1706
# Iter-2200 train loss: 2.0501 valid loss: 2.1012, valid accuracy: 0.1762
# Iter-2300 train loss: 2.1066 valid loss: 2.0932, valid accuracy: 0.1882
# Iter-2400 train loss: 2.1047 valid loss: 2.0850, valid accuracy: 0.2320
# Iter-2500 train loss: 2.0606 valid loss: 2.0735, valid accuracy: 0.2646
# Iter-2600 train loss: 2.0658 valid loss: 2.0572, valid accuracy: 0.2852
# Iter-2700 train loss: 2.1429 valid loss: 2.0346, valid accuracy: 0.3040
# Iter-2800 train loss: 1.9610 valid loss: 2.0018, valid accuracy: 0.3202
# Iter-2900 train loss: 1.9490 valid loss: 1.9648, valid accuracy: 0.3264
# Iter-3000 train loss: 1.9101 valid loss: 1.9243, valid accuracy: 0.3332
# Iter-3100 train loss: 2.0021 valid loss: 1.8833, valid accuracy: 0.3592
# Iter-3200 train loss: 1.7964 valid loss: 1.8458, valid accuracy: 0.3750
# Iter-3300 train loss: 1.8139 valid loss: 1.8117, valid accuracy: 0.3832
# Iter-3400 train loss: 1.7165 valid loss: 1.7823, valid accuracy: 0.3770
# Iter-3500 train loss: 1.7155 valid loss: 1.7579, valid accuracy: 0.3748
# Iter-3600 train loss: 1.7537 valid loss: 1.7361, valid accuracy: 0.3802
# Iter-3700 train loss: 1.6858 valid loss: 1.7180, valid accuracy: 0.3838
# Iter-3800 train loss: 1.6050 valid loss: 1.7029, valid accuracy: 0.3900
# Iter-3900 train loss: 1.7034 valid loss: 1.6900, valid accuracy: 0.3970
# Iter-4000 train loss: 1.7421 valid loss: 1.6775, valid accuracy: 0.4040
# Iter-4100 train loss: 1.6373 valid loss: 1.6652, valid accuracy: 0.4094
# Iter-4200 train loss: 1.6801 valid loss: 1.6538, valid accuracy: 0.4162
# Iter-4300 train loss: 1.6505 valid loss: 1.6428, valid accuracy: 0.4248
# Iter-4400 train loss: 1.7609 valid loss: 1.6332, valid accuracy: 0.4310
# Iter-4500 train loss: 1.5815 valid loss: 1.6224, valid accuracy: 0.4380
# Iter-4600 train loss: 1.6276 valid loss: 1.6124, valid accuracy: 0.4434
# Iter-4700 train loss: 1.5782 valid loss: 1.6014, valid accuracy: 0.4568
# Iter-4800 train loss: 1.6150 valid loss: 1.5903, valid accuracy: 0.4626
# Iter-4900 train loss: 1.5682 valid loss: 1.5803, valid accuracy: 0.4676
# Iter-5000 train loss: 1.7961 valid loss: 1.5694, valid accuracy: 0.4720
# Iter-5100 train loss: 1.5879 valid loss: 1.5569, valid accuracy: 0.4788
# Iter-5200 train loss: 1.6537 valid loss: 1.5441, valid accuracy: 0.4824
# Iter-5300 train loss: 1.5734 valid loss: 1.5309, valid accuracy: 0.4874
# Iter-5400 train loss: 1.7021 valid loss: 1.5174, valid accuracy: 0.4930
# Iter-5500 train loss: 1.5650 valid loss: 1.5040, valid accuracy: 0.4984
# Iter-5600 train loss: 1.7554 valid loss: 1.4900, valid accuracy: 0.5054
# Iter-5700 train loss: 1.5409 valid loss: 1.4761, valid accuracy: 0.5094
# Iter-5800 train loss: 1.3631 valid loss: 1.4620, valid accuracy: 0.5158
# Iter-5900 train loss: 1.4575 valid loss: 1.4478, valid accuracy: 0.5206
# Iter-6000 train loss: 1.5269 valid loss: 1.4339, valid accuracy: 0.5254
# Iter-6100 train loss: 1.3987 valid loss: 1.4200, valid accuracy: 0.5290
# Iter-6200 train loss: 1.5032 valid loss: 1.4066, valid accuracy: 0.5372
# Iter-6300 train loss: 1.4020 valid loss: 1.3935, valid accuracy: 0.5406
# Iter-6400 train loss: 1.4437 valid loss: 1.3805, valid accuracy: 0.5466
# Iter-6500 train loss: 1.4668 valid loss: 1.3678, valid accuracy: 0.5506
# Iter-6600 train loss: 1.2609 valid loss: 1.3552, valid accuracy: 0.5554
# Iter-6700 train loss: 1.3909 valid loss: 1.3428, valid accuracy: 0.5588
# Iter-6800 train loss: 1.4332 valid loss: 1.3309, valid accuracy: 0.5654
# Iter-6900 train loss: 1.0852 valid loss: 1.3199, valid accuracy: 0.5690
# Iter-7000 train loss: 1.2750 valid loss: 1.3083, valid accuracy: 0.5746
# Iter-7100 train loss: 1.2425 valid loss: 1.2967, valid accuracy: 0.5750
# Iter-7200 train loss: 1.2616 valid loss: 1.2855, valid accuracy: 0.5792
# Iter-7300 train loss: 1.0654 valid loss: 1.2746, valid accuracy: 0.5838
# Iter-7400 train loss: 1.1644 valid loss: 1.2641, valid accuracy: 0.5878
# Iter-7500 train loss: 1.2374 valid loss: 1.2537, valid accuracy: 0.5928
# Iter-7600 train loss: 1.1401 valid loss: 1.2438, valid accuracy: 0.6000
# Iter-7700 train loss: 1.1415 valid loss: 1.2341, valid accuracy: 0.6046
# Iter-7800 train loss: 1.2184 valid loss: 1.2252, valid accuracy: 0.6070
# Iter-7900 train loss: 1.0715 valid loss: 1.2158, valid accuracy: 0.6104
# Iter-8000 train loss: 1.3686 valid loss: 1.2077, valid accuracy: 0.6134
# Iter-8100 train loss: 1.3672 valid loss: 1.1990, valid accuracy: 0.6182
# Iter-8200 train loss: 1.1954 valid loss: 1.1904, valid accuracy: 0.6216
# Iter-8300 train loss: 1.2009 valid loss: 1.1813, valid accuracy: 0.6240
# Iter-8400 train loss: 1.1783 valid loss: 1.1729, valid accuracy: 0.6270
# Iter-8500 train loss: 1.1191 valid loss: 1.1643, valid accuracy: 0.6304
# Iter-8600 train loss: 1.1733 valid loss: 1.1559, valid accuracy: 0.6322
# Iter-8700 train loss: 1.0627 valid loss: 1.1482, valid accuracy: 0.6358
# Iter-8800 train loss: 1.2315 valid loss: 1.1403, valid accuracy: 0.6390
# Iter-8900 train loss: 1.0286 valid loss: 1.1331, valid accuracy: 0.6426
# Iter-9000 train loss: 1.1268 valid loss: 1.1260, valid accuracy: 0.6436
# Iter-9100 train loss: 0.9573 valid loss: 1.1190, valid accuracy: 0.6462
# Iter-9200 train loss: 1.1710 valid loss: 1.1116, valid accuracy: 0.6480
# Iter-9300 train loss: 1.1149 valid loss: 1.1050, valid accuracy: 0.6490
# Iter-9400 train loss: 1.1597 valid loss: 1.0988, valid accuracy: 0.6512
# Iter-9500 train loss: 1.0594 valid loss: 1.0927, valid accuracy: 0.6534
# Iter-9600 train loss: 1.1444 valid loss: 1.0861, valid accuracy: 0.6542
# Iter-9700 train loss: 1.0673 valid loss: 1.0803, valid accuracy: 0.6564
# Iter-9800 train loss: 0.9639 valid loss: 1.0752, valid accuracy: 0.6570
# Iter-9900 train loss: 0.9684 valid loss: 1.0700, valid accuracy: 0.6594
# Iter-10000 train loss: 0.9213 valid loss: 1.0642, valid accuracy: 0.6614
# Last iteration - Test accuracy mean: 0.6732, std: 0.0000, loss: 1.0475

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
# plt.plot(nn.losses['smooth train'], label='Train smooth loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
