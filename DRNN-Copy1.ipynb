# %%
# Data
import numpy as np

# if __name__ == '__main__':
with open('data/text_data/japan.txt', 'r') as f:
    txt = f.read()

    X = []
    y = []

    char_to_idx = {char: i for i, char in enumerate(set(txt))}
    idx_to_char = {i: char for i, char in enumerate(set(txt))}
    
    X = [char_to_idx[x] for x in txt]
    X = np.array(X)
    y = [char_to_idx[x] for x in txt[1:]]
    y.append(char_to_idx['.'])
    y = np.array(y)

# %%
# Model
import impl.layer as l

class RNN:

    def __init__(self, D, H, L, char2idx, idx2char, p_dropout):
        self.D = D
        self.H = H
        self.L = L
        self.char2idx = char2idx
        self.idx2char = idx2char
        self.vocab_size = len(char2idx)
        self.losses = {'train':[], 'smooth train':[]}
        self.p_dropout = p_dropout
        
        # Model parameters
        m = dict(
            Wxh=np.random.randn(D, H) / np.sqrt(D / 2.),
            Whh=np.random.randn(H, H) / np.sqrt(H / 2.),
            Why=np.random.randn(H, D) / np.sqrt(H / 2.),
            bh=np.zeros((1, H)),
            by=np.zeros((1, D))
            )
        self.model = []
        for _ in range(self.L):
            self.model.append(m)
            
    def initial_state(self):
        return np.zeros((1, self.H))
    
    def forward(self, X, h, m):
        Wxh, Whh, Why = m['Wxh'], m['Whh'], m['Why']
        bh, by = m['bh'], m['by']

        h_in = h.copy()
        X_in = X.copy()
    
        X = (X_in @ Wxh) + (h_in @ Whh) + bh
        h, h_cache = l.tanh_forward(X)
        y, y_cache = l.fc_forward(h, Why, by)
        
        cache = (X_in, Wxh, h_in, Whh, h_cache, y_cache)

        return y, h, cache

    def backward(self, dy, dh, cache):
        X_in, Wxh, h_in, Whh, h_cache, y_cache = cache

        dh_out = dh.copy()
        
        dh, dWhy, dby = l.fc_backward(dy, y_cache)
        dh += dh_out

        dX = l.tanh_backward(dh, h_cache)

        dbh = dX * 1.0
        dWhh = h_in.T @ dX
        dWxh = X_in.T @ dX
        
        dX_in = dX @ Wxh.T
        dh_in = dX @ Whh.T
        
        dX = dX_in
        dh = dh_in

        grad = dict(Wxh=dWxh, Whh=dWhh, Why=dWhy, bh=dbh, by=dby)
        
        return dX, dh, grad

    def train_forward(self, X_train, h):
        ys, caches = [], []
        h_init = h.copy()
        h = []
        for _ in range(self.L):
            h.append(h_init.copy())
            caches.append([])
            
        for X in X_train:
            X_one_hot = np.zeros(self.D)
            X_one_hot[X] = 1.
            X = X_one_hot.reshape(1, -1)
            for layer in range(self.L):
                y, h[layer], cache = self.forward(X, h[layer], self.model[layer])
                caches[layer].append(cache)
                X = y.copy() # Output of previous layer == input of next layer
            ys.append(y)
            
        return ys, caches

    def cross_entropy(self, y_pred, y_train):
        m = y_pred.shape[0]

        prob = l.softmax(y_pred)
        log_like = -np.log(prob[range(m), y_train])
        data_loss = np.sum(log_like) / m

        return data_loss

    def dcross_entropy(self, y_pred, y_train):
        m = y_pred.shape[0]

        grad_y = l.softmax(y_pred)
        grad_y[range(m), y_train] -= 1.0
        grad_y /= m

        return grad_y
    
    def loss_function(self, y_train, ys):
        loss, dys = 0.0, []

        for y_pred, y in zip(ys, y_train):
            loss += self.cross_entropy(y_pred, y)
            dy = self.dcross_entropy(y_pred, y)
            dys.append(dy)
            
        return loss, dys

    def train_backward(self, dys, caches):
        dh, grad, grads = [], [], []
        for layer in range(self.L):
            dh.append(np.zeros((1, self.H)))
            grad.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
            grads.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
        
        dXs = []
        for t in reversed(range(len(dys))):
            dy = dys[t]
            for layer in reversed(range(self.L)):
                dX, dh[layer], grad[layer] = self.backward(dy, dh[layer], caches[layer][t])
                for key in grad[layer].keys():
                    grads[layer][key] += grad[layer][key]
                dy = dX.copy() # The input for the next layer is the output for the previous layer
            dXs.append(dX)
            
        return dXs, grads
    
    def test(self, X_seed, h, size):
        chars = [self.idx2char[X_seed]]
        idx_list = list(range(self.vocab_size))
        X = X_seed
        
        h_init = h.copy()
        h = []
        for _ in range(self.L):
            h.append(h_init.copy())

        for _ in range(size):
            X_one_hot = np.zeros(self.D)
            X_one_hot[X] = 1.
            X = X_one_hot.reshape(1, -1)
            for layer in range(self.L):
                y, h[layer], _ = self.forward(X, h[layer], self.model[layer])
                X = y.copy()
                
            prob = l.softmax(y)
            idx = np.random.choice(idx_list, p=prob.ravel())
            chars.append(self.idx2char[idx])
            X = idx

        return ''.join(chars)

# %%
def get_minibatch(X, y, minibatch_size, shuffle):
    minibatches = []

    for i in range(0, X.shape[0], minibatch_size):
    # for i in range(0, X.shape[0] - minibatch_size + 1, 1):
        X_mini = X[i:i + minibatch_size]
        y_mini = y[i:i + minibatch_size]
        minibatches.append((X_mini, y_mini))

    return minibatches

def adam_rnn(nn, X_train, y_train, alpha, mb_size, n_iter, print_after):
    M, R = [], []
    for layer in range(nn.L):
        M.append({key: np.zeros_like(val) for key, val in nn.model[layer].items()})
        R.append({key: np.zeros_like(val) for key, val in nn.model[layer].items()})
        
    beta1 = .99
    beta2 = .999
    state = nn.initial_state()
    eps = 1e-8
    smooth_loss = 1.
    minibatches = get_minibatch(X_train, y_train, mb_size, shuffle=False)

    # Epochs
    for iter in range(1, n_iter + 1):
        # Minibatches
        for idx in range(len(minibatches)):
            X_mini, y_mini = minibatches[idx]
            ys, caches = nn.train_forward(X_mini, state)
            loss, dys = nn.loss_function(y_mini, ys)
            _, grads = nn.train_backward(dys, caches)
            nn.losses['train'].append(loss)
            smooth_loss = (0.999 * smooth_loss) + (0.001 * loss)
            nn.losses['smooth train'].append(smooth_loss)

            for layer in range(nn.L):
                for key in grads[layer].keys(): #key, value: items
                    M[layer][key] = l.exp_running_avg(M[layer][key], grads[layer][key], beta1)
                    R[layer][key] = l.exp_running_avg(R[layer][key], grads[layer][key]**2, beta2)

                    m_k_hat = M[layer][key] / (1. - (beta1**(iter)))
                    r_k_hat = R[layer][key] / (1. - (beta2**(iter)))

                    nn.model[layer][key] -= alpha * m_k_hat / (np.sqrt(r_k_hat) + eps)
    
        # Print loss and test sample
        if iter % print_after == 0:
            print('Iter-{} loss: {:.4f}'.format(iter, loss))
            sample = nn.test(X_mini[0], state, size=100)
            print(sample)
            
    return nn

# %%
# Hyper-parameters
time_step = 100 # width, minibatch size and test sample size as well
num_layers = 1 # depth
n_iter = 1000 # epochs
alpha = 1e-4 # learning_rate
p_dropout = 0.95 # q=1-p, q=keep_prob and p=dropout.
print_after = 10 # n_iter//10 # print training loss, valid, and test
num_hidden_units = 64 # num_hidden_units in hidden layer
num_input_units = len(char_to_idx) # vocab_size = len(char_to_idx)

# Build the network and learning it or optimizing it using SGD
net = RNN(D=num_input_units, H=num_hidden_units, L=num_layers, char2idx=char_to_idx, idx2char=idx_to_char, 
          p_dropout=p_dropout)

# Start learning using BP-SGD-ADAM
adam_rnn(nn=net, X_train=X, y_train=y, alpha=alpha, mb_size=time_step, n_iter=n_iter, print_after=print_after)

# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(net.losses['train'], label='Train loss')
plt.plot(net.losses['smooth train'], label='Train smooth loss')
plt.legend()

plt.show()
# Out:
# Iter-10 loss: 108.2485
# ehg)ccG fag susddkan ir.lrtin-oo see peaa oms  gie本 r snihawann aatauaetlrliync  yhn diih lairmI ,pnp
# Iter-20 loss: 105.1927
# eL,gMuee S'g olm n inrn Bltepr ipc wo nienr nngi  ntpe iaondnit v JhctdodSA ,d wd  hro nsn tshdarps n
# Iter-30 loss: 103.9992
# eGm3Jc-girg aolhlccoEJysdnpu, 0lu eed a,l mhs,i i ilsn nt iot ony rhooen
# oEodh,wshw  aex"rnE ne tppno
# Iter-40 loss: 102.7892
# e4- 5dgoi hofe nG oeigiis mmesp rdtrihaa fmtbahtorat'gnl  wl u nfu tsn rntTa ensIri,a kdopaoanoin pas
# Iter-50 loss: 101.7321
# eGIHG6ct0a;fal Ea llcg doiutothoge r.l h ite fsN a ez    eih celralanece d1e gaedt TarShteEt  yt rttl
# Iter-60 loss: 100.7851
# e.lUp.ltr y ydvonxtaoetirt ultErl nN , en CJanl uuriunrl ietiehn hn8  ep5treaat.ronlfs ah nbehtW pm n
# Iter-70 loss: 99.9105
# e-.6 Ileh tsl Er ndosl8i- ial h–aeaowttinhbr  ean,Ua knn ntlnIaRwhsyfnft5i er rhnaeayln kr aeewd2d ia
# Iter-80 loss: 99.0286
# e.xpSprgiuttiprJ"twofrs eel iaeva,rinai. Nrelvogeoloen  k ns en acrna -fb.1yeW ihltwrne gsomeedSo a
# Iter-90 loss: 98.0594
# eLR,WetJ ar ine aorndiaaeanor loeereeoeogamsile W.d a Rnri9ets "ediT 5e,nee eoiaa nsoace tey lfmWster
# Iter-100 loss: 96.9739
# eisiwenjtie  ualprn ue jrUdnuy  to.l ot u pc In indrheUoasthw teah aa5ten  wpdtsavi pn todtpoe9ijRcer
# Iter-110 loss: 95.7893
# eG aarca 4alk isa r 5 enh Mid7d 1nurtst lp tee oh sep ;se ye aEpte en yffn5J rsrah i ao s orariEs ilr
# Iter-120 loss: 94.5677
# eCwa etu uhpdsIinl Al,Gnaiinth JhAea hee eiiy aflcan emneine iannco monejred een tthed neiterttth1e o
# Iter-130 loss: 93.3698
# e. hoprpda ee trl1in  sa oooAsin falSso abnt hmaaot. imsu oftulaay   eo d8sewi OI tclnk oeacr apul tu
# Iter-140 loss: 92.2086
# e5wIsfii chn tds aeoraairs wof1 eieasg  ae holcdsaor leTt,oia  indaiin3ogh peres In gioreagitu u6oknl
# Iter-150 loss: 91.0804
# eJ paolh bzyuuo Japcv,lpse Saamltanlim h-Iuriegtsrckas bofereoorr ' irc uooncth tneet unl ah ctnea os
# Iter-160 loss: 89.9905
# eK tJpan bh hooatf afe ant iltad iiielinso niata5ond JClaye odisrentee ink is  orde  bs hht pnu ,vthn
# Iter-170 loss: 88.9506
# e"y3g pw- de1 af aiee.l on4ei ohgs ih fd5tiorthu co–Hk  r0dopan codleea niae ok ihouec en nn rhGnn ia
# Iter-180 loss: 87.9763
# e SanlntPtnhmi ehant tyco aewhes ohd ind inttvrfy iahtercina  npJh, lhy rpplUt pddiiom meeyo'ato Rapo
# Iter-190 loss: 87.0760
# eWaawFefwtnd ay Noptrin  or cpeslGr sn ea hode  deli n AsreeltlnsEy  resednmo- toess xlEwee chieo,emn
# Iter-200 loss: 86.2448
# eNcodmiat, ,h oret rs hl IHl7l ine Jopvd nnlertflD2yre4thd hD mhprstnaa o4el8rreb in Jdlevdfpa. ra,e5
# Iter-210 loss: 85.4706
# ef JnopndktSgneo torcdlonetGm G5erlousyrihinc, ict tlgahol JaroebeJ1,'gis aatit te nR iyu xo4 he,sWan
# Iter-220 loss: 84.7451
# eL,afy ane1Joe iamgcwn' tpugnor Ihowiphtd Jtpe aragiss ARwcadk e-ir keli1s c pannsiegte genm Jatesmee
# Iter-230 loss: 84.0659
# enp'sesiaesaus se eatinc Jf atseas lL oidun rarc1dgansiJn afcom, chleplnt ay toaod  apcesr toent-dara
# Iter-240 loss: 83.4263
# eDoTne cCinttim ntl f e7 Jpptrtasu.ao nd dnd io oouhrson"yt nthlons ool kndip lntln ini,t rohlctien a
# Iter-250 loss: 82.8167
# e.)che ioacutr s, chpac, lree Sor0hr wlae mesota Intte Gal nap tsirtpenye ihelm. mho porse Sra tn ane
# Iter-260 loss: 82.2219
# ea gond iaotnsuaiaed aoa3tkunyv  ipmthd u  5 thr IftlW turrtee ce Ofr1iNsdgioe Jhiscpen ihe aparaoaie
# Iter-270 loss: 81.6215
# e wUufouJdgas s  hJahaupey Ttmprnestoelr, couliwa sso agduth. ot drsgtr ral war ind 'r eit ra3t neira
# Iter-280 loss: 80.9976
# erarMb Arangea estirrtpe wartstn 0liraneedhco日ld hx adrlg en oh Tin,.tlyapanr -eaaE chorwct ltte ledc
# Iter-290 loss: 80.3448
# encineitn iorot rm iasea  Nan e. a Paret1t warin.2. prissa tr on apde( f ioogrgan 9fs Sandtoe esuous
# Iter-300 loss: 79.6667
# eEa3h aoeuand Jilometh  nse eautmsn cetlimn, tel wf inonlvstoe e pargtuyddwoo Jamangtand Iofet 1nst J
# Iter-310 loss: 78.9688
# eu;uresgyo, toviner ere ohl iae wolsi. Ne shd 1ips i, os Npsandith intto tar gbtrtptnTe earaoltJreiin
# Iter-320 loss: 78.2555
# ef tne hhk -', toenthoi24 ts1nthe atled ohaton 6and uhasd aaggcsyuese Earn ,e hnt updnaet ingthe theo
# Iter-330 loss: 77.5252
# ey Sfn hn Hapen ,s0yi uthe rfs6titeangocirneJilh Iftth tointaiaha snr 9leminn,trme artrlkd a. a-eese
# Iter-340 loss: 76.7720
# ezEk15k3asi "t s gm perlh ithe nwgthicee4oocpand .L ioertftkindee tarean co elendermsr hin the A1lus
# Iter-350 loss: 75.9968
# ed cophryaiae ontwe fins Sh tedtaswgycs arc rargita ix yhutho ir and Toelon .evsisd of tak and de oh
# Iter-360 loss: 75.2087
# eMh Nistooeio. Ja'anc cpetholy Eono hhe terl1os tud oa corskst e ainmdekoeivI ore Gn aim pe t. Th' lu
# Iter-370 loss: 74.4175
# e4n fiuha Sig of JapTnoBU9.h56oletmK nn tre aed ao  emltsee theLloutir. y  apigdds ouohr aed ao.dtiio
# Iter-380 loss: 73.6624
# e'9–huuumxe re trr cy nm4eher Cop Gateea,oiio tsanoort8eowwbamfe tourty tcghr t-d wuolJ'Wan miac ioto
# Iter-390 loss: 72.8861
# eF,emerted ke iho 1dms medtirn  s l urtronny anrfemme JerNe of lasisn xs aaGI tRand dos titn o8alyman
# Iter-400 loss: 72.1638
# epIr9es nex0any cinh toom subilirg 'a iaoli ug r lar fliCf xtpe usonkre Japan Shemcan Nre,K urorath-
# Iter-410 loss: 71.5105
# eu foustea.g onulaIl sedtie ancis  per shllba is dolo uflt.ionein iuthiowo-lt roes. Japan ind an Ohe
# Iter-420 loss: 70.9233
# ed The mhun lhloiitsi ftrt lsemlateis tathan th thet, pelrtrer aod In Btlpsktte oieanl ipe is ipase.c
# Iter-430 loss: 70.3333
# ed ihuoaothb 1rpItion Fmeacees per-pgd Hom dad Cares. ci ynthikns s tisuned mien as ongeis anarnon.c
# Iter-440 loss: 69.8109
# e'1hz  Fpeoueor mE niol. JhedxKa"t rhen Wert. Jppang f0ea 1oev lstew ia oalt in wir eal entard ,imhy
# Iter-450 loss: 69.2355
# e dared panL sg of, ofe5Eda98-n omek ahl m7rched Ce Smmlol lirta s a ar nctdesnes rf,othe Eas untir t
# Iter-460 loss: 68.7019
# eTs Wercolets-sevinr waseyes wiuntrt. TSvthnss  ieren 1iy  ok lope. telmrxinery soesd cirrNan nhi  te
# Iter-470 loss: 68.1606
# exJapany anance eeg.eyI haeanecigrase Japen merhooa4d v本ghe Eolldcdtrth geparopoiae custiA 9ongapir J
# Iter-480 loss: 67.7791
# e, Ahelte hes oplins cxu5te 4froutleddoke ched mednko  s5sthe henino orcerr rp rel caraegInh dinaoe t
# Iter-490 loss: 67.2113
# eu"3tat tousoriy CWxparyy Gioand s moondit ware pale Birs anatatyh imhetcoulyk co is Aled Aialt otord
# Iter-500 loss: 66.7017
# ed Ch mangetym usfrfnat Uestis re th lhl mhd meutonsthesi f04s anexT nl 6n In Th Japang sftnoth ceitt
# Iter-510 loss: 66.3159
# est, toes9unt1d gea orrkEoved J t5tured anc, nhrtsc-ereMine ian is ifgustn hhochof islakyes nf ooulrr
# Iter-520 loss: 65.7762
# e whp tho lendain the,.lmtir f pimaovescoht ani-8.bo3 indth  areycoat.line en thonh ibetoeroy tiopea,
# Iter-530 loss: 65.3946
# ed Ts- irothl comhe aso ln The e2g Gnounslatin ie thecirgi's o(ten porerricg yulesaiin th a8dtoy  ire
# Iter-540 loss: 65.0037
# eA Ongeatut  nxpinttan jcemeare ce pilony ag maeilorirg. th n fars ceperle tis red  arlethentaris tul
# Iter-550 loss: 64.4976
# e' oSes7ahiy mart ch hedGihina an hioeovr insoc ahdcing wm erteoace E.tc6 Eegilos Ch oamy ineuy is on
# Iter-560 loss: 64.2031
# ebtoliouta ornt hin 1.is ol hh rOyi anoroas on wnttointe E7rsthl moethe WevimmNpel orlizi anaoon Ghgt
# Iter-570 loss: 63.7347
# eNwwof ol Ogpeng Sf lorkond oacing ord pard N本cedoth. SandoJal trsl fo btppthed G cherst.e Gegnast Hu
# Iter-580 loss: 63.5387
# e6 ahe 2-syrctce ioted Inrit. ofplr roly8S.n anini. Then is an us che sol thesiorsoe ine ony of inses
# Iter-590 loss: 62.9824
# ecfar, is ch enpt ioao irsiomtericome tedea, Ghs beoll Wes oh 1mpesth the ini,ean of JrpannyI  Chetea
# Iter-600 loss: 62.6439
# ei. Einh an lorrell inod tnasan es beritd ex, feuvnterern Wrmius. %fiv- antdh as uiul 9hkgCgerHas in
# Iter-610 loss: 62.2378
# e-Eapero-a. ware thy ind Witat. Jaland se mhe hal fara tad miutcom,prt th eftrrEss fa, the 1slanghe t
# Iter-620 loss: 61.9717
# e. chenhodean ustime the Pasf vtrl un the lopgortted iorlsgis ls hestog iottrccofwltpandry N5anEkk in
# Iter-630 loss: 61.4893
# e7 apemaran ss Jorad Eed lotul Niu,twin la iuoed th birgkon and Sour. Aiuoregkin iimirapyy 1o eout.dc
# Iter-640 loss: 61.2018
# eO Ene holipelglire sise iggene Oopelit er ro lio
#  fm, mtestfrset us, nas andin  Iredkd o8 i. the wak
# Iter-650 loss: 60.8613
# eWd tiratitati isy ivheye paktedlane anernise nor Jipanjna. of is the Gndmean ty ambllran ry inderiom
# Iter-660 loss: 60.4524
# ethe Eethl Sinmeoni lging oprlini med 8mand imoes istf fhe GLlenoano Ataliest r par of rre pasnwur tu
# Iter-670 loss: 60.0251
# ed Cfxaf aod Eban ion onar and it lec,lirlisourofawand lar rnal inp a, chras, in the Womatcy sore tar
# Iter-680 loss: 59.8075
# eL of an chk Pht aniugon tcttn opsmioo thl 1ftJ 18vm.ed tnith meareid iss iatoe4dutet hmlinee. vareds
# Iter-690 loss: 59.2496
# e)-8opy a. the Fous. JoponlimI are of 19pGd ing ofliwe lkemetthegeagiUnn A,evn colasdas iJar an aod d
# Iter-700 loss: 59.1334
# ede ware isiousek mpen ltly se feldfiuht ofardcoB2ald la te ing woratsi cfluthee bopltnlewa8  edpme t
# Iter-710 loss: 58.7945
# eoIChen thl domlel wert .e pond aJ feolissuseital wnllll wtulat maean e ware ohet9ep13sucol.5 anr dis
# Iter-720 loss: 58.4653
# ed Japan th ingiaht Cseisrtcc heopaonf fhia7 lntartich ndaiwes Fsta Japan is canled Eean sd eiwedeHin
# Iter-730 loss: 58.1177
# ecofhect rrlei caner 1vio ofnin teulesstd taren pirlo,s J pard Sard wukipareswy uEsas as -naicine thy
# Iter-740 loss: 57.7366
# en JhpaGofs. emperted io3 angedas ice aad orp ss lhem pupany. werttoh Eape The tiontis fortd tel ltor
# Iter-750 loss: 57.5565
# e the nrled Orrn bounlrgio thkd Adeseastec espal cousts th chunerjns esler th snaly ted thex"Lot lani
# Iter-760 loss: 57.1952
# ed Whunc af 1n3n tf ioviry In lerloar. ,oKJmaind Ja3 werl lhcM iss oft1E.sereas mautaoilitd Efiltreat
# Iter-770 loss: 56.7514
# ead Eesiousoiim tne Shs oud, arlant c exte kiet.s f.evtard Th ix artino isitS chandwted Weptletin is
# Iter-780 loss: 56.5673
# ep 1rks is tol copae ioiming vopedeve,eoed prlulaleggousiu estor8tse gao ha, Wempes rgd cgovavkrae wa
# Iter-790 loss: 56.2735
# ex ale ponl laliwris toksnit ianony enthl as ceulsgeasian haay ficote axse mage "omlinyas mageretsy
# Iter-800 loss: 55.9705
# ed Aimiged o:udnternduin ci6 1h1 Iwrghee ourtontty pan The OSesean. The Therean touliwa.  Sesthe and
# Iter-810 loss: 55.6557
# es atdll fnxth chkr fomeiche sh vists the Gcanyanese Japrrlicciante s pnottl weltcomital 2ale Paon Jy
# Iter-820 loss: 55.1157
# esourloa. nhe Hpenthf ond cerer7es, ah th Eingkag nase weouas aren apanirt roarge fosy ceaes les ande
# Iter-830 loss: 54.8543
# e wored'd fsustolosesga, Iofutttons. WormtegSen as heiotdsitn i, the foxs oorer. AHapan fd intoo, ote
# Iter-840 loss: 54.8248
# e7;ompen an amilstcare shin 1e4lege J7peJ6日日)tI
# Lsnneoind mrrrep ea a本 Eotel de Uisy arkiofder Inmel
# Iter-850 loss: 54.4534
# el fflrl ag  at r, and J pary Cian nd t lolegeagisg a-refpard 3sNanard To geseato irex in, Txr Japan
# Iter-860 loss: 54.3501
# e1Naw oulyst gh ns ioilititw panpic counso iod intt iy Japan te eo4apen f8 d pan usd mellarr risg ofl
# Iter-870 loss: 54.3985
# e
# d's augery omy Waro sa instid .sstir eammounel xiortin ar thon route tit  a8alan th cilrgind culowi
# Iter-880 loss: 53.7617
# en Cheotr ce Endldinysi.d ingthi nmap tal Japan Se iss is  heshan okeeas 9mieutis ao is lopaeny pavin
# Iter-890 loss: 53.3673
# er1 gi and Bnant dy the the tepeldfart chesard in th  cllerelld Ded tourtoun sarAsgtn thede omlorofst
# Iter-900 loss: 53.0642
# e
# . Earen Japaneacthod lg, wmrel ent ouses. Japan Japandex. ofgpieas tol the prrlort ctelimerestu.gon
# Iter-910 loss: 52.8889
# e 7old pototr torcorgand Iu th and fterdester re capaciin wiki ho 1813acan; io as aseatre nogh- Grmer
# Iter-920 loss: 52.8327
# ed iseth, murry 1ore 17Kl thryg. coprred In th eEelclSlnin Aina atle Iosu anand cabit led ahd Ghen re
# Iter-930 loss: 52.2705
# exiEhe tolying puptst lat af iofelen ohe GEesio1ges wored Is tomeonioo fof onpenir.. Japand upangre.
# Iter-940 loss: 52.2196
# ehe rhpeG orlurgomd bared I. pxrald s. papariy;, rhe tale aid th certlled cile htoryl "sestur rtc, oh
# Iter-950 loss: 51.9754
# ev chl mo omenke mooneis n rhoce parenle. Tlean oI teronohed ure tured d bagcal ivstho .aiint hs Moll
# Iter-960 loss: 51.8518
# e: Srlof Cs Eas, Nh Japan. mnerte tam,8an ha inokicettino an es ard 6ountnd ias aurytf memfpugins, is
# Iter-970 loss: 51.4202
# end Japan was corloly wfgen and tes Eeah fy wucetealyian, Sio of Openelicinnt; Gmoentaryec.xgine ins
# Iter-980 loss: 51.0305
# ecanwesi tse wargeig hitid fine Wapes of iha bfd mpertrd ie toalint in asod ond cofndeare revthe al t
# Iter-990 loss: 51.1313
# e日 1pbol;yn segtar wake Ts  prliroky astea ond caestoe Nllirour. Uanih inoredky pit thin soustith y p
# Iter-1000 loss: 50.8404
# ex.awin pand vssereiliUplya, suret an fpeltorlecand feneic pendld oums isin-kand Jap52 w2tfow本o GDdis
