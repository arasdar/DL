# %%
import numpy as np

with open('data/text_data/japan.txt', 'r') as f:
    txt = f.read()

    X = []
    y = []

    char_to_idx = {char: i for i, char in enumerate(set(txt))}
    idx_to_char = {i: char for i, char in enumerate(set(txt))}

    X = np.array([char_to_idx[x] for x in txt])
    y = [char_to_idx[x] for x in txt[1:]]
    y.append(char_to_idx['.'])
    y = np.array(y)

# %%
import impl.layer as l

class GRU:

    def __init__(self, D, H, L, char2idx, idx2char, p_dropout):
        self.D = D
        self.H = H
        self.L = L
        self.char2idx = char2idx
        self.idx2char = idx2char
        self.vocab_size = len(char2idx)
        self.losses = {'train':[], 'smooth train':[]}
        self.p_dropout = p_dropout
        
        # Model parameters
        Z = H + D
        m = dict(
            Wz=np.random.randn(Z, H) / np.sqrt(Z / 2.),
            Wh=np.random.randn(Z, H) / np.sqrt(Z / 2.),
            Wy=np.random.randn(H, D) / np.sqrt(H / 2.),
            bz=np.zeros((1, H)),
            bh=np.zeros((1, H)),
            by=np.zeros((1, D))
        )
        
        self.model = []
        for _ in range(self.L):
            self.model.append(m)
            
    def initial_state(self):
        return np.zeros((1, self.H))

    def dropout_forward(self, X, p_dropout):
        u = np.random.binomial(1, p_dropout, size=X.shape) / p_dropout
        # q = 1-p_dropout
        # u = np.random.binomial(1, q, size=X.shape)
        out = X * u
        cache = u
        return out, cache

    def dropout_backward(self, dout, cache):
        dX = dout * cache
        return dX
    
    def selu_forward(self, X):
        alpha = 1.6732632423543772848170429916717
        scale = 1.0507009873554804934193349852946
        out = scale * np.where(X>=0.0, X, alpha * (np.exp(X)-1))
        cache = X
        return out, cache

    def selu_backward(self, dout, cache):
        alpha = 1.6732632423543772848170429916717
        scale = 1.0507009873554804934193349852946
        X = cache
        dX_pos = dout.copy()
        dX_pos[X<0] = 0
        dX_neg = dout.copy()
        dX_neg[X>0] = 0
        dX = scale * np.where(X>=0.0, dX_pos, dX_neg * alpha * np.exp(X))
        return dX

    # p_dropout = keep_prob in this case! 
    # Is this true in other cases as well?
    def alpha_dropout_fwd(self, h, q):
        '''h is activation, q is keep probability: q=1-p, p=p_dropout, and q=keep_prob'''
        alpha = 1.6732632423543772848170429916717
        scale = 1.0507009873554804934193349852946
        alpha_p = -scale * alpha
        mask = np.random.binomial(1, q, size=h.shape)
        dropped = (mask * h) + ((1 - mask) * alpha_p)
        a = 1. / np.sqrt(q + (alpha_p ** 2 * q  * (1 - q)))
        b = -a * (1 - q) * alpha_p
        out = (a * dropped) + b
        cache = (a, mask)
        return out, cache

    def alpha_dropout_bwd(self, dout, cache):
        a, mask = cache
        d_dropped = dout * a
        dh = d_dropped * mask
        return dh
    
    def forward(self, X, h, m, train):
        Wz, Wh, Wy = m['Wz'], m['Wh'], m['Wy']
        bz, bh, by = m['bz'], m['bh'], m['by']

        X_in = X.copy()
        h_in = h.copy()

        X = np.column_stack((h_in, X_in))

        hz, hz_cache = l.fc_forward(X, Wz, bz)
        hz, hz_sigm_cache = l.sigmoid_forward(hz)

        hh, hh_cache = l.fc_forward(X, Wh, bh)
        hh, hh_tanh_cache = l.tanh_forward(hh)

        h = h_in + (hz * (hh - h_in))
        # equal to
        # h = (1.0 - hz) * h_in + hz * hh
        # or
        # h = h_in + (hz * hh)
        # or
        # h = h_in + hz
        # or
        # h = h_in + hh

        ## SELU + SELU-Dropout
        #         y, y_cache = l.fc_forward(h, Wy, by)
        #         y, y_selu_cache = self.selu_forward(y)
        #         y = X_in + y
        #         if train: # with Dropout
        #             y, y_do_cache = self.alpha_dropout_fwd(y, self.p_dropout)
        #             cache = (h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache, y_selu_cache, y_do_cache)
        #         else: # no Dropout: testing or validation
        #             cache = (h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache, y_selu_cache)
        
        y, y_cache = l.fc_forward(h, Wy, by)
        y = X_in + y
        
        if train: # with Dropout
            y, y_do_cache = self.dropout_forward(y, self.p_dropout)
            cache = (h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache, y_do_cache)
        else: # no Dropout: testing or validation
            cache = (h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache)

        return y, h, cache

    def backward(self, dy, dh, cache, train):
        if train:
            h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache, y_do_cache = cache
            dy = self.dropout_backward(dout=dy, cache=y_do_cache)
        else:
            h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache = cache
        
        dy_out = dy.copy()
        dh_out = dh.copy()
        
        dh, dWy, dby = l.fc_backward(dy, y_cache)
        
        dh += dh_out
        dh_in1 = dh * (1.0 - hz) # res

        dhh =  dh * hz
        dhh = l.tanh_backward(dhh, hh_tanh_cache)
        dXh, dWh, dbh = l.fc_backward(dhh, hh_cache)
        
        dhz = dh * (hh - h_in)
        dhz = l.sigmoid_backward(dhz, hz_sigm_cache)
        dXz, dWz, dbz = l.fc_backward(dhz, hz_cache)
        
        dX = dXz + dXh
        
        dh_in2 = dX[:, :self.H]
        dh = dh_in1 + dh_in2 # res cells
        
        dX = dX[:, self.H:]
        dX += dy_out # res layers

        grad = dict(Wz=dWz, Wh=dWh, Wy=dWy, bz=dbz, bh=dbh, by=dby)
        
        return dX, dh, grad
    
    def train_forward(self, X_train, h):
        ys, caches = [], []
        h_init = h.copy()
        h = []
        for _ in range(self.L):
            h.append(h_init.copy())
            caches.append([])
            
        for X in X_train:
            X_one_hot = np.zeros(self.D)
            X_one_hot[X] = 1.
            X = X_one_hot.reshape(1, -1)
            for layer in range(self.L):
                y, h[layer], cache = self.forward(X, h[layer], self.model[layer], train=True)
                caches[layer].append(cache)
                X = y.copy()
            ys.append(y)
            
        return ys, caches

    def cross_entropy(self, y_pred, y_train):
        m = y_pred.shape[0]

        prob = l.softmax(y_pred)
        log_like = -np.log(prob[range(m), y_train])
        data_loss = np.sum(log_like) / m

        return data_loss

    def dcross_entropy(self, y_pred, y_train):
        m = y_pred.shape[0]

        grad_y = l.softmax(y_pred)
        grad_y[range(m), y_train] -= 1.0
        grad_y /= m

        return grad_y
    
    def loss_function(self, y_train, ys):
        loss, dys = 0.0, []

        for y_pred, y in zip(ys, y_train):
            loss += self.cross_entropy(y_pred, y)
            dy = self.dcross_entropy(y_pred, y)
            dys.append(dy)
            
        return loss, dys

    def train_backward(self, dys, caches):
        dh, grad, grads = [], [], []
        for layer in range(self.L):
            dh.append(np.zeros((1, self.H)))
            grad.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
            grads.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
            
        dXs = []
        for t in reversed(range(len(dys))):
            dy = dys[t]
            for layer in reversed(range(self.L)):
                dX, dh[layer], grad[layer] = self.backward(dy, dh[layer], caches[layer][t], train=True)                
                for key in grad[layer].keys():
                    grads[layer][key] += grad[layer][key]
                dy = dX.copy()
            dXs.append(dX)
                
        return dXs, grads
    
    def test(self, X_seed, h, size):
        chars = [self.idx2char[X_seed]]
        idx_list = list(range(self.vocab_size))
        X = X_seed
        h_init = h.copy()
        h = []
        for _ in range(self.L):
            h.append(h_init.copy())

        for _ in range(size):
            X_one_hot = np.zeros(self.D)
            X_one_hot[X] = 1.0
            X = X_one_hot.reshape(1, -1)
            for layer in range(self.L):
                y, h[layer], _ = self.forward(X, h[layer], self.model[layer], train=False)
                X = y.copy()
                
            prob = l.softmax(y)
            idx = np.random.choice(idx_list, p=prob.ravel())
            chars.append(self.idx2char[idx])
            X = idx

        return ''.join(chars)

    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        # for i in range(0, X.shape[0] - minibatch_size +1, 1):
        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def adam_rnn(self, X_train, y_train, alpha, mb_size, n_iter, print_after):
        M, R = [], []
         
        # Hidden layers
        for layer in range(nn.L):
            M.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
            R.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
         
        beta1 = .99
        beta2 = .999
        eps = 1e-8
        state = self.initial_state()
        smooth_loss = 1.0
        minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=False)

        # Epochs
        for iter in range(1, n_iter + 1):
            # Minibacthes
            for idx in range(len(minibatches)):
                X_mini, y_mini = minibatches[idx]
                ys, caches = self.train_forward(X_mini, state)
                loss, dys = self.loss_function(y_train=y_mini, ys=ys)
                _, grads = self.train_backward(dys, caches)
                self.losses['train'].append(loss)
                smooth_loss = (0.999 * smooth_loss) + (0.001 * loss)
                self.losses['smooth train'].append(smooth_loss)

                for layer in range(nn.L):
                    for key in grads[layer].keys(): #key, value: items
                        M[layer][key] = l.exp_running_avg(M[layer][key], grads[layer][key], beta1)
                        R[layer][key] = l.exp_running_avg(R[layer][key], grads[layer][key]**2, beta2)

                        m_k_hat = M[layer][key] / (1. - (beta1**(iter)))
                        r_k_hat = R[layer][key] / (1. - (beta2**(iter)))

                        self.model[layer][key] -= alpha * m_k_hat / (np.sqrt(r_k_hat) + eps)

            # Print loss and test sample
            if iter % print_after == 0:
                print('Iter-{} loss: {:.4f}'.format(iter, loss))
                sample = self.test(X_mini[0], state, size=100)
                print(sample)

# %%
# Hyper-parameters
time_step = 10 # width, minibatch size and test sample size as well
num_layers = 10 # depth
n_iter = 10000 # epochs
alpha = 1e-4 # learning_rate
p_dropout = 0.95 # q=1-p, q=keep_prob and p=dropout.
print_after = 10 # n_iter//100 # print training loss, valid, and test
num_hidden_units = 64 # num_hidden_units in hidden layer
num_input_units = len(char_to_idx) # vocab_size = len(char_to_idx)

# Build the network and learning it or optimizing it using SGD
nn = GRU(D=num_input_units, H=num_hidden_units, L=num_layers, p_dropout=p_dropout, char2idx=char_to_idx, idx2char=idx_to_char)

# Start learning using BP-SGD-ADAM
nn.adam_rnn(X_train=X, y_train=y, alpha=alpha, mb_size=time_step, n_iter=n_iter, print_after=print_after)

# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['smooth train'], label='Train smooth loss')
plt.legend()
plt.show()
# Out:
# Iter-10 loss: 36.9298
# c,td efsin tat ir lassat8snan.aric本soe, tmNhosrrog sTCthnegasJsnat8cbir4gs. ts
# czredewismrRs thchcluh
# Iter-20 loss: 34.9455
# c int oole org euuttyennre., na ehalaeaieppiimm coa.itoinm ie abewenmwieldilde 92cetarm. igeg' 1nl um
# Iter-30 loss: 34.6281
# cianveossin. lish 'nciioaniolania a9 Aalad inalete in nanh mr in an in th as th mh iWe hh an 9Wtl vh
# Iter-40 loss: 31.1208
# cide me, oF en, 341he aad in as niW si calonm it in as as mide nmme malas Aneana easd mn thi an c4 mo
# Iter-50 loss: 30.5948
# corrd dususmencithceor tany Euur% 0onnPede od, camhonthe coun,-iur osamen
# asancecacaa caeit is Wontns
# Iter-60 loss: 32.5569
# canh pharatrr of tergdic Wimlth"t Asunvy rtatularal 4本upe, inlamintion "tittexs insa an s icos arhars
# Iter-70 loss: 29.5962
# c, eteb and Woald andanea end Rnsnuunecossuo caneu . in theot tenmame inttrof Jarya astanant Jinnitii
# Iter-80 loss: 31.8593
# cedoft Jryuntor Nokan radparc abu"%on and ninitaenr cenreacacosi
# aran iR 2%soruroururou4soraoussouaru
# Iter-90 loss: 30.3609
# ced asobog themWar. is rlamurthilr-marorm thar mrgalccurobcuttub s usskubru. eution. Hmo44 fofunsccro
# Iter-100 loss: 27.5020
# cmeur par elsudebigunitentermed puuumoortitherikeff xRlcixisa"gean;-HitosoS-se. Sor fosula;ag laesteu
# Iter-110 loss: 27.5519
# ctio. micsa. fhnante fiuntokain ionusestanaangaune8 an worsia is en i8eso entaroe inpe-tiudiJaJama an
# Iter-120 loss: 25.5283
# cg estatanisec in O. Ja41isea,iinc atiealome, in i is an, 188he Nalinwen inliino iisilasena e8 codunh
# Iter-130 loss: 26.0399
# ca tec,opea or.-iititaceat Ix ha. is urtiCaJapapen'panae nina Soe aoeagebaos aag kyoiusaloa an eumapu
# Iter-140 loss: 27.8295
# ceried forst tParampetittor As a opppede. UNop;rcrureas naaomomatitor r urid oo-bAtbbBuzor, in, rripe
# Iter-150 loss: 26.4559
# cily meropuc tent periprt te eat me Rourca ia taoegurre mimnou of ipunonaa evorubes. fru%o ritth t-ro
# Iter-160 loss: 24.0045
# ci,ylitury lanis the soulomint ious laokek, rastio, cavin riunto inccaina Niuntron. nxn sed lario % A
# Iter-170 loss: 21.9332
# ces-merougen Sr eimasense mo lame biptiopopopirikin asgoatytitanten Siontirnta inh rpocins a nest ana
# Iter-180 loss: 21.3573
# ciyost in tolethe censicaeana taven xD an as emeime 0senn a5 6um,z.  in 19, Jicenice iia o, Jatimidoi
# Iter-190 loss: 27.0433
# cam ert-ras cin cedicccc a c, Hivo, is oTlo"ateoi miror thi",-""Hdecos's ac amicha apana caios c cana
# Iter-200 loss: 21.0743
# c te forlesf rlecbecicdcacty cced. o Nitorcu aed rectem ba-Utiba agedthabad.ro naty. an itaccar.d eal
# Iter-210 loss: 18.4080
# cesreciinese Nand Afoulh foba. mhelottetted xxxvexiud. rebsu,cakuna. "Na%ankex. n u Sume. nuamakuluus
# Iter-220 loss: 21.1375
# chenec lUdeuu ime
#  edtt-enude tounthintermempuceuded umed op-ereusaur. in robetterothedt-xto ato-2a.
# Iter-230 loss: 22.2063
# cy itat. Japan is easar a miaicatala, the f lovit-ta an Seter. Japint a natatitaned in t pehaana. cou
# Iter-240 loss: 22.3654
# chas fodh Japan t inter pe 'he e papepaethe nand 21ethoe it thencaacaaeaiona d vae, Soe, Sa in of ise
# Iter-250 loss: 16.8747
# ch Wita nh cherto rto.. N27774777,,-20Sr,diNanor Sed-Nodr. o. %icocacenarona  nr int na cralo, rouaOo
# Iter-260 loss: 25.0290
# chhimelion oliNageaeic ixto 19nal urceaca cte7, ccraP, 6a cederareaceecerecaesece a imei, coanc aal a
# Iter-270 loss: 24.1722
# cisomy un rlyangito counaper is iroroteto anhked-r.rze Saiaec anered and.dd indccaeatanadean renos e
# Iter-280 loss: 22.1034
# ctor atd's fourte, lamnnttit perololimiletettritor an "7latelale, catona cana, cana, H, Icurusina t t
# Iter-290 loss: 24.3688
# cured irnd a. Jaeanttadca aney of in it te copoe codite iopeLater entenne Seeno ttteotape-tiponeaee i
# Iter-300 loss: 27.1418
# ctity fidtoriil leteeeaheeritetittuoman as tentor os the Sae lalaean toucced eceoeaueaportaretes arii
# Iter-310 loss: 24.0705
# cy Gthe hivh ista is 18, nolinimiaina, itolallan eoie8aapabonainn, nana imatita a, iuanatanaian,-Japp
# Iter-320 loss: 19.4387
# citection insenust and-nasea of rlomitudd Nobonotota an in inturolaUduiterourateoWoutonararou or a an
# Iter-330 loss: 17.6430
# cen rypegh in lan ecie7t- eed conuntint in Sinr noiino a-pebper andintin prrest n tio. to titil in in
# Iter-340 loss: 31.5410
# cured-calesle Napanl t iccortio Eartto-9-teeren re peucioauriu iu aicota-'uaetoratenoea,d-He rara a o
# Iter-350 loss: 22.9363
# cidreseco the Jbbec........ 77,M on larle EWr ind f nled ad d Jarad a  Eh. re oWi. 00ronted ovibon in
# Iter-360 loss: 13.1123
# c an Hucist rins pince iun nn e hirin; ithtaica the hat in sirnt in 1s4 the the hented nh nh c aca ao
# Iter-370 loss: 37.9434
# cion lextar nhstonh, theu inton Se in an catieea toudeden outo-meria ii44 4 aiooooatoetoe, tore7sumoh
# Iter-380 loss: 13.8361
# ca terions D sthe sprrans m mmeusa tanominca isia, san reu erowechan c mmaaea a an imaned Wordir  iru
# Iter-390 loss: 9.6422
# c Wtudicate se untitelainnattatintou andis isitaten timteriee of the wuteetin Cinal ireeterere e iin
# Iter-400 loss: 30.6064
# cisy of the eate se7, vicame Se fooeNaa ana  -7te irtoethe taecethiot oana ia a toaate enea a in i, i
# Iter-410 loss: 25.5630
# chereced entunhecan be "本uui,aten neutareanaiaunaeda, So'' cenia, iotiuaa an Wan aaone, ithin ins in
# Iter-420 loss: 18.6891
# cion elowent reaaonenatunamauaa adogetedonantedtinane e tfome ac in mimche ta %a an Hu"aco:. xx-27xt
# Iter-430 loss: 15.5300
# corand Im ilcea ion e sed a nheitetome en no mod couunof morlaroointoo my.oobbminaco for in ic nosin
# Iter-440 loss: 14.6582
# cakus Imin sorfass recseto-ztood raHH aplosist oiof in pilalorlont opafotindo' io aaifaaao ina mo'ema
# Iter-450 loss: 23.1492
# cy into a pitart centento e, the iuno e ieiteto the a  acitar Evan or lar an a e'   a ife a cane a Ja
# Iter-460 loss: 18.6462
# ch antsed Se canouunitan Hile;both toke in 1oi;e iconekooiic ncic, o% iolococininao iaitaonhadinateno
# Iter-470 loss: 22.3835
# camer in 194 4as muni7 in im in fonf'7 in minic in ii on il ii fad il 4lomo a  ib inl il imen i me i
# Iter-480 loss: 28.1414
# cintex and inttant in inste 4t centucectacicedccecadodea ded idece a 47th a cec aconezec ca; tacanoto
# Iter-490 loss: 13.2755
# ch eacanlurce' o eccacotelbcodecten toleu oa imame te NaNipitina'maNuaau anixoxIaokoke'tiolotirionta
# Iter-500 loss: 17.8582
# ch setevo ret A eferiotento in ie oolitid iiniooipirin 1i5 Jabitito45o. Jaouit 6, 7sos laocastoo Auae
# Iter-510 loss: 17.6357
# cy fostontintrtiol peceedel mimn it finss-nttoneccen ediceotel e%, Hilatecaleaaaeasurocerduno cheato
# Iter-520 loss: 17.8780
# cha empan's toseveof pi, intorn inirn iudt% e n1101Himzukd th-2o 2012s Le"d"dd777777777日,iv'de4NN日rpr
# Iter-530 loss: 19.8568
# cy finty gitatarsants nunatu a sacan aaddd taitaliidicetat stida4x'7 latiaan ;pad'vazivoo(o4zIzHazo7'
# Iter-540 loss: 18.1822
# cy hing hist rions n pin in nd nanat nit nihan 4 H DaropH fomanl mafffffffur'c ioo ontf nin noumithlo
# Iter-550 loss: 18.4997
# chimlovhu Spuritoatoboxcit AntotISi' in,7tist77d itin io inonoo ce 日inc i7t;7'777d,d'dddrct',tatenani
# Iter-560 loss: 26.9750
# cotle feme bists 0% mome minaNSSmmmmmmmrror%smfIramat oritartint amtase %iliala me mas a aittoiloft i
# Iter-570 loss: 15.1077
# co ted world's loNobele binRoncninnneusunonatiddin a in b in elins os lionoulotolaticaWakedepaontunin
# Iter-580 loss: 15.7363
# chicy. the E8rt coreo3 t intnd a7y Sa777H477""7:: 7, 7::ocdccidinioc nancIo7tevinaanneco aamend m nan
# Iter-590 loss: 23.7128
# care Caled's tope, inoval tacia aro,, Jape, a,, aretet tap ieiaeesee eeeeleee taudes i e e2La, 47 7 a
# Iter-600 loss: 24.3542
# cyst riratoxggtossrs. mimtl 12. i. an. ia a es.1amaadato d mhaaa . lala–a s iulo  a falasccsdalicevic
# Iter-610 loss: 19.6744
# ceshedt. Japan nan Ne, cedat lasstec'l  Nadaca a oedth  h  i a fhWahiWtWsztttzctttzy'zz setyyzjoNitho
# Iter-620 loss: 17.6443
# cion fountry. in nrtebsy th me    pen d Saan tata a as aae ta a   anoza  NadevNs2d .toddd  2' A 2H'.–
# Iter-630 loss: 19.4398
# ch in the G20 a an Plo, om an an u as ul m'' R s0000,, s,,,,,, c d, l cassel07nL%7,,7lb47, ,70aamo,,,
# Iter-640 loss: 18.4372
# ciodesense Japend nin ie"Cennnanally elove' f Hlloh21日hoconuchoco,contocumenlucclillolccllllececlcla
# Iter-650 loss: 20.7507
# caccinl id the witsl.13  imia o mamliyn,,%to3PJapipanatio a assicin tItapatapaDeobeateitinnnenestins
# Iter-660 loss: 19.1898
# chen tha, cos ascouco, co c ot Japan a icel me,,to c;;; h n oh ; h o San n l iel i, love,,unctoo ac a
# Iter-670 loss: 16.4922
# caltor lareicac.,,,caracantnane a and inensiced edii o o cionnLLBj"nd )xbbIub'. %so7's' 7oao4's',omoo
# Iter-680 loss: 16.7551
# chesided 3本yeis. Anenes is is ivosss fiveessttstlokyi in of in nano e ieediiiapisit npoiarote irsiort
# Iter-690 loss: 26.1841
# capinal Ditaeany An in in Jam imon iiiipmtapethrittataroturunininia mipturIponarinnnatintna isimipome
# Iter-700 loss: 21.2232
# comle Incy andad painsinh sited a laiamaiopaoohioeaatariatalasadnisidissessid ined in nn is na inaaii
# Iter-710 loss: 17.4326
# cy. In in Ansenitrox fomtIdefe t ll 3a. m m–apipaliti, rice o iimi o iloo i f  momii%7ontiin inloiild
# Iter-720 loss: 12.6625
# ctl Oxdolectorcwistenopot ton in ninhes ininopmmpemorereontondrriniiinonnlobal inaroonatiurunen ciin
# Iter-730 loss: 23.2114
# chesmcesmloUcos. in-mlytc. nnnnnnnninnanininman )mntot tuninar laciiiimeadedereadenotin a inae i ana
# Iter-740 loss: 16.7239
# carosican he frrrco oretod-s.om. D foria ffof4ftofolofouocono Star of rton hof in anoo urof 本iciotora
# Iter-750 loss: 17.9558
# ch fo restederiarseseded tx 1oga s tld tiSppppnppaalapapeenupanar, pini, ,,,uptupanpane, anine, as an
# Iter-760 loss: 17.0980
# costuryient Thk of Antupiouriturcudar cil,, min inecin io iulos mimonomuni ic o toninin clioo oftinia
# Iter-770 loss: 18.9081
# consIiu If HEmB ommummy 1ses4y Rom a,mmmn aa  n ioano a  in anioiiiiiaim am n aanaaiaaneaaenaaaneve a
# Iter-780 loss: 27.6556
# caliungitir ageg t nan the frer nar m aed oftar maret u ta re  a, minusao nrroufo  ont o in in ingio
# Iter-790 loss: 19.0069
# c World Wival poletdeder tiin is l neneaenotettdrartst, r, %h ea NaSSne%sas,ama,, maJan an i%a aaaa m
# Iter-800 loss: 20.4032
# c-largest sort emither.otapineciatoos of fommaminnaaaaaiinnmonniamhinominn niiioe inn mmilitouuuth fe
# Iter-810 loss: 16.6550
# ciderions omnn i de Of mlomiabinoca icici c rocoicomcma iicio a iiiicimicoccobcobobcc concoo oc in ti
# Iter-820 loss: 14.8717
# che namletiogh chint an to sso1opapmIo%tooantotodethoto an iononoa aneateuded sme7tomeeenont nothinof
# Iter-830 loss: 11.7504
# comanlecendy WJ% i % Ja%y y emmyo5N5  mi%oommo% nct l o%. %on  ann in iino iiiil mmancon i% inonc %o
# Iter-840 loss: 10.2873
# c op emvinand illfcliron in ond ffiontrardinririon tirnrol uur un liu a in nnuunio ncuuao cut oriinin
# Iter-850 loss: 11.6643
# ches ovolatin indllOstennendolses endn os l sioul tmmaledcodtrrruuu tssr  u ouutu me fuutizev td is f
# Iter-860 loss: 29.3147
# chipilith nin of il f7ef7 f infenf f fon torfi finiic iacinoriiimorf f fanf info f ff f;dfff irfoonfo
# Iter-870 loss: 18.4688
# Iter-1700 loss: 11.6757
# conogyus aneiind ipteette eris  eretttitito nnioritiecentt in innnt  s tee  e ttrittesecsirtt inisti
# Iter-1710 loss: 13.6642
# ctirges fountititorat miropdioadii itisiiiuninriinii  intitttrdi n inifittiiitirtitrartirinrcrinint i
# Iter-1720 loss: 16.6418
# cale is in intoio  e roea e r i  tto ten oetetee ia iriteoae     r torin n   itin crirtr rttrit  tspn
# Iter-1730 loss: 13.5565
# ch icalivovhr niin ucesseuierrrtrrrrmr nnnnnreinitit nrininnnen mnininnnncnnnnnnhnnn n nnnnininnnnnnn
# Iter-1740 loss: 21.1621
# cd thalaeastmathi  e r iiiiiiiii hiri m ciric ararch iii i ihiii mhirinih hiuiniuh iiisii im imaciid
# Iter-1750 loss: 15.9109
# c Gil Onh Snate e nm icaoasedea.'eiiaeiteyesiemedesiiaaed.dydeiddddndddeeee a irideadeiesud.d.rdoport
# Iter-1760 loss: 13.2488
# conhamenitto crermirrirmriuecrtarinataiasmiaititiry tiorttthriioirooooarmmutirioriiatiiiiaaoriimimmir
# Iter-1770 loss: 12.6834
# conomy bomio iniosoo throresthottestttoedittthtttotetthdtttttthit  tiri1es ithiteitttit  ttccemecotet
# Iter-1780 loss: 11.6631
# che isea seded m anhipmor nhrftatr rtrin rin tnt nnert ntrttrit rrritin atacautrretrrintntntttitt nth
# Iter-1790 loss: 8.4469
# cheo'vinhseos odo la anaoostohonppirh---arrcritennenntinciu  r sriirer cirnec n inese rerianeeriirinn
# Iter-1800 loss: 11.3100
# c eution. mii ur phirrorttte ninio i n nitio onnrroenon n nintt cs  hnnoen nnnnnns  innin nnn tit  ii
# Iter-1810 loss: 17.1348
# cy oJapanen' im    etiit  reee irte  i  io      rnnnnrano  n    n e niin a  nnni a   rar is   i t
# Iter-1820 loss: 9.6735
# chevealion leizurmscteeeeeeuniancuc ccc innc ceie nceccnngn  ccn nnnttinnci ignctc cnnic n ncccce   t
# Iter-1830 loss: 27.0426
# cted teleRmteccca mrcloceococ uupteicecitecicect c c ccic c cciccc ccccccccccncnce c c  cccnccc ccac
# Iter-1840 loss: 11.8901
# consyurante pu ortory  ite tiene metirirtaddyiihed tpptt. .. o   ir   t.ridiii.   i ii  itttttocio  e
# Iter-1850 loss: 25.2331
# c Gamiven. rasi. ir  rry i ieeeyicaliieeiieieieuiiaiiniiiiiiiiiciucin iiii iiiiitisiiiniiciic siuuuti
# Iter-1860 loss: 16.0920
# cgles pao rar thmmtnn   th n n  nns  t m a s hus  cist eenn t tes   nnt nnent t   s  uh i n tenn nnnn
# Iter-1870 loss: 12.6147
# c Gte Iarere itatetdde iinselineresescsedec drstses sddedlesde ced reeetesdlsesscdddsttssesscs ecsl c
# Iter-1880 loss: 12.1703
# cvise cou courr ura miinnun nininiiniiniiir intinounnicuniceiiiurnionricoicciniriououhunt piuruirimiu
# Iter-1890 loss: 14.8100
# capital irtato a a pereroaninrrrrrnnncnnrmcnincctrintnrhnnnnttttt tt  coattarteatttirte   crre ttntor
# Iter-1900 loss: 7.0693
# ccealess ay priiieorriit h netcin oh      t     ttt    s          c irtor  nhren ter ntthri ert t c r
# Iter-1910 loss: 8.8748
# ce and a rmilld c sensiniceti t enoiniirnnnnnindinsinittantn ietircirnii nnticuntirinntcnntthiicnnnni
# Iter-1920 loss: 13.1907
# cte 6oranl. ceiesertuttec  s   ctiiteteti cccitic c iethiceeu  ce a neeeeeeee eectttteecic e eee e c
# Iter-1930 loss: 9.4042
# coy the asentand d r e ttenecennarca dhacdadadee eera  ut  tttt deu  ctttt rhectccinhtinc cathcncrtti
# Iter-1940 loss: 22.7025
# cce por a r rr i rttttrtrs ttett   e e      a    hren n   n n   r h   n t n n n n rt     n n nten nnn
# Iter-1950 loss: 21.4130
# c Gereaethes te hh i dccith chr m ia c n on edd tr n  hntd cin      i    irin   c   u r  i c nn r  uu
# Iter-1960 loss: 25.1506
# ched wird hitehto deocts h tos nttt n  ann nnlnea in ie c en   nh d t riii nen u i  nn n ris is isisi
# Iter-1970 loss: 11.4380
# cd inld %nterarorrseshddmers isiu iiiicsi dtestusi   ictic rner nennsiiiih ciis fh   es den ic i  eu
# Iter-1980 loss: 16.7392
# cily ilits natt. a. ded a acp ptmmramicarac raciraramamacaaaaaaaaaaarraara rirnorirstmrarecariettrc i
# Iter-1990 loss: 7.3953
# chanito innt tagiiosi iris m       p  m   irin stilonnlol sns s  ntt  rtss rrs rnss r sin ns s ssss t
# Iter-2000 loss: 24.7273
# condytmmine on tararatcenserts    sssesstst u u uryu tr t camoto o fttrrtimitafttu rr Hho f ouu tkiuu
# Iter-2010 loss: 17.1884
# c, isvvendurtu tdanisitar ii s isir  ss is st itt i  a     i   it iioasassitrintssettanesosissssssss
# Iter-2020 loss: 24.7681
# cameyy pe pittoo opitichretccccontn   ooiio a oro e   e ia  arirt or    r  o    nih n n nioc ionn iii
# Iter-2030 loss: 19.0686
# cy inclanestunatunstitiint. r.sss m  u u  t k  iu  umh.  ir mm rri mimnar o irmi ui t inmnn inmnrmmmt
# Iter-2040 loss: 13.6675
# csy eaceoo tar  anit rirhtanshhahh hiiiie  iniee ie ii e thh t o t  rh r rhirirrr nirhicini corce  ci
# Iter-2050 loss: 19.7702
# cion oficeraddmtot endeo wiuit c    ctttct i  c c wcc st ccthrt titurrca crcthccc arafiniininincttnou
# Iter-2060 loss: 9.3063
# csidezecopered i. e ic m h romoss i mi iririiio oo r oio osiss n  o i   ir o piorichio n oorio siro t
# Iter-2070 loss: 12.5500
# conyt py por p omp rctii er tur irroochothuth utptutht u cicorrnsuriirirrrrrrrrrrrrn rintrrrncrncrrmu
# Iter-2080 loss: 18.8707
# cd, the ann tce  ncccaccono           t onahascacoryatdosoossossssstso thstosddo c d  n o     c acccd
# Iter-2090 loss: 18.1913
# chy wowil sich ithrishichn   o hiihsshhhi ciins iicendccccicicccnc c chata tc  cccc   t cc cichcc1cic
# Iter-2100 loss: 11.2934
# c, in the he s h cesis ceneacae hhc s 6h ss mgchhn h nhnhth h s  th s en nn   s isssthss stse sthisis
# Iter-2110 loss: 14.4204
# conomy by pa  icedtarouiiatarrononotanonsnoossnnthsntinds tstssattttecn tetncsssenis iciisttttir s
# Iter-2120 loss: 13.2014
# camelito 1e 4ifeedeeds dddddddeddedesdde  e s d.  did edsantd osstds s .iasdco sanali e cin.... an i.
# Iter-2130 loss: 10.9674
# c opothe eesh leeee c seses c ctk c a c a c t h cin th hhhh   c c c  tat. .ic  h   h  i i m ctith
# Iter-2140 loss: 6.0415
# canitation tee to pitutipitir tettt tttttf t p peen otttthttnteteee iissntttteteneecttiti   n  t nthh
# Iter-2150 loss: 30.9455
# cs, recexcaddcicet chnssedo fos tttunuuthtteuhttuatunnacin aua nt  tu oou unnun nnnnttun utucutuutnnn
# Iter-2160 loss: 16.5745
# come my of moftirbgfhintrcionontttic citcarccctt cith iacans bssisicictioicactacinttitaorg t eccccacc
# Iter-2170 loss: 9.3507
# caned Ciraeso oo pippapaaoiwe a pup pepna papap aaiponeu  siipe eann nn pnesnaaeaphpetautaasuoaua oee
# Iter-2180 loss: 12.2594
# canese War p d ami ph p r t p ttttistrhtt i mt totii     thh inii iitttt  eio i ie. iiiitt    a  ce i
# Iter-2190 loss: 24.0393
# ctond al pe Rin rhenee earearaertutouo   t tr     ut p     ip  th    mhi pn rurhhrtirsrinhnonnttnhtht
# Iter-2200 loss: 16.4457
# canal mhit  tettttttett    c ct  tc nt t t mtcc ce tacttcccccattttott ctittcc cceccont oocot c      c
# Iter-2210 loss: 13.5861
# constity uu pa pi ppo iiiieto h piipp papappaospi peisii pintiiiia       i  a o  int  p i e iipiu
# Iter-2220 loss: 4.6953
# co, arlalitarig ig c nh n   n restha n n necnscaraarnc annn annrn naannnnnnnn nnnnantnnnc anccctannnn
# Iter-2230 loss: 13.8567
# chmJalap on th nn ri  e ttt slstoat sssinnessns sss tt tatthesu sthss     hstsessts e es sts a es  th
# Iter-2240 loss: 9.4631
# conat mopon thuu miiiimimim p miuurit rrirh rtiritapt irinsiuerut  d d tic t iircctccc n eiteeetttote
# Iter-2250 loss: 25.4018
# comeat Ctogit eio tss glttttt ticgictcccccccccacccccaccc c a tit iatatac tcceat catt tit catiticccith
# Iter-2260 loss: 13.8064
# cd filstii h stteeisareaataatuttattttateretirttttctatcctcttateattttetecttaadaanstttttst irtttttaccist
# Iter-2270 loss: 11.6568
# cy Knitaty pupipirp ippmpmiiemrmiririrmpurtrrettrirrrrcri crrirccircirrrrrrrrrcarrrrrrrrirrricrrrrrir
# Iter-2280 loss: 15.1091
# cy, the thi chii cithiiiiiiiuuutuhuhhhuuhuctht ticthtthiithhithhhhhhghh  hh cechhh hhnhhhhhihhheghehn
# Iter-2290 loss: 24.0432
# ched bichrtin o i anogocasaniiioo s stteses  e eschn asedciaeaiaonc cctos stocon. ocd or t ppitiiinni
# Iter-2300 loss: 16.0670
# city prrorercerepirimicirarir rirrrit poropitmi mi mimiiririiiraratrr rirrrimtotoiuttum ttttt ttts rt
# Iter-2310 loss: 14.9682
# cire llglet peboapioionorino ioniiiio iiiiiioitiiiiiiiiiiiiiiiiiiiiiiiiiiuiiiiuiiiiiiiiiiiiiugioiiiii
# Iter-2320 loss: 14.9558
# camy centurilititiiiiiisititiiiiseiiiercciiciiceiiciiieeytiiiiatiiiiiitttiiittiinetttttttttttttttt tt
# Iter-2330 loss: 14.8801
# consty mirt  rr r p paie t iieitiepeeminirtitioeriniioint isiiii on  iiin riiiriit  ttiiiiiieiie iiio
# Iter-2340 loss: 16.8046
# city pepprefir iaiarp rio ee euo  mur pup  iu  urooooooooe  orori  ossoteeeeeeoteeeeoteeee thte eeett
# Iter-2350 loss: 7.4939
# combamby ca a o  al lattrapw prd ar rt p pipl p p cis ssalatlnnneran cc c c c itrtaeaao camlcnilicccc
# Iter-2360 loss: 14.6898
# comcemeale.  pe  ie pip rm s r tslce e c c cctcttctttt c cntc e cac cet ttat r tttt t r s t c   t Rc
# Iter-2370 loss: 9.3636
# ccenry Ind Rilotat tisisiaoa ae eenassintshareata1ef.aicicenessassssnrsinasssssnssicssacat csarisesss
# Iter-2380 loss: 19.4557
# cidestarel. ayy, sg s catttaskeraradeea ammerira  rea aria rrie   rmirirrr carncer r  n n   rocacaoam
# Iter-2390 loss: 5.1788
# che tion. A55s1988  a s o to  8 it e   tiisiia aahn i sa ii4shnaessth nh4nnheneenta inooeinsente  his
# Iter-2400 loss: 24.5651
# cy Ganloti0analalarelallalac ledutl lialdllllelelll aulaicaacii idaaaiaaaaaaaaa ass ii  aaaiiia iat
# Iter-2410 loss: 4.6931
# chaibins, asy fur rrtiroortttoarprtttpttrtigertorar ororrirtrsttittrotarttcttatttieatiiiioortnnttttet
# Iter-2420 loss: 20.2106
# cedity a prered,eesser at ceaeces.cec.rrkccaaayrccccmaccydiccccds.cdrs ccyy  ccydccicers.ccsydy ichsi
# Iter-2430 loss: 23.2259
# camt o isolaterioii aenea  tasa aaaaaasas i ass iaaoo ianaaaaaaisiiiaoiaaaaa aaaadsaisoasa  o iiosa i
# Iter-2440 loss: 11.8086
# coxcran a a g neaaln lalat nitet aei    teras etee e ceannaasennataaananaunaaaaatllsaaaaalaleaaaaaata
# Iter-2450 loss: 14.4933
# cy, the th witiiningiiiiiici  nii cyd a miiiiiiiiirtictit mmiiceichiiiitumm itiui    iuitunrititrmtin
# Iter-2460 loss: 13.3294
# con the mboliggfom a motht mggmagaaataaaaaahaaaaaaaaaaata atat ttatttttttti  a ttatatatatatatatatatat
# Iter-2470 loss: 22.2893
# c Gurdes usic ssuuessudssessusavesdaruuuarctetuuaatatasatataraasssssa aan tuskkaaasstssaasdausnuuunus
# Iter-2480 loss: 14.2225
# ctd in lland iae deaiiarlealaaraiaalalatuiaaaartcrindshsiusis s leeiius a eat aaaaa a taratttiiiii ti
# Iter-2490 loss: 9.9073
# checistedeighesteseattu uasaaaaaaasesesee u a s sssisaeeassseeass ansssssa is a aisasatatasanta  eeee
# Iter-2500 loss: 9.7689
# ched loleg 2lelottwlsssssossssaaaasaaaasaaasasaaaaasasaaaaaaaassssaaaaasaaaaashsaaaaaaaaaasasasasaasa
# Iter-2510 loss: 12.9201
# co declanese toseis so  sa toceaeeeeeeaieauuueeaaeaaaeeoraer c soctct icietair ccc ctceaecear u carer
# Iter-2520 loss: 13.7037
# const tomert p cn cuucho tttuthuuuuuueu   uuutith tu hhnt  tu hiniichtihthhuuuhthhuhhuuu  uthi huhuhh
# Iter-2530 loss: 19.1680
# c Gaves.
# . se setch en cen thn n tee inece iisseste aeee eeeenestsuusuusiiisusssssaasuuaaaaaaauuuasuu
# Iter-2540 loss: 18.2369
# chl techcecteceeccdthccr crsicictctittcicccccccicccccccccccccccccccccccccccecctsssccc  ss cccccscctcc
# Iter-2550 loss: 21.2898
# camety is tonsescatadaaaeinnnnennsa enaianatasagnoeena esaeisananagananaaaaaoiiaaaaaaisaeeeaeooaa,aoa
# Iter-2560 loss: 8.0511
# cd whapeus tic weu tic ato tksertteccacccccctitttttctticccttctttttdtttttacicctccccciiccchchticitiiici
# Iter-2570 loss: 13.3895
# cfes6 isttvin 2hh  Paaaaaaaaaalaaaaaaaaaaaaaaaa   a atanaiaaa ani a a   i aa a  n nanaiaanaaa asianap
# Iter-2580 loss: 17.4487
# cheh clalest minereeii inot sasinstannoaaninasiattannannannnnninia in naannomainsnsstntntrrnarcintins
# Iter-2590 loss: 28.9539
# cllotitofer a d ci aadtildeaeae dca a i d c ma ain vav aia aa ara as                       m      i
# Iter-2600 loss: 18.7084
# cerieled lecasorand, ceerartcrirarrnce rnrarttteeacaaatttttereeetteteetttteetatt reeetrattttt  rteae
# Iter-2610 loss: 6.7022
# cd ense Hors tiokakes icaiii cciccic iicaciic   e iatatif iiriciraracerleeesssussasissssississs isis
# Iter-2620 loss: 15.3437
# chipanity mmerleiscaaassso o  ociinnnllccriera cens eii  treeaeneriint irceriiniiin irie ariirireieie
# Iter-2630 loss: 12.6601
# cfcaled o ece erer prorararariiiiee e itdiieiiiiiiiiiiitni i i iriiiririi  riririririrititiritrr sirr
# Iter-2640 loss: 8.5184
# ctextitat 9elerinataariiianrasaariarae araraa  ir a c rrris in a  ar arsir as arrar  asirinarrararari
# Iter-2650 loss: 8.5342
# checi9an tani4is a aii aneeeeo an ensseoinis  esshsgsiiinini   nss istaaissash asss tsis   iis innine
# Iter-2660 loss: 15.6035
# chity ith R9s stse sst  eeeee a e s t i a e a amarm aaes a as at as asmm as m ieucte      s        ss
# Iter-2670 loss: 13.3572
# cifemen'e inetesea ireteaeeeececerece eeres e siseeessacdransra eransesasstt r atta cn n caaaatattttt
# Iter-2680 loss: 14.6587
# c. Japan issss apappapateosaaataasliassa astet a sttsttt sttt istss  tnitei   i  t aniisa    s taa  t
# Iter-2690 loss: 13.3851
# ch, theith itiehtmiytc ceehhhhvhat3 ihahhian i ctacciiicaiiiiiiihiiiiiihiia iiiiii ia  ia a      h
# Iter-2700 loss: 16.3100
# city propertocoppppreeeeroerrocitieoocor ooooperaroronrrororepteoererooerearetractcctcciochcettttictt
# Iter-2710 loss: 7.4400
# che inlalediss si segan sariiiiirisiiiiiosiaaiasanasaaa iii iiaia a ariiia aiaea a cos a   airia i a
# Iter-2720 loss: 6.5163
# chirtlititapan ermeie andia a s ssseaid ie tere e   teeaisarai aaana a iaaaaa eaa aa ai iiii aaee a i
# Iter-2730 loss: 9.5189
# cks. worldes wylattd,daaedaraaad  arae c r rir riaiw rirosawe sttara atarcadeace aawattrdiwarraraarea
# Iter-2740 loss: 11.9687
# cedledlor and whtht s lethintetaetttaahafnteatanmeaaataetee minariaaeaeueeoaete erreeaeeneaee aroeara
# Iter-2750 loss: 12.3253
# c Gandex Hukyiyeta ecccsiiuuseses ssssssksssss asa ssss tsHedeHse0scesessacasssarnssfsascaeceesoee ee
# Iter-2760 loss: 19.8546
# cedsity Sea Jageccy aunoseasasasa  e rss ssssccsoleciaiaisssaseasasaaaaaacaaaaciraaacaaiaaaaaaaaaaass
# Iter-2770 loss: 10.7572
# chy 6ery Japanina   a ial a aatalatatatata  a  t                      r
# Iter-2780 loss: 7.5700
# cita mee pperpep pppopecceer  riri       r piiio iii piiaoiiiaiiiaiiraiiiiiiiiieiiiiiiiiitiiiriiiiiri
# Iter-2790 loss: 8.2689
# chio che alle seisithtari tifea    a  ra frf i  rir th  llain aa  e s   a sesanhta aa ar riatraf  a
# Iter-2800 loss: 15.6196
# c Gabos I. let mstesaaa aaaeaseet eessssae aaa aaaaaaaasa aa aaaraaaaaaaaaaaaaarattaa arta ad  r maaa
# Iter-2810 loss: 29.2522
# cle in etend med Ptec  e  d   y cc  daaa d ddd; dr c ni     aryt r  t   d i  r r a a        ca
# Iter-2820 loss: 9.8839
# chest ccmccediced innxict iciiiciinticiiiiifniccictccciitttiiiitaticiiiiiciiiciitiintiiiiiiiiii iiini
# Iter-2830 loss: 16.5479
# conat more, mt bn ioss i os o tissia isiororas   orosisosooos sososti oso orooasosioasosoaooa ararasa
# Iter-2840 loss: 29.1156
# comed and Tuenn rn rlorarossnsarsss  ss ssssssss ssssssaasss sssasss sirssssss rirssssossrar asrsssar
# Iter-2850 loss: 17.9098
# conomy by pouoreteecoooosoooo本oseretttrifofttttfhfotefiifttititotir ttsettthsoritt atorirhrioostosssa
# Iter-2860 loss: 12.7165
# chillldecea ar,edcapalapewaaaaaaar rararaaaaaaaaaaaaaaaaaaaaaaaaaareraaaaaaacaraaaaaaaararaaaaararaaa
# Iter-2870 loss: 22.5372
# cy enions in lasto  ooooooooso oioo  ss so sose    ii is  eos s ososss  s  iiooooss sssssssstsh sssst
# Iter-2880 loss: 14.6986
# c. Japanese petisiea a s  p a sessa eeeaasseasssssisss aatsassseineneeeteaea a aas s a i aetaaseaa ee
# Iter-2890 loss: 7.3294
# conythu and bi icimiitheeoei iiciimsimeiiiimiiiieshehiih gi   ishi gimiigi ii   i  miiigioigii iii
# Iter-2900 loss: 18.7451
# citainyyuua eriseseuemeceeecccececccc eeccseeetoseee estseee see esi c po erte e s at essdatstatcnecl
# Iter-2910 loss: 21.8234
# chato anita a inarceee bea. ii.iir nno cicaia aaiiiicaiatacaririiloiiaaaaaaaaaaaaaaoa ceaia    ii aai
# Iter-2920 loss: 11.8969
# c Gavede.
# . soseepsssapateeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# Iter-3140 loss: 9.8464
# con-mo by meoosiissss tt  iiiiisiiitttttitarimiittattoosisaiaaaatooaraoracalotasptaaoo a orort trtrii
# Iter-3150 loss: 13.8146
# city eaperit reeartptpeaeoporeopopiaaaaate esereaaseereeeareea  rrrerrrarsttteeesseeeeoaoerrr ratrtar
# Iter-3160 loss: 16.9833
# camest cortrare wateaiiiaaaaaiitararlraiaaaiatiiiataiimaiiamiiiiisiiiiiitiiiiiiiiiiimiiiimiiiimiasiii
# Iter-3170 loss: 14.5065
# city in tivesttisiteipaaaiiniisi pi piss ar  p iirtnir te irttteaiitoatttirirarrara pn i ttss eree ri
# Iter-3180 loss: 9.6746
# ch pircelobiccceesoceaeisi sssssos.aasosss ssooooooiooosiscsssooooacapoooooossooooooaooooooooaoiooooo
# Iter-3190 loss: 13.0912
# ch eacanic. So seos thih is a rimsotohttstsnstahsssssfH seeee ereeee eeeeeeei isit a ahhhehete s ccae
# Iter-3200 loss: 10.8204
# c. Tath es ritsiha ssss ssssasaaiass aaasasasas tisaaaaasaiaaa asaaaaaaaaaiaaaaaiassa aaaasaaa assasa
# Iter-3210 loss: 12.9161
# cy srveaed fusi uriueouia aua  r  a ounueeforitta trr ciiirtuuuuorathtaetiroiaaiaracaeaiianooatooiaaa
# Iter-3220 loss: 9.0052
# colametionded tt teaiatataaaraaarrrataaaaarootoopoooraeooossareiitutiianaterrottoiioooirsssotattertro
# Iter-3230 loss: 17.3042
# ceo, the caciioccccashhcacctchfifeseoiciihcttscahiriiooiohcoaaagoicia ariroamchctn aicaciii cicio  ia
# Iter-3240 loss: 7.9408
# ce, the chcieehtccccccccaccchcccccccihccccchn etcctcccctccccccccccccccccccccccccccccccccccccccccccccc
# Iter-3250 loss: 12.8586
# cled-Japann asseinsseelas  tn it let n iatasalan  a talases terin atananes irt a t t e t t sefettnira
# Iter-3260 loss: 13.3759
# cs, the hh fhthtis coielictcuthhacc ciacacttihccac  cacccccicciciccccccccccctcccicccat cicoicccccccic
# Iter-3270 loss: 24.3274
# cod eatla, fiomt eetththteathhttttttttttttttttthttttttth ttettttttttthtttttttttacc cithec hecttttttat
# Iter-3280 loss: 10.0866
# c GuIed.
# . ucadaaaceaaaarareeeadeatereivavgaatavasavesekusaadsstaaarvreararaidsavcvsrersdvtevsssvarar
# Iter-3290 loss: 16.9125
# chedtacinarsansnaeeanigssirilanneanaanaaaananaaa aaaanaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaana aaaaaaa a
# Iter-3300 loss: 17.8579
# city peroperroerreeerrreetrrrrroooeterrarepotrrtaitotatrtopareroooiirorroroproprearoceeeapororoarrrii
# Iter-3310 loss: 8.1750
# co Glded ac c aaaaalalat cftals a as c tataaaawacaattadeceeeaeaea aaaec e a eacacacaceceeaaaacfeawcaa
# Iter-3320 loss: 18.6464
# c Ga.vea.
# uusastiss c aasss teuuaaeateaaaetaa asoauaauaartateeaasssssse uusaraseaisaar mama e rareiaa
# Iter-3330 loss: 14.9692
# ced'Japan sess a henssasseasa isesaiiiiiissssss ta eis asisss a ii  iis asaasaiaaass asssssassisss is
# Iter-3730 loss: 10.6785
# cstaC manseu to  a tatt aatattattstashett iuthiusoaiittttsso s eua tuhussuahuah ttt tatsusuuehtiiseai
# Iter-3740 loss: 5.0792
# cy inity Seeendene aed tsesestetetstteettrhttttheaaiiiiiaaaiaiiari hteeaieetaeatntaetattttaearatttttt
# Iter-3750 loss: 12.4824
# cl Incedeadddrdeaea a teaiacafure  a ea aveaaeea aaaaeaia aaaeeai  e a   eaaiaia aea   iaaaaaaa
# Iter-3760 loss: 17.8240
# citesiea in aaviieeea av r ris r ttn    teeerteaetteiin    eaes   iaaaat t iet tta ea    tit a r r
# Iter-3770 loss: 15.8098
# chencufing t sofeaiiererortraraea fffsrhsfetrhffsouaiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii
# Iter-3780 loss: 10.2460
# cocos borterecy Heo it t ttthtttctttttccthehttththttththhhtttttettthtttttttttttttttthhtttththttthtt
# Iter-3790 loss: 12.6460
# cteco caleteeead.ladetaxetutttese aatieeee eaeiiaetiiieeaae aicaaio ias aoissssiaaasoaiiaoasoayttiaoa
# Iter-3800 loss: 17.3330
# ciped copes Jalaro s ososif teif osm tsftf itfifalttlmfta t f lff ftti f f iu r f f fuc tiotff iutttt
# Iter-3810 loss: 14.1700
# c 4G G99adea d aatama aetaltm aatalasseuaa aaaustmt    a.    emcu   e.m  e.me .emesem  mmmmmmat  a a
# Iter-3820 loss: 10.5903
# cle' inantesen tn eeeeeeeaaeneneaeeeaeaeeea eeeeeei aeneeeeeeeeeeeeeeaeeeeaieeeeeeeeeeeeeeseeeoeeeeae
# Iter-3830 loss: 5.3768
# ...
# Iter-8740 loss: 17.2599
# chi 5emSliese Setinmettapuusbmebeembuieeeeubeeetesmeseeaeummmmeeeieeieomobeeeimeestebmbimommmmmmmceee
# Iter-8750 loss: 21.3594
# caitl atpelercermmttrttmtttttmttnttmnttttmmttttta tmtttttctattttttttttttttttttttttttttttttttttttttttt
# Iter-8760 loss: 22.8090
# conitutommmoooimiutmbot tobumybutbutithbboiiiiiospuoutiimobuuumsoubituobiuiumoeotootoioooooubomssuust
# Iter-8770 loss: 18.6741
# ciress ess snloosoeseaea  ee  seseeenomaeamosseroseanaeeeesaseorsbtsescaesieseesehreeeeomtcnsessessse
# Iter-8780 loss: 19.1086
# came tiowg fnetarmmh femeapiectetm l.ttcparaeoemifir tareraa.m.mamamererarer naroroter roriroearocar
# Iter-8790 loss: 22.1962
# cha ramesanthmtpereatpesppiaitalaseraspoaapoaarptssataitttitapelepampppapirassspapeppsmmaaeamanapapsp
# Iter-8800 loss: 16.3154
# cir ofis Jappn aap aaaaaatpppaptpppapppnpptoippppptpappppnpaap esaaappppppepppiaptapppppptpppppppnlpp
# Iter-8810 loss: 17.9933
# csmt renatarane aaobertttneeounooaapoaetgeoeaeaneoattetttsooeeenieeaotteottroeieameeaneeeeeneeaeooear
# Iter-8820 loss: 13.2401
# che whessihe iiiiputhsuuuuusslithmieuuusiuuluuiiuruurulusasumassmuuusulesipusimssuuirimes lucissslilr
# Iter-8830 loss: 17.7539
# chiss rcempomsapilhmsimtt mmenetnt.teoeresereserlteretecetererererereresltesrreretetere etlttresetest
# Iter-8840 loss: 11.2374
# ce sexessseedip mmsmmammmmieaemmm umammmrmmmmmmmmmmmmmmmmsmmmmmmmpmmmmmmsmmmsmtmmmmmpmmmmmmmmmmmmmmmm
# Iter-8850 loss: 6.2204
# cor Ouufiin my infamenaniame pmtiti.f it fu rsie.a tttttts.mm ri.t mn.er.ofuf u sie  b t tcum..s.ii..
# Iter-8860 loss: 10.3998
# con tiy imy mb omtmmmmm tttttt1ttttttt ttttttttttt t tttt tttttttttttt tttt ttttttttttttttttttttttt t
# Iter-8870 loss: 12.9442
# caliolelal sysa lole eoefec m.eleneetatymiloma.m le alllan mr  er merani  memamare aloo cmtmentnfat m
# Iter-8880 loss: 12.0413
# cas lcrtrsss mtanecinemamimin ttttetaraneiranmliniotimtmtttrttamtintentariemmmt miieetinttnti antrtin
# Iter-8890 loss: 11.2222
# cas whesich pimcm    ttt ce   tmctt  tttttttttttittttttttttttttt ttttttttttttttttett tttttit mtttmttt
# Iter-8900 loss: 11.0089
# che whircthss imw  iiiiiiiiiiia i aastaaiiiiitssiii iitttttieitthtttettsttiii  aiiiiitt ti   ttiiceii
# Iter-8910 loss: 34.8899
# conouo mo pynpptoo o tissso o iiot tin sinotopao  ttofitpnpomtnopoppittsi osooas niiho toopitootttiio
# Iter-8920 loss: 11.1555
# certopal pprurart  o hi       i mm m mmem meem  tmmmmmmmmmmmmmmmm miiemem eomoiiem mmmmimimmeeimmem
# Iter-8930 loss: 8.7014
# chsss tttfrreeealiliebmmallJefalomapalaperlehimtpurpemamalseormmuneurmpurhueue.lipmteresceue.menhpiru
# Iter-8940 loss: 10.7083
# cCGam mmanamnarareeen.eeat....em.ammme...mem...mem.o...m.....meeeeee.h.m.a.eem.memeaeem.eeememee...m.
# Iter-8950 loss: 19.5887
# ciKn aoryerialtmm beeaammn ertiseaeroeora aata.ttlieemaeee.meeheaeet.eaaeeeeeeeiaieeseaeeettee myerl.
# Iter-8960 loss: 8.7252
# c Gatessses eaa.sstttssttttsassssatssssttsssttatttttssttttttatsssstttssttttstssttttsttttttstsssttttts
# Iter-8970 loss: 19.0581
# ctisntelearr rtet 2te ptltr2learealharalete 2lboroellloleeioattttbolsrapittelael.stoboollabttalllolat
# Iter-8980 loss: 10.8692
# citng morboterthttmmmissiiiiiiiiiii sss i sm msiaississssiaiissssssssssssssssssssissssssssssss  sssaa
# Iter-8990 loss: 12.8007
# cdd cielouriueioariulsit tiooisaat tesishel tiiioaiimhie iiliiiiii iiiiiiiiiiiiiiiittiiiyiiaiohttiioi
# Iter-9000 loss: 17.2707
# ctith cisstua euam...s  u.mas..rim..iiest..imi.iesiii i....ie iii.eeaoh.s.anim.sip.siiir.iiininim.mae
# Iter-9010 loss: 16.4436
# cy indion of Jap l           sis                e        sieo                    a           e
# Iter-9020 loss: 14.7565
# cterd of Japapl ianaeeeoeaa eeos ao  o         l a      e o        e       llaeaaln   oaaoe et  o
# Iter-9030 loss: 17.1262
# counitiinll.l.rl ae.iiwatoliiamalymllaritirawonananuwon.t winin.iriniliteninuitomid.n.nunom.n.mal.n.n
# Iter-9040 loss: 13.4729
# car cteriotioo 1a..tcimmmm.m ir.e imiiniieiamimmmanisiiiiiiiimmmmmmmmemenaiiiiiae.mmminimtiiimiiiiiim
# Iter-9050 loss: 21.3521
# canicrrge e bmt lereatoncorlrre detortsl ttes.tmmlir n elanselint.n ninira er n    sereninont.nhtonie
# Iter-9060 loss: 11.9386
# chu-ilkgmterosis trIas sssiimsssssmssaaaaastaasaaaa tsssssttaasstasassttsssssssaesssaaaiem aasssmaaaa
# Iter-9070 loss: 14.1867
# caea in on weleaiaraacinollritititatiisneremttirlllran ittlmal melopillriciltmasaaisenemitit mttimitl
# Iter-9080 loss: 20.9472
# csnalatt faltrpmmrpteprtmrmttfpitrnammmtmfmmmtmmmamnpamamfmpmatemtmtwf mmmlammmmmmmammmmmmmmmamfmmmmm
# Iter-9090 loss: 11.9491
# cyntive oatanil paril iinnamis mpeppthwtttrie eme ie mn nhiii  ssininontrin.timiine iirpmmiintmmmminn
# Iter-9100 loss: 19.8482
# coejye firlis miaariwimt iiiiid ainiie iiiiiiteieeeiiiiie. iiiiieeiiemeiiiiiiie iieiioiiiiiiiiiiiiiii
# Iter-9110 loss: 30.8788
# cted sonH Indoremuurun.sef. f shekukh .mffrfffrf.kfkrlurss.seefun%s0%%.te8ttmfestettt.0eeeetc.ttttett
# Iter-9120 loss: 17.0362
# con.ty botyymfipurittnomub.minomumitttonomomhnipitimof iinioutopuroo piniiitsipoip mhooriinybsn m tir
# Iter-9130 loss: 17.8941
# car ce oneec cesieitimttiroititfnimtrieitentmattarimeetmticacfeteeetnaeamonitetem.nitimetsnlimarireel
# Iter-9140 loss: 8.0022
# chileolalawtsssstttr.ltt.ssrh till.sastnlirettcttttttssmctstnl ctstttttttlttttlttttsttnttttmt.limtttt
# Iter-9150 loss: 21.4887
# coms forinooetttttttttttettttttttttttttttttttttttttttttttttttttttttettttttttttttttttttttttttttttttttt
# Iter-9160 loss: 17.3798
# css lary isteasrreieheratfralurrmemmorerrerothuerilurtttlolorurimeremeeeehremeeolelarophmlsirsrrsishr
# Iter-9170 loss: 15.3213
# ctlith fereegttme.ar.pttttlss..mmmimusaun.me.m.m.t...uut.ri.r.gsm..mte.m.reame m..m.thmttm.m..m.tth.t
# Iter-9180 loss: 16.2712
# ce wontdeolitlcithesiucuhmirhurutiotithshtumiusi c  ssschus t it ustsssisu cied sisusatuticmi a isaui
# Iter-9190 loss: 14.5576
# cangges  re.eme.immttttettete  teemanimme etetoreneetenetintttntme metet  ttmttmmmtmmmmmmmetetctetett
# Iter-9200 loss: 20.0866
# cd, tome ctctthact iitte fluil cl itcmil timiltttttalhetmmtatitlmtirhmtplsaltmipitathmimlieammmmeeee
# Iter-9210 loss: 38.2819
# ch GnPss amtieai uusmmmmmummmammmmmmummummmmmmmmmmummmmammmmmmiummmmmmummuummmmmmmmmumumumumumumultum
# Iter-9220 loss: 20.5484
# cCGamees.
# .
#  maee.mmm...e.eeeemttttti.ammmttes.eeeieeemmmmmmmmtmmtteetm.u....mmmmmmm........m......am
# Iter-9230 loss: 11.6891
# ce Ibene andundudtuuriooediet.mam uereesuu Sesoer.ieeriie tutittmetpeumetumtttubuummumebmmeteboimumim
# Iter-9240 loss: 7.7985
# cd's the clterarueob.hmmtun tmittthnlmmrtttthutthbtmatttmmtthsmmmmhhmhhhhhh the mt tttmmhurte.tumhhht
# Iter-9250 loss: 22.8043
# chukcan the mlamaure mer.rsmmttmm.mmmmemurum mm.mmmm.tummmmmemmummm.mmemmthmmmm.t.s.m.m.u.m.m.mamrm.m
# Iter-9260 loss: 16.8491
# chmintcectar frkalsdortrer.rtttrrrtslrerslarlnorostsrl.rertt.mermrmmlmlnsrcn mmrmmmmmrlmmrallmmmissrs
# Iter-9270 loss: 13.8175
# c Gamal.
# ase mteae.teeemttestea.raseaeeetaapmt.seseammmeameteatesse.etmpea.tttmpeamesmeeetttath.e.eat
# Iter-9280 loss: 12.5298
# chmprn Hasestnmumtomtmettterottmtreoiemmtnmenommtepetttattthtorot mteottttthlmtetb...utotttte..attttt
# Iter-9290 loss: 8.5586
# cal wid alelemm wiitttttttttttttttttttit iitttteetttiiitt.tteetttiiie ttittiiiiiiiiitetciiitttitttite
# Iter-9300 loss: 15.6062
# contiom. botibin paarpimmsis iaismappmoap pet pittoii tissseopotstiiiioieeiitr taaiiiaiesiitom ttte i
# Iter-9310 loss: 16.8103
# citsriona faronmpdrradattrorglpnytotorsaaronsie mssssrlarerormrrrilynolarhrtoransrtomoitsarhl.alllola
# Iter-9320 loss: 13.0356
# citulapiae parirtur.r.tt s ee  eeaacimo etipaesta.aiattertpimtetimittmteamoiartariltpiprmtrattesittea
# Iter-9330 loss: 14.2585
# cd eappnsrlnssprhtederh tir ptitataripsserhlltolinftsurertriirthritepputbibuthshmurtrsrtpssosuterolut
# Iter-9340 loss: 24.7651
# con toyuittiuoinh somh.nomtn  tiii.nhtttm.intis muitnuno ii.moinhpom nit oi.iiii iiihn iiiiniby.ttito
# Iter-9350 loss: 21.9497
# co5herynay byntstmmpttttttotmmitsttt.itatt.ttttt.tsn itttttttttt tttnttttptttmmnth..spttenu.tottttt i
# Iter-9360 loss: 11.1407
# cd evleristitt uieuer.rliiimurhirrhuuiiur.uiiioiiipo .biiaiii iiiupitsiiiiilpomiiom iiaetii iiriihiob
# Iter-9370 loss: 21.5832
# cigi cenorlaaapdnmmllal tsal lttoromela.tatorormmtmmnanulelt lnnt atteso aranimldeonsngeerop aelalhmc
# Iter-9380 loss: 15.3307
# cer ththttechisDiiss sssssas s     iiiaa                .                                      i   si
# Iter-9390 loss: 18.1996
# cakle parime ssrpamar mmtmmmtmmimmmimemmmimtmtm.t mettmmm mimttttmmmmtm mam mtmimtmmtmmtmmmmmmmiitmmm
# Iter-9400 loss: 20.0111
# catio paacartceririsin ldinsnon liraf ranolirisyrenan btrrrilonininsratarrnipar n rinonln r ninhr rln
# Iter-9410 loss: 11.2837
# cy, thacee Sthuee04veeete tt itet      a i      s  e            te    ve ii         i   D           s
# Iter-9420 loss: 11.8766
# ce stessrd itet mmtmmmmmmnemmmmttitmmmmttimt mimimmmtttttmthmnnethhinthimmmuminhmmmmmmmtttmmmmemhrhmm
# Iter-9430 loss: 19.5593
# clitelitoe fieciiellotertessret vel.iriarles.cergcericttuet rilire fer.mwilorssitlslaipilitilondmtn l
# Iter-9440 loss: 14.4906
# cenc toe codttaluuttmmmmmtemmmmmetummmmmemtrmmmttiterermmetuummmterommmtmmmmttmtmmmmmmmermmmomerermmm
# Iter-9450 loss: 14.1582
# ch' the ntensllnleserhesosthst shrlssussshchmsumsustsitushthmcelhthummmummushtttsmhmsimuehmmtttim ths
# Iter-9460 loss: 14.3422
# cys thosamisoe pirsrtelettelalhrlerttielhmttbeelieltettolimietiecolhmebithlm sheessnaliimamtiiiero be
# Iter-9470 loss: 6.5034
# cce wareee assi  un mmmmmmmmmmmtmmiimmmmmmmmimmmmimmmmmmiemmmemmmmmmmmmmmmmmmmmmmmmmimmmmmmeemimmimii
# Iter-9480 loss: 11.7152
# ce
#  eimJcpllac iariciciceceppc tinlbilimomerhmichcirirhpityt taw miirttitothihpecimppulemiremimhn pec
# Iter-9490 loss: 14.0586
# cowannwirgt timtulit i..t.y...t...m.tm.............im...tt.....t.........m.....m......tttt...........
# Iter-9500 loss: 16.2369
# ci parite'am. ippe'tptmppspppaptttlalaasttaanaaaaatatasatalalttataaatataaatatat aalaaaallalalanalalpa
# Iter-9510 loss: 26.4003
# ch whied cesattisiittrtiniimitetiiiisamirttitttinimititis.tititttititamitttittstttisttiiintitinimisti
# Iter-9520 loss: 13.8254
# coniti9y. o 1e sstoiiimtmoto   iooitotoooiiimiriiioo sttmo  mpoooiim iooomiiii toto tttiomotlo   moio
# Iter-9530 loss: 8.3851
# cc,latats pemotomtt m.....mmttm....temmmmmmmmmmmmmmmmmmmm.mmmmmmmmmmmmmmmetmmmmmmmmmmmmmmmmmmmmmmmmmm
# Iter-9540 loss: 38.2547
# c Gamesaad.Wals.teetemnammemmmnammm.emlml.meameoemn..tme..ttemm.lamalallerm.l.....n.rae..aanal.ma....
# Iter-9550 loss: 15.8829
# came thertenpeama aeitttt  tttttttttttattttamtttmttttttttttttttttttttttttttttttttttttttttttttttattttt
# Iter-9560 loss: 9.3769
# cas ang pirpthssytg ee.eemmy.mmmeml eeeee eeee.ees eeee  eea ee   teeee  eeet   eea.e  eet t s.s eeee
# Iter-9570 loss: 10.2168
# cd,kem0isud ms env piitmpeppiiimpeiipipiipiiiiiiitiiiieeiiiipiie ih itiiipiiiiiiiiiiiieiii eimveeeoii
# Iter-9580 loss: 17.0467
# cul clwom trtrte timitu tepttrtntntmpppmimmmtrpmmmttttmmmmmimmmpnmmimtttbntmtmapemetamirtnttmtnammmmm
# Iter-9590 loss: 20.6178
# che wicsn n ra s thttemhpphmtlsltipeimiths iitimttittircniitemmml themmemclleehcimaiitemtiiocettlmipe
# Iter-9600 loss: 16.3776
# citoopin hunoopipprppikppopp pppppnpppippunpnitonpiriipippipitipapoppp titopopop tpnppppalippp ropinp
# Iter-9610 loss: 10.4245
# catesion Itt anae  feiiiiii  ii  ia ii  tii iiiiiimite  nii    ief iiiiiiiitiiini iliti eli  iiiiiiit
# Iter-9620 loss: 13.9315
# chsmaescecaank S Werwawmmpwrmmapapsppmmpawmmemmwmaeamoiseawapmmmmmwartrappimmearaw iieappmppm irarchm
# Iter-9630 loss: 8.7737
# cl and dadomannooeeeooopnninponpipanppppaaa po aa  nappp aaaappaasaassppppa  ppaaaaaaaaeaasaaaaapaapp
# Iter-9640 loss: 9.5308
# cast an eaiagemmmamii   t    mmemmmmmremmeeiem  mimm ecee immiiimmimmimmimimiimmmtmmimmii imeimmmmiim
# Iter-9650 loss: 12.2640
# city tinn on anapananannalammenoate or sanatanaaonaparoWenolanatat namenaranouananasorfponoon eiron p
# Iter-9660 loss: 19.5330
# casth anetessgenarpered tnteneimeeessesseeeamttet.teees.esmeemeetetteseeeeeieneeeeebeeeneeeatetestess
# Iter-9670 loss: 16.5895
# chilpaceat anlumu  m   n e        aati m ii i   i ihia i  a iiiiiiisi n niiiaiiiiiiiii  niiaiiiiiiiii
# Iter-9680 loss: 5.3892
# ch-eised salateiss mtisemimt.imiiiii ittiiiiiitamnmme...se.ne..iiiiiiu.aueie..i i.miiumiitteeeiiin.es
# Iter-9690 loss: 21.1088
# comolen Ine r nniiii ian  n   hr s i     r i i    ii       i m   iri   i       n   rn np
# Iter-9700 loss: 13.9475
# co insindanfis innnsconnnnnaunttennrinttushtttptrutet ontblufiinipiiitiiiriiiipirttoniriniinrrrittrun
# Iter-9710 loss: 25.9769
# ctige ninapilarirecieipamelilimerilimimopmtppicemteceeneronin.romomimttesetanipimooinonalimoreeerinir
# Iter-9720 loss: 12.7208
# ch whtdrslttesite ss ceu  olactmtateueimtepirsieariuttehtutttitasttiateiattiptttmiitmtiiheemisspisiss
# Iter-9730 loss: 21.6184
# catmlalan Ptiwnntlittan lendt m mt clstin i icttstte ecesttntcti ttrnanttittmirin n c tttttt n  tlit
# Iter-9740 loss: 48.0139
# che wlustessst i io h chht uhtlrh h t  hhhhhhhht h shl t   hht thhtthhhhhllhthohhthht iththhlhhhtth
# Iter-9750 loss: 14.0030
# citg papfalybairngr rrsitrurr eerelhfbv clvltetorleerhoairrittromfeerrocli rlllepsllfloohcrrfooeeeerh
# Iter-9760 loss: 15.4351
# c insse Waasaas.s.t mm mmmmmumtmmtlmlmlmmmmmtmtmmmummmmmmmmmmmmmmmemmmmmummmmmammmmmmmmmmmammmmmmmmmm
# Iter-9770 loss: 30.0838
# c Gmttsesse Wa..............t........................................................................
# Iter-9780 loss: 18.3650
# chi Recisese-nn  eeeeeeis eee eeeateaiaeeeaa eeeeeeeeeeaaeeaaeeeeeeeeeeaaeeeeeeeeeeeeeaeeaeeeeetieeee
# Iter-9790 loss: 12.0474
# che ixndd in 1iii   por eeoiiiee ii iieiie ieimecat iiieepeeistt iii iaaeirereeiseiie  .st ii iie
# Iter-9800 loss: 15.4961
# cama oreanate tonnon oon tte nan.rrrensenna  tan rteenen r ttttnon ciron ltrenir.n rttic ltrtttt.tsr
# Iter-9810 loss: 8.8342
# ch whesth ustssausttttttttssihttsssssttttessssssssstssssssstitttnt stissssssssesststttssstisssssssa s
# Iter-9820 loss: 16.3855
# cmwite of eoonocneetatttttiiiitcctttltttttttehntttttttiltntttttttttttttttttettattttttttttillttttttttt
# Iter-9830 loss: 10.8179
# copirtotitynfinnuntrnnlmelotleatettmlstttrpu llrlptrrtrsireltunoltttte rnsuttlgn.mmelutttall fencnt.r
# Iter-9840 loss: 16.5890
# catunesss Wamammiamtiaimimm m mmimimmmiiaiimmmtmeottaa. si miamtaro mess mt rtimai s.immammmiiassi ae
# Iter-9850 loss: 17.6582
# civemcart ore orll a trrttecllicllllyltrorllgneutmalyrllalglglllur1lurerclle sllglrrll.lllylln.ssngla
# Iter-9860 loss: 17.3716
# ctre the eate herttitentishtthteetheeeraauhtatheeeehtuitesttetttefhesttetuthrtteuheuueietheththuthete
# Iter-9870 loss: 11.4231
# c,d Wopinirilininingntril ltrgrler. llyutttttltttrtltttlhthn thlan rhtttsnlrtthnhrtthlhltthn tlltthth
# Iter-9880 loss: 11.9611
# che whtsrese thiaussimtttisctttinetetsseitiindure mttssuttttsatumutattttutumeisittemuttttttittthmsumi
# Iter-9890 loss: 10.6019
# ca rhegin terarinenfe Wereroereetmrlete ern onterfiniierceririre taee eeriteremotereeetertetercrreror
# Iter-9900 loss: 34.6786
# crriar hhthrhncnpllhtithrplhchtacumunirhlithlulhmhpirheothphrtl tinaghresttilhchllrarithlurilhrarulir
# Iter-9910 loss: 30.0892
# ch andss 2etiiateiiiiiitiieaaatiiiiiiiaeaiiaimiiitiaa aaiaaeaaaa  iieaaiiiiaaaataaaaaaeeeaiii iie iti
# Iter-9920 loss: 14.0381
# c1mesetutamurglmerbatolgsamersrtalgmirolauttttttarulaenturarslurel.lgeralllaluturertaammttamersrimuma
# Iter-9930 loss: 11.8801
# cclak Hevumsr mmor.ltttt.rtit er ele . uteeamn e.eererme u er emr m..olr p r a t.ter mmree.  rererete
# Iter-9940 loss: 24.3733
# cdex laxpx larllaesm tmr.mttumttiteoitirimotrtttittitctttootitoeamttin ctturtitmdiitt tinteleerthettm
# Iter-9950 loss: 9.1781
# c Geases..sss..s.amttetessattaatseatattatetaesaatettt.eaeamettttatattt.ttttttmaeaaaaatttattteeaeasat.
# Iter-9960 loss: 18.8826
# camg of tletttataaaaaaaeeeaaaaaaaaaaaaaaaaaaaaaaaaaaaaataaaaaaaacaaaaaaoaeoeeeeoaaataaaaaaaataoaaaiae
# Iter-9970 loss: 12.3177
# curesa ge aertheitiioeitrmeroetusmttaemiiinoreurureeuuerie.ttnmieeriieihrmeta  euiiruaiinilrni rrisio
# Iter-9980 loss: 13.5779
# cyn oftin ou Ilspnn...lamptttrt trrrttslnmmt tttlrlmttmcpttlinirrrtttttmttr rtssttttlllrlitttpmtt rl.
# Iter-9990 loss: 10.1387
# cits parolyur s oeeeeeeoeeeeeoeet.....eeei..eeoao.ee..eeeereeieeeo.eeeeeeooeeeeiioeet..eeee..e.eee..e
# Iter-10000 loss: 19.8576
# cinmflrre aaooeei torna eee tcnai cal ae eenoaeea ii een  oeedr oeaca mee ai eicdaellidaeen ton ieeen
