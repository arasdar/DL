# %%
import numpy as np

with open('data/text_data/japan.txt', 'r') as f:
    txt = f.read()

    X = []
    y = []

    char_to_idx = {char: i for i, char in enumerate(set(txt))}
    idx_to_char = {i: char for i, char in enumerate(set(txt))}

    X = np.array([char_to_idx[x] for x in txt])
    y = [char_to_idx[x] for x in txt[1:]]
    y.append(char_to_idx['.'])
    y = np.array(y)

# %%
import impl.layer as l

class GRU:

    def __init__(self, D, H, L, char2idx, idx2char, p_dropout):
        self.D = D
        self.H = H
        self.L = L
        self.char2idx = char2idx
        self.idx2char = idx2char
        self.vocab_size = len(char2idx)
        self.losses = {'train':[], 'smooth train':[]}
        self.p_dropout = p_dropout
        
        # Model parameters
        Z = H + D
        m = dict(
            Wz=np.random.randn(Z, H) / np.sqrt(Z / 2.),
            Wh=np.random.randn(Z, H) / np.sqrt(Z / 2.),
            Wy=np.random.randn(H, D) / np.sqrt(H / 2.),
            bz=np.zeros((1, H)),
            bh=np.zeros((1, H)),
            by=np.zeros((1, D))
        )
        
        self.model = []
        for _ in range(self.L):
            self.model.append(m)
            
    def initial_state(self):
        return np.zeros((1, self.H))

    def dropout_forward(self, X, p_dropout):
        u = np.random.binomial(1, p_dropout, size=X.shape) / p_dropout
        # q = 1-p_dropout
        # u = np.random.binomial(1, q, size=X.shape)
        out = X * u
        cache = u
        return out, cache

    def dropout_backward(self, dout, cache):
        dX = dout * cache
        return dX
    
    def selu_forward(self, X):
        alpha = 1.6732632423543772848170429916717
        scale = 1.0507009873554804934193349852946
        out = scale * np.where(X>=0.0, X, alpha * (np.exp(X)-1))
        cache = X
        return out, cache

    def selu_backward(self, dout, cache):
        alpha = 1.6732632423543772848170429916717
        scale = 1.0507009873554804934193349852946
        X = cache
        dX_pos = dout.copy()
        dX_pos[X<0] = 0
        dX_neg = dout.copy()
        dX_neg[X>0] = 0
        dX = scale * np.where(X>=0.0, dX_pos, dX_neg * alpha * np.exp(X))
        return dX

    # p_dropout = keep_prob in this case! 
    # Is this true in other cases as well?
    def alpha_dropout_fwd(self, h, q):
        '''h is activation, q is keep probability: q=1-p, p=p_dropout, and q=keep_prob'''
        alpha = 1.6732632423543772848170429916717
        scale = 1.0507009873554804934193349852946
        alpha_p = -scale * alpha
        mask = np.random.binomial(1, q, size=h.shape)
        dropped = (mask * h) + ((1 - mask) * alpha_p)
        a = 1. / np.sqrt(q + (alpha_p ** 2 * q  * (1 - q)))
        b = -a * (1 - q) * alpha_p
        out = (a * dropped) + b
        cache = (a, mask)
        return out, cache

    def alpha_dropout_bwd(self, dout, cache):
        a, mask = cache
        d_dropped = dout * a
        dh = d_dropped * mask
        return dh
    
    def forward(self, X, h, m, train):
        Wz, Wh, Wy = m['Wz'], m['Wh'], m['Wy']
        bz, bh, by = m['bz'], m['bh'], m['by']

        X_in = X.copy()
        h_in = h.copy()

        X = np.column_stack((h_in, X_in))

        hz, hz_cache = l.fc_forward(X, Wz, bz)
        hz, hz_sigm_cache = l.sigmoid_forward(hz)

        hh, hh_cache = l.fc_forward(X, Wh, bh)
        hh, hh_tanh_cache = l.tanh_forward(hh)

        h = h_in + (hz * (hh - h_in))
        # equal to
        # h = (1.0 - hz) * h_in + hz * hh
        # or
        # h = h_in + (hz * hh)
        # or
        # h = h_in + hz
        # or
        # h = h_in + hh

        # SELU + SELU-Dropout
        y, y_cache = l.fc_forward(h, Wy, by)
        y, y_selu_cache = self.selu_forward(y)
        y = X_in + y
        
        if train: # with Dropout
            y, y_do_cache = self.alpha_dropout_fwd(y, self.p_dropout)
            cache = (h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache, y_selu_cache, y_do_cache)
        else: # no Dropout: testing or validation
            cache = (h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache, y_selu_cache)

        return y, h, cache

    def backward(self, dy, dh, cache, train):
        if train:
            h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache, y_selu_cache, y_do_cache = cache
            dy = self.alpha_dropout_bwd(dout=dy, cache=y_do_cache)
        else:
            h_in, hz, hz_cache, hz_sigm_cache, hh, hh_cache, hh_tanh_cache, y_cache, y_selu_cache = cache
        
        dy_out = dy.copy()
        dh_out = dh.copy()
        
        dy = self.selu_backward(dy, y_selu_cache)
        dh, dWy, dby = l.fc_backward(dy, y_cache)
        
        dh += dh_out
        dh_in1 = dh * (1.0 - hz) # res

        dhh =  dh * hz
        dhh = l.tanh_backward(dhh, hh_tanh_cache)
        dXh, dWh, dbh = l.fc_backward(dhh, hh_cache)
        
        dhz = dh * (hh - h_in)
        dhz = l.sigmoid_backward(dhz, hz_sigm_cache)
        dXz, dWz, dbz = l.fc_backward(dhz, hz_cache)
        
        dX = dXz + dXh
        
        dh_in2 = dX[:, :self.H]
        dh = dh_in1 + dh_in2 # res cells
        
        dX = dX[:, self.H:]
        dX += dy_out # res layers

        grad = dict(Wz=dWz, Wh=dWh, Wy=dWy, bz=dbz, bh=dbh, by=dby)
        
        return dX, dh, grad
    
    def train_forward(self, X_train, h):
        ys, caches = [], []
        h_init = h.copy()
        h = []
        for _ in range(self.L):
            h.append(h_init.copy())
            caches.append([])
            
        for X in X_train:
            X_one_hot = np.zeros(self.D)
            X_one_hot[X] = 1.
            X = X_one_hot.reshape(1, -1)
            for layer in range(self.L):
                y, h[layer], cache = self.forward(X, h[layer], self.model[layer], train=True)
                caches[layer].append(cache)
                X = y.copy()
            ys.append(y)
            
        return ys, caches

    def cross_entropy(self, y_pred, y_train):
        m = y_pred.shape[0]

        prob = l.softmax(y_pred)
        log_like = -np.log(prob[range(m), y_train])
        data_loss = np.sum(log_like) / m

        return data_loss

    def dcross_entropy(self, y_pred, y_train):
        m = y_pred.shape[0]

        grad_y = l.softmax(y_pred)
        grad_y[range(m), y_train] -= 1.0
        grad_y /= m

        return grad_y
    
    def loss_function(self, y_train, ys):
        loss, dys = 0.0, []

        for y_pred, y in zip(ys, y_train):
            loss += self.cross_entropy(y_pred, y)
            dy = self.dcross_entropy(y_pred, y)
            dys.append(dy)
            
        return loss, dys

    def train_backward(self, dys, caches):
        dh, grad, grads = [], [], []
        for layer in range(self.L):
            dh.append(np.zeros((1, self.H)))
            grad.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
            grads.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
            
        dXs = []
        for t in reversed(range(len(dys))):
            dy = dys[t]
            for layer in reversed(range(self.L)):
                dX, dh[layer], grad[layer] = self.backward(dy, dh[layer], caches[layer][t], train=True)                
                for key in grad[layer].keys():
                    grads[layer][key] += grad[layer][key]
                dy = dX.copy()
            dXs.append(dX)
                
        return dXs, grads
    
    def test(self, X_seed, h, size):
        chars = [self.idx2char[X_seed]]
        idx_list = list(range(self.vocab_size))
        X = X_seed
        h_init = h.copy()
        h = []
        for _ in range(self.L):
            h.append(h_init.copy())

        for _ in range(size):
            X_one_hot = np.zeros(self.D)
            X_one_hot[X] = 1.0
            X = X_one_hot.reshape(1, -1)
            for layer in range(self.L):
                y, h[layer], _ = self.forward(X, h[layer], self.model[layer], train=False)
                X = y.copy()
                
            prob = l.softmax(y)
            idx = np.random.choice(idx_list, p=prob.ravel())
            chars.append(self.idx2char[idx])
            X = idx

        return ''.join(chars)

    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        # for i in range(0, X.shape[0] - minibatch_size +1, 1):
        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def adam_rnn(self, X_train, y_train, alpha, mb_size, n_iter, print_after):
        M, R = [], []
         
        # Hidden layers
        for layer in range(nn.L):
            M.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
            R.append({key: np.zeros_like(val) for key, val in self.model[layer].items()})
         
        beta1 = .99
        beta2 = .999
        eps = 1e-8
        state = self.initial_state()
        smooth_loss = 1.0
        minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=False)

        # Epochs
        for iter in range(1, n_iter + 1):
            # Minibacthes
            for idx in range(len(minibatches)):
                X_mini, y_mini = minibatches[idx]
                ys, caches = self.train_forward(X_mini, state)
                loss, dys = self.loss_function(y_train=y_mini, ys=ys)
                _, grads = self.train_backward(dys, caches)
                self.losses['train'].append(loss)
                smooth_loss = (0.999 * smooth_loss) + (0.001 * loss)
                self.losses['smooth train'].append(smooth_loss)

                for layer in range(nn.L):
                    for key in grads[layer].keys(): #key, value: items
                        M[layer][key] = l.exp_running_avg(M[layer][key], grads[layer][key], beta1)
                        R[layer][key] = l.exp_running_avg(R[layer][key], grads[layer][key]**2, beta2)

                        m_k_hat = M[layer][key] / (1. - (beta1**(iter)))
                        r_k_hat = R[layer][key] / (1. - (beta2**(iter)))

                        self.model[layer][key] -= alpha * m_k_hat / (np.sqrt(r_k_hat) + eps)

            # Print loss and test sample
            if iter % print_after == 0:
                print('Iter-{} loss: {:.4f}'.format(iter, loss))
                sample = self.test(X_mini[0], state, size=100)
                print(sample)

# %%
# Hyper-parameters
time_step = 100 # width, minibatch size and test sample size as well
num_layers = 1 # depth
n_iter = 10000 # epochs
alpha = 1e-4 # learning_rate
p_dropout = 0.95 # q=1-p, q=keep_prob and p=dropout.
print_after = 10 # n_iter//100 # print training loss, valid, and test
num_hidden_units = 64 # num_hidden_units in hidden layer
num_input_units = len(char_to_idx) # vocab_size = len(char_to_idx)

# Build the network and learning it or optimizing it using SGD
nn = GRU(D=num_input_units, H=num_hidden_units, L=num_layers, p_dropout=p_dropout, char2idx=char_to_idx, idx2char=idx_to_char)

# Start learning using BP-SGD-ADAM
nn.adam_rnn(X_train=X, y_train=y, alpha=alpha, mb_size=time_step, n_iter=n_iter, print_after=print_after)

# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['smooth train'], label='Train smooth loss')
plt.legend()
plt.show()
# Out:
# Iter-10 loss: 110.6712
# enwwwh日mli i  esaioohh  sa    ,reenstmp9 hdgnb hettn  sahayrnp eo mae ad rawzepatnn  e Ugtuioereeprsa
# Iter-20 loss: 102.4333
# eE2Dshls epeeedaane oo  ra.  tp1niiihcadtreytrP;ie htaee–"o% tiuooo tm m s tuoooipraRroo uhdeho lina.
# Iter-30 loss: 103.8332
# eFcf bWriKSosJ toedho eppaato  otmee an6 he  reac, n poo  oo JJlsd Badan   u  ,nsbw tene  rn iigel.s
# Iter-40 loss: 103.7657
# egp.sFatipJbe WaedSoe d lecopDieme2llJ mtlfce
# pptoilorndpe   ra nius  eralteu
#   ntvl.inyiu esaast bob
# Iter-50 loss: 108.2371
# e5l8yut.y Jtd,phn uwcvceths hhcrs r日lgh c p i t  at eeemodd orep4e prnaoHummpar oRondddalanoututdr(ta
# Iter-60 loss: 102.3077
# e–dfgf–eIpea iio d uld 5angto  ohud thiroitteeets(aCoJya9is loy acn "ir in ler kog ttterlattiae sr,ot
# Iter-70 loss: 97.3487
# e(J2ninnO a3georae or uo rfh ;e ger1t eanees oxCinai-h  if,mhr"u. onh  a  hK本ieyrnntsdeat daid w本e日 c
# Iter-80 loss: 103.5549
# eJifWn0innc 1pee ofhe ori oite o,rit mheromt rSin peHpeauud hp wenlxa es Ot–kan-pd iftln日 ziiin ryke
# Iter-90 loss: 96.2999
# e(amm- Dry tA' iuh fllojiitsHgc,O 本arCl,oio yhd hi2e he ic yggdnal,hHpmrfadd srr7hShd J uh the Nererl
# Iter-100 loss: 89.9609
# ee8isi an Eori tta hop.nt Ih eme ondiKo 10roMtt T0Josst4tbhh bman nrithetoB irt anttan pcny uai,ib yr
# Iter-110 loss: 98.8424
# eTon  rasJiis att ipae i1 mirs d laintat esto o, ins ereas Jaress E. arltpsroaFdngt. gaponFl th eeh
# y
# Iter-120 loss: 94.1029
# eot7 vekuldosa ey miret mceiunt 'y tttegra1a d ean, Oaavg tpis bhiltrgw.n  s'rterneitesi hn JneLtFme
# Iter-130 loss: 87.8091
# ep735 int he ocfp;hesseWe AardrKr lyttie dopFm ptweroonoy Jaua 4e thl onet8hWm orOu.tT0eDpoPo, ynd wh
# Iter-140 loss: 93.1011
# eyOha, che8Wap nist one)s ir%d . d in Is . ind g rcdJr%ar  olirfdc8hd Sfryh bbrdnt ind 8oyvo ueanle o
# Iter-150 loss: 94.2042
# eHBpend colgtoFet'r ioa l oWon hanan ohe tama7j aWan cerobllSthiger'sthe topyt Saho in thTkvMvltoy on
# Iter-160 loss: 92.5199
# eOd-%ayad  hi arpee t)"ht he om, capeNen in ioy Japendt yed toGlorlanB8Paial iiitheate iund it oiee a
# Iter-170 loss: 92.6733
# epe:TTe panan tupytklFk.twopom aaeo)sk JHehye Se romeco chin sst Jyeand sn ia utrn8 thin  he ii las i
# Iter-180 loss: 94.6174
# e.pHcWaukc. t.6s本es ld forldinh Hap s mhe Coltane thm Oonnscs chinit. onkP Astuny Ire maoy pegand jhe
# Iter-190 loss: 86.5252
# ephets. Janki it pog topis tRe Sillin3 w ro, et4med Jhpxnit es orla2 Miano iotattNeaxofcorual Gatea g
# Iter-200 loss: 84.2337
# ee ,othe oae tte  Thy PstU. fheRp.il  a ieslargopleniaL cf-thengzwora t本rlot.e6Nkte inilanhe 0a Eil-t
# Iter-210 loss: 90.1429
# eu a. thiWyru snhesnou "nrladaWal Jathe 4rm powanlxeg thet2paddoa eoted ihe the okhiGcllaed aleros re
# Iter-220 loss: 87.2672
# e,.tay nrrepinx Wase iof th8pank  hhee parle a"he insthincr5the dirle tanglopesnawcce opld et  entm h
# Iter-230 loss: 84.4665
# eglon the strrey eM an llas0 peaiLois so inlan ee ant difgcpe%ieotid otitbm, jolldt9Sn, uh Kt an oea
# Iter-240 loss: 85.8850
# et worotg-steopobed iitn hrIe 5ore Sa and waivesiniy kakGid tho eacand man omivtoJapbf oo ul pHof whe
# Iter-250 loss: 91.2950
# ec"pand. fite larsa phn2ve eisad pe eire tid No ano ouu moret5Dn: sot eRterag was ww6item Ahinl th
#  o
# Iter-260 loss: 83.3174
# e2p pisind chonores"s thind foicd eP aspes ra por lires werciusta ceJaai apees aFHon Jap-t thxa( Wnr
# Iter-270 loss: 77.8563
# ed,and conat orogSeaso f of, xEEJxman, aad DiOlxplare many iniic4tha.d d:nI bestteroltMon thestehirg
# Iter-280 loss: 83.1495
# eRDed iase or, sf W8rWc8ss3 or uT poryovudand on mace favenoce
# p  cemfamg ritte
# c–unorthe ea and wh
# Iter-290 loss: 79.4890
# e, Daldo'ld chelPPapan ian ezcSnith 3the fNive arlorany JPgants the Sorl Japas minunory ih cerzatO wo
# Iter-300 loss: 79.4271
# e'wy Japanend mbes8err oppoHglsFe ind mnljeasd ar fentn int ,rortepitn roeat  f iilg.is sont7 reand t
# Iter-310 loss: 76.1796
# ey laryys eita ceatas in5bomofed ind wol:re 2an ane oals uithe wogves Jasandkey oe torthy enter fore
# Iter-320 loss: 81.1151
# evo3a xeitse euur vette t-dwtar opgino tLeesty ciron ay nf ShintL0fA rltIn Eipedst endo0d cngsepa' th
# Iter-330 loss: 85.9084
# ede. umgereate  orland Bhthe uril the 19ll gouttecthe pardhis the RUpbon tpeno1nt inciteriunx Leioni
# Iter-340 loss: 74.9972
# e cCalderlace outt r-eaty egdar 1s. ch the ouith al tomithllgrSend lorland ere yur, salio f ucouithi
# Iter-350 loss: 86.7258
# e bathe ainn s8 Abine pariRCt in lthe .rbtdd nxes andeHt 本hecLcint
# ry catertary.ic andhp d larjeshuta
# Iter-360 loss: 80.0970
# e3e the Gara aF is, GreisWllmaag estancf uCitho anund GoC and Ja-aOnvpog tobed ealy4lly Sin 1s thee e
# Iter-370 loss: 74.2199
# evoredst Japand2ujow a go. Japan fiK. G9hion nprin os IWArudas wtha frrndHendig 1sl fotre aD the cofn
# Iter-380 loss: 79.0566
# e. 6his olarlA ppind Japan Uioste io taed zJapap's cisthe Gld 本f Boplbins iisd iourthe f:Japorea arll
# Iter-390 loss: 81.6533
# ems. marthe aIhes coran Japan 1he Carind in ghThe he orvoon lAUDA 6JaponnLi6d. Upcenornd ringggr', Nn
# Iter-400 loss: 82.3220
# e wincturpin ow vigech (7 pianlisaleG ob-trr)d gintoccen. SrectuFfpored terycond pat4yy iMtor ol. as
# Iter-410 loss: 75.4716
# ey to yarN w-umthing reatir sc2WeIcddald Japan ted Iallowe rlerla caand nithe aores jx he ceper ce pe
# Iter-420 loss: 71.6284
# exthe amkes a"I, wary ,ibng dastee00l Siiltiniin the xuutse fpris as thico tto, ind anesh Inse emlerJ
# Iter-430 loss: 75.6743
# earil aneS6a fours-d23edone 1a", chetar epniltdy mr theje Apwhl led argc 本ies ai Japas  aad inlyHiIn
# Iter-440 loss: 75.8828
# esfe tiets lerNest-poro本rtes . uhe ou'to-Japanisithin tornd in fhecex, bald by 5rreMo–thiTe  Japan it
# Iter-450 loss: 78.8740
# ebdErld Nsyesu 2D%%tina an ins phorloch to Ir thinhur ralasgea9de inis utini uta5c ay Ind'W whth  hwa
# Iter-460 loss: 79.2031
# ectentin the Enped. It en es . ONkhini un 0P Eomhth urexturldisuredin rbgurlam a eorlJupanI-ivinc wis
# Iter-470 loss: 75.6150
# es thic5al to3on .CCiJaray ons Japan eh hh the cofoll-6-pe2toriani Ehin Owentre tar es ther Intem at
# Iter-480 loss: 80.6855
# e6 1ar asl aal tilateryest ong enpar osT, bhe ionltrSes Japan peiserlury ind s2 Japang,if the curstkd
# Iter-490 loss: 74.9441
# ef forrt's afdes nprrons nip of wirthiths nins crepest Witer c1isi nthinllaled mar of teven ar es af,
# Iter-500 loss: 68.4956
# eand jlurund anke Wam estse the woms frith who st ind tor Uacxnd EnsB 7rjT Sin is 1hFe's )ith Jayas i
# Iter-510 loss: 68.5869
# ed cares ar es. 1h Uh the Eurll p' auutarlasM the Eapttae and Seoth ind mh enolsesint westreletot' in
# Iter-520 loss: 75.1554
# es ofk
# zliestur cen ores  om The Fomss uriot esiandon, Japan th pirte the bargecbay Slaran hiJopan ta
# Iter-530 loss: 78.4534
# e .aty Sind. She
# Di warclurland Honped eo8ex aSvesina copicina an e6 print( ionte fe -perte% fod duno
# Iter-540 loss: 81.2830
# eGta-and in. T2iIndesolalieat tiind wures an uthe iontt. Liba dya  fins- Japnn 1Ps JasaHet an haa, po
# Iter-550 loss: 72.3857
# e hilans ceiltte eand aly fWIr8MR0us and Woflang po0the foziterex Japan se te2 and sem1a, 0colliot of
# Iter-560 loss: 73.7428
# ed ardlat 1ith and ale bon the Sgein M. anhinerthelgorld s curDtain s, -urote lamkio 1hb kT Natany 6.
# Iter-570 loss: 70.7369
# eG Asand the Rap2o siat oles. biJcpat in es ionsl boun ry catd-sjiJapar 9amesea of 7iec,efe rousiand
# Iter-580 loss: 75.6164
# es ardjithe tummesta) the Ga thicar, Nhees Ihithe "otltem7, hind torld lrin a 9hg an ss ttored Japan
# Iter-590 loss: 75.3070
# e. and and aed okmitor-7' lalg7 ffpirce pemientur is thutA IiSalyCTHghethe cert0om al eny thiinale wu
# Iter-600 loss: 63.9631
# eddis dmper as as oJala. wal mopbtokid pomionted in the catt yr 1ren the togbHu-'s heAclaryJapen, sh
# Iter-610 loss: 67.5630
# exHa5d ante us, the ectar gat oma ai an 1oped rokan Warges wand c日llcorid of e2alacona. The SBurad In
# Iter-620 loss: 67.2244
# eg as lomfe. Gos of N184185 Wstionto ferud lyyirn 5f loreas ll one Glbe7pergis of the cither of Japan
# Iter-630 loss: 67.5260
# e of 184l poS5ite iof 2uy,,s a , poredof thilas andithe Su's outhin Tita8ly AEpay or5ldik wors shh iz
# Iter-640 loss: 61.0470
# eyc. Ar1h, ward sstau U, in 194h9inntzi7 ia andLs;ard6ang th the Rorly vin The Arat onan S7n Ni"7Ta G
# Iter-650 loss: 64.6359
# eceated Parea Sih 6 4an本 ahesiargesin ur,  fror C1ipa ou the will of borns fiio tome ong sstt enth la
# Iter-660 loss: 65.5586
# ex , peress chrteveceeter es lares allond Wanded pargsst miMe sr shire cina, Copoine(eThe cornd n, bh
# Iter-670 loss: 63.6700
# e1 thi0 pand In mainnt5 fiomilldin resthimy ard Japan in , 5an's alan isthe outlead the ald d indothe
# Iter-680 loss: 62.1672
# ed 4xt vopertav mellorothiis Garer and the Nop8rr cointh famhed ofx Ej本rns T eanofe th thenflof Nrora
# Iter-690 loss: 61.2393
# expertary str ofithith gestoS tneWse trel rt bolleand Japanas swNiten Wudbd led Krveokagvcclionte per
# Iter-700 loss: 56.0471
# e 47th uoutery in th- Weatg , an wepers and;. Therctas tion Iides dored py Sfo hoped lome and Rwis. C
# Iter-710 loss: 65.5352
# e ta-lerulal pirlen pirllokeogndited wor:sud Japanind sita andd Cons (ceanl Japan ins in Japand is se
# Iter-720 loss: 65.3979
# extmrinte %ich estiritex witan Wis and meitene Japanchis 本ihe, mf ri-ra3 on the Rwan's as ompiorea es
# Iter-730 loss: 55.1495
# ed at es ar pokwa nd ciintrSenkii  Warntut opey-lf ereleurle ph Japand ur G45O es as paca and no heve
# Iter-740 loss: 67.2422
# ent. Japan in  arEJspanewoo Japanesy Wand Wand8. 0Spccaforllly llur本ao -outony Nhe Sanj8 ;han yy,sthi
# Iter-750 loss: 59.0376
# ejH's tort Stang inges iourty peons cclmoubts in bich the tacthele ror thetoKoy aPKina ; atoonml ir l
# Iter-760 loss: 53.3984
# e San :018 onlit to anan his , Japan pes o日ulCoK'id.ibhc the es or theNind Wal eata , at bourtaryjoun
# Iter-770 loss: 57.2772
# eO as, Wintt taBgent io iochis ma and ionlec9 T an una5,, a th-cerLowa ss foweresta–5jit an Japan ins
# Iter-780 loss: 57.8582
# eh Ef aro5 as Kfe bofthr kop oumy it on the 1ope of the 1oxA an, the EWan an, Hs ino 1h S anekded Gog
# Iter-790 loss: 56.5902
# ees andpJapan es ithisgminC tre Suris liThe Wasth laliRaLalo ares in the Gorlas the wory st ontey ort
# Iter-800 loss: 51.3920
# e% Japan's iacd Hoyis amd ind ha9dulles ul rrouedUl, th thestartho eWd) Chero fegted fr p8ornami t th
# Iter-810 loss: 62.2653
# ecdaly Eforlory um thiCh cera as sma'd comper th la
#  namy ax mzun the s lfeCktomenrbf , the frursej i
# Iter-820 loss: 53.6091
# e 85m rrlahe s atdevesteres im te camab un es inGt ponttryiven mWar orla', in thonNed st co npry is a
# Iter-830 loss: 57.8181
# eve
# . Sfere tominaly', the "y-urleri ghin mapercary. Khirs andendare lSra w7vercomlitu an is. phont p
# Iter-840 loss: 61.9227
# eh on the woky Empatiey st poundckugilal iagaf hrbse frry satpond reanke Pisilam'ea yst be'a wors cun
# Iter-850 loss: 55.3841
# eht Tilesunir aomed Af ax 1rth in th  ioght ind Wares in is andey it9d. Jrpan hich icedmlliositmendur
# Iter-860 loss: 49.3453
# enjaus wons rman mmewero the suatd ea unstron"ttukecof ard Gistory p. 1o8, comity the morly-( E-S;9:z
# Iter-870 loss: 59.2159
# eO 0ompblly Japantse Eait la as inoh the 19pr icatenLeshl sAprsigan the ffuurloms teutir aag Efst orl
# Iter-880 loss: 55.6706
# e merree. China :out . Japanira and aik dur-d's nop3r ouany'lSHicomarbove win thendayy in the Sju, t9
# Iter-890 loss: 58.9191
# erglicter en origssniP tanc porutry. GRB(JL::::za;CHz%he eary plres and 日f Iappeored iig oumle, 12s b
# Iter-900 loss: 52.8775
# e% lires. 1862 G2y and, , :h mperis. mmitoolicito lluceaturyhis cp p4r paron8 whI xD afnom; rypin ish
# Iter-910 loss: 47.2935
# eg orleG Sind Risid Wer ois and iouth-peccenopLorind ah h laca.and uf Japan's hacklatf aret momen. Kp
# Iter-920 loss: 46.7250
# e, woryds a doliow, thire Osglrte tery cenduded Sea a4I fohHBT
#
# :Bzo;%io5 18reoflity is irth decande
# Iter-930 loss: 52.7202
# esBdintorla d inth and lorl Wmt or esea8, ihisCrupenperter Nimtbins arle fal mellloperian il toutity
# Iter-940 loss: 50.5095
# e to5l utusiand Ia caan–ins i2 in1i4h ith shilaf us3eg and the world Japanjsio the  ostre tar espleit
# Iter-950 loss: 54.4370
# e pirP aro atceno-penan ceastregisad Wur at ins "h fithe Rasig pnd whalalofilar ealio tarcof and Soon
# Iter-960 loss: 45.6052
# e8. The ULaly Rust38 Wipan fouj thosa本 lyingky uL9478hino HiChancicovettef ir日llar Lo6tto is and d of
# Iter-970 loss: 55.1958
# e poruppeina a and oxtutOentpo th –dDingolllrx Ijatecy almeWir po
#  iolabit tujias thi roOa, ta is and
# Iter-980 loss: 65.5360
# e tored 3i o a. cpurno-larnnd ia anikoH The ontomerbyos te5cas eat tealaec aa Ps :hur Goe and ou7"h J
# Iter-990 loss: 56.2953
# eWes arderlao  alerd me ana osily-eoyrWh larghg tort melital Comnalo"1, 3i"ofofmeomula Sea ingeopet.
# Iter-1000 loss: 44.0586
# e noperugices Th Hie本riandD, JaparexEI and (o8an csitEdy mivt orollofe or 1. arlodi we Japan's icttt
# Iter-1010 loss: 53.4872
# en mpares
# . Japan ion the Gokydin was bar Sun imitite Tokes Toveres1 botuntemiint. Thi en omalf Japan
# Iter-1020 loss: 55.2156
# ectirof Japan Eish Chen palee t, N2tiJapaniPas athy of movy1s a lotithe wonT arecaryu fC–isn isad Jap
# Iter-1030 loss: 43.4582
# e tory 9th isededion 3h anof the Geszer ,sst mperea-cenod and Wasko-u, ariss an thorom tok o alaol th
# Iter-1040 loss: 55.4096
# e torld. ind Wored l0 cpalled in 196S andis ioes the thol wy cong-pane Taa ana ouny5 SiSend fiU1sthig
# Iter-1050 loss: 52.6361
# et on the.Glount Supediinter ab tectercest diredis. Japan taa of tor corn. Tfky Bjcw Efperred .ikhilh
# Iter-1060 loss: 55.9469
# ed and Wamly murthe and ry and Ekurbom, in ihe Socio io tirishina mase af of 1947, the Rmint ind inis
# Iter-1070 loss: 47.5228
# er oflInd Nompay A20 0ho , oikh the andey War ts tho forGg1 th en aArgato  ofaty Lestrlalitatig of 19
# Iter-1080 loss: 58.1476
# ed and angivel porly E9ped engldod ten ishowir PeagirtheshercOfertedis  cendurf us lares inC, hevfope
# Iter-1090 loss: 41.3653
# ex ardh Ew)d hesrof the Empergr pecrty inghs d rores lnd potarehithm Rasko-Japanese Taven pecred Japa
# Iter-1100 loss: 45.8977
# e-lapeesty bfulrolf1ite wh, ts the Wovle-d War x. Featt of iruded Chancofointpomutarof the UDitnte Un
# Iter-1110 loss: 41.0345
# ecy in, mf Japan ses anved osto2 ta, wintha fogstrrg Anta Upasion. Japan hssh Irrease tjolso tow. cre
# Iter-1120 loss: 39.9743
# es of roKe1 17  mpareed. chesitethe ted Japan, forUn it :9uc omlitece fiunthishl Ir maiged ofh mellor
# Iter-1130 loss: 52.0623
# en am eros the 1asI a'd CofntD estarcond in is i8poa witTd Saalini日a ank iistofiind Chinncige torleg本
# Iter-1140 loss: 46.3241
# eRpes thi s reitldigngud Japan,siounthi ahas ofathe Elle prreasllywith EJapan,  hejtulopaland, Fith t
# Iter-1150 loss: 40.1908
# eveod Nigos. aujithv ousteece%f mperegitt. IsHin Chinnradaldina  heanll-ralangiathe woftroperna mAany
# Iter-1160 loss: 45.7272
# e and rosita-iona ok0 7"h inwored pergan fa; Japanisa WThitheghed ande pfrcmperces in Enpeestlith pes
# Iter-1170 loss: 52.7536
# ed agghoas  turympbo hesh perintrry 1947 oTh. anges loletaroy tig por and wivedes. t8en mmerterC ofer
# Iter-1180 loss: 38.5724
# eved ce tokloppen mnureallex, thrccyanm lsila. The popimite,and of日7heNiOnAsiat Cuvea-ofobea thy Ind
# Iter-1190 loss: 52.8346
# en 日h peron lion in Aseand ind aper ell.rminttenrea toHy h Th  Japax'g Nahe a asea and Wanded wad sha
# Iter-1200 loss: 51.5105
# e forCe felOrreany . The and,  fomerces. J8pan'se on-mbbuse if 1947, Japan ista f Japan seu whe Gn ix
# Iter-1210 loss: 42.6444
# eT1 poentina, Owoped coryoct un io,stnkJMpaDenofiin, ih. ar hishI Gy yshtthe ho, the Glakecunicd itio
# Iter-1220 loss: 39.0005
# ex ururs aint meottree caty fianded ande fTre botten ive ar ind coreg torud Ains S xivhecoly cfintr c
# Iter-1230 loss: 38.8162
# eThe hegverper al tron whes the ptris is the Batre is iin, Whs Slama thesgopnf fopirpecn nupbo forlec
# Iter-1240 loss: 49.9424
# ean KaBsautkomia tori an 1sithe abd ges. mMerterteceflis thr scana countryistobyFito t sered orlghisP
# Iter-1250 loss: 37.8575
# e the tmober wist enfilursea a mbilecita ter csinily o-lare gs an es allom theChSea tollis the ter wh
# Iter-1260 loss: 37.6767
# e"Gto woly Tha Solto-Niren the Eapo este ind and haWan peg trec lrilstecheve torlas ang the cit. the
# Iter-1270 loss: 43.0096
# eF of O700,, snd
# orly sha moulerky P purlilitulesbplerureslit in powint fithiconal 5ithe woflom pato
# Iter-1280 loss: 42.6136
# ec ankeS ialOerig, the Paply in ons ecouniDe g ha ar alard ie exkion the , ar h upedesR porllicited i
# Iter-1290 loss: 48.4108
# ejNionlers ahutargest rim4outory int iolU, Ef he porlas if ir here, tho mmangeJapan eas Uipurbes Japa
# Iter-1300 loss: 40.7857
# en mplrter erlioo at cntemf ouper an wolldisl burgest 6Ipiothiinas cuunt yusth Japan tows a to's FEmp
# Iter-1310 loss: 48.9865
# ee tith pal esiun Delalgesta日 GCoun8pon th entesursteJakand io a3ico and Iitexpantes ir of 1888, In J
# Iter-1320 loss: 44.3350
# even my Emperes ind r oblar ves iUcthe Chanditud on the Unstheccerold pinterbonides inured in the Gof
# Iter-1330 loss: 48.7347
# eghiig purrr an Wis lares a( Pnalar miort 2uChHintis wionte Eart. The GEEasem. Dbertres bomed in ahis
# Iter-1340 loss: 45.9140
# eChin margesta trocean Degolat Huciankiy s rostenpapatefrler ar arce ail3 onm9the watves an B asld Th
# Iter-1350 loss: 59.0335
# egwo4t rs intions. Obctpes thesh irod s-Japaneges ahe world's tertho and ea, frittinje tris dm orles.
# Iter-1360 loss: 42.1165
# en and Searo-iencean Ped bod Rusa an inhs arlata laliua the towFrw toe and io nora, in firstan rthin
# Iter-1370 loss: 39.3461
# e. chllerc9a  orwin whith is didiN powctucin. The Too anxis ardedyored and Wa  arly a, c, the cerHed
# Iter-1380 loss: 32.8634
# e. of the Me sive) an orlarest. Trerertu penthe wor4 ch Ind NNapare, sh OEhox3G, dnd Tok ourlaunt in
# Iter-1390 loss: 33.4575
# eg miturpey witt anand fivo and follec日in-largpea wstx5e prle Niathoue ,-Japan thes zHd lirase SunkD,
# Iter-1400 loss: 47.3185
# ed Empetorl mg teves par e0a7d Chinstandevendes inKory. FroD Wer are sthicg orpes re poper. Uhas mast
# Iter-1410 loss: 38.0933
# entevbend chin Ied,9 Curle iK0 frondens pevea0, Hn The are" to yes iowan mun3th-in4nry Sty The angke
# Iter-1420 loss: 40.4661
# ed of mhe 12, the carled. Ind Sines ax onstion,
# 6Mind ihedand searec1 ne aces. The country wich a-des
# Iter-1430 loss: 45.9691
# e corlll) Wyrla,, andcdion mperowlleop ir China tes andes arA-pareediit of shinctun. Japan's icant po
# Iter-1440 loss: 35.3555
# egeFvir Japanises aidevisedes logurrled ngrgg rrop bily it the woduded5 in the tits wworth latoy ind
# Iter-1450 loss: 31.9107
# ed the purker a meven mandion metiond Wulb, ah c"rlaty Ee anas oubile Sua, Huntareana dout CDiwan -aa
# Iter-1460 loss: 38.9296
# e, cales the lopmbil pa"inand fiu, laresci. mtireamitl peared it the Count torlemandwof creatloy rive
# Iter-1470 loss: 45.1380
# e( ofibal, shathe halal proa the IN. The Saat in taoce3wes the warmy itho ID ioukod nokes in the hirs
# Iter-1480 loss: 36.6127
# e tarLesl Te boulons InI hiDhand in Nhirsonou isio- anectar rAan Chrbano angerlat e3 lyunthedicnto y
# Iter-1490 loss: 31.5555
# e porleat s tion. Ifentureany. A7Hu
# ahaSAAiiPhaid itionacy milo aleh the 12mbBrlollhi. The cean tures
# Iter-1500 loss: 37.3209
# ea al Japan the E7, the G20 and ,s aidhtivogaland cticiperpec loped in the gPitho hing tromesting an;
# Iter-1510 loss: 40.2792
# er anmicllloped pirod and Neakaok, the thestringolyr2 Thinandes  aterth leGo– an io nat ko testecaan
# Iter-1520 loss: 38.8904
# eP inila y3in tan soinar Sta oilita te ter arce ba H6g trres and Stiea anded Ta the forst mifurbomy.
# Iter-1530 loss: 30.3347
# ed of whrle inof t8exianl. and canaldos Pionald Jipantey a jsthind ae NigGrgdangcvan PUpa1 "Seanok ou
# Iter-1540 loss: 29.1751
# en istren 298rseand Poali
# . The Peanareala Umilere9mencen intmelernmea the warg mWtryoby, KrL sornd W
# Iter-1550 loss: 39.1236
# e thures ino pean0, Kouhad Hhe Miis curon cestirita a an hish es the strmededofy 18ca anves in Japan,
# Iter-1560 loss: 52.0216
# ex andD lergest ofuredeSinto n the Houn本CH Jaianoi. The niogaA. The Umillterpar ceateH ifititte iontb
# Iter-1570 loss: 33.5112
# ed ind Chis tegest ertesed-inded rcdes inrry has cumbor ouuus-Candinod an enoper end 6ipon es iint he
# Iter-1580 loss: 34.1303
# exh. Froml an si1tte ,wited ceosuc5oped estorian in i3ad boukai, isinino-n日beeTo livangDwaje purthi i
# Iter-1590 loss: 28.0609
# en ist;reDeat ofe catatue aldy, whith pand poralkyiped Japan'si and ofilares an ryorth Aecaioa thi an
# Iter-1600 loss: 33.9659
# ed itst. Nista
# . An Thi anded ettev an coes truKopreseloby bale whard tores aive thr wostr. iha tayin
# Iter-1610 loss: 40.5697
# e perbed pores an eiserer ans xaat"-iandeEinal orale to atan onurs, Afichorzlo atar ertho and tor e:.
# Iter-1620 loss: 27.5063
# etMen heccrtect engentrond Wan Insedoanto s ciitt( italerol bilituraoknoun if iilal oved eas owaro ue
# Iter-1630 loss: 27.5457
# eugas insterrest in pursh ind prom on bimes if 19p1r3e Sin the E1pme orlesiand Worlary sticnth 1rrlle
# Iter-1640 loss: 32.3897
# encinn perused in 1 me pomes. ChhheF%nd tares. A2h porcdan picolationes aMomeklope woE s8E, oed foull
# Iter-1650 loss: 33.5248
# ecolaly Hturaan pucins an hapargest muiinnbcrenjish the calgedta caccered iutho Sentus 1948, waricoa
# Iter-1660 loss: 26.3467
# exth-largy p Ole2, in the o9st endion thi S-an Nearlale as hrocl 186– Ingss. Frth the bolly ur shi no
# Iter-1670 loss: 37.5778
# ed wirld a godad pes o-Iata oMeas Tis oumpre eoplo watI nflary shi t本us of Tomy17m  arkes aivediry wh
# Iter-1680 loss: 27.1858
# eUfil t0rl cfte, fomentes iovat 4y ind Japan ins have os ary, FaKp eshateon pintr Chin tores an tivev
# Iter-1690 loss: 39.3227
# eD intreccan megitust in in6, Hu-porilo, Japin towantt oo ther eo an escinslit in makiog sid HonaWas
# Iter-1700 loss: 26.1218
# exthing ltre am 1rth ceat xceanst to tory sthing crea th bety-fergrgestar sealel Sin thr ama yaN, raa
# Iter-1710 loss: 25.9559
# eclliotho ardes if the carled, wtoithol"rth me-abpengid por as inithe ChLm9tbepslito d ome本iomleex s
# Iter-1720 loss: 31.2236
# exCh peded "rng An ECh noru fy 17th ansto the marloby "pionkryistomion ceaty wiastarn mifeitony atse
# Iter-1730 loss: 31.4985
# e9 E日mabing an 98Ja'anes. Whhe tarsestpictriteo . of Japanisig Koula%aio ti0t 本aiangeMt of inaroy s0
# Iter-1740 loss: 43.6086
# eGtursl tiotvenerd an copar, parzeviroplOis, mint;poy oun"s ando nnperntreg:ed fory stmtro Sea the Gs
# Iter-1750 loss: 31.5492
# eJapan (Nuhed-日ages. and porlalwhin mfefoboly byrbac  omes. TeP innpurieges imest mJapay if NistaOCCo
# Iter-1760 loss: 40.7935
# en c8ko lo les, which popa- ertevin. Iras ichactinsil tar ais of Japanke ,94Skn( ofiJapan has g Unthe
# Iter-1770 loss: 25.4859
# ed late uf Jmpan eas ofain the Conntfy I fer. wholltas turtd cing. inar rean Ch6 and siase Beant in t
# Iter-1780 loss: 43.9639
# eg on ry-Japan's inal meanewte tar t. T ex solllly Inddin tor sUs a2d ingsunth- anded Mowes aTd Toe a
# Iter-1790 loss: 24.7311
# ed Paceon. hrs the xumblled at eterres, the Gopernoky pires hichi2a  asal fomaktous aid dired's tae c
# Iter-1800 loss: 32.1589
# encerned pceapal efion the Mnas wicherea, 3Bdang at ey ont 2019–sllighis verea toe s x96anny Ni'gnst:
# Iter-1810 loss: 25.3245
# es rivethen eater and r3er inate Risstaro Japandin naranding mreatiky hined ander aHghHun mh-lergest
# Iter-1820 loss: 36.2438
# expowitad ,De tar omiteo–se ballyuptr esStbom an pea colllow wato nnce it I8 E94Tiand ay pargasta Sea
# Iter-1830 loss: 24.6209
# ed of 186853s Ptaith- aCata cona日d HDD ingcrurmled Narts-iand in 1938 andina P aNaeF'or esNihesixd1s日
# Iter-1840 loss: 44.2217
# ed iothe Und  atMe talylica as .eard mf-easa of the Ullltecban endisi3t ana Parivew. InMeowh t murrea
# Iter-1850 loss: 30.0917
# e7thu and peroe l'o thi goper letirnfic4ln 5frbothe curon lacendin  mperpan enoli. and Japanesi ghicn
# Iter-1860 loss: 31.1195
# es of Japan hes of Japan Sex ah "inald coflurted inghs arde;t rea pary sita% oM esithe ) is to-per es
# Iter-1870 loss: 28.8428
# end mitota endi g omp5rellowid Me"ina the hestrzenclllerth. rco Japansed
# an, Upan canatdiledEa acg o
# Iter-1880 loss: 24.7718
# en fumbollK2) LanttChigand st Incexperte-sare star Dinend peyiin E%sitection. Aanat 2Tea anan ase ,".
# Iter-1890 loss: 30.7265
# es ofmerbed Cexcangis levore thi fmint erollerted andef anghesh ranesg. Jypar esPa. Japan wosh prmo f
# Iter-1900 loss: 36.1506
# el of Japany in-kary ihgasticn fopor eaclioban moferopumbeltor esice tion Huris un i2aan tNilas ua本is
# Iter-1910 loss: 34.2044
# en aper anserwoce woth. aswata I wach at 0ti anfegist rngintrmy. Anou intos eionw fimh the s. Japan s
# Iter-1920 loss: 37.5625
# eSta yest enker I-d veven mill of J8pan, is thegilns. brbong botev Japan's aixtthe cornd SexxSux,h in
# Iter-1930 loss: 28.5609
# e;Paatyutnd if 1ive ho Ind Wisthte the purth-largpdt ex ar hou. 1858 Bfan–rys ind io atim, EmMithe wo
# Iter-1940 loss: 38.8955
# ed int5 u1 pecary cn ofate laveonlleb2the cauOlOupey, in E94h, whic lateconLing omA East it the ffurm
# Iter-1950 loss: 29.8654
# e forl povinlligittIymeryest mowitored. The TTeaneulio Japang os rokio as foforc;intred intmeKerd at
# Iter-1960 loss: 23.8670
# e tard il of Wes isa.a-Tokend Siagofuremiiit outinOchOcenxd f ghmas lopen me porloi: thi what cnaro f
# Iter-1970 loss: 23.2185
# en the wortry waro Stituniresinn freaneosed exthicantrry ind and reaRopoD. The Eapa Seatedid bor of2
# Iter-1980 loss: 23.0580
# ecofound Sias, uhake thicaly,c, Hur,, hhghm perwallrealloun mirontla, isia8 D aiat ora aevines corlob
# Iter-1990 loss: 23.3141
# exthe sutme oured in stureal of 1 re 12, the sumised fomboteon the Sins aidedas Topeann kokliteat mxi
# Iter-2000 loss: 29.9775
# e1 m2 Japan has The coff. brranfeuntye Witn m an preitzon chint un rapente Sint miurterino aed it anl
# Iter-2010 loss: 39.7319
# en chake 0t maunty, in NiFEC9 Japonigis the iola iouna Smino,itovec the corlt"-la andirente nfred the
# Iter-2020 loss: 32.8770
# ed ind Emse forse thi chand of the woul pemsurthi andes  fopar es(mevy pur h89Un hase tounten Ts Japa
# Iter-2030 loss: 38.2673
# ex Japan is a houh countUe nt pricest mbirea. T6ernenwia don. Japan 1ish aWms and laggotan ,, firctar
# Iter-2040 loss: 28.8623
# en bard Hith s rcoplire fed intith cwestzeE prles an %tsiras tares and iag exper es the Rupan is unic
# Iter-2050 loss: 34.7614
# ed Emperom Lest mountevino a Kous ar hish is ander agest. Japane a6 Efleth lake ga the G Diantatae en
# Iter-2060 loss: 39.5395
# es and poflorily ix awdiled matoy llomilt ureed fith se Sin the Empare maliturtecinnledi
# ankes andevb
# Iter-2070 loss: 27.0859
# e"staty it arde
# . ones. copit5-ureansc worth if tit1. I aigiotho Ind 0ivesean ky int mfirFLise an eas
# Iter-2080 loss: 33.9555
# eG a5sed Japan tae thinand Ky 19955320mann-gint ereadan Sea )aithe wer,d fr mper dlome. mp
# ured Nirto
# Iter-2090 loss: 22.5528
# en ipita esea and fer15te enollorg with Orallogith- arI dak ouularusigLonsten mevecoly rotod int %f t
# Iter-2100 loss: 38.2416
# e fommryminy rowis cithB and sig9ta U, the G8, anztreanlil Ir efiloe tok Go, in thes toest 18un asirg
# Iter-2110 loss: 34.9541
# ef Japan") in bousokn pico cgun Pe in the G Deanthen"canke 5arthe d lerolat in parted ind1r hian logi
# Iter-2120 loss: 33.4829
# encoffrce ou maringia , I本 Nipandio athe wata crurad in the Rups, is the sorensed Japan laig Naty. Ab
# Iter-2130 loss: 21.4401
# ec of 188355  slle5c of Japan iLs of Japannth  Westho fecte(th- astreija to th warns ffchrcerparidsta
# Iter-2140 loss: 21.7311
# ed ind surented lore s creftgestas Its ou-perled of Japan has f Japan ter osare-Jaranghogv'n corroc t
# Iter-2150 loss: 26.8307
# en  prro1xth cSintuinoleof of the wors om inth peantoun ty intMon m aamioula, i, and HoAlati. Coin Ef
# Iter-2160 loss: 26.3834
# ed of 1863. Empetion ease ursed Ches Ph tory. An"inand ny purth-iatopy. Ituin Ta-danteos lilata naMte
# Iter-2170 loss: 33.6759
# eg of m8kions ticw . revenoly ct–0thednllto ted. anded noullllitatecpallerlarerf conted iigat 1two a
# Iter-2180 loss: 26.9233
# ecPacino wHry intteanledMit mifr ored Wor s and GDDeatoyurc'in thithonle and coantry wh h the d resol
# Iter-2190 loss: 27.1265
# e tory cl oule, The coflJapan (eas of% 18 anakio hiMi thean Ezsh hes's rl3ty malegsithec)-rara, and x
# Iter-2200 loss: 26.5701
# e maly mprreallo(u fre,shallotes ipecitoled Sing of Japan 3ish Rulat enwelird sid parwhis 8pinction,
# Iter-2210 loss: 33.3104
# en apvenelll5orll mith un oasliun in ix ar s and Wowpor 日co nory wod thx asktozin couten isggdeo e4,
# Iter-2220 loss: 34.5085
# en maletutr esta the "sta acinth ceroty. Anda, Koo dacy of A201815, (n peeper ins am enthv world-Want
# Iter-2230 loss: 35.2030
# ef omiladiy o ae thorecteotPe fomt. Japan e) o本ed pu5se wasi th 17th enlllit0th incath-Jaraskio f of
# Iter-2240 loss: 34.3075
# e% of Japan's iongint , ullert lagalleif th  ohulak To. Tiothe Uast urea, puro-lergeso trec an "stile
# Iter-2250 loss: 33.8794
# ecGliwat re本, and Nopurinse with 本al moftion ese-Hond of 1868 an 6isn by purisan Cuknou, tares inlatd
# Iter-2260 loss: 39.9740
# ed Japan ses Japan ios 7ime, fich potve center aa wiou, pingishy rmainto fomy country sidtoc ae本er La
# Iter-2270 loss: 34.5876
# en istabyes forr (oplobes was rlaLmo2iesCith  is Japan is. Apurthi h unte pulles59 minofyustyisin App
# Iter-2280 loss: 31.9137
# ed itsthiOl0te be coperce firh surthi arghrm cite trod andest reviles tionmerven tou yss Aopais opion
# Iter-2290 loss: 30.0449
# e tored 20m:. The wore 12m and Russo usi–nHo aaly, par7o the GToaton PaTwach and Japan 1a B andons an
# Iter-2300 loss: 28.2672
# el of rbelse nan eswivetomy fro, the rurud Nigsol. Emit oreNiankudisnWe% to Japang an Nf inht rean Ch
# Iter-2310 loss: 38.1722
# ed litho f tme thr efllegporaea, P andicoflob. "8un and Japan's 'iggorom mbye winarumef.chmintery. m-
# Iter-2320 loss: 37.8812
# eWfol renirar fea, coreate. icoat on therce
# . met on maintois tixthe hirg ss perled Japan foP mfiita
# Iter-2330 loss: 39.1594
# en mareEHu the PaFingh ar 1ssi wrss t parledin" pardili'o tare 6tea, collos is imrio a07, thi ac2s Ja
# Iter-2340 loss: 24.9653
# eh as country s wored picateNigin日t本 CDanan OsharOGlona d cen日ipal -oolltoyu Seisin Japan, Ias oulari
# Iter-2350 loss: 20.6263
# ec intren as rwurth8 wttored fis the Empero Ned.lirest urteoper Oupurisad SinpcingAtaith the waith be
# Iter-2360 loss: 20.3243
# ed ithly chngopabe geath-Japanato-anfcof. Frhard-lateestic fio, the worl whith  isilnow on Atur eof J
# Iter-2370 loss: 33.8290
# end WWrl 1 maItyuy sexpandedtirgesl purne purle
# . Coencino peveHounard Japan whi stu5bore E9se popel
# Iter-2380 loss: 38.1543
# eg of J8pan.iTok ofoleKry siveteO Go, st thechlof "pocnomiintin. Astat end ouslo-Japanose wand Sintim
# Iter-2390 loss: 43.4547
# emeLopLond Was ofvur本Cs 5eko whin too1. C an hish"mpllly-pera–s Teiteredec fourse Surth- argest cxpor
# Iter-2400 loss: 20.4090
# e thu cruntre asth uhthesed.errla the fer, patOcyEDints the larl 's tion hiend ficed xnd Rulan"e6. An
# Iter-2410 loss: 27.4421
# e tory purea, histo:f rres. mbrceipiteryas comitr an9 Sean, 9hi hesive tar esta, candin the Eappes at
# Iter-2420 loss: 27.3294
# eKyuran Las towhot ofyubille Iwor. enceCs.recou tre eatua wila, ithicenstrexea me torth s oc% ol the
# Iter-2430 loss: 34.3590
# ething torth an East Ataed Jalan os 19395% in eshingrig st mi(rea, Upinthe warl pallitith in the 1Lo
# Iter-2440 loss: 29.1215
# ed intAr anhtoend naude fecof be't torlo(a on Japan (on Oapanises Tiko-targest Japa, Eust acis. ithiK
# Iter-2450 loss: 39.3967
# enterna, whith- areg arged f urzes omlit thesEWre trucs andectecygs reakd boflarcery-kerpon the Sinh
# Iter-2460 loss: 36.9260
# en mary ut pedilalo Heam ores at othenardes ffictzer mpcenpereas ofith wheastrynst crteota ceand inft
# Iter-2470 loss: 26.3529
# exth the dly bellerpecourwy' would Hupuria, whinh is aro2 . ralleowith intti7 .h cantpon theanlleO ca
# Iter-2480 loss: 46.5176
# exthi gn本rd late. a doke ppurconnir oD aint pin"h f rhdesunturla-d canouI. CEanB and Wend. mrll;arl o
# Iter-2490 loss: 27.7578
# ef urles and zea Sumino IOChS.O%TInnTTThe TTokbob7, Japaniie Ceine of incana-, Wan ot the to3t enofu"
# Iter-2500 loss: 29.5998
# eP and Hounaly in "9pand a worldec ane thith-uanded Nistomy it5 o umbingos texthe anct of Japanised J
# Iter-2510 loss: 30.7216
# ed forld in the nat. The nmpen Japan in Th HounJapan (ish ionat Cy bite of Japanises The Saad ,utionG
# Iter-2520 loss: 25.2818
# ed and WeHrt ur eapar ean miontby i–s itha econfoby P7, NackaP on. I 9ubykionR. SDnt korlatoyy wIt ro
# Iter-2530 loss: 25.8512
# en Sumiof esich wero  oist tu ea. tiondenf os lePinumianches f Japan'se aamef in 18m5in"tyR Asiind it
# Iter-2540 loss: 24.1414
# ecGlopat on isalitolnto n8rr aithe wirtd in the Sed ex, surtrty h Tan onaty in Taidan iostary of olli
# Iter-2550 loss: 36.5274
# ed fitst ingleSwe 1s aav, ompreccored nf ioctalise foun wrest, of erSthes8ofer pro5strj oflleroplli'g
# Iter-2560 loss: 31.5309
# ed Itsex and cf 18ro anded if corse vioke is anderyast un erbat end Ni9gs les "a nsulad Taedin-dhHun"
# Iter-2570 loss: 26.0494
# e torPdinn ishiceaime thG Pealacofyicatoyy
# . Asilaion Wevilo th wer8d nar estan wos日t ren iohtveceas
# Iter-2580 loss: 31.2820
# ef intreacd Wod earns anderon eshllerighe 17thecentur an in Whs hreants ve wirl meat. Axpardel wotit
# Iter-2590 loss: 25.9266
# e warg puntro, The LEsthisid tog ofrin the early Empors liinthr ansteareess ithon carcoun WyusWhe s a
# Iter-2600 loss: 26.4689
# e porigrcuna yyki, Ih ha angrlark in thecenompen ed thes lat( Japanu"iss and Japan'se Was the 17th ch
# Iter-2610 loss: 18.5752
# en%uWa ergased Sthe war, (Japane ss Brono Sulion ih hhr aigsd WorcosEan menzlo Japanjs h 本he mallyu,
# Iter-2620 loss: 28.6863
# e thigh-largest 19th aediotho. Chon gsenturin', worco itlof escanaHd intou aro s. Ari's th Secterilo
# Iter-2630 loss: 24.4684
# eMed itoond. mity in the alded Niggsentu theinnof. mrpirteM iigthiperopecredind the sHurs ingiat of 1
# Iter-2640 loss: 30.1122
# e thiled pfrie thec estoby syuracinst Coftory stroth. wrlw rs ar–ed, an thard cnto lithitg teealeRu,s
# Iter-2650 loss: 19.1756
# e worldef Corle fvured ingd Japane ma Snite isintron ea. Tn: Seand iont1 me Nipulihy Tn "osntryu, rar
# Iter-2660 loss: 22.9845
# e) of the Uxps terion miceteryis, tol thr IP-leot of inoI d5in, the country wist 2xisnteroT enI ar an
# Iter-2670 loss: 32.0789
# en the Seat of secons lered 1ath of toUad in apan ter;pretsllteviner ppentho pertP inal counopye mal.
# Iter-2680 loss: 25.8135
# eChine and aillof JapaniRessI wored fimated nilg meferHHes an"upentropin" tor as and oiule–Deengint c
# Iter-2690 loss: 39.8764
# e tored 3id RhighS Iid The Tarmo Anding omd miprea at inat In (JakanoDi gevoverlly wite plrEmpe orol
# Iter-2700 loss: 29.2357
# eko-Japan'sn ancetforse war Oupor-Naresil orlithe Upilter angrea, twed of 1sre inomed. Tho chaper as
# Iter-2710 loss: 18.9897
# ec1ure ssolapan toundry ns arandela ofitheunereabed of the noun. Apexcaron tho Holity- ar .a. The Jap
# Iter-2720 loss: 24.1966
# ed itgve cond silgea a derFeopar Rapan ins iacateon the cars ofe mFimthe pla9eo n, ma tio Kex, rlncun
# Iter-2730 loss: 43.1880
# ee f9uryFist the Siak oun Japanina an EesteapeW piL pare didloun salat tn日lesabiod e5hex Japan is 6 I
# Iter-2740 loss: 18.4377
# eby prres ind. meurle. SticeKomper as anded intory snd Nfrloulto- eslin thes Japan the 125 maty 1ith
# Iter-2750 loss: 34.8305
# ec intreces. metrleBpand starN 1, G mrofrer an hishd founary Bnd Sunceanes2 cmteFth- erollinn furpan
# Iter-2760 loss: 22.6555
# en Japan") 3is aiged pits e anir andery of the wist UnaN hesh mprrpestumperte', foftoreac crused Japa
# Iter-2770 loss: 18.9489
# enthuncenf re penkil Japan wos Jaka, in chicedilg of erces ured she sountry %it th  a sid6red it'o to
# Iter-2780 loss: 18.5162
# ed of the 1s, iwic, pertho y firo an cith the PangK本ur8. hind lorpea ty sistdas ofoled antreaid bog h
# Iter-2790 loss: 18.2885
# econ. AsEare itha woch womed coulay Russ, ihile ofirlecoin本 Hokin the iontr 20 arly. Sin the Catity s
# Iter-2800 loss: 23.8757
# e) of Japan, The Runs. Japan, is a, is.aJapaniwas the f-rarleg byupuut onas. Tho andid powina perivet
# Iter-2810 loss: 30.5092
# estimeveloby bok of Wer ans Mepor emd rigesty. The% ofterbel lomioucEmiino Imin. The countre Eas of t
# Iter-2820 loss: 29.6172
# el of rbouse ing hivedsloresta mevingsa penterilely ommebttye frtvry ca ensH mian peuper Japanises a.
# Iter-2830 loss: 17.4207
# ecy nutheclanl Bfcincctevicoly pean country o m boty porth in ainsth Japan ing Fim0th ofartoul a asUj
# Iter-2840 loss: 29.3881
# enGBraand if Japano es anded aldectare sturecoins ardedevet pardern meantory byu titho-verces ar esur
# Iter-2850 loss: 17.5749
# ed of 1865 on the "sgitwotI cpariont miinter.e. To: mefecof本e, nor asis. "hhictrthis ttan enver pa wo
# Iter-2860 loss: 22.6180
# eggontr . Nirto thex Japan ta R inttith canst ben umientyr. Japan sos ofkubiledisndevented an evOuras
# Iter-2870 loss: 39.6253
# ed 's colyt. Nilate Sivi;ccrionllboledxestro leg1sup Wiggsta loly amaed ftPe wald rthouckecof mherouy
# Iter-2880 loss: 31.8255
# en mary ut ecdano"s and Sian-zevedest ecpir4l raadengisathe cart rnd Siand io to1SeI indas Canntjo fo
# Iter-2890 loss: 23.6967
# ed Japan in 1947, Japan iosa tomile aEmmolita, wof 1rth senturOe Emintto es5ath  arlala divore pardhc
# Iter-2900 loss: 17.8476
# end pirse thicenompec as the Worth wgecturts te angital muatrecenoutar suatd ixJapan wos r8rinan eeas
# Iter-2910 loss: 27.0026
# e日G Apan-Japanese War and in aboce jouth t an alR. ommeRtios la Sma. Tokrorci,ed-larofictanins iturta
# Iter-2920 loss: 28.3878
# en urly int eroflorce ta the wot-deby ar esan miptroresiand Sianoby conithe Chin ton strin and invere
# Iter-2930 loss: 46.1592
# ed of bokus 's Teakoku rressithes icgat r. Eas the d-rana as inak hu anop.a omkeres the suragesth The
# Iter-2940 loss: 28.4182
# e Country s amL0rg and bo本th-largestirOcont. TTe fiog reler an laoko th The TfiforopeanderFima cmino
# Iter-2950 loss: 29.5095
# er of 17, molllol Iixthe hasgvuntrec5ored aa tis lare ol 18,8 JapanNisid roges and Wellory it the wor
# Iter-2960 loss: 29.9734
# expHexthm prlesit. Japan wese purle th  e日llerog 1swe arth is and ioflarles. mertorolledist mperteroh
# Iter-2970 loss: 17.2203
# e poritay Cs ingitht Oceanas ans a4my atre, Nh ombilid Tokyo In4cifouryopinc'a in th thended ioveAxBa
# Iter-2980 loss: 28.9257
# e) of Japan's ind bored in sh 1s6 the sux,s andeHurpa-dKrosed endored icth. Ta. Tea angistimpe8 of it
# Iter-2990 loss: 26.7383
# end an 1sgh on the Med o ferrloAlath ghecelper al hised )7urc ans the terod ch :arth andisnd aumee in
# Iter-3000 loss: 22.6351
# ef it–sed and aist mborea Syu aipKo honh letrer2ed and " targ ma pekio and if tre1sla diothe. The caa
# Iter-3010 loss: 25.4046
# expa3 en is 'okFoHs ahe Taid nowurud Syagonn the (mpJapan esoknou. Was lasth and if Japan issithon ci
# Iter-3020 loss: 17.3654
# eg of 188,pcendliog eJapandhe g tare cmgxrges. Nicantr it. Chincounat denllout". The teolao t.iJapan
# Iter-3030 loss: 30.6262
# e torthp endarae tel3.  aesturbezed The aistiinnsiof of mailin, 9y iSinio hiJapan ses mbebouy, whil
# .
# Iter-3040 loss: 29.9045
# er of brtyos UanttedMand mititacity the PaankiI HeJapan"helllctar hula- OEa5y s7 the and G %est ofece
# Iter-3050 loss: 17.2003
# e torven fy 17th anToy , mencrperte gester and War e tary shats-decotyop lligsaT rre)ollryHurth ipwar
# Iter-3060 loss: 31.9178
# en a-kerupe-ourles. 1brot taele0j Worth whe wotarceligy fruh mato uL Sen oG Japani sha, waa the stuth
# Iter-3070 loss: 36.2379
# ed and Willered inteawi"ston in the Empithe wo-llry sored sighoh la atde wio, thP coan byur"d in in 1
# Iter-3080 loss: 40.3766
# eCh fe or asea ason aic Japan is a divent;r anes the Gslinflurecear of it an ex EmstFimRdabi st71 ryl
# Iter-3090 loss: 34.6783
# ed of 18,8 and ta in ae oul9 a aod Hispon AsiintCi.nT ine sedErgedSin pokud's Toe 18t8 Japan is dired
# Iter-3100 loss: 26.5756
# ed and Wa5d ki popron mhecenou Sed iolatimy. and corlowinn ceRHowiso thes fimp eo an pogital "smit0tx
# Iter-3110 loss: 29.9904
# e) of 42purFiand in UoThitenstvergeltpe rortvon maintoKy thencconimi teN, raato I cimhitr Sta ne in l
# Iter-3120 loss: 17.3183
# en ofmentuly w o" tregsstteventcon. Arumionlira is aigho a divio thes lorgs tjo Japanesis warled. hho
# Iter-3130 loss: 31.1156
# end Hobed ingUpar Mes, mintoboledeWist ratation inhlehe and %as rer eacteenlliug poredsla Oedipenop i
# Iter-3140 loss: 17.0902
# echisidan asalaccJapan"hen my from teDesogest. Japan is a–cen esolei)n L shgaclig. the  Eman muli本ila
# Iter-3150 loss: 17.2028
# end Sino-1. Tokeo and caro un aumesily wto thnlery shtovigeran Nfertarly-Japane es and of 1947, indiN
# Iter-3160 loss: 16.6093
# er of Jrpan ies ih inthe ande fred om enfres on the nould. The coun. Cpurnoulinoper eacmestio tonke t
# Iter-3170 loss: 34.5503
# ecturigo, the county ucest 6igh is Whe s tar aed of in lep. Jaea, sno Sea, Ressiof in thi hast an eri
# Iter-3180 loss: 16.5786
# e thith ined as reand. Ase foratke tBunbat on Mesc8 itht cJapan es anged fith  ald tare cp ata thin f
# Iter-3190 loss: 44.2548
# en mxar, an cheand, EfWor ha.anand aakey aid Hus as Sna of 1865, Japan lis The Sin. The Senjigh tho h
# Iter-3200 loss: 36.9139
# ed by b7, rb-lerings fecrtesta the s-gerule worle. Nish pronla mict onuly-cand str ofalecealalde4f me
# Iter-3210 loss: 23.6668
# ed of 18p3e nalitt in thesed本ly bkl porlaTa doHn. Nha amutarendinnto rgarest bof of Japanin s and Jap
# Iter-3220 loss: 23.6050
# encountry  stx%sithtud denes anectare of the Ripan esiin t(e ,f int, the turid sar Paalo itia med本igi
# Iter-3230 loss: 27.7437
# e8 of Japan iTs  Jupan ses Empan ed ande aaleUusO popurickeobSey is omperDer al Wos  rruaty I TTa Oco
# Iter-3240 loss: 21.4884
# ed of 1,331 ma.cT. The Japan es and of Japan, is meio, cinty cpentury sid, the shrborl engiontura, wi
# Iter-3250 loss: 28.2245
# e torlo-lanUnar asand in omminel ,8 inghtur torgs, Emitthes5rume fecolye flurctalig tar hK. Tha coll(
# Iter-3260 loss: 16.8624
# ed forld in the Ungitho h st erla日g stre-careest mitotoll a. Fburth is ompi
# . Chen. Japan eased She o
# Iter-3270 loss: 28.7426
# et on maictoky anM the Empe01 porandegiol War Sistomino, Woullgiantm fr esuresi. Aban orxa melion la
# Iter-3280 loss: 19.3896
# estirn cito-lest arectare po0thruntoun tome tesio6 the "Lant"ons r)oun thon te本 zeve4f thuland an hes
# Iter-3290 loss: 26.6237
# ed ftrrovlllef the peateku
# . LLod gggstre matuy, the dfirMelloredan cmparterinco feu, thuuslefof bro4
# Iter-3300 loss: 33.4971
# e Cornoth ing–sto Idinobed e; leverdece oy 1935 chinglcovereud foranke tion and nWer rils, the Caint
# Iter-3310 loss: 36.4969
# e world's torte tegitst ai westocllitotur an is  mpar estarh s tivive arges and Hficaryys nfeis tHrus
# Iter-3320 loss: 20.8320
# en aris aidh t minatomy ith o marectid carna wint miinterio'n Eald Statec fechtre parlediKy cpurlloum
# Iter-3330 loss: 27.5580
# ed lored 20 the nftctuped logonat CuufeWor as and Westory indDs redllive a deviogst arectar GEusalatx
# Iter-3340 loss: 24.4273
# expaj mowat ro Tacdtotyes fouct ecoly.17945,, mllitith perged toecoF. ftud NatDs legit t wectrof of J
# Iter-3350 loss: 17.0796
# ed inBracknd in perced 5f Japan's timy rr)eMacd if ahechicanges ia the e wodH anes tho amdest ofed co
# Iter-3360 loss: 21.1302
# e torBdan Gosiand Hindkbiry in thUbsed sldesud erupeaten ised forones ind ou2theand lige a9me tiry sh
# Iter-3370 loss: 26.5989
# expar e)mir to, 1937 Nestiind. brofctrcane tiving anderend Neseopaoc an 2uursed ni-s rethe turyd War
# Iter-3380 loss: 31.3757
# ed intry Ningpan Em. Hor audes initaky 4, inchtho esta mestgectooy . mectteviol N peofllerys mecolaro
# Iter-3390 loss: 20.7680
# expar ensarerpal erpalic日tar Insiand STakyoT irTokyobireapa. Naoko tou o日y hxs carpolit3yu Senjoiat m
# Iter-3400 loss: 22.6197
# ed in be mecizas Cha. Tokyo Sintereontr ":uf creatty and the Empate of 1rredan mesolatoy it wict ofi1
# Iter-3410 loss: 24.8390
# ed EmperJapan wos r
# . The Reshi hasa terUe too lald ailat ;ficarest: I oficao oxppecergern1 m, Jmpan
# Iter-3420 loss: 28.6044
# e nored in 1s4h Chana an EmaW ored Ningsam本. Secondeseviog the wato the cofrod NithO Moy ig of mevelo
# Iter-3430 loss: 35.8585
# e9 194h ioncini d in thes of )rigsaig ll goplear 9i. Tob. %cof Jrpan is and, whish thes at; tazloufes
# Iter-3440 loss: 23.5612
# ectHon bo, th HHe mar, st6,, i% an srstean fess thecc,rlade Itan contony phe tho Sen io as omekecovur
# Iter-3450 loss: 16.0247
# e folKreplligotat ro wala oml日bry, in Uss the fllorg sC–rro andentayinat an isiat-ountey in thi esty
# Iter-3460 loss: 33.9321
# ecoly. Sumime oa mhikM, Tha efoint, joldo Atpan wostrined Cx ferorestrof es1ure os Jakan-sig-oaty inc
# Iter-3470 loss: 21.1164
# ed StarO7194, to tor oLsth the forll. IF irlaT  mian-bybAis the country wist miHolbbo, th Ohhciand Si
# Iter-3480 loss: 22.3921
# en lymprote. The poulat-Japaniin Werel of erpesnd fivadens woritery wingpan ens dakad ihal conat fowi
# Iter-3490 loss: 16.7315
# ed of 12385. and in then eopanteding p:irt;if poteanecony Ifxiphand renjo 1xth is atd laec an Lopana4
# Iter-3500 loss: 16.3557
# e( arehes lopen preanen oma ond Sec,h in oupjo st country indisa Sumeiteobion eLdin tas eacthe Expe t
# Iter-3510 loss: 28.9452
# en ap milatoy ,an  8ha arof an espare gstroulo angint. Asctionturea, Chith ige thor estWrcteound fore
# Iter-3520 loss: 16.2213
# eend intos 8ed io ta's un;rrawepon warag ffurrteshitho Seacciind 3eveinoper es of prenseDend lores an
# Iter-3530 loss: 21.1469
# ed forst in the nar sirnt4ty was of ancesest mcillac, fich io lire siand Hu parithinhi anded redis ic
# Iter-3540 loss: 20.9959
# ecDe1tto Japan candennceur e ea of inol% an Eustroce Earo ot thise of lpuna worloTS Cezno Japan eahic
# Iter-3550 loss: 30.8225
# ed int18 Nean9ci ioghich-iSnath TTeancofion the Pangictionomy-batses fccr arthe esntecpurig
# . CEano a
# Iter-3560 loss: 23.2957
# ed of Japan, The nTo uCpine osKfecon  pa, thi)s a iStary sttece, the 186 ean tegistred intresil ton a
# Iter-3570 loss: 23.7412
# ed of bo, sis rumineliEs and perteuned The Siaton Te wouldek orsd an esparceHtu areesh Frromla:ict io
# Iter-3580 loss: 15.6546
# eko utudiseda. The ceun reoper ons beand is af ixtas canto f andedeatdes a6den Rhesnturs Ceg,z o at o
# Iter-3590 loss: 15.5035
# e torEd ing 0t%es lares pianc whesturoh largha. Eape or a4s if horss and Niano-koy pirlawat of Japan
# Iter-3600 loss: 23.7427
# ef of Japan, The nTo 'akio A7if militar asiig in prrcestiry ins ureh arjes. rbome pesio thithecdlolio
# Iter-3610 loss: 21.0910
# ed of Japan i4s nxmarto insthi edLalo andeCErwe o urjo stuFim dRussedea, poclsimitobo feudes ar ergal
# Iter-3620 loss: 20.4788
# ed Siay I feritse an popalacdicidopend nngaean ftered it on meconopy in thu countr un and the woul. A
# Iter-3630 loss: 21.1030
# e tored pinstimeoblMe thi as onImN Aopa. Japanisas Japan to espane maatecyisi, 2a wo una Seakio, and
# Iter-3640 loss: 21.3009
# en 2018–20Japan, Sh ihesturealliun boupon eshi. The Coupme1 opuraPkioSima iosthicentry wares19gh whiM
# Iter-3650 loss: 15.4737
# es of m本bures in Ohecta日o aland in 184hh wod,d pinded lored s rrvestoly bite f mhe6nat on is a wor u;
# Iter-3660 loss: 31.3890
# e normecn milation in the PaCo injouh dhe Torla8an Seatoou and Wargakn mf inare pinttin parioonominy
# Iter-3670 loss: 20.3639
# end by 18p3 ehend Seniio Mecourel inthine shure per, tommertes is atse follerog tar esNis Cy ponseand
# Iter-3680 loss: 24.0550
# e tor. vichta tevinest bito terednato-larane ia anume cofotrtus. or Nihen本 meatoy. Toe torlatI, is an
# Iter-3690 loss: 22.3676
# emeat en insthe EaCk of Japan is atd Japan")is rogestred alled arlod hire ssard c9 e oAulariog. Atime
# Iter-3700 loss: 28.2720
# e torlo-labend an exper es tee so lel, tha tured in the Global Co tare parecdis deveEmpeLar testy crr
# Iter-3710 loss: 15.5032
# e torth-largy,athce yWornd's ioghec prsevecand Nhean-ked fed fforse6e2, Esstechint treaserthe werlopu
# Iter-3720 loss: 27.6781
# e torlo日y Wucthe Ta1 nn ircdive ,esa arectar G', wirth lato-largfit. eran erlale pWar crlalit:a d Tok
# Iter-3730 loss: 38.2585
# ed of 1868, Fint mficeboigits imhtBrcopytrtreGseromitak Tiv eacthinntit. "ecat oy the country om 2Ior
# Iter-3740 loss: 39.5175
# ed forso the GNop-ondly i. ond conand in pirna Sian Dienoumebees in cirnt rof cimatI of rboun Dient o
# Iter-3750 loss: 20.7805
# ething and eallezeI Obrisen Empitivedest of inecmevulegof th theanont. CEmpereepirionturteong. Ath r
# Iter-3760 loss: 21.9604
# e torlopy cith in persed forst in of me3,, in thecoonuthe Paggict expe,tho tre shc to:st theLd of sho
# Iter-3770 loss: 25.6847
# ed onHry Land os 3iminiveHd indes cHrect'd cantewis texpar espaf endes and Naggst本ich wist rnallDecto
# Iter-3780 loss: 15.4442
# e mal;borr:ar OE6kkin, ih aa meat'on int roal'cong bmictured in athen caRpest ony "mperterine ty porc
# Iter-3790 loss: 27.6609
# e9 194, thiced ist日e ios o om. Japay ins5a Iidod io a
#  ciun the UNald.i
# . TxcTay Tropani(y by miottoy
# Iter-3800 loss: 22.5622
# e forrres f mrverea, cnimed. mectren,8 ficovtecisatrecfiandsed andes andecsarerd andercase thecB mill
# Iter-3810 loss: 15.5992
# encJapan essi.ange tWrresily cruath-Jaean iy surchoigtomy Atume:ino De Japan, as churid siches9 2iN1t
# Iter-3820 loss: 29.0301
# ...
# Iter-8570 loss: 8.6236
# ed liggGsttunn Sya ic Achiod is acd Japan in Nihilang sargatt enebollor 1arn wh–laco". 971, n intary
# Iter-8580 loss: 13.5463
# ety in thr 4miJapanied. The Gly ard ca war is.
# . Ahiiatdoy ingis. mbimear esHon, in 1947, Japan wos S
# Iter-8590 loss: 13.4726
# e4ulimeno alaate". A pOreseting powan: . Japand an e28ar colmetred Nhead West ronaldenci0a tor
# . In c
# Iter-8600 loss: 22.0986
# e torAdiand I ved本3U Nsliontupeckeou% ca ofotho and
# . Nipponio. Japan's Ug hise Gullareasif conompee
# Iter-8610 loss: 8.6033
# ed first in the Ciunt onslame of 186, inlJtys nowh sOKeoth cenduri4g vivis. Locats in tirsedolotMea,
# Iter-8620 loss: 8.2566
# ed and wMicMecony Pa ana the world's fichterles ffor omlHcome. ofole4ci–s oKoAs asmon% bom and HoTai
# Iter-8630 loss: 8.5235
# e world's largest lrte thM Rusido, Kyuwirthisndigntte ai%bot tict eUper wBst ore, and RGwstatI In a;p
# Iter-8640 loss: 13.0230
# ed first in the number of Nobent weMe chisertdoingig–str and revee liog snrthean of". Iroilisy ficI a
# Iter-8650 loss: 8.5598
# e tory ctmeiolopincowion Asian Chinand anderopte eno palacona6 CEmio truper an the countre os dbou p3
# Iter-8660 loss: 8.2433
# e world's lorrlst mbinterinnturioe 本is, imBlare starecHty ehvfles ea tLaresd. rorld h Brons 5menterof
# Iter-8670 loss: 13.9907
# e world's largest metropolitan area with over om . orl3a jion0t rnand intirnoly ches. m rrleta omele(
# Iter-8680 loss: 8.5314
# ed Japan in y rTd enturea, wived Nitros lito s siof omerenSin et en,joarth sh sartalicangcy is aT2e p
# Iter-8690 loss: 13.2031
# et7o eGleTLopengulan  area and ifiande nit(ea, Tex andOchare os ah:iI f4sh ropke lotyenwiM if armeEab
# Iter-8700 loss: 8.1095
# e nor
# . Sen The Taadicind Sun"3iTe no6, ancRuNipelid Sea Se4, uthol9 u per e3Ad, in the Gllive ,upL7J
# Iter-8710 loss: 8.2492
# ed first in the numi5c olleigid d Senoumabo o parase an;meorlybb;r an d lopol txurh in tarMe wiso tme
# Iter-8720 loss: 14.8870
# e torI3cy  andis %5d JapanFion War hes nfurdeland Natan neso h mab) ut manfed in t r:d consomelofecxa
# Iter-8730 loss: 8.4702
# e nor'd to1ss 3and aikho a fer efGlo an ecpan ras rac obig.eT e danjogs tion exphr giljoopela日d aiest
# Iter-8740 loss: 7.9628
# e: ur erunoplecony pacsedinWored and s arecHun ro-lernes. roct evifole pectio9 and in 193. TaWwol oum
# Iter-8750 loss: 13.1407
# ed first in the Countre s aruest lite fict endes aDe:Htr The Sea, is in 194, in(ciminouJapan-eanas ae
# Iter-8760 loss: 13.9971
# e nomsertayi andPlate niha to es and issleborpecwly rr ejbitg tse2 urtheag ofgir4ll it theccbinglorea
# Iter-8770 loss: 13.1332
# e norfdcy sexted oEmi0th The Sea, shiOcha, Hunar Dienturion in mheconpleich par esiIndures of inHrrha
# Iter-8780 loss: 14.9644
# er axghkterne imperecr efdar es"ataF and s ureloW canc6vilCo Imoun 2015–201 lajingitas weaisx Ehul me
# Iter-8790 loss: 13.1752
# e torOrKa, santrof rre4sh f6rctestal OG5olntit n whRapanied late "6lAbp8eceOrudin -s ranjian it n3ur
# Iter-8800 loss: 14.2635
# e mofrrbole chijcl47r Na8FiWti本 did, the Gmpire Hurisilithincgiond es Japan io Chi1 dSecean Singryab,
# Iter-8810 loss: 17.9906
# e forurOlyarn it  tiopWes Ofkiol East in, ar espar profwirtd Sian, ih an"ppecteriLo, in Chucano andh
# Iter-8820 loss: 8.4869
# econ. AsitC the coulnd  erpan, (miJopuline 9s日 Oapan, and cainttann ly tirth whestute carwest ere9 日t
# Iter-8830 loss: 13.7053
# e world's largest metropoin b9upicilarly, the RN1ar4, 'h conaly NHthinnturean China Sea anghinglbCs a
# Iter-8840 loss: 21.8023
# ecd itP1. ecLad toreans it i. 186 fillley the world's the 12umary of isil日y inhone seand inte n6mpe9t
# Iter-8850 loss: 20.3489
# ed Asian coNion本 ImicdDeroes ing the doly Cunce mi Rma1 te8 ingtIKsed ar oss vurod lagionaly it mivit
# Iter-8860 loss: 18.0813
# e torMe ,t an8;ia the eatod in ay rbollon2 hecho opa's counclyD. ond f5cBrpen ly of in(cano Undx milr
# Iter-8870 loss: 13.7378
# es om;rbores and Unat CJapan es orionf the Rusoly, the whg otamecoty Mf3od kar Sua oCh ind the G20 ar
# Iter-8880 loss: 17.6777
# er and Winter Olympic ;rchio-lers 本kpenice4p Japanaswtin enSea and We8, canal  rured Japan's iv:ot mb
# Iter-8890 loss: 8.5355
# es of 'sotesean mitatorl. A2a2h the4copNk eKi6RThigen s trre pacteyiby fos the G8 liontgyn, wiuth ian
# Iter-8900 loss: 17.8621
# e torcomy 9. Toked of rboly 1941, which 日m To es the sorlacity fMec, in8aty solgos dgWisth ma6abeng p
# Iter-8910 loss: 23.2823
# ed intry his dably cearent wecB"and int Easith tes aMked andex ander3" paity-ifvo : 9rpentDe naomedC4
# Iter-8920 loss: 13.7097
# ezed ar'ed ande world into RDeong
# . mivio 'h courtcoin ti0th  TaadinNiventre ab–les d.emecHthish is本a
# Iter-8930 loss: 18.0067
# e pori tomy ut4, hilg bNFhrl–ceB an" tomlbo, Tokyo intar"oun period in the Pantuli–ons the Sunceshinc
# Iter-8940 loss: 14.1353
# e sor ome bopekul 1ute and the MeCi carD on a mToFea Old ins the male Ts roulad Nf boped and s ardecl
# Iter-8950 loss: 17.6193
# ed first in the number of Nobel laureates of anTer and0on tucthe Tar Sea of jogsopal me 2-)erfore 0S
# Iter-8960 loss: 13.0605
# ed first in the nurse torlest expoethore sictroom. A) an hhna mylitely shar to sepmed loean aM: it on
# Iter-8970 loss: 20.2473
# ed first in the number of Nobel largeranged forEd in(the naHima. Arpar eateoo OlaD, of rroOlamingiHu
# Iter-8980 loss: 14.3296
# e tor. 19te teKyespar xs arBctab toGts an copartering tror andecnnomanzec aianti– ast ;biJaparilas To
# Iter-8990 loss: 18.1012
# e nornd in 1941 min6ine thi lorvble clar es-abomy ith the Eapipal w(sar pored in 1941, xn intory into
# Iter-9000 loss: 19.0664
# e nomarecoy mintmineacing wwor mJapan ,Japan iogital B aioL Eusedex. Japan besHomiHot ox maringa In t
# Iter-9010 loss: 18.5889
# ewocm bomed bodeciCe. and ingdeacly int r3llhiand Siarec in -iasty in otbe worst. The noped ead, urSa
# Iter-9020 loss: 7.9836
# er oma. Japan tes aparnouthEu,edod r, ghrlome trEmbeL ea le:Euredal9gingiJatay iLand Sia ofuised, sit
# Iter-9030 loss: 12.8313
# ed first in the number of Nobel laureates of ancePenlonpenoxur'dand shigand s" tating pate c'antity o
# Iter-9040 loss: 8.1938
# er of 1937 exwar, dhitrots am%ioI med)lo 7L man, whilio as mivitern Nmalia the hismd rveey by purths
# Iter-9050 loss: 23.8334
# ed firsc io Asiand is omdico 5mpar e.cinirths ande tored and ts n"ran ntSin of2, hand anderr2H TheFio
# Iter-9060 loss: 13.9994
# e torDwet of eropo% o teJapan hes China, powair of 194, in the fiTs eandis9 ares tiot erDethore s4cth
# Iter-9070 loss: 12.6307
# e nolarecoDWect otzeo follocesal olali7a ac–in5s 78pJapan ins bucheacon tiois a9–onions amoctebore th
# Iter-9080 loss: 8.3229
# e nord7cS o;Gceron; sur"s-lire siliti, Kyeshh. rfoleaporilaticy fetd ansexas  nolaWJl asWpun JapanicK
# Iter-9090 loss: 12.9078
# er as omdio, Rupan, %hs ten3j% dhktopuOWertal peured R1ursgiscomy ur is 1945, minWgicd,p oTso anan We
# Iter-9100 loss: 18.8686
# e micrtad nes id Abo4s tound miontern ingDe9De peotjo th t eanom tre sh roplesea 2; firr ard cand in
# Iter-9110 loss: 7.8669
# ed first in the number of N–ountrean wig tare wain, the Easitar is. Abimetr es–res ar estanop indarap
# Iter-9120 loss: 18.0553
# e nordAcy ownded filatse fed it anLen per 5kiry is a7d lo alamave7 preat6 of )ives fargyHun wur6d's n
# Iter-9130 loss: 13.1706
# ety iU stutencedHlotes ffo6 otBechios Lurinpe wh thoperle the0turedes om Hinsea Cornoc) LarKoe ind r
# Iter-9140 loss: 18.6696
# en%ist of in,mancithe soulapexithH rmaith inkl m. Japan's n rrd HoKcoandne iviMJapan ensi
# . itoM' s a
# Iter-9150 loss: 22.2944
# ed instr cMend Sea, if e3;pe
# . Anon hKot entalind gho Stat of Japan's 8inItary sh gi7th persedicn ;pc
# Iter-9160 loss: 18.7698
# ed first in the number of Wholstcead SeHoy iith f 8hr tstxE perolya mmext. Thean os larin 1im9 at in
# Iter-9170 loss: 12.6267
# e torSm9 and inyar mi5bit 日o cvurrgish caresta 3oy in am5Gr1 cangenti; ar:o hila ged parJaNa silio St
# Iter-9180 loss: 21.9528
# e world's largest metropolFTa dored io
# . In chaDe of rrecoUno tiyhT Imayjionst Styoin Eosh brletteyh
# Iter-9190 loss: 13.5696
# entury cing mures in ti)s ar htToky . TeaDwet orMe and xa war8 Cfino ompiOicote ,D ftorth KstaH-nary
# Iter-9200 loss: 14.0868
# e tor;d rreal nRus. Jupan es an29 Japan es ijzest mOreKpur la4, in imhitest ictaly," palat-eapoUp:e E
# Iter-9210 loss: 8.1306
# er at
# . and the world's na1rth intt本". Top ol reanl 1945 morlow-kory sha dhingryke tJmpan e5stowes te
# Iter-9220 loss: 7.9258
# er of fro. ) larn us ozul penap6y in 5t 1. enre "sul1ut iaed io jo sory siljog mtdere本thilentrba and
# Iter-9230 loss: 17.7592
# eP andeS aipo. rron paec)zio copeuted in the w,sth-larand in5T redelbog 186 Hunam, it ljionJlyar Nwh(
# Iter-9240 loss: 8.1455
# ed first in the number of Nobel laureates of an日eWentKyu Secoun r7T6 anGs, in Japan's n marect. eEHty
# Iter-9250 loss: 13.1960
# e nor2h SeR3aCO ingioz18 Siand ioInd Seckeuil EficLar lililltio n1mjI Japan, and toitan Swai5 Is enri
# Iter-9260 loss: 17.4873
# e torgnct en,zu  omesko In the oKyl8pu
# . An–sho 8idived ul lestoknyicinomixe ciihtit)) istlefeyd porl
# Iter-9270 loss: 12.7702
# e Pald0io a% ot ofil, Th roxNdh Japan tes 2umpen, of Japan is5a mencepeIJapang and fianted ande parej
# Iter-9280 loss: 7.9346
# econ. Asith N本 ann"stal P%ysi nesh porseit an soit1 un Japaniud War UnstrocG ofobor 's teopod lare an
# Iter-9290 loss: 19.6619
# e world's largest mehCd Sexoun. Siand io thrirc0Larn liggran esuliont r The wowid3s y Tar Tomyary cpa
# Iter-9300 loss: 14.4737
# e Pallity tre sorCh.iI cKre日p icRaping as B(u6, Japan日it ines am6 it li
# . In ixhh rt4lerellitely mafi
# Iter-9310 loss: 12.0455
# e world's latres latp aiar an,  anrs –nunUpcenocminto2 s; arome f's, orHkrowhos 8inoP aro日d Westd ing
# Iter-9320 loss: 19.7031
# er alFhith in the yjsidhS ax shr an peJapan ensidan ceicankey is ")"1 d, the world's thorc-partes and
# Iter-9330 loss: 34.0999
# ecsu)bo, th  he orth 8ecand louguling and Henjandin, wantt ipmotho0h Namecinomy of eapan ponatio men;
# Iter-9340 loss: 21.4176
# e norud bigse fourP eodldSin ag6ettFisedWrr d% FiHwB hist 'silalane an enpaiwha g of oT-kekuh ye wor
# Iter-9350 loss: 23.2568
# e torx41 the Russthixgllof the and pe fer-parles and worigistd Japanines Tokyouy xumaday Cy witoro nT
# Iter-9360 loss: 14.3909
# epyy rrewsw tof es aG loollio, 19, th chacon) Wns realnou and Wistory ingIs the nntre collenMth  wart
# Iter-9370 loss: 12.5942
# ecturitol woist mi2l boLgo, dncithA wsily iEHsi c:ar eTpere g Hon precHle BBup.e cortali g anterented
# Iter-9380 loss: 16.7631
# ed ing's le.x. Farctes allstiStare salioutrecinos aid Horsolimniig an e ped eRtho Unst arec4a omijo s
# Iter-9390 loss: 19.5141
# ed first in the number of Nobel laureates of anSen ainstt ned ioves 8acind War hild-nores an E5par ma
# Iter-9400 loss: 16.4325
# ed xurs2 Japan ino thiLMourea In isiande nitaD P4agoDinctarcResol thoAstalo mare,citho gharl uN.h irt
# Iter-9410 loss: 11.5716
# e norKrly aIdcline2 aanow iD anar aB aG, th. Eustodiled as ot,3 cimo toes folzoA aame20 hese jojorgo
# Iter-9420 loss: 12.5940
# e norrdcin in China isa. Tha ameis Wmoio ce0bedcedpcrigCsiia aty in Japan, in 1945, Jppan iost2ich of
# Iter-9430 loss: 16.0331
# er aad WIn pReanot 本 m9vareco Bp of Nopeand nDic0 rro12t cenand in 1iun Er heg mofteby–sen of the Sej
# Iter-9440 loss: 11.6324
# e world. Japan ens dTredein:d Sexcea4lo 1-th an4cThisototy y and s rares and inItary wnd rame in yhec
# Iter-9450 loss: 11.8471
# e world's largest mmertomifocutLoce end B本sar Asian c0oD on the warled, frch2parn lard, the East areh
# Iter-9460 loss: 7.9425
# ed first in the number of Nobel laureates of an0eckan) of the Risong,ctnomibithAigJa–sh) Japan tbo h"
# Iter-9470 loss: 12.8569
# ed firsu 0t the worl 18 Sda:D coparilb. To. mfmitetIesed into parHedin日 thead oesouf of Japan io sith
# Iter-9480 loss: 13.6527
# ed first in the Countre s ard sored in the strit ;r (wWortor. Thg cofrercy into n 47borePxFiatd Sha.
# Iter-9490 loss: 19.0839
# e nor(me2e asist. Japan本 ercand starecc–red th  nemberGd fferrperremist erthigesty in fir5d Nisas mek
# Iter-9500 loss: 22.8765
# e% ot pboitys wut0th anded intomenllere warmming ouckekio high the GsliEurles, and the and se beread
# Iter-9510 loss: 11.6157
# e world's largest metropolitan area with over w4"htKrths waes amaedecofyN, nalAstarhecG Japanisa. Jap
# Iter-9520 loss: 12.8360
# e norha In isilatoyN fturtce fTomy frlo the cor:Ug ct andcInh She acding toveOcysiTo the who2 parigli
# Iter-9530 loss: 17.6880
# er and Winter Olympic NaUpsitCeinatory chto th earme tila of tho h pate %%st tithiPa and and eande As
# Iter-9540 loss: 12.4991
# ered into a 本Cxina SPa enUpse oefted purpea d divee populalieetFiog lileland an eseareds inat arealan
# Iter-9550 loss: 21.1654
# ef Japan in Firod giout iEuc-naigse thi bo –ont the feu,t 3. mmirioptrexWs. Eact oke G2, .ns ra pelio
# Iter-9560 loss: 8.0462
# e foorud0,l o本 Iko Ieapeone and tor and s ranes and, thith-tareg and ctirnomvin日 (Japani es and the f
# Iter-9570 loss: 28.1113
# ed istar is.d rith FiItb S and giora1 tn a0日 the eErse hild is6dapcein:F r6 116, ,f tiots narIed Japa
# Iter-9580 loss: 7.7809
# ecenduryyu, wa6 rodicanduSy ong io,uracilil Counlions ameiterOlymin the eIry s fith the Gllired vigge
# Iter-9590 loss: 17.2973
# ed ficstpente fitt meBrany thurad ingigutide neg
# . ment re inglopal tuaveHcTaidingIpaineas coboly-eap
# Iter-9600 loss: 7.7643
# ed instr n(cary of Nipunar I日0th ipaik((Ru"SinAni9. O gorstino feu, ropcra, wiacd inUpGy of 1bou 2 Se
# Iter-9610 loss: 12.2007
# ec3日. TJapanese War, the Russo:l teof eapen East of Japan was WBmanturealecon mymite t4omectobe, Havi
# Iter-9620 loss: 18.0570
# e of
# . Stai6 of the EmpiLor. es larec is Noku1i, the Searoke Sea aJapan"inG 7bobe sol powur dalesglao
# Iter-9630 loss: 7.3251
# e8poncte. The G's and maLKeunes ind forudal De onnmecktoe entrrc Ja9a, cand1d ingo mestury bing ar he
# Iter-9640 loss: 11.9678
# e torCo 8e ourregi日th -Japan. e. Tomanty ng 1tr tar end Noredsl Ocpaniedsan erdared if treas iind ben
# Iter-9650 loss: 13.0292
# eInd per, "h onmzer lictReno o ko to日y Ind 20rry Senou Chingreds rreR2has constrero in 1stDeen5"mbate
# Iter-9660 loss: 7.7723
# ed 本Lard inst In tiophe eEd end e ay oy land Nivuna mo本nd ing 4olrd nnot d nare as the :o-lert os den
# Iter-9670 loss: 27.0778
# e korud iI sexxustrecSeacen, Lactyos Paean fgarthe lere p%ust encBoard StimonF bou, sh bitrea Japan)
# Iter-9680 loss: 7.4338
# e nomary cith untkexpletId the world', fy2r realioe Kig本sar Chinacans aa on;Wirta Inst本hjo orlaag oCh
# Iter-9690 loss: 18.3895
# ed first in the number of Nobel laureates of and Ni%lou buw, ih h;rrareaHfy the watity in the world's
# Iter-9700 loss: 12.4324
# er and Winter Olympic pacesoJgy本Cin. IIn3'he and日s aimolT expir7t ryecSnaid War a0 eryh ivil th waI i
# Iter-9710 loss: 12.2417
# e nor%y. the ncreM it
# . Anon and isilake of Wicol gipan tounaw日 I nhe Sins Uh h Japan t;o Japan wos
# Iter-9720 loss: 7.7826
# ecsion tuy hisgd-nmbores aidjiths amand randefmeroperceciyU SheEpan Japan ing 9tutjoino n mer
# . An-Ph
# Iter-9730 loss: 12.0074
# er a8d9Honami6o, mivend Sured in omper esteE perodengcoun 20thenwostochilt omer and eceleople Pa7 ero
# Iter-9740 loss: 7.6040
# e world's largest mate the worm 's tomtestar noundrbingijnl5m Japanith  The Starthi eEsst rt3i
# . Agos
# Iter-9750 loss: 7.4975
# e world's largest metropolitan area wich 96pekeino, in kek,o fecolyist'o glrer本 s mantion P"Krth01 rn
# Iter-9760 loss: 17.6423
# en p'rltothr. cing cojl3,  oM5ith the watr peacory of peopae Gso in the Wes, tunce %–o( e8 p untec Ef
# Iter-9770 loss: 7.7780
# e world's largest met
# . Asii. Japan oCh bat8en JapanesR para in the Rist. Janates. Janat oeslean eudr
# Iter-9780 loss: 13.4103
# ed of 1868,  nturRSea io th3L cofigurud Shx Sint menkePipen io the early itho I ad;poryest folotgont
# Iter-9790 loss: 23.2128
# e porimaAn fiintrougle;p2rarpenturingiin is a xoB and Ruban in th is onh本sh iTaa feard itUAseac-Japan
# Iter-9800 loss: 17.9459
# er and Winter Olympic 3a lion)Japan hosed rudEe hisg ptreanun
# . Nin and it lies. coantecily rumedely
# Iter-9810 loss: 7.7561
# ed fiwst Fiot of Japan'se 3Fu, cte
# . Asiin 1uby, Japanina Ind firth largest cith the UFith the world'
# Iter-9820 loss: 18.2788
# e world's lacred lorcolatco o an pro35l mekoMu indis a, parced into tar and soughlle gdeanpelxNm poll
# Iter-9830 loss: 17.0227
# e3by icolambyrbest ithof copulilan aB1ath cint) tured in6 st in,ctrul(mika, Py inomlketholLoso Sea, %
