# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# y_test.shape, y_val.shape, y_train.shape
# X_train.shape, X_train.dtype, X_val.shape, X_val.dtype, X_test.shape, X_test.dtype
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # number of layers or depth
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        # The adaptive/learnable/updatable random feedforward
        self.model = []
        self.W_fixed = []
        self.grads = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad = []
        for layer in range(L):
            grad.append({key: np.zeros_like(val) for key, val in self.model[1][layer].items()})
        self.grads.append(grad)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Outout layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        #         # dX = dout @ W.T # Backprop
        #         dX = dout @ W_fixed.T # fb alignment

        return dW, db # dX, 

    def train_forward(self, X):
        caches = []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
        y, nl_cache = l.sigmoid_forward(X=y)
        X = y.copy() # pass to the next layer
        caches.append((fc_cache, nl_cache)) # caches[0]
        
        # Hidden layers
        fc_caches, nl_caches = [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
            y, nl_cache = l.sigmoid_forward(X=y)
            X = y.copy() # pass to next layer
            fc_caches.append(fc_cache)
            nl_caches.append(nl_cache)
        caches.append((fc_caches, nl_caches)) # caches[1]
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        caches.append(fc_cache) # caches[2]

        return y, caches

    def loss_function(self, y, y_train):
        
        loss = cross_entropy(y, y_train) # softmax is included
        dy = dcross_entropy(y, y_train) # dsoftmax is included
        
        return loss, dy
        
    def train_backward(self, dy, caches):
        # Output layer
        fc_cache = caches[2]
        dout = dy
        dW, db = self.fc_backward(dout=dout, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dy @ self.W_fixed[2].T # fixed random weight
        self.grads[2]['W'] = dW
        self.grads[2]['b'] = db

        # Hidden layer
        fc_caches, nl_caches = caches[1]
        for layer in reversed(range(self.L)):
            # Feedback path
#             dout = l.sigmoid_backward(cache=nl_caches[layer], dout=dy)
            dout = dy
            dW, db = self.fc_backward(dout=dout, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dy @ self.W_fixed[1][layer].T # fixxed random feedback
            self.grads[1][layer]['W'] = dW
            self.grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache, nl_cache = caches[0]
#         dout = l.sigmoid_backward(cache=nl_cache, dout=dy)
        dout = dy 
        dW, db = self.fc_backward(dout=dout, cache=fc_cache, W_fixed=self.W_fixed[0])
#         dy = dy @ self.W_fixed[1][layer].T # fixxed random feedback: NOT used
        self.grads[0]['W'] = dW
        self.grads[0]['b'] = db

        return dy
    
    def test(self, X):
        y_logit, _ = self.train_forward(X)
        
        # if self.mode == 'classification':
        y_prob = l.softmax(y_logit) # for accuracy== acc
        y_pred = np.argmax(y_prob, axis=1) # for loss==err
        
        return y_pred, y_logit
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            y, caches = self.train_forward(X_mini)
            loss, dy = self.loss_function(y, y_mini)
            _ = self.train_backward(dy, caches)
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in self.grads[0].keys():
                self.model[0][key] -= alpha * self.grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in self.grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * self.grads[1][layer][key]

            # Update the model for output layer
            for key in self.grads[2].keys():
                self.model[2][key] -= alpha * self.grads[2][key]
                
            # Validate the updated model
            y_pred, y_logit = self.test(X_val)
            valid_loss, _ = self.loss_function(y_logit, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val)
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_logit = nn.test(X_test)
        loss, _ = self.loss_function(y_logit, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 10000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 64 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 100 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 1 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-100 train loss: 2.3470 valid loss: 2.3853, valid accuracy: 0.0976
# Iter-200 train loss: 2.4011 valid loss: 2.3662, valid accuracy: 0.0976
# Iter-300 train loss: 2.3823 valid loss: 2.3521, valid accuracy: 0.0976
# Iter-400 train loss: 2.3217 valid loss: 2.3419, valid accuracy: 0.0976
# Iter-500 train loss: 2.3744 valid loss: 2.3339, valid accuracy: 0.0976
# Iter-600 train loss: 2.3488 valid loss: 2.3277, valid accuracy: 0.0976
# Iter-700 train loss: 2.3298 valid loss: 2.3231, valid accuracy: 0.0976
# Iter-800 train loss: 2.3278 valid loss: 2.3192, valid accuracy: 0.0976
# Iter-900 train loss: 2.2703 valid loss: 2.3159, valid accuracy: 0.0976
# Iter-1000 train loss: 2.3244 valid loss: 2.3133, valid accuracy: 0.0976
# Iter-1100 train loss: 2.2893 valid loss: 2.3112, valid accuracy: 0.0976
# Iter-1200 train loss: 2.3363 valid loss: 2.3094, valid accuracy: 0.0976
# Iter-1300 train loss: 2.3254 valid loss: 2.3077, valid accuracy: 0.0976
# Iter-1400 train loss: 2.2963 valid loss: 2.3067, valid accuracy: 0.0976
# Iter-1500 train loss: 2.3227 valid loss: 2.3055, valid accuracy: 0.0976
# Iter-1600 train loss: 2.3193 valid loss: 2.3048, valid accuracy: 0.0976
# Iter-1700 train loss: 2.2950 valid loss: 2.3041, valid accuracy: 0.0942
# Iter-1800 train loss: 2.2997 valid loss: 2.3036, valid accuracy: 0.0790
# Iter-1900 train loss: 2.3092 valid loss: 2.3030, valid accuracy: 0.0552
# Iter-2000 train loss: 2.3159 valid loss: 2.3025, valid accuracy: 0.0416
# Iter-2100 train loss: 2.2974 valid loss: 2.3023, valid accuracy: 0.0718
# Iter-2200 train loss: 2.3071 valid loss: 2.3019, valid accuracy: 0.1192
# Iter-2300 train loss: 2.2936 valid loss: 2.3015, valid accuracy: 0.1164
# Iter-2400 train loss: 2.2975 valid loss: 2.3013, valid accuracy: 0.1208
# Iter-2500 train loss: 2.3033 valid loss: 2.3009, valid accuracy: 0.1074
# Iter-2600 train loss: 2.2941 valid loss: 2.3007, valid accuracy: 0.0952
# Iter-2700 train loss: 2.3059 valid loss: 2.3006, valid accuracy: 0.0996
# Iter-2800 train loss: 2.3096 valid loss: 2.3005, valid accuracy: 0.1060
# Iter-2900 train loss: 2.3062 valid loss: 2.3002, valid accuracy: 0.1004
# Iter-3000 train loss: 2.2982 valid loss: 2.2999, valid accuracy: 0.1098
# Iter-3100 train loss: 2.3021 valid loss: 2.2997, valid accuracy: 0.1186
# Iter-3200 train loss: 2.3036 valid loss: 2.2995, valid accuracy: 0.1108
# Iter-3300 train loss: 2.3071 valid loss: 2.2994, valid accuracy: 0.1268
# Iter-3400 train loss: 2.3045 valid loss: 2.2992, valid accuracy: 0.1270
# Iter-3500 train loss: 2.2978 valid loss: 2.2990, valid accuracy: 0.1246
# Iter-3600 train loss: 2.2956 valid loss: 2.2989, valid accuracy: 0.1282
# Iter-3700 train loss: 2.2957 valid loss: 2.2986, valid accuracy: 0.1292
# Iter-3800 train loss: 2.2865 valid loss: 2.2985, valid accuracy: 0.1290
# Iter-3900 train loss: 2.3077 valid loss: 2.2982, valid accuracy: 0.1300
# Iter-4000 train loss: 2.2901 valid loss: 2.2980, valid accuracy: 0.1338
# Iter-4100 train loss: 2.3098 valid loss: 2.2978, valid accuracy: 0.1338
# Iter-4200 train loss: 2.3117 valid loss: 2.2974, valid accuracy: 0.1368
# Iter-4300 train loss: 2.2903 valid loss: 2.2972, valid accuracy: 0.1400
# Iter-4400 train loss: 2.2994 valid loss: 2.2969, valid accuracy: 0.1446
# Iter-4500 train loss: 2.2774 valid loss: 2.2965, valid accuracy: 0.1448
# Iter-4600 train loss: 2.2870 valid loss: 2.2963, valid accuracy: 0.1462
# Iter-4700 train loss: 2.2756 valid loss: 2.2959, valid accuracy: 0.1530
# Iter-4800 train loss: 2.3088 valid loss: 2.2957, valid accuracy: 0.1546
# Iter-4900 train loss: 2.3002 valid loss: 2.2953, valid accuracy: 0.1502
# Iter-5000 train loss: 2.2989 valid loss: 2.2949, valid accuracy: 0.1588
# Iter-5100 train loss: 2.2952 valid loss: 2.2946, valid accuracy: 0.1674
# Iter-5200 train loss: 2.2850 valid loss: 2.2943, valid accuracy: 0.1786
# Iter-5300 train loss: 2.2768 valid loss: 2.2937, valid accuracy: 0.1794
# Iter-5400 train loss: 2.2888 valid loss: 2.2933, valid accuracy: 0.1790
# Iter-5500 train loss: 2.2986 valid loss: 2.2928, valid accuracy: 0.1790
# Iter-5600 train loss: 2.2781 valid loss: 2.2923, valid accuracy: 0.1714
# Iter-5700 train loss: 2.2859 valid loss: 2.2919, valid accuracy: 0.1696
# Iter-5800 train loss: 2.2818 valid loss: 2.2913, valid accuracy: 0.1746
# Iter-5900 train loss: 2.2882 valid loss: 2.2909, valid accuracy: 0.1762
# Iter-6000 train loss: 2.2887 valid loss: 2.2904, valid accuracy: 0.1802
# Iter-6100 train loss: 2.2665 valid loss: 2.2899, valid accuracy: 0.1840
# Iter-6200 train loss: 2.2840 valid loss: 2.2893, valid accuracy: 0.1880
# Iter-6300 train loss: 2.2999 valid loss: 2.2887, valid accuracy: 0.1910
# Iter-6400 train loss: 2.2878 valid loss: 2.2880, valid accuracy: 0.1932
# Iter-6500 train loss: 2.2686 valid loss: 2.2873, valid accuracy: 0.1936
# Iter-6600 train loss: 2.2794 valid loss: 2.2867, valid accuracy: 0.1948
# Iter-6700 train loss: 2.2898 valid loss: 2.2859, valid accuracy: 0.1960
# Iter-6800 train loss: 2.2894 valid loss: 2.2852, valid accuracy: 0.1974
# Iter-6900 train loss: 2.2750 valid loss: 2.2844, valid accuracy: 0.2000
# Iter-7000 train loss: 2.2840 valid loss: 2.2836, valid accuracy: 0.2048
# Iter-7100 train loss: 2.2978 valid loss: 2.2828, valid accuracy: 0.2082
# Iter-7200 train loss: 2.2813 valid loss: 2.2821, valid accuracy: 0.2078
# Iter-7300 train loss: 2.2807 valid loss: 2.2811, valid accuracy: 0.2106
# Iter-7400 train loss: 2.2742 valid loss: 2.2802, valid accuracy: 0.2088
# Iter-7500 train loss: 2.2958 valid loss: 2.2792, valid accuracy: 0.2126
# Iter-7600 train loss: 2.2893 valid loss: 2.2783, valid accuracy: 0.2136
# Iter-7700 train loss: 2.2809 valid loss: 2.2773, valid accuracy: 0.2148
# Iter-7800 train loss: 2.2843 valid loss: 2.2763, valid accuracy: 0.2194
# Iter-7900 train loss: 2.2926 valid loss: 2.2753, valid accuracy: 0.2220
# Iter-8000 train loss: 2.2875 valid loss: 2.2742, valid accuracy: 0.2236
# Iter-8100 train loss: 2.2586 valid loss: 2.2731, valid accuracy: 0.2256
# Iter-8200 train loss: 2.2670 valid loss: 2.2719, valid accuracy: 0.2274
# Iter-8300 train loss: 2.2490 valid loss: 2.2706, valid accuracy: 0.2302
# Iter-8400 train loss: 2.2853 valid loss: 2.2693, valid accuracy: 0.2362
# Iter-8500 train loss: 2.2565 valid loss: 2.2680, valid accuracy: 0.2408
# Iter-8600 train loss: 2.2638 valid loss: 2.2667, valid accuracy: 0.2402
# Iter-8700 train loss: 2.2675 valid loss: 2.2652, valid accuracy: 0.2378
# Iter-8800 train loss: 2.2408 valid loss: 2.2636, valid accuracy: 0.2374
# Iter-8900 train loss: 2.2504 valid loss: 2.2620, valid accuracy: 0.2398
# Iter-9000 train loss: 2.2583 valid loss: 2.2605, valid accuracy: 0.2398
# Iter-9100 train loss: 2.2657 valid loss: 2.2590, valid accuracy: 0.2416
# Iter-9200 train loss: 2.2645 valid loss: 2.2572, valid accuracy: 0.2400
# Iter-9300 train loss: 2.2481 valid loss: 2.2555, valid accuracy: 0.2424
# Iter-9400 train loss: 2.2497 valid loss: 2.2537, valid accuracy: 0.2420
# Iter-9500 train loss: 2.2613 valid loss: 2.2520, valid accuracy: 0.2462
# Iter-9600 train loss: 2.2645 valid loss: 2.2502, valid accuracy: 0.2492
# Iter-9700 train loss: 2.2489 valid loss: 2.2484, valid accuracy: 0.2500
# Iter-9800 train loss: 2.2276 valid loss: 2.2465, valid accuracy: 0.2490
# Iter-9900 train loss: 2.2274 valid loss: 2.2445, valid accuracy: 0.2498
# Iter-10000 train loss: 2.2335 valid loss: 2.2424, valid accuracy: 0.2494
# Last iteration - Test accuracy mean: 0.2652, std: 0.0000, loss: 2.2389

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
# plt.plot(nn.losses['smooth train'], label='Train smooth loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
