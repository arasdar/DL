# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# y_test.shape, y_val.shape, y_train.shape
# X_train.shape, X_train.dtype, X_val.shape, X_val.dtype, X_test.shape, X_test.dtype
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # number of layers or depth
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        # The adaptive/learnable/updatable random feedforward
        self.model = []
        self.W_fixed = []
        self.grads = []
        self.ys_prev = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})
        # Previous output layer
        self.ys_prev.append(0.0)

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad_L = []
        for _ in range(L):
            grad_L.append({key: np.zeros_like(val) for key, val in self.model[1][0].items()})
        self.grads.append(grad_L)
        # Previous output layer
        ys_prev_L = []
        for _ in range(L):
            ys_prev_L.append(0.0)
        self.ys_prev.append(ys_prev_L)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Outout layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        # Previous output layer
        self.ys_prev.append(0.0)
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
        dX = dout @ W.T # Backprop
#         dX = dout @ W_fixed.T # fb alignment

        return dX, dW, db

    def train_forward(self, X, train):
        caches, ys = [], []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
        y, nl_cache = l.tanh_forward(X=y)
        if train:
            caches.append((fc_cache, nl_cache))
        ys.append(y) # ys[0]
        X = y.copy() # pass to the next layer
        
        # Hidden layers
        fc_caches, nl_caches, ys_L = [], [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
            y, nl_cache = l.tanh_forward(X=y)
            ys_L.append(y) # ys[1][layer]
            X = y.copy() # pass to next layer
            if train:
                fc_caches.append(fc_cache)
                nl_caches.append(nl_cache)
        if train:
            caches.append((fc_caches, nl_caches)) # caches[1]            
        ys.append(ys_L) # ys[1]            
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[2]

        return ys, caches # for backpropating the error

    def loss_function(self, y, y_train):
        
        loss = cross_entropy(y, y_train) # softmax is included
        dy = dcross_entropy(y, y_train) # dsoftmax is included
        
        return loss, dy
        
    def train_backward(self, dy, caches, ys):
        grads, ys_prev = self.grads, self.ys_prev # initialized by Zero in every iteration/epoch
        
        # Output layer
        fc_cache = caches[2]
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
        grads[2]['W'] = dW
        grads[2]['b'] = db

        # Hidden layer
        fc_caches, nl_caches = caches[1]
        for layer in reversed(range(self.L)):
#             dy *= ys[1][layer] - ys_prev[1][layer] # temporal diff instead of differentiable function
            dy = l.tanh_backward(cache=nl_caches[layer], dout=dy) # diffable function
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
            grads[1][layer]['W'] = dW
            grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache, nl_cache = caches[0]
#         dy *= ys[0] - ys_prev[0] # temporal diff instead of differentiable function
        dy = l.tanh_backward(cache=nl_cache, dout=dy) # diffable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        grads[0]['W'] = dW
        grads[0]['b'] = db

        return dX, grads
    
    def test(self, X):
        ys_logit, _ = self.train_forward(X, train=False)
        y_logit = ys_logit[2] # last layer
        
        # if self.mode == 'classification':
        y_prob = l.softmax(y_logit) # for accuracy == acc
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_logit
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            ys, caches = self.train_forward(X_mini, train=True)
            loss, dy = self.loss_function(ys[2], y_mini)
            _, grads = self.train_backward(dy, caches, ys) # ys[0], ys[1] and ys_prev are used for backprop
            self.ys_prev = ys # for next iteration or epoch learning dW and db
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in grads[0].keys():
                self.model[0][key] -= alpha * grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * grads[1][layer][key]

            # Update the model for output layer
            for key in grads[2].keys():
                self.model[2][key] -= alpha * grads[2][key]
                
            # Validate the updated model
            y_pred, y_logit = self.test(X_val)
            valid_loss, _ = self.loss_function(y_logit, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val) # confusion matrix
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_logit = nn.test(X_test)
        loss, _ = self.loss_function(y_logit, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 1000000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 50 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 100 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 2 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-100 train loss: 2.2804 valid loss: 2.2786, valid accuracy: 0.1362
# Iter-200 train loss: 2.2655 valid loss: 2.2519, valid accuracy: 0.2030
# Iter-300 train loss: 2.2429 valid loss: 2.2265, valid accuracy: 0.2796
# Iter-400 train loss: 2.2063 valid loss: 2.2012, valid accuracy: 0.3504
# Iter-500 train loss: 2.1563 valid loss: 2.1764, valid accuracy: 0.4120
# Iter-600 train loss: 2.1500 valid loss: 2.1511, valid accuracy: 0.4618
# Iter-700 train loss: 2.1393 valid loss: 2.1257, valid accuracy: 0.4950
# Iter-800 train loss: 2.0970 valid loss: 2.1006, valid accuracy: 0.5164
# Iter-900 train loss: 2.1108 valid loss: 2.0751, valid accuracy: 0.5380
# Iter-1000 train loss: 2.0310 valid loss: 2.0497, valid accuracy: 0.5554
# Iter-1100 train loss: 1.9877 valid loss: 2.0241, valid accuracy: 0.5708
# Iter-1200 train loss: 2.0185 valid loss: 1.9984, valid accuracy: 0.5800
# Iter-1300 train loss: 1.9692 valid loss: 1.9716, valid accuracy: 0.5858
# Iter-1400 train loss: 1.9401 valid loss: 1.9451, valid accuracy: 0.5938
# Iter-1500 train loss: 1.8805 valid loss: 1.9185, valid accuracy: 0.6012
# Iter-1600 train loss: 1.8804 valid loss: 1.8918, valid accuracy: 0.6020
# Iter-1700 train loss: 1.8488 valid loss: 1.8649, valid accuracy: 0.6058
# Iter-1800 train loss: 1.9411 valid loss: 1.8379, valid accuracy: 0.6094
# Iter-1900 train loss: 1.8130 valid loss: 1.8114, valid accuracy: 0.6138
# Iter-2000 train loss: 1.7906 valid loss: 1.7846, valid accuracy: 0.6162
# Iter-2100 train loss: 1.8048 valid loss: 1.7576, valid accuracy: 0.6178
# Iter-2200 train loss: 1.7693 valid loss: 1.7313, valid accuracy: 0.6218
# Iter-2300 train loss: 1.6894 valid loss: 1.7051, valid accuracy: 0.6250
# Iter-2400 train loss: 1.7366 valid loss: 1.6790, valid accuracy: 0.6302
# Iter-2500 train loss: 1.7015 valid loss: 1.6533, valid accuracy: 0.6344
# Iter-2600 train loss: 1.6869 valid loss: 1.6285, valid accuracy: 0.6390
# Iter-2700 train loss: 1.6628 valid loss: 1.6038, valid accuracy: 0.6430
# Iter-2800 train loss: 1.6967 valid loss: 1.5792, valid accuracy: 0.6476
# Iter-2900 train loss: 1.5708 valid loss: 1.5552, valid accuracy: 0.6496
# Iter-3000 train loss: 1.4758 valid loss: 1.5315, valid accuracy: 0.6544
# Iter-3100 train loss: 1.4777 valid loss: 1.5086, valid accuracy: 0.6592
# Iter-3200 train loss: 1.4561 valid loss: 1.4861, valid accuracy: 0.6658
# Iter-3300 train loss: 1.4679 valid loss: 1.4635, valid accuracy: 0.6696
# Iter-3400 train loss: 1.4569 valid loss: 1.4421, valid accuracy: 0.6758
# Iter-3500 train loss: 1.3830 valid loss: 1.4211, valid accuracy: 0.6802
# Iter-3600 train loss: 1.4805 valid loss: 1.4003, valid accuracy: 0.6848
# Iter-3700 train loss: 1.3509 valid loss: 1.3801, valid accuracy: 0.6900
# Iter-3800 train loss: 1.3727 valid loss: 1.3605, valid accuracy: 0.6946
# Iter-3900 train loss: 1.3558 valid loss: 1.3412, valid accuracy: 0.6982
# Iter-4000 train loss: 1.2600 valid loss: 1.3222, valid accuracy: 0.7010
# Iter-4100 train loss: 1.3056 valid loss: 1.3036, valid accuracy: 0.7048
# Iter-4200 train loss: 1.3606 valid loss: 1.2855, valid accuracy: 0.7106
# Iter-4300 train loss: 1.1629 valid loss: 1.2676, valid accuracy: 0.7132
# Iter-4400 train loss: 1.2688 valid loss: 1.2503, valid accuracy: 0.7174
# Iter-4500 train loss: 1.3177 valid loss: 1.2332, valid accuracy: 0.7198
# Iter-4600 train loss: 1.2872 valid loss: 1.2163, valid accuracy: 0.7252
# Iter-4700 train loss: 1.1847 valid loss: 1.2002, valid accuracy: 0.7288
# Iter-4800 train loss: 1.1441 valid loss: 1.1843, valid accuracy: 0.7326
# Iter-4900 train loss: 1.1207 valid loss: 1.1688, valid accuracy: 0.7356
# Iter-5000 train loss: 1.0934 valid loss: 1.1535, valid accuracy: 0.7394
# Iter-5100 train loss: 1.1665 valid loss: 1.1385, valid accuracy: 0.7422
# Iter-5200 train loss: 1.0719 valid loss: 1.1240, valid accuracy: 0.7462
# Iter-5300 train loss: 1.0732 valid loss: 1.1097, valid accuracy: 0.7506
# Iter-5400 train loss: 1.1508 valid loss: 1.0957, valid accuracy: 0.7546
# Iter-5500 train loss: 1.1587 valid loss: 1.0820, valid accuracy: 0.7580
# Iter-5600 train loss: 1.0867 valid loss: 1.0684, valid accuracy: 0.7608
# Iter-5700 train loss: 1.1859 valid loss: 1.0553, valid accuracy: 0.7632
# Iter-5800 train loss: 0.9849 valid loss: 1.0423, valid accuracy: 0.7668
# Iter-5900 train loss: 1.0573 valid loss: 1.0298, valid accuracy: 0.7702
# Iter-6000 train loss: 0.9276 valid loss: 1.0174, valid accuracy: 0.7738
# Iter-6100 train loss: 1.0007 valid loss: 1.0053, valid accuracy: 0.7768
# Iter-6200 train loss: 1.0035 valid loss: 0.9936, valid accuracy: 0.7786
# Iter-6300 train loss: 0.9923 valid loss: 0.9820, valid accuracy: 0.7808
# Iter-6400 train loss: 0.9766 valid loss: 0.9706, valid accuracy: 0.7844
# Iter-6500 train loss: 0.9714 valid loss: 0.9596, valid accuracy: 0.7868
# Iter-6600 train loss: 0.8422 valid loss: 0.9488, valid accuracy: 0.7902
# Iter-6700 train loss: 0.9858 valid loss: 0.9382, valid accuracy: 0.7932
# Iter-6800 train loss: 0.9919 valid loss: 0.9280, valid accuracy: 0.7958
# Iter-6900 train loss: 0.9652 valid loss: 0.9178, valid accuracy: 0.7992
# Iter-7000 train loss: 0.9883 valid loss: 0.9078, valid accuracy: 0.8032
# Iter-7100 train loss: 1.0061 valid loss: 0.8979, valid accuracy: 0.8060
# Iter-7200 train loss: 0.9264 valid loss: 0.8885, valid accuracy: 0.8086
# Iter-7300 train loss: 0.9309 valid loss: 0.8789, valid accuracy: 0.8110
# Iter-7400 train loss: 0.9085 valid loss: 0.8698, valid accuracy: 0.8138
# Iter-7500 train loss: 1.0017 valid loss: 0.8608, valid accuracy: 0.8156
# Iter-7600 train loss: 0.7373 valid loss: 0.8518, valid accuracy: 0.8176
# Iter-7700 train loss: 0.8496 valid loss: 0.8433, valid accuracy: 0.8194
# Iter-7800 train loss: 0.8015 valid loss: 0.8347, valid accuracy: 0.8220
# Iter-7900 train loss: 0.7777 valid loss: 0.8264, valid accuracy: 0.8230
# Iter-8000 train loss: 0.9239 valid loss: 0.8182, valid accuracy: 0.8266
# Iter-8100 train loss: 0.8411 valid loss: 0.8102, valid accuracy: 0.8284
# Iter-8200 train loss: 0.8935 valid loss: 0.8025, valid accuracy: 0.8312
# Iter-8300 train loss: 0.8198 valid loss: 0.7948, valid accuracy: 0.8326
# Iter-8400 train loss: 0.9150 valid loss: 0.7871, valid accuracy: 0.8344
# Iter-8500 train loss: 0.9558 valid loss: 0.7798, valid accuracy: 0.8372
# Iter-8600 train loss: 0.7188 valid loss: 0.7728, valid accuracy: 0.8372
# Iter-8700 train loss: 0.6267 valid loss: 0.7656, valid accuracy: 0.8392
# Iter-8800 train loss: 0.8826 valid loss: 0.7585, valid accuracy: 0.8418
# Iter-8900 train loss: 0.7062 valid loss: 0.7519, valid accuracy: 0.8422
# Iter-9000 train loss: 0.8773 valid loss: 0.7454, valid accuracy: 0.8428
# Iter-9100 train loss: 0.8520 valid loss: 0.7390, valid accuracy: 0.8446
# Iter-9200 train loss: 0.6714 valid loss: 0.7325, valid accuracy: 0.8452
# Iter-9300 train loss: 0.5944 valid loss: 0.7263, valid accuracy: 0.8472
# Iter-9400 train loss: 0.6822 valid loss: 0.7203, valid accuracy: 0.8482
# Iter-9500 train loss: 0.6801 valid loss: 0.7142, valid accuracy: 0.8500
# Iter-9600 train loss: 0.6067 valid loss: 0.7083, valid accuracy: 0.8514
# Iter-9700 train loss: 0.6673 valid loss: 0.7026, valid accuracy: 0.8528
# Iter-9800 train loss: 0.8289 valid loss: 0.6970, valid accuracy: 0.8528
# Iter-9900 train loss: 0.5317 valid loss: 0.6917, valid accuracy: 0.8530
# Iter-10000 train loss: 0.6044 valid loss: 0.6863, valid accuracy: 0.8534
# Iter-10100 train loss: 0.6560 valid loss: 0.6810, valid accuracy: 0.8538
# Iter-10200 train loss: 0.7279 valid loss: 0.6758, valid accuracy: 0.8552
# Iter-10300 train loss: 0.7822 valid loss: 0.6706, valid accuracy: 0.8564
# Iter-10400 train loss: 0.7491 valid loss: 0.6657, valid accuracy: 0.8572
# Iter-10500 train loss: 0.7187 valid loss: 0.6609, valid accuracy: 0.8572
# Iter-10600 train loss: 0.6149 valid loss: 0.6561, valid accuracy: 0.8594
# Iter-10700 train loss: 0.6780 valid loss: 0.6514, valid accuracy: 0.8602
# Iter-10800 train loss: 0.7636 valid loss: 0.6469, valid accuracy: 0.8604
# Iter-10900 train loss: 0.6632 valid loss: 0.6425, valid accuracy: 0.8606
# Iter-11000 train loss: 0.5968 valid loss: 0.6381, valid accuracy: 0.8612
# Iter-11100 train loss: 0.7713 valid loss: 0.6337, valid accuracy: 0.8628
# Iter-11200 train loss: 0.5679 valid loss: 0.6292, valid accuracy: 0.8632
# Iter-11300 train loss: 0.7023 valid loss: 0.6249, valid accuracy: 0.8646
# Iter-11400 train loss: 0.8263 valid loss: 0.6208, valid accuracy: 0.8664
# Iter-11500 train loss: 0.6516 valid loss: 0.6166, valid accuracy: 0.8666
# Iter-11600 train loss: 0.4534 valid loss: 0.6127, valid accuracy: 0.8680
# Iter-11700 train loss: 0.5392 valid loss: 0.6086, valid accuracy: 0.8688
# Iter-11800 train loss: 0.5684 valid loss: 0.6048, valid accuracy: 0.8688
# Iter-11900 train loss: 0.8121 valid loss: 0.6010, valid accuracy: 0.8696
# Iter-12000 train loss: 0.4991 valid loss: 0.5974, valid accuracy: 0.8704
# Iter-12100 train loss: 0.7544 valid loss: 0.5937, valid accuracy: 0.8716
# Iter-12200 train loss: 0.4547 valid loss: 0.5900, valid accuracy: 0.8722
# Iter-12300 train loss: 0.6180 valid loss: 0.5865, valid accuracy: 0.8728
# Iter-12400 train loss: 0.6942 valid loss: 0.5829, valid accuracy: 0.8734
# Iter-12500 train loss: 0.6241 valid loss: 0.5795, valid accuracy: 0.8734
# Iter-12600 train loss: 0.5048 valid loss: 0.5763, valid accuracy: 0.8738
# Iter-12700 train loss: 0.5702 valid loss: 0.5731, valid accuracy: 0.8750
# Iter-12800 train loss: 0.6497 valid loss: 0.5700, valid accuracy: 0.8744
# Iter-12900 train loss: 0.5878 valid loss: 0.5669, valid accuracy: 0.8754
# Iter-13000 train loss: 0.4428 valid loss: 0.5638, valid accuracy: 0.8760
# Iter-13100 train loss: 0.3922 valid loss: 0.5607, valid accuracy: 0.8770
# Iter-13200 train loss: 0.4463 valid loss: 0.5576, valid accuracy: 0.8766
# Iter-13300 train loss: 0.4537 valid loss: 0.5546, valid accuracy: 0.8770
# Iter-13400 train loss: 0.5816 valid loss: 0.5515, valid accuracy: 0.8766
# Iter-13500 train loss: 0.5141 valid loss: 0.5486, valid accuracy: 0.8768
# Iter-13600 train loss: 0.5395 valid loss: 0.5459, valid accuracy: 0.8780
# Iter-13700 train loss: 0.4628 valid loss: 0.5431, valid accuracy: 0.8778
# Iter-13800 train loss: 0.6367 valid loss: 0.5403, valid accuracy: 0.8782
# Iter-13900 train loss: 0.5848 valid loss: 0.5376, valid accuracy: 0.8800
# Iter-14000 train loss: 0.6964 valid loss: 0.5350, valid accuracy: 0.8798
# Iter-14100 train loss: 0.7711 valid loss: 0.5325, valid accuracy: 0.8812
# Iter-14200 train loss: 0.7393 valid loss: 0.5298, valid accuracy: 0.8812
# Iter-14300 train loss: 0.5262 valid loss: 0.5272, valid accuracy: 0.8812
# Iter-14400 train loss: 0.6140 valid loss: 0.5246, valid accuracy: 0.8810
# Iter-14500 train loss: 0.7740 valid loss: 0.5222, valid accuracy: 0.8810
# Iter-14600 train loss: 0.5418 valid loss: 0.5197, valid accuracy: 0.8816
# Iter-14700 train loss: 0.3653 valid loss: 0.5174, valid accuracy: 0.8820
# Iter-14800 train loss: 0.4969 valid loss: 0.5149, valid accuracy: 0.8826
# Iter-14900 train loss: 0.4193 valid loss: 0.5128, valid accuracy: 0.8826
# Iter-15000 train loss: 0.6524 valid loss: 0.5106, valid accuracy: 0.8828
# Iter-15100 train loss: 0.4628 valid loss: 0.5085, valid accuracy: 0.8836
# Iter-15200 train loss: 0.7028 valid loss: 0.5061, valid accuracy: 0.8838
# Iter-15300 train loss: 0.5901 valid loss: 0.5037, valid accuracy: 0.8838
# Iter-15400 train loss: 0.5624 valid loss: 0.5015, valid accuracy: 0.8836
# Iter-15500 train loss: 0.5406 valid loss: 0.4992, valid accuracy: 0.8838
# Iter-15600 train loss: 0.6146 valid loss: 0.4970, valid accuracy: 0.8846
# Iter-15700 train loss: 0.4934 valid loss: 0.4949, valid accuracy: 0.8848
# Iter-15800 train loss: 0.4498 valid loss: 0.4930, valid accuracy: 0.8850
# Iter-15900 train loss: 0.5507 valid loss: 0.4909, valid accuracy: 0.8850
# Iter-16000 train loss: 0.4425 valid loss: 0.4889, valid accuracy: 0.8856
# Iter-16100 train loss: 0.4359 valid loss: 0.4869, valid accuracy: 0.8860
# Iter-16200 train loss: 0.4685 valid loss: 0.4849, valid accuracy: 0.8862
# Iter-16300 train loss: 0.4564 valid loss: 0.4830, valid accuracy: 0.8864
# Iter-16400 train loss: 0.5229 valid loss: 0.4810, valid accuracy: 0.8856
# Iter-16500 train loss: 0.3708 valid loss: 0.4790, valid accuracy: 0.8866
# Iter-16600 train loss: 0.5885 valid loss: 0.4771, valid accuracy: 0.8868
# Iter-16700 train loss: 0.4545 valid loss: 0.4753, valid accuracy: 0.8868
# Iter-16800 train loss: 0.4452 valid loss: 0.4735, valid accuracy: 0.8872
# Iter-16900 train loss: 0.4942 valid loss: 0.4717, valid accuracy: 0.8878
# Iter-17000 train loss: 0.6165 valid loss: 0.4700, valid accuracy: 0.8876
# Iter-17100 train loss: 0.3987 valid loss: 0.4683, valid accuracy: 0.8880
# Iter-17200 train loss: 0.5910 valid loss: 0.4665, valid accuracy: 0.8880
# Iter-17300 train loss: 0.4764 valid loss: 0.4648, valid accuracy: 0.8880
# Iter-17400 train loss: 0.3554 valid loss: 0.4632, valid accuracy: 0.8884
# Iter-17500 train loss: 0.6987 valid loss: 0.4617, valid accuracy: 0.8894
# Iter-17600 train loss: 0.6399 valid loss: 0.4598, valid accuracy: 0.8894
# Iter-17700 train loss: 0.3720 valid loss: 0.4581, valid accuracy: 0.8898
# Iter-17800 train loss: 0.4328 valid loss: 0.4563, valid accuracy: 0.8902
# Iter-17900 train loss: 0.5108 valid loss: 0.4548, valid accuracy: 0.8908
# Iter-18000 train loss: 0.5767 valid loss: 0.4532, valid accuracy: 0.8912
# Iter-18100 train loss: 0.3022 valid loss: 0.4518, valid accuracy: 0.8914
# Iter-18200 train loss: 0.5200 valid loss: 0.4501, valid accuracy: 0.8914
# Iter-18300 train loss: 0.3862 valid loss: 0.4485, valid accuracy: 0.8920
# Iter-18400 train loss: 0.5639 valid loss: 0.4469, valid accuracy: 0.8912
# Iter-18500 train loss: 0.4977 valid loss: 0.4454, valid accuracy: 0.8924
# Iter-18600 train loss: 0.5420 valid loss: 0.4440, valid accuracy: 0.8918
# Iter-18700 train loss: 0.7124 valid loss: 0.4425, valid accuracy: 0.8918
# Iter-18800 train loss: 0.5627 valid loss: 0.4412, valid accuracy: 0.8918
# Iter-18900 train loss: 0.4384 valid loss: 0.4398, valid accuracy: 0.8932
# Iter-19000 train loss: 0.4971 valid loss: 0.4383, valid accuracy: 0.8934
# Iter-19100 train loss: 0.3618 valid loss: 0.4371, valid accuracy: 0.8942
# Iter-19200 train loss: 0.6244 valid loss: 0.4356, valid accuracy: 0.8942
# Iter-19300 train loss: 0.3187 valid loss: 0.4343, valid accuracy: 0.8948
# Iter-19400 train loss: 0.3917 valid loss: 0.4330, valid accuracy: 0.8946
# Iter-19500 train loss: 0.4010 valid loss: 0.4316, valid accuracy: 0.8956
# Iter-19600 train loss: 0.4304 valid loss: 0.4304, valid accuracy: 0.8964
# Iter-19700 train loss: 0.4504 valid loss: 0.4291, valid accuracy: 0.8964
# Iter-19800 train loss: 0.6391 valid loss: 0.4278, valid accuracy: 0.8968
# Iter-19900 train loss: 0.4624 valid loss: 0.4265, valid accuracy: 0.8970
# Iter-20000 train loss: 0.4907 valid loss: 0.4252, valid accuracy: 0.8974
# Iter-20100 train loss: 0.5054 valid loss: 0.4240, valid accuracy: 0.8972
# Iter-20200 train loss: 0.5800 valid loss: 0.4228, valid accuracy: 0.8970
# Iter-20300 train loss: 0.3756 valid loss: 0.4217, valid accuracy: 0.8976
# Iter-20400 train loss: 0.4446 valid loss: 0.4206, valid accuracy: 0.8976
# Iter-20500 train loss: 0.4073 valid loss: 0.4194, valid accuracy: 0.8980
# Iter-20600 train loss: 0.3922 valid loss: 0.4181, valid accuracy: 0.8982
# Iter-20700 train loss: 0.4325 valid loss: 0.4170, valid accuracy: 0.8986
# Iter-20800 train loss: 0.4089 valid loss: 0.4159, valid accuracy: 0.8990
# Iter-20900 train loss: 0.3849 valid loss: 0.4147, valid accuracy: 0.8990
# Iter-21000 train loss: 0.4879 valid loss: 0.4137, valid accuracy: 0.8998
# Iter-21100 train loss: 0.4738 valid loss: 0.4126, valid accuracy: 0.8998
# Iter-21200 train loss: 0.5066 valid loss: 0.4116, valid accuracy: 0.9000
# Iter-21300 train loss: 0.4696 valid loss: 0.4104, valid accuracy: 0.9002
# Iter-21400 train loss: 0.2646 valid loss: 0.4094, valid accuracy: 0.9000
# Iter-21500 train loss: 0.3961 valid loss: 0.4083, valid accuracy: 0.9006
# Iter-21600 train loss: 0.6287 valid loss: 0.4074, valid accuracy: 0.9004
# Iter-21700 train loss: 0.5248 valid loss: 0.4064, valid accuracy: 0.9004
# Iter-21800 train loss: 0.5746 valid loss: 0.4052, valid accuracy: 0.9010
# Iter-21900 train loss: 0.3468 valid loss: 0.4041, valid accuracy: 0.9010
# Iter-22000 train loss: 0.2886 valid loss: 0.4031, valid accuracy: 0.9012
# Iter-22100 train loss: 0.3553 valid loss: 0.4021, valid accuracy: 0.9014
# Iter-22200 train loss: 0.3847 valid loss: 0.4009, valid accuracy: 0.9016
# Iter-22300 train loss: 0.4176 valid loss: 0.3998, valid accuracy: 0.9016
# Iter-22400 train loss: 0.3225 valid loss: 0.3990, valid accuracy: 0.9020
# Iter-22500 train loss: 0.3095 valid loss: 0.3982, valid accuracy: 0.9018
# Iter-22600 train loss: 0.5191 valid loss: 0.3972, valid accuracy: 0.9020
# Iter-22700 train loss: 0.4023 valid loss: 0.3962, valid accuracy: 0.9020
# Iter-22800 train loss: 0.3992 valid loss: 0.3953, valid accuracy: 0.9024
# Iter-22900 train loss: 0.4634 valid loss: 0.3944, valid accuracy: 0.9024
# Iter-23000 train loss: 0.2536 valid loss: 0.3933, valid accuracy: 0.9028
# Iter-23100 train loss: 0.5096 valid loss: 0.3924, valid accuracy: 0.9030
# Iter-23200 train loss: 0.3212 valid loss: 0.3914, valid accuracy: 0.9034
# Iter-23300 train loss: 0.4637 valid loss: 0.3905, valid accuracy: 0.9034
# Iter-23400 train loss: 0.4691 valid loss: 0.3896, valid accuracy: 0.9036
# Iter-23500 train loss: 0.3599 valid loss: 0.3887, valid accuracy: 0.9038
# Iter-23600 train loss: 0.4547 valid loss: 0.3880, valid accuracy: 0.9040
# Iter-23700 train loss: 0.4513 valid loss: 0.3871, valid accuracy: 0.9040
# Iter-23800 train loss: 0.4671 valid loss: 0.3862, valid accuracy: 0.9042
# Iter-23900 train loss: 0.6746 valid loss: 0.3853, valid accuracy: 0.9042
# Iter-24000 train loss: 0.4748 valid loss: 0.3845, valid accuracy: 0.9042
# Iter-24100 train loss: 0.2986 valid loss: 0.3836, valid accuracy: 0.9042
# Iter-24200 train loss: 0.4089 valid loss: 0.3829, valid accuracy: 0.9042
# Iter-24300 train loss: 0.3541 valid loss: 0.3821, valid accuracy: 0.9038
# Iter-24400 train loss: 0.3288 valid loss: 0.3812, valid accuracy: 0.9040
# Iter-24500 train loss: 0.3855 valid loss: 0.3805, valid accuracy: 0.9042
# Iter-24600 train loss: 0.2708 valid loss: 0.3798, valid accuracy: 0.9050
# Iter-24700 train loss: 0.2749 valid loss: 0.3790, valid accuracy: 0.9046
# Iter-24800 train loss: 0.3733 valid loss: 0.3782, valid accuracy: 0.9050
# Iter-24900 train loss: 0.5373 valid loss: 0.3775, valid accuracy: 0.9054
# Iter-25000 train loss: 0.2679 valid loss: 0.3767, valid accuracy: 0.9054
# Iter-25100 train loss: 0.4747 valid loss: 0.3758, valid accuracy: 0.9054
# Iter-25200 train loss: 0.5207 valid loss: 0.3749, valid accuracy: 0.9056
# Iter-25300 train loss: 0.4500 valid loss: 0.3743, valid accuracy: 0.9060
# Iter-25400 train loss: 0.3469 valid loss: 0.3734, valid accuracy: 0.9060
# Iter-25500 train loss: 0.2857 valid loss: 0.3726, valid accuracy: 0.9066
# Iter-25600 train loss: 0.2327 valid loss: 0.3718, valid accuracy: 0.9068
# Iter-25700 train loss: 0.4761 valid loss: 0.3709, valid accuracy: 0.9074
# Iter-25800 train loss: 0.2622 valid loss: 0.3702, valid accuracy: 0.9078
# Iter-25900 train loss: 0.2497 valid loss: 0.3694, valid accuracy: 0.9076
# Iter-26000 train loss: 0.2520 valid loss: 0.3688, valid accuracy: 0.9082
# Iter-26100 train loss: 0.5792 valid loss: 0.3678, valid accuracy: 0.9080
# Iter-26200 train loss: 0.4251 valid loss: 0.3672, valid accuracy: 0.9082
# Iter-26300 train loss: 0.6276 valid loss: 0.3666, valid accuracy: 0.9082
# Iter-26400 train loss: 0.4770 valid loss: 0.3661, valid accuracy: 0.9084
# Iter-26500 train loss: 0.4200 valid loss: 0.3653, valid accuracy: 0.9080
# Iter-26600 train loss: 0.3906 valid loss: 0.3646, valid accuracy: 0.9078
# Iter-26700 train loss: 0.3754 valid loss: 0.3638, valid accuracy: 0.9086
# Iter-26800 train loss: 0.4653 valid loss: 0.3630, valid accuracy: 0.9082
# Iter-26900 train loss: 0.3511 valid loss: 0.3624, valid accuracy: 0.9084
# Iter-27000 train loss: 0.3683 valid loss: 0.3618, valid accuracy: 0.9088
# Iter-27100 train loss: 0.3547 valid loss: 0.3613, valid accuracy: 0.9082
# Iter-27200 train loss: 0.3328 valid loss: 0.3606, valid accuracy: 0.9082
# Iter-27300 train loss: 0.4803 valid loss: 0.3601, valid accuracy: 0.9086
# Iter-27400 train loss: 0.4784 valid loss: 0.3595, valid accuracy: 0.9086
# Iter-27500 train loss: 0.3288 valid loss: 0.3590, valid accuracy: 0.9090
# Iter-27600 train loss: 0.3118 valid loss: 0.3584, valid accuracy: 0.9086
# Iter-27700 train loss: 0.2055 valid loss: 0.3578, valid accuracy: 0.9090
# Iter-27800 train loss: 0.4566 valid loss: 0.3572, valid accuracy: 0.9088
# Iter-27900 train loss: 0.3336 valid loss: 0.3566, valid accuracy: 0.9092
# Iter-28000 train loss: 0.4031 valid loss: 0.3560, valid accuracy: 0.9092
# Iter-28100 train loss: 0.3332 valid loss: 0.3551, valid accuracy: 0.9090
# Iter-28200 train loss: 0.5248 valid loss: 0.3547, valid accuracy: 0.9090
# Iter-28300 train loss: 0.3954 valid loss: 0.3541, valid accuracy: 0.9092
# Iter-28400 train loss: 0.4163 valid loss: 0.3535, valid accuracy: 0.9100
# Iter-28500 train loss: 0.2446 valid loss: 0.3528, valid accuracy: 0.9100
# Iter-28600 train loss: 0.2516 valid loss: 0.3523, valid accuracy: 0.9100
# Iter-28700 train loss: 0.4427 valid loss: 0.3518, valid accuracy: 0.9106
# Iter-28800 train loss: 0.3215 valid loss: 0.3513, valid accuracy: 0.9106
# Iter-28900 train loss: 0.3724 valid loss: 0.3506, valid accuracy: 0.9110
# Iter-29000 train loss: 0.2971 valid loss: 0.3501, valid accuracy: 0.9104
# Iter-29100 train loss: 0.5167 valid loss: 0.3496, valid accuracy: 0.9104
# Iter-29200 train loss: 0.3419 valid loss: 0.3489, valid accuracy: 0.9110
# Iter-29300 train loss: 0.6042 valid loss: 0.3483, valid accuracy: 0.9116
# Iter-29400 train loss: 0.3404 valid loss: 0.3477, valid accuracy: 0.9114
# Iter-29500 train loss: 0.3697 valid loss: 0.3473, valid accuracy: 0.9120
# Iter-29600 train loss: 0.1411 valid loss: 0.3466, valid accuracy: 0.9118
# Iter-29700 train loss: 0.4086 valid loss: 0.3461, valid accuracy: 0.9118
# Iter-29800 train loss: 0.3051 valid loss: 0.3455, valid accuracy: 0.9120
# Iter-29900 train loss: 0.3459 valid loss: 0.3449, valid accuracy: 0.9122
# Iter-30000 train loss: 0.2971 valid loss: 0.3441, valid accuracy: 0.9126
# Iter-30100 train loss: 0.4769 valid loss: 0.3436, valid accuracy: 0.9126
# Iter-30200 train loss: 0.3495 valid loss: 0.3433, valid accuracy: 0.9118
# Iter-30300 train loss: 0.5347 valid loss: 0.3428, valid accuracy: 0.9120
# Iter-30400 train loss: 0.5495 valid loss: 0.3423, valid accuracy: 0.9124
# Iter-30500 train loss: 0.6600 valid loss: 0.3417, valid accuracy: 0.9122
# Iter-30600 train loss: 0.4284 valid loss: 0.3412, valid accuracy: 0.9122
# Iter-30700 train loss: 0.3005 valid loss: 0.3407, valid accuracy: 0.9122
# Iter-30800 train loss: 0.5952 valid loss: 0.3401, valid accuracy: 0.9124
# Iter-30900 train loss: 0.3130 valid loss: 0.3395, valid accuracy: 0.9122
# Iter-31000 train loss: 0.1842 valid loss: 0.3389, valid accuracy: 0.9128
# Iter-31100 train loss: 0.5523 valid loss: 0.3386, valid accuracy: 0.9132
# Iter-31200 train loss: 0.3154 valid loss: 0.3382, valid accuracy: 0.9124
# Iter-31300 train loss: 0.3558 valid loss: 0.3377, valid accuracy: 0.9132
# Iter-31400 train loss: 0.3462 valid loss: 0.3371, valid accuracy: 0.9132
# Iter-31500 train loss: 0.2244 valid loss: 0.3367, valid accuracy: 0.9134
# Iter-31600 train loss: 0.4441 valid loss: 0.3364, valid accuracy: 0.9132
# Iter-31700 train loss: 0.3912 valid loss: 0.3362, valid accuracy: 0.9134
# Iter-31800 train loss: 0.4353 valid loss: 0.3358, valid accuracy: 0.9132
# Iter-31900 train loss: 0.2956 valid loss: 0.3354, valid accuracy: 0.9134
# Iter-32000 train loss: 0.3594 valid loss: 0.3349, valid accuracy: 0.9134
# Iter-32100 train loss: 0.5485 valid loss: 0.3345, valid accuracy: 0.9130
# Iter-32200 train loss: 0.4714 valid loss: 0.3339, valid accuracy: 0.9130
# Iter-32300 train loss: 0.6086 valid loss: 0.3335, valid accuracy: 0.9134
# Iter-32400 train loss: 0.2696 valid loss: 0.3329, valid accuracy: 0.9140
# Iter-32500 train loss: 0.1994 valid loss: 0.3326, valid accuracy: 0.9138
# Iter-32600 train loss: 0.2631 valid loss: 0.3320, valid accuracy: 0.9146
# Iter-32700 train loss: 0.3250 valid loss: 0.3315, valid accuracy: 0.9142
# Iter-32800 train loss: 0.5206 valid loss: 0.3311, valid accuracy: 0.9142
# Iter-32900 train loss: 0.4149 valid loss: 0.3306, valid accuracy: 0.9142
# Iter-33000 train loss: 0.2480 valid loss: 0.3302, valid accuracy: 0.9144
# Iter-33100 train loss: 0.3001 valid loss: 0.3295, valid accuracy: 0.9142
# Iter-33200 train loss: 0.2916 valid loss: 0.3292, valid accuracy: 0.9146
# Iter-33300 train loss: 0.4094 valid loss: 0.3289, valid accuracy: 0.9142
# Iter-33400 train loss: 0.4452 valid loss: 0.3286, valid accuracy: 0.9148
# Iter-33500 train loss: 0.3878 valid loss: 0.3281, valid accuracy: 0.9146
# Iter-33600 train loss: 0.4197 valid loss: 0.3277, valid accuracy: 0.9142
# Iter-33700 train loss: 0.3887 valid loss: 0.3275, valid accuracy: 0.9144
# Iter-33800 train loss: 0.4475 valid loss: 0.3270, valid accuracy: 0.9150
# Iter-33900 train loss: 0.3681 valid loss: 0.3267, valid accuracy: 0.9148
# Iter-34000 train loss: 0.3276 valid loss: 0.3263, valid accuracy: 0.9144
# Iter-34100 train loss: 0.3561 valid loss: 0.3258, valid accuracy: 0.9150
# Iter-34200 train loss: 0.4760 valid loss: 0.3254, valid accuracy: 0.9144
# Iter-34300 train loss: 0.3188 valid loss: 0.3251, valid accuracy: 0.9150
# Iter-34400 train loss: 0.3531 valid loss: 0.3246, valid accuracy: 0.9150
# Iter-34500 train loss: 0.2715 valid loss: 0.3243, valid accuracy: 0.9150
# Iter-34600 train loss: 0.2516 valid loss: 0.3238, valid accuracy: 0.9144
# Iter-34700 train loss: 0.4583 valid loss: 0.3232, valid accuracy: 0.9150
# Iter-34800 train loss: 0.4675 valid loss: 0.3228, valid accuracy: 0.9150
# Iter-34900 train loss: 0.4368 valid loss: 0.3223, valid accuracy: 0.9150
# Iter-35000 train loss: 0.1867 valid loss: 0.3219, valid accuracy: 0.9150
# Iter-35100 train loss: 0.6904 valid loss: 0.3213, valid accuracy: 0.9152
# Iter-35200 train loss: 0.2592 valid loss: 0.3210, valid accuracy: 0.9150
# Iter-35300 train loss: 0.2343 valid loss: 0.3206, valid accuracy: 0.9148
# Iter-35400 train loss: 0.2170 valid loss: 0.3202, valid accuracy: 0.9144
# Iter-35500 train loss: 0.5055 valid loss: 0.3199, valid accuracy: 0.9146
# Iter-35600 train loss: 0.3207 valid loss: 0.3196, valid accuracy: 0.9146
# Iter-35700 train loss: 0.2843 valid loss: 0.3192, valid accuracy: 0.9148
# Iter-35800 train loss: 0.3807 valid loss: 0.3187, valid accuracy: 0.9148
# Iter-35900 train loss: 0.2077 valid loss: 0.3184, valid accuracy: 0.9146
# Iter-36000 train loss: 0.4643 valid loss: 0.3181, valid accuracy: 0.9146
# Iter-36100 train loss: 0.4445 valid loss: 0.3176, valid accuracy: 0.9152
# Iter-36200 train loss: 0.3767 valid loss: 0.3174, valid accuracy: 0.9156
# Iter-36300 train loss: 0.2388 valid loss: 0.3171, valid accuracy: 0.9156
# Iter-36400 train loss: 0.2065 valid loss: 0.3166, valid accuracy: 0.9164
# Iter-36500 train loss: 0.4716 valid loss: 0.3164, valid accuracy: 0.9162
# Iter-36600 train loss: 0.3516 valid loss: 0.3163, valid accuracy: 0.9166
# Iter-36700 train loss: 0.2225 valid loss: 0.3157, valid accuracy: 0.9168
# Iter-36800 train loss: 0.3813 valid loss: 0.3155, valid accuracy: 0.9158
# Iter-36900 train loss: 0.3307 valid loss: 0.3151, valid accuracy: 0.9166
# Iter-37000 train loss: 0.3485 valid loss: 0.3146, valid accuracy: 0.9168
# Iter-37100 train loss: 0.2076 valid loss: 0.3145, valid accuracy: 0.9166
# Iter-37200 train loss: 0.3127 valid loss: 0.3144, valid accuracy: 0.9164
# Iter-37300 train loss: 0.3053 valid loss: 0.3140, valid accuracy: 0.9164
# Iter-37400 train loss: 0.3223 valid loss: 0.3137, valid accuracy: 0.9164
# Iter-37500 train loss: 0.2935 valid loss: 0.3132, valid accuracy: 0.9166
# Iter-37600 train loss: 0.3859 valid loss: 0.3129, valid accuracy: 0.9160
# Iter-37700 train loss: 0.2513 valid loss: 0.3124, valid accuracy: 0.9160
# Iter-37800 train loss: 0.3889 valid loss: 0.3120, valid accuracy: 0.9164
# Iter-37900 train loss: 0.2654 valid loss: 0.3117, valid accuracy: 0.9172
# Iter-38000 train loss: 0.2851 valid loss: 0.3111, valid accuracy: 0.9174
# Iter-38100 train loss: 0.2319 valid loss: 0.3106, valid accuracy: 0.9176
# Iter-38200 train loss: 0.3479 valid loss: 0.3102, valid accuracy: 0.9168
# Iter-38300 train loss: 0.2874 valid loss: 0.3098, valid accuracy: 0.9176
# Iter-38400 train loss: 0.4897 valid loss: 0.3094, valid accuracy: 0.9176
# Iter-38500 train loss: 0.5945 valid loss: 0.3090, valid accuracy: 0.9174
# Iter-38600 train loss: 0.3267 valid loss: 0.3088, valid accuracy: 0.9178
# Iter-38700 train loss: 0.2927 valid loss: 0.3086, valid accuracy: 0.9178
# Iter-38800 train loss: 0.5342 valid loss: 0.3084, valid accuracy: 0.9172
# Iter-38900 train loss: 0.2414 valid loss: 0.3083, valid accuracy: 0.9172
# Iter-39000 train loss: 0.2794 valid loss: 0.3081, valid accuracy: 0.9168
# Iter-39100 train loss: 0.3256 valid loss: 0.3078, valid accuracy: 0.9172
# Iter-39200 train loss: 0.2022 valid loss: 0.3075, valid accuracy: 0.9170
# Iter-39300 train loss: 0.6108 valid loss: 0.3072, valid accuracy: 0.9172
# Iter-39400 train loss: 0.3254 valid loss: 0.3066, valid accuracy: 0.9172
# Iter-39500 train loss: 0.1430 valid loss: 0.3063, valid accuracy: 0.9176
# Iter-39600 train loss: 0.2800 valid loss: 0.3060, valid accuracy: 0.9178
# Iter-39700 train loss: 0.1397 valid loss: 0.3058, valid accuracy: 0.9176
# Iter-39800 train loss: 0.4947 valid loss: 0.3052, valid accuracy: 0.9176
# Iter-39900 train loss: 0.3136 valid loss: 0.3050, valid accuracy: 0.9178
# Iter-40000 train loss: 0.3074 valid loss: 0.3047, valid accuracy: 0.9178
# Iter-40100 train loss: 0.5175 valid loss: 0.3043, valid accuracy: 0.9176
# Iter-40200 train loss: 0.1812 valid loss: 0.3040, valid accuracy: 0.9178
# Iter-40300 train loss: 0.2613 valid loss: 0.3036, valid accuracy: 0.9180
# Iter-40400 train loss: 0.2735 valid loss: 0.3034, valid accuracy: 0.9180
# Iter-40500 train loss: 0.3748 valid loss: 0.3031, valid accuracy: 0.9184
# Iter-40600 train loss: 0.2916 valid loss: 0.3030, valid accuracy: 0.9186
# Iter-40700 train loss: 0.5765 valid loss: 0.3030, valid accuracy: 0.9188
# Iter-40800 train loss: 0.3890 valid loss: 0.3023, valid accuracy: 0.9190
# Iter-40900 train loss: 0.2846 valid loss: 0.3020, valid accuracy: 0.9192
# Iter-41000 train loss: 0.2734 valid loss: 0.3015, valid accuracy: 0.9198
# Iter-41100 train loss: 0.3159 valid loss: 0.3012, valid accuracy: 0.9186
# Iter-41200 train loss: 0.2543 valid loss: 0.3009, valid accuracy: 0.9182
# Iter-41300 train loss: 0.2963 valid loss: 0.3007, valid accuracy: 0.9192
# Iter-41400 train loss: 0.3446 valid loss: 0.3004, valid accuracy: 0.9188
# Iter-41500 train loss: 0.5049 valid loss: 0.3000, valid accuracy: 0.9194
# Iter-41600 train loss: 0.3801 valid loss: 0.2996, valid accuracy: 0.9196
# Iter-41700 train loss: 0.2844 valid loss: 0.2994, valid accuracy: 0.9198
# Iter-41800 train loss: 0.2744 valid loss: 0.2991, valid accuracy: 0.9202
# Iter-41900 train loss: 0.2283 valid loss: 0.2988, valid accuracy: 0.9194
# Iter-42000 train loss: 0.2640 valid loss: 0.2984, valid accuracy: 0.9196
# Iter-42100 train loss: 0.2454 valid loss: 0.2982, valid accuracy: 0.9194
# Iter-42200 train loss: 0.3082 valid loss: 0.2981, valid accuracy: 0.9194
# Iter-42300 train loss: 0.2848 valid loss: 0.2977, valid accuracy: 0.9198
# Iter-42400 train loss: 0.4136 valid loss: 0.2975, valid accuracy: 0.9200
# Iter-42500 train loss: 0.5215 valid loss: 0.2972, valid accuracy: 0.9202
# Iter-42600 train loss: 0.3768 valid loss: 0.2969, valid accuracy: 0.9198
# Iter-42700 train loss: 0.3663 valid loss: 0.2965, valid accuracy: 0.9198
# Iter-42800 train loss: 0.3014 valid loss: 0.2964, valid accuracy: 0.9198
# Iter-42900 train loss: 0.2174 valid loss: 0.2963, valid accuracy: 0.9204
# Iter-43000 train loss: 0.5281 valid loss: 0.2962, valid accuracy: 0.9198
# Iter-43100 train loss: 0.2209 valid loss: 0.2960, valid accuracy: 0.9196
# Iter-43200 train loss: 0.3196 valid loss: 0.2958, valid accuracy: 0.9198
# Iter-43300 train loss: 0.1428 valid loss: 0.2957, valid accuracy: 0.9200
# Iter-43400 train loss: 0.4021 valid loss: 0.2954, valid accuracy: 0.9200
# Iter-43500 train loss: 0.1724 valid loss: 0.2951, valid accuracy: 0.9198
# Iter-43600 train loss: 0.3877 valid loss: 0.2947, valid accuracy: 0.9198
# Iter-43700 train loss: 0.4022 valid loss: 0.2944, valid accuracy: 0.9198
# Iter-43800 train loss: 0.3398 valid loss: 0.2940, valid accuracy: 0.9196
# Iter-43900 train loss: 0.3634 valid loss: 0.2938, valid accuracy: 0.9194
# Iter-44000 train loss: 0.3122 valid loss: 0.2936, valid accuracy: 0.9198
# Iter-44100 train loss: 0.2560 valid loss: 0.2934, valid accuracy: 0.9198
# Iter-44200 train loss: 0.1671 valid loss: 0.2931, valid accuracy: 0.9194
# Iter-44300 train loss: 0.3001 valid loss: 0.2929, valid accuracy: 0.9194
# Iter-44400 train loss: 0.2926 valid loss: 0.2925, valid accuracy: 0.9200
# Iter-44500 train loss: 0.5362 valid loss: 0.2923, valid accuracy: 0.9196
# Iter-44600 train loss: 0.4259 valid loss: 0.2920, valid accuracy: 0.9202
# Iter-44700 train loss: 0.1926 valid loss: 0.2917, valid accuracy: 0.9206
# Iter-44800 train loss: 0.2707 valid loss: 0.2914, valid accuracy: 0.9210
# Iter-44900 train loss: 0.2755 valid loss: 0.2912, valid accuracy: 0.9206
# Iter-45000 train loss: 0.2383 valid loss: 0.2909, valid accuracy: 0.9204
# Iter-45100 train loss: 0.3470 valid loss: 0.2905, valid accuracy: 0.9204
# Iter-45200 train loss: 0.3522 valid loss: 0.2904, valid accuracy: 0.9202
# Iter-45300 train loss: 0.3179 valid loss: 0.2901, valid accuracy: 0.9198
# Iter-45400 train loss: 0.2964 valid loss: 0.2900, valid accuracy: 0.9198
# Iter-45500 train loss: 0.4177 valid loss: 0.2897, valid accuracy: 0.9202
# Iter-45600 train loss: 0.3628 valid loss: 0.2893, valid accuracy: 0.9206
# Iter-45700 train loss: 0.2704 valid loss: 0.2890, valid accuracy: 0.9210
# Iter-45800 train loss: 0.1411 valid loss: 0.2886, valid accuracy: 0.9208
# Iter-45900 train loss: 0.2418 valid loss: 0.2884, valid accuracy: 0.9206
# Iter-46000 train loss: 0.2304 valid loss: 0.2882, valid accuracy: 0.9206
# Iter-46100 train loss: 0.2615 valid loss: 0.2879, valid accuracy: 0.9212
# Iter-46200 train loss: 0.2283 valid loss: 0.2877, valid accuracy: 0.9210
# Iter-46300 train loss: 0.2478 valid loss: 0.2874, valid accuracy: 0.9208
# Iter-46400 train loss: 0.1720 valid loss: 0.2872, valid accuracy: 0.9206
# Iter-46500 train loss: 0.3317 valid loss: 0.2870, valid accuracy: 0.9212
# Iter-46600 train loss: 0.2390 valid loss: 0.2868, valid accuracy: 0.9212
# Iter-46700 train loss: 0.2671 valid loss: 0.2866, valid accuracy: 0.9212
# Iter-46800 train loss: 0.0989 valid loss: 0.2865, valid accuracy: 0.9210
# Iter-46900 train loss: 0.1093 valid loss: 0.2864, valid accuracy: 0.9208
# Iter-47000 train loss: 0.2608 valid loss: 0.2861, valid accuracy: 0.9210
# Iter-47100 train loss: 0.1935 valid loss: 0.2857, valid accuracy: 0.9212
# Iter-47200 train loss: 0.3805 valid loss: 0.2854, valid accuracy: 0.9214
# Iter-47300 train loss: 0.3157 valid loss: 0.2852, valid accuracy: 0.9214
# Iter-47400 train loss: 0.1388 valid loss: 0.2850, valid accuracy: 0.9212
# Iter-47500 train loss: 0.3310 valid loss: 0.2848, valid accuracy: 0.9216
# Iter-47600 train loss: 0.4038 valid loss: 0.2844, valid accuracy: 0.9214
# Iter-47700 train loss: 0.2800 valid loss: 0.2841, valid accuracy: 0.9216
# Iter-47800 train loss: 0.3597 valid loss: 0.2840, valid accuracy: 0.9220
# Iter-47900 train loss: 0.2125 valid loss: 0.2839, valid accuracy: 0.9222
# Iter-48000 train loss: 0.2417 valid loss: 0.2837, valid accuracy: 0.9220
# Iter-48100 train loss: 0.3621 valid loss: 0.2837, valid accuracy: 0.9222
# Iter-48200 train loss: 0.2682 valid loss: 0.2836, valid accuracy: 0.9218
# Iter-48300 train loss: 0.2901 valid loss: 0.2832, valid accuracy: 0.9218
# Iter-48400 train loss: 0.2346 valid loss: 0.2830, valid accuracy: 0.9218
# Iter-48500 train loss: 0.2830 valid loss: 0.2831, valid accuracy: 0.9222
# Iter-48600 train loss: 0.4125 valid loss: 0.2829, valid accuracy: 0.9222
# Iter-48700 train loss: 0.2579 valid loss: 0.2827, valid accuracy: 0.9220
# Iter-48800 train loss: 0.4214 valid loss: 0.2823, valid accuracy: 0.9224
# Iter-48900 train loss: 0.3362 valid loss: 0.2819, valid accuracy: 0.9226
# Iter-49000 train loss: 0.3134 valid loss: 0.2817, valid accuracy: 0.9224
# Iter-49100 train loss: 0.3638 valid loss: 0.2815, valid accuracy: 0.9224
# Iter-49200 train loss: 0.1213 valid loss: 0.2812, valid accuracy: 0.9220
# Iter-49300 train loss: 0.1701 valid loss: 0.2811, valid accuracy: 0.9226
# Iter-49400 train loss: 0.1636 valid loss: 0.2809, valid accuracy: 0.9228
# Iter-49500 train loss: 0.2409 valid loss: 0.2808, valid accuracy: 0.9226
# Iter-49600 train loss: 0.2326 valid loss: 0.2807, valid accuracy: 0.9224
# Iter-49700 train loss: 0.1474 valid loss: 0.2806, valid accuracy: 0.9222
# Iter-49800 train loss: 0.2414 valid loss: 0.2802, valid accuracy: 0.9226
# Iter-49900 train loss: 0.3030 valid loss: 0.2799, valid accuracy: 0.9226
# Iter-50000 train loss: 0.2387 valid loss: 0.2798, valid accuracy: 0.9228
# Iter-50100 train loss: 0.4853 valid loss: 0.2796, valid accuracy: 0.9228
# Iter-50200 train loss: 0.5611 valid loss: 0.2793, valid accuracy: 0.9226
# Iter-50300 train loss: 0.3016 valid loss: 0.2790, valid accuracy: 0.9226
# Iter-50400 train loss: 0.2378 valid loss: 0.2788, valid accuracy: 0.9226
# Iter-50500 train loss: 0.2951 valid loss: 0.2784, valid accuracy: 0.9228
# Iter-50600 train loss: 0.2327 valid loss: 0.2782, valid accuracy: 0.9232
# Iter-50700 train loss: 0.1986 valid loss: 0.2778, valid accuracy: 0.9228
# Iter-50800 train loss: 0.2798 valid loss: 0.2777, valid accuracy: 0.9226
# Iter-50900 train loss: 0.2722 valid loss: 0.2775, valid accuracy: 0.9224
# Iter-51000 train loss: 0.4184 valid loss: 0.2773, valid accuracy: 0.9228
# Iter-51100 train loss: 0.2601 valid loss: 0.2772, valid accuracy: 0.9228
# Iter-51200 train loss: 0.3549 valid loss: 0.2770, valid accuracy: 0.9232
# Iter-51300 train loss: 0.3198 valid loss: 0.2768, valid accuracy: 0.9224
# Iter-51400 train loss: 0.2464 valid loss: 0.2766, valid accuracy: 0.9222
# Iter-51500 train loss: 0.5358 valid loss: 0.2764, valid accuracy: 0.9228
# Iter-51600 train loss: 0.3017 valid loss: 0.2761, valid accuracy: 0.9228
# Iter-51700 train loss: 0.5473 valid loss: 0.2761, valid accuracy: 0.9230
# Iter-51800 train loss: 0.3468 valid loss: 0.2760, valid accuracy: 0.9230
# Iter-51900 train loss: 0.4423 valid loss: 0.2758, valid accuracy: 0.9228
# Iter-52000 train loss: 0.2927 valid loss: 0.2756, valid accuracy: 0.9234
# Iter-52100 train loss: 0.3202 valid loss: 0.2755, valid accuracy: 0.9234
# Iter-52200 train loss: 0.2292 valid loss: 0.2752, valid accuracy: 0.9234
# Iter-52300 train loss: 0.1529 valid loss: 0.2749, valid accuracy: 0.9236
# Iter-52400 train loss: 0.2237 valid loss: 0.2747, valid accuracy: 0.9234
# Iter-52500 train loss: 0.2377 valid loss: 0.2748, valid accuracy: 0.9234
# Iter-52600 train loss: 0.2477 valid loss: 0.2746, valid accuracy: 0.9234
# Iter-52700 train loss: 0.3912 valid loss: 0.2743, valid accuracy: 0.9238
# Iter-52800 train loss: 0.2658 valid loss: 0.2740, valid accuracy: 0.9236
# Iter-52900 train loss: 0.2295 valid loss: 0.2737, valid accuracy: 0.9236
# Iter-53000 train loss: 0.1623 valid loss: 0.2732, valid accuracy: 0.9236
# Iter-53100 train loss: 0.2224 valid loss: 0.2730, valid accuracy: 0.9236
# Iter-53200 train loss: 0.3485 valid loss: 0.2730, valid accuracy: 0.9234
# Iter-53300 train loss: 0.4029 valid loss: 0.2727, valid accuracy: 0.9232
# Iter-53400 train loss: 0.3762 valid loss: 0.2726, valid accuracy: 0.9234
# Iter-53500 train loss: 0.2816 valid loss: 0.2723, valid accuracy: 0.9234
# Iter-53600 train loss: 0.3183 valid loss: 0.2722, valid accuracy: 0.9238
# Iter-53700 train loss: 0.6241 valid loss: 0.2722, valid accuracy: 0.9240
# Iter-53800 train loss: 0.2985 valid loss: 0.2720, valid accuracy: 0.9238
# Iter-53900 train loss: 0.2294 valid loss: 0.2718, valid accuracy: 0.9234
# Iter-54000 train loss: 0.4325 valid loss: 0.2716, valid accuracy: 0.9236
# Iter-54100 train loss: 0.2842 valid loss: 0.2712, valid accuracy: 0.9232
# Iter-54200 train loss: 0.2560 valid loss: 0.2711, valid accuracy: 0.9236
# Iter-54300 train loss: 0.2752 valid loss: 0.2708, valid accuracy: 0.9238
# Iter-54400 train loss: 0.1869 valid loss: 0.2705, valid accuracy: 0.9240
# Iter-54500 train loss: 0.4300 valid loss: 0.2704, valid accuracy: 0.9240
# Iter-54600 train loss: 0.6001 valid loss: 0.2705, valid accuracy: 0.9236
# Iter-54700 train loss: 0.1965 valid loss: 0.2703, valid accuracy: 0.9236
# Iter-54800 train loss: 0.2033 valid loss: 0.2701, valid accuracy: 0.9238
# Iter-54900 train loss: 0.1679 valid loss: 0.2701, valid accuracy: 0.9240
# Iter-55000 train loss: 0.1397 valid loss: 0.2700, valid accuracy: 0.9242
# Iter-55100 train loss: 0.3051 valid loss: 0.2696, valid accuracy: 0.9236
# Iter-55200 train loss: 0.4334 valid loss: 0.2695, valid accuracy: 0.9232
# Iter-55300 train loss: 0.2157 valid loss: 0.2693, valid accuracy: 0.9232
# Iter-55400 train loss: 0.2405 valid loss: 0.2691, valid accuracy: 0.9236
# Iter-55500 train loss: 0.1900 valid loss: 0.2690, valid accuracy: 0.9236
# Iter-55600 train loss: 0.2538 valid loss: 0.2689, valid accuracy: 0.9236
# Iter-55700 train loss: 0.3645 valid loss: 0.2689, valid accuracy: 0.9238
# Iter-55800 train loss: 0.2858 valid loss: 0.2687, valid accuracy: 0.9234
# Iter-55900 train loss: 0.3955 valid loss: 0.2688, valid accuracy: 0.9236
# Iter-56000 train loss: 0.1534 valid loss: 0.2685, valid accuracy: 0.9240
# Iter-56100 train loss: 0.2633 valid loss: 0.2685, valid accuracy: 0.9238
# Iter-56200 train loss: 0.1024 valid loss: 0.2683, valid accuracy: 0.9236
# Iter-56300 train loss: 0.1699 valid loss: 0.2681, valid accuracy: 0.9234
# Iter-56400 train loss: 0.2044 valid loss: 0.2679, valid accuracy: 0.9232
# Iter-56500 train loss: 0.4403 valid loss: 0.2678, valid accuracy: 0.9230
# Iter-56600 train loss: 0.2968 valid loss: 0.2675, valid accuracy: 0.9234
# Iter-56700 train loss: 0.1984 valid loss: 0.2673, valid accuracy: 0.9236
# Iter-56800 train loss: 0.4255 valid loss: 0.2670, valid accuracy: 0.9234
# Iter-56900 train loss: 0.3010 valid loss: 0.2669, valid accuracy: 0.9236
# Iter-57000 train loss: 0.3776 valid loss: 0.2665, valid accuracy: 0.9240
# Iter-57100 train loss: 0.1984 valid loss: 0.2664, valid accuracy: 0.9240
# Iter-57200 train loss: 0.1281 valid loss: 0.2661, valid accuracy: 0.9238
# Iter-57300 train loss: 0.3770 valid loss: 0.2658, valid accuracy: 0.9238
# Iter-57400 train loss: 0.4852 valid loss: 0.2655, valid accuracy: 0.9240
# Iter-57500 train loss: 0.2615 valid loss: 0.2655, valid accuracy: 0.9240
# Iter-57600 train loss: 0.4167 valid loss: 0.2653, valid accuracy: 0.9242
# Iter-57700 train loss: 0.2713 valid loss: 0.2651, valid accuracy: 0.9242
# Iter-57800 train loss: 0.1724 valid loss: 0.2647, valid accuracy: 0.9250
# Iter-57900 train loss: 0.1785 valid loss: 0.2646, valid accuracy: 0.9250
# Iter-58000 train loss: 0.1778 valid loss: 0.2645, valid accuracy: 0.9244
# Iter-58100 train loss: 0.1546 valid loss: 0.2644, valid accuracy: 0.9246
# Iter-58200 train loss: 0.3870 valid loss: 0.2642, valid accuracy: 0.9244
# Iter-58300 train loss: 0.2696 valid loss: 0.2640, valid accuracy: 0.9246
# Iter-58400 train loss: 0.2650 valid loss: 0.2639, valid accuracy: 0.9244
# Iter-58500 train loss: 0.2659 valid loss: 0.2638, valid accuracy: 0.9248
# Iter-58600 train loss: 0.2380 valid loss: 0.2638, valid accuracy: 0.9246
# Iter-58700 train loss: 0.3452 valid loss: 0.2638, valid accuracy: 0.9250
# Iter-58800 train loss: 0.4913 valid loss: 0.2638, valid accuracy: 0.9242
# Iter-58900 train loss: 0.1951 valid loss: 0.2635, valid accuracy: 0.9246
# Iter-59000 train loss: 0.3506 valid loss: 0.2632, valid accuracy: 0.9248
# Iter-59100 train loss: 0.1944 valid loss: 0.2632, valid accuracy: 0.9246
# Iter-59200 train loss: 0.3328 valid loss: 0.2630, valid accuracy: 0.9248
# Iter-59300 train loss: 0.2829 valid loss: 0.2628, valid accuracy: 0.9248
# Iter-59400 train loss: 0.3714 valid loss: 0.2626, valid accuracy: 0.9244
# Iter-59500 train loss: 0.2331 valid loss: 0.2624, valid accuracy: 0.9250
# Iter-59600 train loss: 0.2838 valid loss: 0.2625, valid accuracy: 0.9248
# Iter-59700 train loss: 0.2996 valid loss: 0.2624, valid accuracy: 0.9248
# Iter-59800 train loss: 0.2827 valid loss: 0.2621, valid accuracy: 0.9244
# Iter-59900 train loss: 0.2232 valid loss: 0.2617, valid accuracy: 0.9246
# Iter-60000 train loss: 0.1999 valid loss: 0.2618, valid accuracy: 0.9244
# Iter-60100 train loss: 0.2580 valid loss: 0.2619, valid accuracy: 0.9250
# Iter-60200 train loss: 0.2354 valid loss: 0.2617, valid accuracy: 0.9250
# Iter-60300 train loss: 0.2489 valid loss: 0.2615, valid accuracy: 0.9250
# Iter-60400 train loss: 0.2203 valid loss: 0.2614, valid accuracy: 0.9248
# Iter-60500 train loss: 0.3748 valid loss: 0.2614, valid accuracy: 0.9254
# Iter-60600 train loss: 0.3807 valid loss: 0.2609, valid accuracy: 0.9252
# Iter-60700 train loss: 0.1658 valid loss: 0.2606, valid accuracy: 0.9252
# Iter-60800 train loss: 0.2851 valid loss: 0.2605, valid accuracy: 0.9258
# Iter-60900 train loss: 0.2874 valid loss: 0.2602, valid accuracy: 0.9252
# Iter-61000 train loss: 0.2237 valid loss: 0.2602, valid accuracy: 0.9252
# Iter-61100 train loss: 0.1703 valid loss: 0.2599, valid accuracy: 0.9256
# Iter-61200 train loss: 0.2707 valid loss: 0.2597, valid accuracy: 0.9252
# Iter-61300 train loss: 0.2146 valid loss: 0.2597, valid accuracy: 0.9250
# Iter-61400 train loss: 0.1163 valid loss: 0.2594, valid accuracy: 0.9254
# Iter-61500 train loss: 0.1900 valid loss: 0.2593, valid accuracy: 0.9250
# Iter-61600 train loss: 0.2331 valid loss: 0.2589, valid accuracy: 0.9256
# Iter-61700 train loss: 0.3599 valid loss: 0.2589, valid accuracy: 0.9254
# Iter-61800 train loss: 0.2379 valid loss: 0.2587, valid accuracy: 0.9258
# Iter-61900 train loss: 0.1245 valid loss: 0.2585, valid accuracy: 0.9262
# Iter-62000 train loss: 0.3726 valid loss: 0.2584, valid accuracy: 0.9264
# Iter-62100 train loss: 0.1845 valid loss: 0.2583, valid accuracy: 0.9260
# Iter-62200 train loss: 0.3139 valid loss: 0.2580, valid accuracy: 0.9262
# Iter-62300 train loss: 0.2581 valid loss: 0.2578, valid accuracy: 0.9262
# Iter-62400 train loss: 0.3646 valid loss: 0.2577, valid accuracy: 0.9260
# Iter-62500 train loss: 0.2652 valid loss: 0.2575, valid accuracy: 0.9264
# Iter-62600 train loss: 0.3886 valid loss: 0.2577, valid accuracy: 0.9264
# Iter-62700 train loss: 0.2214 valid loss: 0.2575, valid accuracy: 0.9266
# Iter-62800 train loss: 0.0986 valid loss: 0.2570, valid accuracy: 0.9264
# Iter-62900 train loss: 0.1425 valid loss: 0.2570, valid accuracy: 0.9260
# Iter-63000 train loss: 0.3117 valid loss: 0.2568, valid accuracy: 0.9260
# Iter-63100 train loss: 0.2023 valid loss: 0.2567, valid accuracy: 0.9262
# Iter-63200 train loss: 0.2261 valid loss: 0.2565, valid accuracy: 0.9260
# Iter-63300 train loss: 0.0928 valid loss: 0.2563, valid accuracy: 0.9266
# Iter-63400 train loss: 0.1840 valid loss: 0.2563, valid accuracy: 0.9264
# Iter-63500 train loss: 0.3117 valid loss: 0.2562, valid accuracy: 0.9264
# Iter-63600 train loss: 0.2251 valid loss: 0.2562, valid accuracy: 0.9268
# Iter-63700 train loss: 0.1772 valid loss: 0.2560, valid accuracy: 0.9268
# Iter-63800 train loss: 0.3839 valid loss: 0.2558, valid accuracy: 0.9270
# Iter-63900 train loss: 0.1112 valid loss: 0.2558, valid accuracy: 0.9266
# Iter-64000 train loss: 0.3094 valid loss: 0.2557, valid accuracy: 0.9264
# Iter-64100 train loss: 0.1812 valid loss: 0.2554, valid accuracy: 0.9264
# Iter-64200 train loss: 0.2351 valid loss: 0.2553, valid accuracy: 0.9268
# Iter-64300 train loss: 0.1447 valid loss: 0.2552, valid accuracy: 0.9272
# Iter-64400 train loss: 0.3342 valid loss: 0.2551, valid accuracy: 0.9270
# Iter-64500 train loss: 0.2677 valid loss: 0.2550, valid accuracy: 0.9274
# Iter-64600 train loss: 0.1753 valid loss: 0.2550, valid accuracy: 0.9274
# Iter-64700 train loss: 0.2801 valid loss: 0.2549, valid accuracy: 0.9272
# Iter-64800 train loss: 0.1373 valid loss: 0.2548, valid accuracy: 0.9268
# Iter-64900 train loss: 0.2976 valid loss: 0.2545, valid accuracy: 0.9268
# Iter-65000 train loss: 0.2436 valid loss: 0.2543, valid accuracy: 0.9266
# Iter-65100 train loss: 0.1315 valid loss: 0.2541, valid accuracy: 0.9268
# Iter-65200 train loss: 0.4040 valid loss: 0.2540, valid accuracy: 0.9266
# Iter-65300 train loss: 0.2448 valid loss: 0.2540, valid accuracy: 0.9272
# Iter-65400 train loss: 0.3084 valid loss: 0.2538, valid accuracy: 0.9272
# Iter-65500 train loss: 0.4159 valid loss: 0.2534, valid accuracy: 0.9276
# Iter-65600 train loss: 0.2214 valid loss: 0.2534, valid accuracy: 0.9280
# Iter-65700 train loss: 0.2041 valid loss: 0.2533, valid accuracy: 0.9274
# Iter-65800 train loss: 0.4029 valid loss: 0.2530, valid accuracy: 0.9278
# Iter-65900 train loss: 0.1034 valid loss: 0.2528, valid accuracy: 0.9278
# ...
# Iter-275600 train loss: 0.0603 valid loss: 0.1263, valid accuracy: 0.9638
# Iter-275700 train loss: 0.1373 valid loss: 0.1264, valid accuracy: 0.9640
# Iter-275800 train loss: 0.1624 valid loss: 0.1263, valid accuracy: 0.9642
# Iter-275900 train loss: 0.0608 valid loss: 0.1260, valid accuracy: 0.9642
# Iter-276000 train loss: 0.0840 valid loss: 0.1261, valid accuracy: 0.9650
# Iter-276100 train loss: 0.1400 valid loss: 0.1260, valid accuracy: 0.9642
# Iter-276200 train loss: 0.2617 valid loss: 0.1261, valid accuracy: 0.9644
# Iter-276300 train loss: 0.0478 valid loss: 0.1260, valid accuracy: 0.9644
# Iter-276400 train loss: 0.0226 valid loss: 0.1260, valid accuracy: 0.9638
# Iter-276500 train loss: 0.0675 valid loss: 0.1259, valid accuracy: 0.9644
# Iter-276600 train loss: 0.0744 valid loss: 0.1258, valid accuracy: 0.9644
# Iter-276700 train loss: 0.1139 valid loss: 0.1259, valid accuracy: 0.9644
# Iter-276800 train loss: 0.1605 valid loss: 0.1259, valid accuracy: 0.9638
# Iter-276900 train loss: 0.0359 valid loss: 0.1259, valid accuracy: 0.9638
# Iter-277000 train loss: 0.0806 valid loss: 0.1259, valid accuracy: 0.9642
# Iter-277100 train loss: 0.1300 valid loss: 0.1258, valid accuracy: 0.9640
# Iter-277200 train loss: 0.0888 valid loss: 0.1259, valid accuracy: 0.9640
# Iter-277300 train loss: 0.0598 valid loss: 0.1258, valid accuracy: 0.9644
# Iter-277400 train loss: 0.0860 valid loss: 0.1258, valid accuracy: 0.9642
# Iter-277500 train loss: 0.1402 valid loss: 0.1259, valid accuracy: 0.9642
# Iter-277600 train loss: 0.1493 valid loss: 0.1259, valid accuracy: 0.9648
# Iter-277700 train loss: 0.0305 valid loss: 0.1259, valid accuracy: 0.9642
# Iter-277800 train loss: 0.1011 valid loss: 0.1259, valid accuracy: 0.9642
# Iter-277900 train loss: 0.1082 valid loss: 0.1258, valid accuracy: 0.9644
# Iter-278000 train loss: 0.0588 valid loss: 0.1258, valid accuracy: 0.9638
# Iter-278100 train loss: 0.2920 valid loss: 0.1257, valid accuracy: 0.9636
# Iter-278200 train loss: 0.1161 valid loss: 0.1257, valid accuracy: 0.9634
# Iter-278300 train loss: 0.0499 valid loss: 0.1259, valid accuracy: 0.9632
# Iter-278400 train loss: 0.0514 valid loss: 0.1261, valid accuracy: 0.9630
# Iter-278500 train loss: 0.1667 valid loss: 0.1261, valid accuracy: 0.9634
# Iter-278600 train loss: 0.0395 valid loss: 0.1260, valid accuracy: 0.9634
# Iter-278700 train loss: 0.0767 valid loss: 0.1261, valid accuracy: 0.9640
# Iter-278800 train loss: 0.2966 valid loss: 0.1260, valid accuracy: 0.9634
# Iter-278900 train loss: 0.0807 valid loss: 0.1261, valid accuracy: 0.9634
# Iter-279000 train loss: 0.0776 valid loss: 0.1260, valid accuracy: 0.9636
# Iter-279100 train loss: 0.1393 valid loss: 0.1260, valid accuracy: 0.9638
# Iter-279200 train loss: 0.0302 valid loss: 0.1259, valid accuracy: 0.9636
# Iter-279300 train loss: 0.0816 valid loss: 0.1259, valid accuracy: 0.9634
# Iter-279400 train loss: 0.2688 valid loss: 0.1257, valid accuracy: 0.9636
# Iter-279500 train loss: 0.1253 valid loss: 0.1256, valid accuracy: 0.9632
# Iter-279600 train loss: 0.1654 valid loss: 0.1256, valid accuracy: 0.9636
# Iter-279700 train loss: 0.1673 valid loss: 0.1257, valid accuracy: 0.9638
# Iter-279800 train loss: 0.0240 valid loss: 0.1257, valid accuracy: 0.9634
# Iter-279900 train loss: 0.0464 valid loss: 0.1255, valid accuracy: 0.9632
# Iter-280000 train loss: 0.0368 valid loss: 0.1255, valid accuracy: 0.9634
# Iter-280100 train loss: 0.0384 valid loss: 0.1254, valid accuracy: 0.9638
# Iter-280200 train loss: 0.0598 valid loss: 0.1253, valid accuracy: 0.9640
# Iter-280300 train loss: 0.0704 valid loss: 0.1252, valid accuracy: 0.9636
# Iter-280400 train loss: 0.1489 valid loss: 0.1249, valid accuracy: 0.9638
# Iter-280500 train loss: 0.1965 valid loss: 0.1251, valid accuracy: 0.9636
# Iter-280600 train loss: 0.1391 valid loss: 0.1252, valid accuracy: 0.9644
# Iter-280700 train loss: 0.0199 valid loss: 0.1252, valid accuracy: 0.9638
# Iter-280800 train loss: 0.0923 valid loss: 0.1252, valid accuracy: 0.9634
# Iter-280900 train loss: 0.0481 valid loss: 0.1251, valid accuracy: 0.9640
# Iter-281000 train loss: 0.0672 valid loss: 0.1251, valid accuracy: 0.9642
# Iter-281100 train loss: 0.1290 valid loss: 0.1250, valid accuracy: 0.9646
# Iter-281200 train loss: 0.1420 valid loss: 0.1251, valid accuracy: 0.9646
# Iter-281300 train loss: 0.0264 valid loss: 0.1253, valid accuracy: 0.9648
# Iter-281400 train loss: 0.0213 valid loss: 0.1256, valid accuracy: 0.9648
# Iter-281500 train loss: 0.0871 valid loss: 0.1254, valid accuracy: 0.9646
# Iter-281600 train loss: 0.0594 valid loss: 0.1253, valid accuracy: 0.9646
# Iter-281700 train loss: 0.1582 valid loss: 0.1252, valid accuracy: 0.9644
# Iter-281800 train loss: 0.1274 valid loss: 0.1251, valid accuracy: 0.9646
# Iter-281900 train loss: 0.0667 valid loss: 0.1251, valid accuracy: 0.9648
# Iter-282000 train loss: 0.1382 valid loss: 0.1251, valid accuracy: 0.9650
# Iter-282100 train loss: 0.1420 valid loss: 0.1251, valid accuracy: 0.9646
# Iter-282200 train loss: 0.0251 valid loss: 0.1249, valid accuracy: 0.9642
# Iter-282300 train loss: 0.2033 valid loss: 0.1249, valid accuracy: 0.9644
# Iter-282400 train loss: 0.0768 valid loss: 0.1251, valid accuracy: 0.9638
# Iter-282500 train loss: 0.0937 valid loss: 0.1253, valid accuracy: 0.9640
# Iter-282600 train loss: 0.1982 valid loss: 0.1254, valid accuracy: 0.9640
# Iter-282700 train loss: 0.2398 valid loss: 0.1253, valid accuracy: 0.9640
# Iter-282800 train loss: 0.0925 valid loss: 0.1254, valid accuracy: 0.9644
# Iter-282900 train loss: 0.0412 valid loss: 0.1253, valid accuracy: 0.9644
# Iter-283000 train loss: 0.2119 valid loss: 0.1255, valid accuracy: 0.9638
# Iter-283100 train loss: 0.0691 valid loss: 0.1254, valid accuracy: 0.9642
# Iter-283200 train loss: 0.0518 valid loss: 0.1254, valid accuracy: 0.9640
# Iter-283300 train loss: 0.0621 valid loss: 0.1252, valid accuracy: 0.9648
# Iter-283400 train loss: 0.0328 valid loss: 0.1251, valid accuracy: 0.9646
# Iter-283500 train loss: 0.0273 valid loss: 0.1252, valid accuracy: 0.9644
# Iter-283600 train loss: 0.1153 valid loss: 0.1251, valid accuracy: 0.9638
# Iter-283700 train loss: 0.1618 valid loss: 0.1251, valid accuracy: 0.9640
# Iter-283800 train loss: 0.2729 valid loss: 0.1252, valid accuracy: 0.9642
# Iter-283900 train loss: 0.1957 valid loss: 0.1250, valid accuracy: 0.9642
# Iter-284000 train loss: 0.0253 valid loss: 0.1250, valid accuracy: 0.9642
# Iter-284100 train loss: 0.0702 valid loss: 0.1248, valid accuracy: 0.9644
# Iter-284200 train loss: 0.1479 valid loss: 0.1248, valid accuracy: 0.9648
# Iter-284300 train loss: 0.0585 valid loss: 0.1248, valid accuracy: 0.9646
# Iter-284400 train loss: 0.0912 valid loss: 0.1247, valid accuracy: 0.9644
# Iter-284500 train loss: 0.0372 valid loss: 0.1247, valid accuracy: 0.9644
# Iter-284600 train loss: 0.2649 valid loss: 0.1246, valid accuracy: 0.9646
# Iter-284700 train loss: 0.0725 valid loss: 0.1246, valid accuracy: 0.9648
# Iter-284800 train loss: 0.0560 valid loss: 0.1246, valid accuracy: 0.9642
# Iter-284900 train loss: 0.2448 valid loss: 0.1246, valid accuracy: 0.9644
# Iter-285000 train loss: 0.1103 valid loss: 0.1245, valid accuracy: 0.9646
# Iter-285100 train loss: 0.0953 valid loss: 0.1244, valid accuracy: 0.9640
# Iter-285200 train loss: 0.0869 valid loss: 0.1244, valid accuracy: 0.9642
# Iter-285300 train loss: 0.1301 valid loss: 0.1244, valid accuracy: 0.9648
# Iter-285400 train loss: 0.1710 valid loss: 0.1244, valid accuracy: 0.9646
# Iter-285500 train loss: 0.2873 valid loss: 0.1244, valid accuracy: 0.9644
# Iter-285600 train loss: 0.1159 valid loss: 0.1243, valid accuracy: 0.9638
# Iter-285700 train loss: 0.0575 valid loss: 0.1243, valid accuracy: 0.9638
# Iter-285800 train loss: 0.0752 valid loss: 0.1242, valid accuracy: 0.9646
# Iter-285900 train loss: 0.1285 valid loss: 0.1244, valid accuracy: 0.9642
# Iter-286000 train loss: 0.0358 valid loss: 0.1242, valid accuracy: 0.9646
# Iter-286100 train loss: 0.0650 valid loss: 0.1242, valid accuracy: 0.9648
# Iter-286200 train loss: 0.0800 valid loss: 0.1240, valid accuracy: 0.9646
# Iter-286300 train loss: 0.0763 valid loss: 0.1240, valid accuracy: 0.9644
# Iter-286400 train loss: 0.0347 valid loss: 0.1241, valid accuracy: 0.9646
# Iter-286500 train loss: 0.0624 valid loss: 0.1241, valid accuracy: 0.9646
# Iter-286600 train loss: 0.0425 valid loss: 0.1240, valid accuracy: 0.9646
# Iter-286700 train loss: 0.1738 valid loss: 0.1241, valid accuracy: 0.9646
# Iter-286800 train loss: 0.0855 valid loss: 0.1240, valid accuracy: 0.9644
# Iter-286900 train loss: 0.0827 valid loss: 0.1241, valid accuracy: 0.9648
# Iter-287000 train loss: 0.1265 valid loss: 0.1241, valid accuracy: 0.9648
# Iter-287100 train loss: 0.0638 valid loss: 0.1240, valid accuracy: 0.9650
# Iter-287200 train loss: 0.1973 valid loss: 0.1238, valid accuracy: 0.9650
# Iter-287300 train loss: 0.0913 valid loss: 0.1239, valid accuracy: 0.9650
# Iter-287400 train loss: 0.1921 valid loss: 0.1239, valid accuracy: 0.9648
# Iter-287500 train loss: 0.0890 valid loss: 0.1240, valid accuracy: 0.9648
# Iter-287600 train loss: 0.0742 valid loss: 0.1239, valid accuracy: 0.9650
# Iter-287700 train loss: 0.0294 valid loss: 0.1239, valid accuracy: 0.9650
# Iter-287800 train loss: 0.0525 valid loss: 0.1240, valid accuracy: 0.9648
# Iter-287900 train loss: 0.2466 valid loss: 0.1239, valid accuracy: 0.9650
# Iter-288000 train loss: 0.3183 valid loss: 0.1239, valid accuracy: 0.9648
# Iter-288100 train loss: 0.1830 valid loss: 0.1239, valid accuracy: 0.9648
# Iter-288200 train loss: 0.0635 valid loss: 0.1239, valid accuracy: 0.9648
# Iter-288300 train loss: 0.0655 valid loss: 0.1239, valid accuracy: 0.9646
# Iter-288400 train loss: 0.1181 valid loss: 0.1237, valid accuracy: 0.9646
# Iter-288500 train loss: 0.0652 valid loss: 0.1236, valid accuracy: 0.9638
# Iter-288600 train loss: 0.0334 valid loss: 0.1236, valid accuracy: 0.9636
# Iter-288700 train loss: 0.0212 valid loss: 0.1237, valid accuracy: 0.9642
# Iter-288800 train loss: 0.1962 valid loss: 0.1236, valid accuracy: 0.9638
# Iter-288900 train loss: 0.0251 valid loss: 0.1237, valid accuracy: 0.9640
# Iter-289000 train loss: 0.0826 valid loss: 0.1235, valid accuracy: 0.9646
# Iter-289100 train loss: 0.1024 valid loss: 0.1235, valid accuracy: 0.9646
# Iter-289200 train loss: 0.0328 valid loss: 0.1234, valid accuracy: 0.9648
# Iter-289300 train loss: 0.0245 valid loss: 0.1234, valid accuracy: 0.9652
# Iter-289400 train loss: 0.2327 valid loss: 0.1234, valid accuracy: 0.9648
# Iter-289500 train loss: 0.1643 valid loss: 0.1233, valid accuracy: 0.9648
# Iter-289600 train loss: 0.1176 valid loss: 0.1234, valid accuracy: 0.9648
# Iter-289700 train loss: 0.0428 valid loss: 0.1232, valid accuracy: 0.9648
# Iter-289800 train loss: 0.0857 valid loss: 0.1234, valid accuracy: 0.9652
# Iter-289900 train loss: 0.0776 valid loss: 0.1236, valid accuracy: 0.9650
# Iter-290000 train loss: 0.1919 valid loss: 0.1236, valid accuracy: 0.9654
# Iter-290100 train loss: 0.0330 valid loss: 0.1235, valid accuracy: 0.9654
# Iter-290200 train loss: 0.2009 valid loss: 0.1234, valid accuracy: 0.9646
# Iter-290300 train loss: 0.0636 valid loss: 0.1237, valid accuracy: 0.9648
# Iter-290400 train loss: 0.0847 valid loss: 0.1237, valid accuracy: 0.9652
# Iter-290500 train loss: 0.1495 valid loss: 0.1236, valid accuracy: 0.9650
# Iter-290600 train loss: 0.0665 valid loss: 0.1237, valid accuracy: 0.9646
# Iter-290700 train loss: 0.0890 valid loss: 0.1237, valid accuracy: 0.9650
# Iter-290800 train loss: 0.0731 valid loss: 0.1236, valid accuracy: 0.9646
# Iter-290900 train loss: 0.2029 valid loss: 0.1235, valid accuracy: 0.9646
# Iter-291000 train loss: 0.0538 valid loss: 0.1234, valid accuracy: 0.9648
# Iter-291100 train loss: 0.2044 valid loss: 0.1235, valid accuracy: 0.9648
# Iter-291200 train loss: 0.0436 valid loss: 0.1235, valid accuracy: 0.9648
# Iter-291300 train loss: 0.1336 valid loss: 0.1235, valid accuracy: 0.9650
# Iter-291400 train loss: 0.0568 valid loss: 0.1236, valid accuracy: 0.9646
# Iter-291500 train loss: 0.0343 valid loss: 0.1237, valid accuracy: 0.9650
# Iter-291600 train loss: 0.0253 valid loss: 0.1240, valid accuracy: 0.9650
# Iter-291700 train loss: 0.0879 valid loss: 0.1241, valid accuracy: 0.9644
# Iter-291800 train loss: 0.2351 valid loss: 0.1240, valid accuracy: 0.9654
# Iter-291900 train loss: 0.0539 valid loss: 0.1239, valid accuracy: 0.9644
# Iter-292000 train loss: 0.0529 valid loss: 0.1239, valid accuracy: 0.9644
# Iter-292100 train loss: 0.0456 valid loss: 0.1238, valid accuracy: 0.9642
# Iter-292200 train loss: 0.1078 valid loss: 0.1238, valid accuracy: 0.9646
# Iter-292300 train loss: 0.0845 valid loss: 0.1239, valid accuracy: 0.9646
# Iter-292400 train loss: 0.0547 valid loss: 0.1241, valid accuracy: 0.9650
# Iter-292500 train loss: 0.0268 valid loss: 0.1240, valid accuracy: 0.9644
# Iter-292600 train loss: 0.0784 valid loss: 0.1238, valid accuracy: 0.9648
# Iter-292700 train loss: 0.1129 valid loss: 0.1238, valid accuracy: 0.9642
# Iter-292800 train loss: 0.0743 valid loss: 0.1237, valid accuracy: 0.9640
# Iter-292900 train loss: 0.1293 valid loss: 0.1236, valid accuracy: 0.9640
# Iter-293000 train loss: 0.1238 valid loss: 0.1237, valid accuracy: 0.9642
# Iter-293100 train loss: 0.1519 valid loss: 0.1237, valid accuracy: 0.9636
# Iter-293200 train loss: 0.1104 valid loss: 0.1237, valid accuracy: 0.9644
# Iter-293300 train loss: 0.0404 valid loss: 0.1236, valid accuracy: 0.9646
# Iter-293400 train loss: 0.1171 valid loss: 0.1236, valid accuracy: 0.9648
# Iter-293500 train loss: 0.1610 valid loss: 0.1237, valid accuracy: 0.9644
# Iter-293600 train loss: 0.0265 valid loss: 0.1239, valid accuracy: 0.9644
# Iter-293700 train loss: 0.0427 valid loss: 0.1240, valid accuracy: 0.9646
# Iter-293800 train loss: 0.0550 valid loss: 0.1238, valid accuracy: 0.9644
# Iter-293900 train loss: 0.1336 valid loss: 0.1237, valid accuracy: 0.9648
# Iter-294000 train loss: 0.0686 valid loss: 0.1236, valid accuracy: 0.9642
# Iter-294100 train loss: 0.0548 valid loss: 0.1234, valid accuracy: 0.9644
# Iter-294200 train loss: 0.1250 valid loss: 0.1235, valid accuracy: 0.9642
# Iter-294300 train loss: 0.0240 valid loss: 0.1236, valid accuracy: 0.9638
# Iter-294400 train loss: 0.1645 valid loss: 0.1237, valid accuracy: 0.9640
# Iter-294500 train loss: 0.0925 valid loss: 0.1237, valid accuracy: 0.9640
# Iter-294600 train loss: 0.0417 valid loss: 0.1237, valid accuracy: 0.9640
# Iter-294700 train loss: 0.0960 valid loss: 0.1239, valid accuracy: 0.9640
# Iter-294800 train loss: 0.0976 valid loss: 0.1238, valid accuracy: 0.9636
# Iter-294900 train loss: 0.0370 valid loss: 0.1237, valid accuracy: 0.9640
# Iter-295000 train loss: 0.0670 valid loss: 0.1236, valid accuracy: 0.9646
# Iter-295100 train loss: 0.0634 valid loss: 0.1235, valid accuracy: 0.9646
# Iter-295200 train loss: 0.2038 valid loss: 0.1234, valid accuracy: 0.9640
# Iter-295300 train loss: 0.0550 valid loss: 0.1234, valid accuracy: 0.9638
# Iter-295400 train loss: 0.0636 valid loss: 0.1233, valid accuracy: 0.9646
# Iter-295500 train loss: 0.0716 valid loss: 0.1233, valid accuracy: 0.9644
# Iter-295600 train loss: 0.1670 valid loss: 0.1233, valid accuracy: 0.9644
# Iter-295700 train loss: 0.1909 valid loss: 0.1232, valid accuracy: 0.9646
# Iter-295800 train loss: 0.1766 valid loss: 0.1232, valid accuracy: 0.9638
# Iter-295900 train loss: 0.1184 valid loss: 0.1232, valid accuracy: 0.9644
# Iter-296000 train loss: 0.0346 valid loss: 0.1231, valid accuracy: 0.9642
# Iter-296100 train loss: 0.0781 valid loss: 0.1231, valid accuracy: 0.9646
# Iter-296200 train loss: 0.0857 valid loss: 0.1229, valid accuracy: 0.9646
# Iter-296300 train loss: 0.0987 valid loss: 0.1229, valid accuracy: 0.9646
# Iter-296400 train loss: 0.1051 valid loss: 0.1228, valid accuracy: 0.9648
# Iter-296500 train loss: 0.1273 valid loss: 0.1229, valid accuracy: 0.9648
# Iter-296600 train loss: 0.1079 valid loss: 0.1229, valid accuracy: 0.9648
# Iter-296700 train loss: 0.1138 valid loss: 0.1229, valid accuracy: 0.9648
# Iter-296800 train loss: 0.3093 valid loss: 0.1228, valid accuracy: 0.9648
# Iter-296900 train loss: 0.1385 valid loss: 0.1227, valid accuracy: 0.9650
# Iter-297000 train loss: 0.0741 valid loss: 0.1225, valid accuracy: 0.9644
# Iter-297100 train loss: 0.1297 valid loss: 0.1226, valid accuracy: 0.9644

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
