# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # layers
        self.C = C # classes
        self.losses = {'train':[], 'train_acc':[], 
                       'valid':[], 'valid_acc':[], 
                       'test':[], 'test_acc':[]}
        
        self.model = []
        self.W_fixed = []
        self.grads = []
        self.dy_prev = np.zeros((1, C))
        self.y_prev = np.zeros((1, C))
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad_L = []
        for _ in range(L):
            grad_L.append({key: np.zeros_like(val) for key, val in self.model[1][0].items()})
        self.grads.append(grad_L)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Output layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
        dX = dout @ W.T # vanilla Backprop
#         dX = dout @ W_fixed.T # fba backprop

        return dX, dW, db

    def train_forward(self, X, train):
        caches, ys = [], []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
        y, nl_cache = l.tanh_forward(X=y)
#         y, nl_cache = l.sigmoid_forward(X=y)
        if train:
            caches.append((fc_cache, nl_cache))
        X = y.copy() # pass to the next layer
        
        # Hidden layers
        fc_caches, nl_caches = [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
            y, nl_cache = l.tanh_forward(X=y)
#             y, nl_cache = l.sigmoid_forward(X=y)
            X = y.copy() # pass to next layer
            if train:
                fc_caches.append(fc_cache)
                nl_caches.append(nl_cache)
        if train:
            caches.append((fc_caches, nl_caches)) # caches[1]            
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        y_prob = l.softmax(X=y)
        if train:
            caches.append(fc_cache)

        return y_prob, caches # for backpropating the error

    def cross_entropy(self, y_prob, y_train):
        m = y_prob.shape[0]

        #         prob = l.softmax(y_pred)
        log_like = -np.log(y_prob[range(m), y_train] + l.eps) # to avoid the devision by zero
        data_loss = np.sum(log_like) / m

        return data_loss

    def dcross_entropy(self, y_prob, y_train): # this is equal for both since the reg_loss (noise) derivative is ZERO.
        m = y_prob.shape[0]

        #         grad_y = l.softmax(y_pred)
        grad_y = y_prob
        grad_y[range(m), y_train] -= 1.
        grad_y /= m

        return grad_y

    def loss_function(self, y_prob, y_train):
        
        loss = self.cross_entropy(y_prob, y_train) # softmax is included
        dy = self.dcross_entropy(y_prob, y_train) # dsoftmax is included

        return loss, dy
        
    def train_backward(self, dy, caches, y):
        grads = self.grads.copy() # initialized by Zero in every iteration/epoch
#         dy_prev = self.dy_prev.copy() # for temporal differencing
#         self.dy_prev = dy.copy() # next iteration/ epoch
#         y_prev = self.y_prev.copy() # for temporal differencing
#         self.y_prev = y.copy() # next iteration/ epoch
        
        # Output layer
        fc_cache = caches[2]
        # softmax_backward is included in dcross_entropy.
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
# #         dy =  dy @ self.W_fixed[2].T # done
#         dy_prev =  dy_prev @ self.W_fixed[2].T
#         y =  y @ self.W_fixed[2].T # done
#         y_prev =  y_prev @ self.W_fixed[2].T
        grads[2]['W'] = dW
        grads[2]['b'] = db

        # Hidden layer
        fc_caches, nl_caches = caches[1]
        for layer in reversed(range(self.L)):
            dy = l.tanh_backward(cache=nl_caches[layer], dout=dy) # diffable function
#             dy = l.sigmoid_backward(cache=nl_caches[layer], dout=dy) # diffable function
#             dy *= dy - dy_prev # temporal diff instead of differentiable function
#             dy *= y - y_prev # temporal diff instead of differentiable function
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
# #             dy =  dy @ self.W_fixed[2].T # done
#             dy_prev =  dy_prev @ self.W_fixed[1][layer].T
#             y =  y @ self.W_fixed[1][layer].T # done
#             y_prev =  y_prev @ self.W_fixed[1][layer].T
            grads[1][layer]['W'] = dW
            grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache, nl_cache = caches[0]
        dy = l.tanh_backward(cache=nl_cache, dout=dy) # diffable function
#         dy = l.sigmoid_backward(cache=nl_caches[layer], dout=dy) # diffable function
#         dy *= dy - dy_prev # temporal diff instead of differentiable function
#         dy *= y - y_prev # temporal diff instead of differentiable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        grads[0]['W'] = dW
        grads[0]['b'] = db

        return dX, grads
    
    def test(self, X):
        y_prob, _ = self.train_forward(X, train=False)
        
        # if self.mode == 'classification':
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_prob
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            y_prob, caches = self.train_forward(X_mini, train=True)
            _, dy = self.loss_function(y_prob, y_mini)
            _, grads = self.train_backward(dy, caches, y_prob)
            
            # Update the model for input layer
            for key in grads[0].keys():
                self.model[0][key] -= alpha * grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * grads[1][layer][key]

            # Update the model for output layer
            for key in grads[2].keys():
                self.model[2][key] -= alpha * grads[2][key]
            
            # Training accuracy
            y_pred, y_prob = self.test(X_mini)
            loss, _ = self.loss_function(y_prob, y_mini) # softmax is included in entropy loss function
            self.losses['train'].append(loss)
            acc = np.mean(y_pred == y_mini) # confusion matrix
            self.losses['train_acc'].append(acc)

            # Validate the updated model
            y_pred, y_prob = self.test(X_val)
            valid_loss, _ = self.loss_function(y_prob, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val) # confusion matrix
            self.losses['valid_acc'].append(valid_acc)
            
            # Test the final model
            y_pred, y_prob = nn.test(X_test)
            test_loss, _ = self.loss_function(y_prob, y_test) # softmax is included in entropy loss function
            self.losses['test'].append(test_loss)
            test_acc = np.mean(y_pred == y_test)
            self.losses['test_acc'].append(test_acc)
#             print('Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.
#             format(acc.mean(), acc.std(), loss))
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{}, train loss-{:.4f}, acc-{:.4f}, valid loss-{:.4f}, acc-{:.4f}, test loss-{:.4f}, acc-{:.4f}'.format(
                   iter, loss, acc, valid_loss, valid_acc, test_loss, test_acc))

# %%
# Hyper-parameters
n_iter = 1000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 50 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 10 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 2 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-10, train loss-2.3211, acc-0.1200, valid loss-2.3219, acc-0.0792, test loss-2.3225, acc-0.0729
# Iter-20, train loss-2.3300, acc-0.0800, valid loss-2.3182, acc-0.0856, test loss-2.3188, acc-0.0773
# Iter-30, train loss-2.3206, acc-0.0800, valid loss-2.3144, acc-0.0918, test loss-2.3150, acc-0.0833
# Iter-40, train loss-2.3271, acc-0.0400, valid loss-2.3108, acc-0.0992, test loss-2.3113, acc-0.0892
# Iter-50, train loss-2.3352, acc-0.0600, valid loss-2.3070, acc-0.1072, test loss-2.3074, acc-0.0955
# Iter-60, train loss-2.3264, acc-0.0600, valid loss-2.3032, acc-0.1142, test loss-2.3037, acc-0.1028
# Iter-70, train loss-2.3040, acc-0.1000, valid loss-2.2995, acc-0.1228, test loss-2.3000, acc-0.1119
# Iter-80, train loss-2.3018, acc-0.1200, valid loss-2.2959, acc-0.1318, test loss-2.2963, acc-0.1209
# Iter-90, train loss-2.3131, acc-0.1000, valid loss-2.2922, acc-0.1414, test loss-2.2926, acc-0.1330
# Iter-100, train loss-2.2653, acc-0.2000, valid loss-2.2891, acc-0.1520, test loss-2.2894, acc-0.1417
# Iter-110, train loss-2.3035, acc-0.1800, valid loss-2.2852, acc-0.1620, test loss-2.2854, acc-0.1539
# Iter-120, train loss-2.2739, acc-0.2200, valid loss-2.2818, acc-0.1696, test loss-2.2821, acc-0.1650
# Iter-130, train loss-2.3112, acc-0.1600, valid loss-2.2785, acc-0.1804, test loss-2.2788, acc-0.1766
# Iter-140, train loss-2.2829, acc-0.2200, valid loss-2.2751, acc-0.1918, test loss-2.2753, acc-0.1870
# Iter-150, train loss-2.2484, acc-0.2800, valid loss-2.2716, acc-0.2008, test loss-2.2717, acc-0.1992
# Iter-160, train loss-2.2538, acc-0.2200, valid loss-2.2680, acc-0.2104, test loss-2.2681, acc-0.2128
# Iter-170, train loss-2.2582, acc-0.1600, valid loss-2.2645, acc-0.2206, test loss-2.2646, acc-0.2230
# Iter-180, train loss-2.2507, acc-0.3600, valid loss-2.2610, acc-0.2298, test loss-2.2610, acc-0.2362
# Iter-190, train loss-2.2760, acc-0.2200, valid loss-2.2577, acc-0.2398, test loss-2.2578, acc-0.2454
# Iter-200, train loss-2.2636, acc-0.1800, valid loss-2.2544, acc-0.2488, test loss-2.2544, acc-0.2538
# Iter-210, train loss-2.2621, acc-0.1800, valid loss-2.2510, acc-0.2570, test loss-2.2510, acc-0.2617
# Iter-220, train loss-2.2688, acc-0.3000, valid loss-2.2474, acc-0.2668, test loss-2.2473, acc-0.2701
# Iter-230, train loss-2.2448, acc-0.2200, valid loss-2.2441, acc-0.2764, test loss-2.2440, acc-0.2789
# Iter-240, train loss-2.2237, acc-0.2800, valid loss-2.2409, acc-0.2812, test loss-2.2408, acc-0.2856
# Iter-250, train loss-2.2634, acc-0.2400, valid loss-2.2376, acc-0.2878, test loss-2.2375, acc-0.2925
# Iter-260, train loss-2.2017, acc-0.4400, valid loss-2.2343, acc-0.2974, test loss-2.2342, acc-0.2991
# Iter-270, train loss-2.2353, acc-0.3600, valid loss-2.2310, acc-0.3056, test loss-2.2309, acc-0.3095
# Iter-280, train loss-2.2154, acc-0.3200, valid loss-2.2277, acc-0.3114, test loss-2.2276, acc-0.3164
# Iter-290, train loss-2.2465, acc-0.3600, valid loss-2.2245, acc-0.3182, test loss-2.2243, acc-0.3222
# Iter-300, train loss-2.2286, acc-0.3400, valid loss-2.2213, acc-0.3242, test loss-2.2211, acc-0.3272
# Iter-310, train loss-2.2223, acc-0.3400, valid loss-2.2181, acc-0.3310, test loss-2.2179, acc-0.3309
# Iter-320, train loss-2.1929, acc-0.3600, valid loss-2.2147, acc-0.3378, test loss-2.2144, acc-0.3351
# Iter-330, train loss-2.2164, acc-0.3200, valid loss-2.2114, acc-0.3418, test loss-2.2112, acc-0.3415
# Iter-340, train loss-2.2307, acc-0.3000, valid loss-2.2082, acc-0.3466, test loss-2.2080, acc-0.3457
# Iter-350, train loss-2.2023, acc-0.3600, valid loss-2.2051, acc-0.3506, test loss-2.2048, acc-0.3501
# Iter-360, train loss-2.1925, acc-0.4800, valid loss-2.2019, acc-0.3538, test loss-2.2016, acc-0.3555
# Iter-370, train loss-2.2034, acc-0.3200, valid loss-2.1984, acc-0.3586, test loss-2.1981, acc-0.3608
# Iter-380, train loss-2.2084, acc-0.3400, valid loss-2.1951, acc-0.3602, test loss-2.1948, acc-0.3634
# Iter-390, train loss-2.1934, acc-0.4600, valid loss-2.1922, acc-0.3660, test loss-2.1918, acc-0.3671
# Iter-400, train loss-2.2338, acc-0.2800, valid loss-2.1889, acc-0.3686, test loss-2.1885, acc-0.3715
# Iter-410, train loss-2.1798, acc-0.4200, valid loss-2.1858, acc-0.3726, test loss-2.1854, acc-0.3769
# Iter-420, train loss-2.2016, acc-0.4000, valid loss-2.1827, acc-0.3770, test loss-2.1823, acc-0.3799
# Iter-430, train loss-2.1867, acc-0.4200, valid loss-2.1798, acc-0.3806, test loss-2.1794, acc-0.3829
# Iter-440, train loss-2.1723, acc-0.4000, valid loss-2.1771, acc-0.3842, test loss-2.1767, acc-0.3873
# Iter-450, train loss-2.1664, acc-0.4200, valid loss-2.1741, acc-0.3868, test loss-2.1737, acc-0.3894
# Iter-460, train loss-2.1656, acc-0.3400, valid loss-2.1710, acc-0.3920, test loss-2.1706, acc-0.3927
# Iter-470, train loss-2.1549, acc-0.4200, valid loss-2.1681, acc-0.3950, test loss-2.1677, acc-0.3953
# Iter-480, train loss-2.1611, acc-0.4600, valid loss-2.1651, acc-0.3970, test loss-2.1647, acc-0.3987
# Iter-490, train loss-2.1690, acc-0.4200, valid loss-2.1622, acc-0.3994, test loss-2.1617, acc-0.4012
# Iter-500, train loss-2.1402, acc-0.4200, valid loss-2.1590, acc-0.4028, test loss-2.1586, acc-0.4041
# Iter-510, train loss-2.1863, acc-0.3400, valid loss-2.1560, acc-0.4038, test loss-2.1555, acc-0.4068
# Iter-520, train loss-2.1682, acc-0.4000, valid loss-2.1529, acc-0.4076, test loss-2.1525, acc-0.4091
# Iter-530, train loss-2.1323, acc-0.4800, valid loss-2.1500, acc-0.4094, test loss-2.1495, acc-0.4121
# Iter-540, train loss-2.1553, acc-0.3400, valid loss-2.1470, acc-0.4122, test loss-2.1465, acc-0.4150
# Iter-550, train loss-2.1220, acc-0.4600, valid loss-2.1444, acc-0.4156, test loss-2.1439, acc-0.4191
# Iter-560, train loss-2.1592, acc-0.4400, valid loss-2.1414, acc-0.4160, test loss-2.1409, acc-0.4218
# Iter-570, train loss-2.1824, acc-0.2800, valid loss-2.1384, acc-0.4188, test loss-2.1379, acc-0.4236
# Iter-580, train loss-2.1432, acc-0.2800, valid loss-2.1357, acc-0.4212, test loss-2.1351, acc-0.4255
# Iter-590, train loss-2.1317, acc-0.4200, valid loss-2.1328, acc-0.4242, test loss-2.1322, acc-0.4274
# Iter-600, train loss-2.1235, acc-0.4600, valid loss-2.1297, acc-0.4254, test loss-2.1291, acc-0.4292
# Iter-610, train loss-2.0810, acc-0.5600, valid loss-2.1266, acc-0.4274, test loss-2.1260, acc-0.4302
# Iter-620, train loss-2.1324, acc-0.4200, valid loss-2.1237, acc-0.4290, test loss-2.1231, acc-0.4321
# Iter-630, train loss-2.0992, acc-0.5400, valid loss-2.1206, acc-0.4316, test loss-2.1200, acc-0.4343
# Iter-640, train loss-2.1224, acc-0.4400, valid loss-2.1180, acc-0.4346, test loss-2.1174, acc-0.4366
# Iter-650, train loss-2.1207, acc-0.4600, valid loss-2.1151, acc-0.4360, test loss-2.1145, acc-0.4374
# Iter-660, train loss-2.1184, acc-0.4800, valid loss-2.1123, acc-0.4366, test loss-2.1116, acc-0.4390
# Iter-670, train loss-2.0922, acc-0.4200, valid loss-2.1095, acc-0.4384, test loss-2.1088, acc-0.4406
# Iter-680, train loss-2.1186, acc-0.4800, valid loss-2.1066, acc-0.4394, test loss-2.1059, acc-0.4432
# Iter-690, train loss-2.1087, acc-0.4000, valid loss-2.1037, acc-0.4410, test loss-2.1030, acc-0.4440
# Iter-700, train loss-2.1133, acc-0.4200, valid loss-2.1009, acc-0.4428, test loss-2.1002, acc-0.4447
# Iter-710, train loss-2.0536, acc-0.5200, valid loss-2.0981, acc-0.4448, test loss-2.0974, acc-0.4468
# Iter-720, train loss-2.0671, acc-0.4600, valid loss-2.0954, acc-0.4454, test loss-2.0946, acc-0.4475
# Iter-730, train loss-2.0755, acc-0.5200, valid loss-2.0924, acc-0.4462, test loss-2.0917, acc-0.4493
# Iter-740, train loss-2.0910, acc-0.4000, valid loss-2.0895, acc-0.4462, test loss-2.0887, acc-0.4505
# Iter-750, train loss-2.0690, acc-0.5400, valid loss-2.0866, acc-0.4476, test loss-2.0859, acc-0.4521
# Iter-760, train loss-2.1029, acc-0.5400, valid loss-2.0840, acc-0.4488, test loss-2.0832, acc-0.4544
# Iter-770, train loss-2.1036, acc-0.4200, valid loss-2.0811, acc-0.4512, test loss-2.0803, acc-0.4560
# Iter-780, train loss-2.1139, acc-0.3800, valid loss-2.0782, acc-0.4524, test loss-2.0773, acc-0.4579
# Iter-790, train loss-2.0655, acc-0.4800, valid loss-2.0755, acc-0.4540, test loss-2.0746, acc-0.4602
# Iter-800, train loss-2.0774, acc-0.4200, valid loss-2.0728, acc-0.4548, test loss-2.0720, acc-0.4614
# Iter-810, train loss-2.0502, acc-0.4800, valid loss-2.0701, acc-0.4560, test loss-2.0692, acc-0.4628
# Iter-820, train loss-2.0506, acc-0.4600, valid loss-2.0672, acc-0.4588, test loss-2.0663, acc-0.4639
# Iter-830, train loss-2.0823, acc-0.4600, valid loss-2.0644, acc-0.4610, test loss-2.0636, acc-0.4659
# Iter-840, train loss-2.0363, acc-0.5200, valid loss-2.0615, acc-0.4626, test loss-2.0606, acc-0.4673
# Iter-850, train loss-2.0823, acc-0.3600, valid loss-2.0589, acc-0.4644, test loss-2.0580, acc-0.4692
# Iter-860, train loss-2.0914, acc-0.3400, valid loss-2.0562, acc-0.4664, test loss-2.0552, acc-0.4712
# Iter-870, train loss-2.0560, acc-0.4600, valid loss-2.0535, acc-0.4672, test loss-2.0525, acc-0.4726
# Iter-880, train loss-2.0290, acc-0.4200, valid loss-2.0507, acc-0.4684, test loss-2.0498, acc-0.4732
# Iter-890, train loss-2.0576, acc-0.3800, valid loss-2.0480, acc-0.4692, test loss-2.0470, acc-0.4737
# Iter-900, train loss-2.0653, acc-0.4000, valid loss-2.0453, acc-0.4704, test loss-2.0444, acc-0.4754
# Iter-910, train loss-2.0772, acc-0.4400, valid loss-2.0428, acc-0.4720, test loss-2.0418, acc-0.4774
# Iter-920, train loss-2.1078, acc-0.3600, valid loss-2.0402, acc-0.4740, test loss-2.0392, acc-0.4795
# Iter-930, train loss-2.0362, acc-0.4400, valid loss-2.0377, acc-0.4752, test loss-2.0367, acc-0.4808
# Iter-940, train loss-1.9886, acc-0.5600, valid loss-2.0349, acc-0.4768, test loss-2.0338, acc-0.4815
# Iter-950, train loss-2.0114, acc-0.5800, valid loss-2.0322, acc-0.4790, test loss-2.0312, acc-0.4826
# Iter-960, train loss-2.0405, acc-0.4800, valid loss-2.0294, acc-0.4800, test loss-2.0283, acc-0.4839
# Iter-970, train loss-2.0279, acc-0.5200, valid loss-2.0268, acc-0.4812, test loss-2.0257, acc-0.4856
# Iter-980, train loss-2.0138, acc-0.5400, valid loss-2.0241, acc-0.4824, test loss-2.0230, acc-0.4873
# Iter-990, train loss-2.0147, acc-0.5000, valid loss-2.0214, acc-0.4828, test loss-2.0203, acc-0.4870
# Iter-1000, train loss-1.9909, acc-0.5400, valid loss-2.0187, acc-0.4838, test loss-2.0176, acc-0.4870

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.plot(nn.losses['test'], label='Test loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['train_acc'], label='Train accuracy')
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.plot(nn.losses['test_acc'], label='Test accuracy')
plt.legend()
plt.show()
