# %%
# Data
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import impl.layer as l

# Dataset preparation and pre-processing
mnist = input_data.read_data_sets('data/MNIST_data/', one_hot=False)

X_train, y_train = mnist.train.images, mnist.train.labels
X_val, y_val = mnist.validation.images, mnist.validation.labels
X_test, y_test = mnist.test.images, mnist.test.labels
# y_test.shape, y_val.shape, y_train.shape
# X_train.shape, X_train.dtype, X_val.shape, X_val.dtype, X_test.shape, X_test.dtype
# Out:
# Extracting data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Pre-processing: normalizing
def normalize(X):
    # max scale for images 255= 2**8= 8 bit grayscale for each channel
    return (X - X.mean(axis=0)) #/ X.std(axis=0)

X_train, X_val, X_test = normalize(X=X_train), normalize(X=X_val), normalize(X=X_test)

# %%
# Model
import impl.layer as l # or from impl.layer import *
from impl.loss import * # import all functions from impl.loss file # import impl.loss as loss_func
from sklearn.utils import shuffle as skshuffle

class FFNN:

    def __init__(self, D, C, H, L):
        self.L = L # number of layers or depth
        self.losses = {'train':[], 'valid':[], 'valid_acc':[]}
        
        # The adaptive/learnable/updatable random feedforward
        self.model = []
        self.W_fixed = []
        self.grads = []
        self.ys_prev = []
        low, high = -1, 1
        
        # Input layer: weights/ biases
        m = dict(W=np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.), b=np.zeros((1, H)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(D, H), low=low, high=high) / np.sqrt(D / 2.)
        self.W_fixed.append(m)
        # Input layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[0].items()})
        # Previous output layer
        self.ys_prev.append(0.0)

        # Hidden layers: weights/ biases
        m_L = []
        for _ in range(L):
            m = dict(W=np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, H)))
            m_L.append(m)
        self.model.append(m_L)
        # Fixed feedback weight
        m_L = []
        for _ in range(L):
            m = np.random.uniform(size=(H, H), low=low, high=high) / np.sqrt(H / 2.)
            m_L.append(m)
        self.W_fixed.append(m_L)
        # Hidden layer: gradients
        grad_L = []
        for _ in range(L):
            grad_L.append({key: np.zeros_like(val) for key, val in self.model[1][0].items()})
        self.grads.append(grad_L)
        # Previous output layer
        ys_prev_L = []
        for _ in range(L):
            ys_prev_L.append(0.0)
        self.ys_prev.append(ys_prev_L)
        
        # Output layer: weights/ biases
        m = dict(W=np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.), b=np.zeros((1, C)))
        self.model.append(m)
        # Fixed feedback weight
        m = np.random.uniform(size=(H, C), low=low, high=high) / np.sqrt(H / 2.)
        self.W_fixed.append(m)
        # Outout layer: gradients
        self.grads.append({key: np.zeros_like(val) for key, val in self.model[2].items()})
        # Previous output layer
        self.ys_prev.append(0.0)
        
    def fc_forward(self, X, W, b):
        out = (X @ W) + b
        cache = (W, X)
        return out, cache

    def fc_backward(self, dout, cache, W_fixed):
        W, X = cache

        dW = X.T @ dout
        db = np.sum(dout, axis=0).reshape(1, -1) # db_1xn
        
        # dX = dout @ W.T # Backprop
        dX = dout @ W_fixed.T # fb alignment

        return dX, dW, db

    def train_forward(self, X, train):
        caches, ys = [], []
        
        # Input layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[0]['W'], b=self.model[0]['b']) # X_1xD, y_1xc
        y, _ = l.selu_forward(X=y)
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[0]
        X = y.copy() # pass to the next layer
        
        # Hidden layers
        fc_caches, ys_L, do_caches = [], [], []
        for layer in range(self.L):
            y, fc_cache = self.fc_forward(X=X, W=self.model[1][layer]['W'], b=self.model[1][layer]['b'])
            y, _ = l.selu_forward(X=y)
            fc_caches.append(fc_cache)
            ys_L.append(y) # ys[1][layer]
            X = y.copy() # pass to next layer
        if train:
            caches.append(fc_caches) # caches[1]
        ys.append(ys_L) # ys[1]            
        
        # Output layer
        y, fc_cache = self.fc_forward(X=X, W=self.model[2]['W'], b=self.model[2]['b'])
        if train:
            caches.append(fc_cache)
        ys.append(y) # ys[2]

        return ys, caches # for backpropating the error

    def loss_function(self, y, y_train):
        
        loss = cross_entropy(y, y_train) # softmax is included
        dy = dcross_entropy(y, y_train) # dsoftmax is included
        
        return loss, dy
        
    def train_backward(self, dy, caches):
        grads = self.grads # initialized by Zero in every iteration/epoch
        ys, ys_prev = self.ys, self.ys_prev # temporal diff instead of differentiable function
        
        # Output layer
        fc_cache = caches[2]
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[2])
        dy = dX.copy()
        grads[2]['W'] = dW
        grads[2]['b'] = db

        # Hidden layer
        fc_caches = caches[1]
        for layer in reversed(range(self.L)):
            dy *= ys[1][layer] - ys_prev[1][layer] # temporal diff instead of differentiable function
            dX, dW, db = self.fc_backward(dout=dy, cache=fc_caches[layer], W_fixed=self.W_fixed[1][layer])
            dy = dX.copy()
            grads[1][layer]['W'] = dW
            grads[1][layer]['b'] = db
        
        # Input layer
        fc_cache = caches[0]
        dy *= ys[0] - ys_prev[0] # temporal diff instead of differentiable function
        dX, dW, db = self.fc_backward(dout=dy, cache=fc_cache, W_fixed=self.W_fixed[0])
        grads[0]['W'] = dW
        grads[0]['b'] = db

        return dX, grads
    
    def test(self, X):
        ys_logit, _ = self.train_forward(X, train=False)
        y_logit = ys_logit[2] # last layer
        
        # if self.mode == 'classification':
        y_prob = l.softmax(y_logit) # for accuracy == acc
        y_pred = np.argmax(y_prob, axis=1) # for loss ==err
        
        return y_pred, y_logit
        
    def get_minibatch(self, X, y, minibatch_size, shuffle):
        minibatches = []

        if shuffle:
            X, y = skshuffle(X, y)

        for i in range(0, X.shape[0], minibatch_size):
            X_mini = X[i:i + minibatch_size]
            y_mini = y[i:i + minibatch_size]
            minibatches.append((X_mini, y_mini))

        return minibatches

    def sgd(self, train_set, val_set, alpha, mb_size, n_iter, print_after):
        X_train, y_train = train_set
        X_val, y_val = val_set

        # Epochs
        for iter in range(1, n_iter + 1):

            # Minibatches
            minibatches = self.get_minibatch(X_train, y_train, mb_size, shuffle=True)
            idx = np.random.randint(0, len(minibatches))
            X_mini, y_mini = minibatches[idx]
            
            # Train the model
            self.ys, caches = self.train_forward(X_mini, train=True)
            loss, dy = self.loss_function(self.ys[2], y_mini)
            _, grads = self.train_backward(dy, caches) # self.ys_prev is used here for dfunc/ diff
            self.ys_prev = self.ys # for next iteration or epoch
            self.losses['train'].append(loss)
            
            # Update the model for input layer
            for key in grads[0].keys():
                self.model[0][key] -= alpha * grads[0][key]

            # Update the model for the hidden layers
            for layer in range(self.L):
                for key in grads[1][layer].keys():
                    self.model[1][layer][key] -= alpha * grads[1][layer][key]

            # Update the model for output layer
            for key in grads[2].keys():
                self.model[2][key] -= alpha * grads[2][key]
                
            # Validate the updated model
            y_pred, y_logit = self.test(X_val)
            valid_loss, _ = self.loss_function(y_logit, y_val) # softmax is included in entropy loss function
            self.losses['valid'].append(valid_loss)
            valid_acc = np.mean(y_pred == y_val) # confusion matrix
            self.losses['valid_acc'].append(valid_acc)
            
            # Print the model info: loss & accuracy or err & acc
            if iter % print_after == 0:
                print('Iter-{} train loss: {:.4f} valid loss: {:.4f}, valid accuracy: {:.4f}'.format(
                    iter, loss, valid_loss, valid_acc))

        # Test the final model
        y_pred, y_logit = nn.test(X_test)
        loss, _ = self.loss_function(y_logit, y_test) # softmax is included in entropy loss function
        acc = np.mean(y_pred == y_test)
        print('Last iteration - Test accuracy mean: {:.4f}, std: {:.4f}, loss: {:.4f}'.format(
            acc.mean(), acc.std(), loss))

# %%
# Hyper-parameters
n_iter = 1000 # number of epochs
alpha = 1e-3 # learning_rate
mb_size = 50 # 2**10==1024 # width, timestep for sequential data or minibatch size
print_after = 10 # n_iter//10 # print loss for train, valid, and test
num_hidden_units = 32 # number of kernels/ filters in each layer
num_input_units = X_train.shape[1] # noise added at the input lavel as input noise we can use dX or for more improvement
num_output_units = y_train.max() + 1 # number of classes in this classification problem
num_layers = 100 # depth 

# Build the model/NN and learn it: running session.
nn = FFNN(C=num_output_units, D=num_input_units, H=num_hidden_units, L=num_layers)

nn.sgd(train_set=(X_train, y_train), val_set=(X_val, y_val), mb_size=mb_size, alpha=alpha, 
           n_iter=n_iter, print_after=print_after)
# Out:
# Iter-10 train loss: 2.3368 valid loss: 2.3179, valid accuracy: 0.1286
# Iter-20 train loss: 2.3444 valid loss: 2.3175, valid accuracy: 0.1288
# Iter-30 train loss: 2.4104 valid loss: 2.3169, valid accuracy: 0.1278
# Iter-40 train loss: 2.2629 valid loss: 2.3164, valid accuracy: 0.1284
# Iter-50 train loss: 2.3706 valid loss: 2.3160, valid accuracy: 0.1282
# Iter-60 train loss: 2.3265 valid loss: 2.3157, valid accuracy: 0.1284
# Iter-70 train loss: 2.2645 valid loss: 2.3152, valid accuracy: 0.1276
# Iter-80 train loss: 2.2813 valid loss: 2.3147, valid accuracy: 0.1264
# Iter-90 train loss: 2.2900 valid loss: 2.3143, valid accuracy: 0.1268
# Iter-100 train loss: 2.3213 valid loss: 2.3139, valid accuracy: 0.1254
# Iter-110 train loss: 2.2700 valid loss: 2.3134, valid accuracy: 0.1244
# Iter-120 train loss: 2.2774 valid loss: 2.3128, valid accuracy: 0.1246
# Iter-130 train loss: 2.2520 valid loss: 2.3123, valid accuracy: 0.1244
# Iter-140 train loss: 2.3199 valid loss: 2.3119, valid accuracy: 0.1248
# Iter-150 train loss: 2.3409 valid loss: 2.3115, valid accuracy: 0.1244
# Iter-160 train loss: 2.3694 valid loss: 2.3110, valid accuracy: 0.1246
# Iter-170 train loss: 2.3354 valid loss: 2.3107, valid accuracy: 0.1246
# Iter-180 train loss: 2.3564 valid loss: 2.3103, valid accuracy: 0.1242
# Iter-190 train loss: 2.2655 valid loss: 2.3100, valid accuracy: 0.1246
# Iter-200 train loss: 2.2909 valid loss: 2.3097, valid accuracy: 0.1240
# Iter-210 train loss: 2.3581 valid loss: 2.3093, valid accuracy: 0.1242
# Iter-220 train loss: 2.2551 valid loss: 2.3090, valid accuracy: 0.1240
# Iter-230 train loss: 2.4474 valid loss: 2.3086, valid accuracy: 0.1240
# Iter-240 train loss: 2.3217 valid loss: 2.3084, valid accuracy: 0.1240
# Iter-250 train loss: 2.3272 valid loss: 2.3080, valid accuracy: 0.1238
# Iter-260 train loss: 2.2904 valid loss: 2.3077, valid accuracy: 0.1238
# Iter-270 train loss: 2.2913 valid loss: 2.3072, valid accuracy: 0.1236
# Iter-280 train loss: 2.3740 valid loss: 2.3068, valid accuracy: 0.1238
# Iter-290 train loss: 2.2836 valid loss: 2.3065, valid accuracy: 0.1236
# Iter-300 train loss: 2.2562 valid loss: 2.3061, valid accuracy: 0.1236
# Iter-310 train loss: 2.2957 valid loss: 2.3058, valid accuracy: 0.1236
# Iter-320 train loss: 2.3064 valid loss: 2.3055, valid accuracy: 0.1234
# Iter-330 train loss: 2.3394 valid loss: 2.3051, valid accuracy: 0.1234
# Iter-340 train loss: 2.3248 valid loss: 2.3048, valid accuracy: 0.1234
# Iter-350 train loss: 2.3537 valid loss: 2.3045, valid accuracy: 0.1234
# Iter-360 train loss: 2.3334 valid loss: 2.3041, valid accuracy: 0.1234
# Iter-370 train loss: 2.2887 valid loss: 2.3038, valid accuracy: 0.1234
# Iter-380 train loss: 2.3061 valid loss: 2.3035, valid accuracy: 0.1232
# Iter-390 train loss: 2.3133 valid loss: 2.3032, valid accuracy: 0.1230
# Iter-400 train loss: 2.3422 valid loss: 2.3028, valid accuracy: 0.1230
# Iter-410 train loss: 2.2874 valid loss: 2.3025, valid accuracy: 0.1230
# Iter-420 train loss: 2.4200 valid loss: 2.3022, valid accuracy: 0.1228
# Iter-430 train loss: 2.3514 valid loss: 2.3018, valid accuracy: 0.1230
# Iter-440 train loss: 2.3360 valid loss: 2.3014, valid accuracy: 0.1228
# Iter-450 train loss: 2.3089 valid loss: 2.3011, valid accuracy: 0.1228
# Iter-460 train loss: 2.2560 valid loss: 2.3008, valid accuracy: 0.1228
# Iter-470 train loss: 2.3282 valid loss: 2.3005, valid accuracy: 0.1228
# Iter-480 train loss: 2.2826 valid loss: 2.3001, valid accuracy: 0.1230
# Iter-490 train loss: 2.2890 valid loss: 2.2997, valid accuracy: 0.1228
# Iter-500 train loss: 2.3278 valid loss: 2.2995, valid accuracy: 0.1228
# Iter-510 train loss: 2.3956 valid loss: 2.2991, valid accuracy: 0.1228
# Iter-520 train loss: 2.2899 valid loss: 2.2988, valid accuracy: 0.1226
# Iter-530 train loss: 2.2949 valid loss: 2.2986, valid accuracy: 0.1226
# Iter-540 train loss: 2.3077 valid loss: 2.2985, valid accuracy: 0.1226
# Iter-550 train loss: 2.2734 valid loss: 2.2982, valid accuracy: 0.1222
# Iter-560 train loss: 2.3244 valid loss: 2.2980, valid accuracy: 0.1226
# Iter-570 train loss: 2.3135 valid loss: 2.2979, valid accuracy: 0.1230
# Iter-580 train loss: 2.3283 valid loss: 2.2977, valid accuracy: 0.1230
# Iter-590 train loss: 2.3223 valid loss: 2.2975, valid accuracy: 0.1224
# Iter-600 train loss: 2.3625 valid loss: 2.2972, valid accuracy: 0.1226
# Iter-610 train loss: 2.3446 valid loss: 2.2969, valid accuracy: 0.1224
# Iter-620 train loss: 2.3234 valid loss: 2.2966, valid accuracy: 0.1224
# Iter-630 train loss: 2.2973 valid loss: 2.2964, valid accuracy: 0.1224
# Iter-640 train loss: 2.2544 valid loss: 2.2962, valid accuracy: 0.1226
# Iter-650 train loss: 2.2952 valid loss: 2.2960, valid accuracy: 0.1224
# Iter-660 train loss: 2.2733 valid loss: 2.2958, valid accuracy: 0.1224
# Iter-670 train loss: 2.2873 valid loss: 2.2956, valid accuracy: 0.1224
# Iter-680 train loss: 2.3161 valid loss: 2.2953, valid accuracy: 0.1224
# Iter-690 train loss: 2.2894 valid loss: 2.2951, valid accuracy: 0.1224
# Iter-700 train loss: 2.2792 valid loss: 2.2950, valid accuracy: 0.1224
# Iter-710 train loss: 2.2724 valid loss: 2.2947, valid accuracy: 0.1222
# Iter-720 train loss: 2.3157 valid loss: 2.2944, valid accuracy: 0.1220
# Iter-730 train loss: 2.2661 valid loss: 2.2942, valid accuracy: 0.1220
# Iter-740 train loss: 2.3114 valid loss: 2.2940, valid accuracy: 0.1220
# Iter-750 train loss: 2.3134 valid loss: 2.2938, valid accuracy: 0.1220
# Iter-760 train loss: 2.2855 valid loss: 2.2936, valid accuracy: 0.1220
# Iter-770 train loss: 2.3514 valid loss: 2.2934, valid accuracy: 0.1222
# Iter-780 train loss: 2.2700 valid loss: 2.2932, valid accuracy: 0.1224
# Iter-790 train loss: 2.2980 valid loss: 2.2930, valid accuracy: 0.1224
# Iter-800 train loss: 2.3338 valid loss: 2.2927, valid accuracy: 0.1224
# Iter-810 train loss: 2.2564 valid loss: 2.2926, valid accuracy: 0.1214
# Iter-820 train loss: 2.2688 valid loss: 2.2923, valid accuracy: 0.1214
# Iter-830 train loss: 2.3231 valid loss: 2.2921, valid accuracy: 0.1214
# Iter-840 train loss: 2.3187 valid loss: 2.2919, valid accuracy: 0.1214
# Iter-850 train loss: 2.2852 valid loss: 2.2917, valid accuracy: 0.1214
# Iter-860 train loss: 2.3556 valid loss: 2.2915, valid accuracy: 0.1212
# Iter-870 train loss: 2.3052 valid loss: 2.2914, valid accuracy: 0.1214
# Iter-880 train loss: 2.2285 valid loss: 2.2911, valid accuracy: 0.1212
# Iter-890 train loss: 2.3103 valid loss: 2.2909, valid accuracy: 0.1218
# Iter-900 train loss: 2.2565 valid loss: 2.2907, valid accuracy: 0.1224
# Iter-910 train loss: 2.3164 valid loss: 2.2905, valid accuracy: 0.1226
# Iter-920 train loss: 2.3006 valid loss: 2.2904, valid accuracy: 0.1228
# Iter-930 train loss: 2.2623 valid loss: 2.2903, valid accuracy: 0.1230
# Iter-940 train loss: 2.3001 valid loss: 2.2901, valid accuracy: 0.1228
# Iter-950 train loss: 2.3369 valid loss: 2.2900, valid accuracy: 0.1244
# Iter-960 train loss: 2.3074 valid loss: 2.2898, valid accuracy: 0.1258
# Iter-970 train loss: 2.3176 valid loss: 2.2896, valid accuracy: 0.1272
# Iter-980 train loss: 2.2988 valid loss: 2.2895, valid accuracy: 0.1258
# Iter-990 train loss: 2.2654 valid loss: 2.2894, valid accuracy: 0.1282
# Iter-1000 train loss: 2.2640 valid loss: 2.2892, valid accuracy: 0.1278
# Last iteration - Test accuracy mean: 0.1278, std: 0.0000, loss: 2.2944

# %%
# # Display the learning curve and losses for training, validation, and testing
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.plot(nn.losses['train'], label='Train loss')
plt.plot(nn.losses['valid'], label='Valid loss')
plt.legend()
plt.show()

# %%
plt.plot(nn.losses['valid_acc'], label='Valid accuracy')
plt.legend()
plt.show()
