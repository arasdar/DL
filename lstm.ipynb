# %%
import sys
import numpy as np
# import impl.neuralnet as nn
# import impl.RNN as rnn
import impl.LSTM as lstm
import impl.solver as solver

# %%
time_step = 10
n_iter = 1000000 # epochs
alpha = 1e-3
print_after = 1000
H = 64

# %%
# if __name__ == '__main__':
with open('data/text_data/japan.txt', 'r') as f:
    txt = f.read()

    X = []
    y = []

    char_to_idx = {char: i for i, char in enumerate(set(txt))}
    idx_to_char = {i: char for i, char in enumerate(set(txt))}

    X = np.array([char_to_idx[x] for x in txt])
    y = [char_to_idx[x] for x in txt[1:]]
    y.append(char_to_idx['.'])
    y = np.array(y)

# %%
vocab_size = len(char_to_idx)

# %%
net = lstm.LSTM(vocab_size, H=H, char2idx=char_to_idx, idx2char=idx_to_char)
# net = nn.RNN(vocab_size, H=H, char2idx=char_to_idx, idx2char=idx_to_char)
# net = rnn.RNN(vocab_size, H=H, char2idx=char_to_idx, idx2char=idx_to_char)
# net = nn.GRU(vocab_size, H=H, char2idx=char_to_idx, idx2char=idx_to_char)

# %%
solver.adam_rnn(
    net, X, y,
    alpha=alpha,
    mb_size=time_step,
    n_iter=n_iter,
    print_after=print_after
)
# Out:
# =========================================================================
# Iter-1000 loss: 3.4521
# =========================================================================
#  on6 mhst cunito nihetseth an intiter onIe end Eorr iins topoarsrige 9ip, ains elsle t falpia cthisa
# =========================================================================
#
#
# =========================================================================
# Iter-2000 loss: 2.8242
# =========================================================================
# o shh ind ihits Japan Ca ia, is theol fimd as chor che mwisI heyiOts mpaleron berlind , th Ch iru, I
# =========================================================================
#
#
# =========================================================================
# Iter-3000 loss: 2.4284
# =========================================================================
# rte Hfrte cite Ninlittory Tiona, Napawest ac as n"stand Ailaf isind iolithy inkme parled as iitt ty
# =========================================================================
#
#
# =========================================================================
# Iter-4000 loss: 2.1619
# =========================================================================
# u.ro7 canlekiclcines alatirnt . the wed of Japaakes. msourly An Jppnen'" CJapan, The vio tF finst ma
# =========================================================================
#
#
# =========================================================================
# Iter-5000 loss: 1.9665
# =========================================================================
# contory CAsiche 1691 K5 core in of Japanges- venth percacand Fisst rekedibere Wete ,byd 4xgiton waed
# =========================================================================
#
#
# =========================================================================
# Iter-6000 loss: 1.8198
# =========================================================================
# orien, malletoun Toretofin 9uroy Naine gesouraowhind indem in rde Aesterzen Ajithe and Tolateo, hast
# =========================================================================
#
#
# =========================================================================
# Iter-7000 loss: 1.6856
# =========================================================================
# a eg hilagyonh as cydes. the the zarlg sistoledaxt beniselovintan the worlald wess. f-lucateo foicty
# =========================================================================
#
#
# =========================================================================
# Iter-8000 loss: 1.5690
# =========================================================================
# in8rl vemexdexpante- as reno horaons of th ont. high nor, in8, War bac eas in the cruntyBingusE the
# =========================================================================
#
#
# =========================================================================
# Iter-9000 loss: 1.4613
# =========================================================================
# st micintDofendlar ala high-of mhenwas a the nmaled Woftitas ve8 Akomfeined in 1Jaand wac the sfra t
# =========================================================================
#
#
# =========================================================================
# Iter-10000 loss: 1.3779
# =========================================================================
#  Japan te 10.–. Tie cape enge cofent orea 18, .", un"by wecthe and 4Ematnir gurgest lemati nan inmlr
# =========================================================================
#
#
# =========================================================================
# Iter-11000 loss: 1.2903
# =========================================================================
# res P meat. Ther mikusky mesiter ol al1 Thien a dicanaig ariod in iolsogsico ofiry essing and owith
# =========================================================================
#
#
# =========================================================================
# Iter-12000 loss: 1.2169
# =========================================================================
#  world's fomutalicaness. Homyly wat of N5635, Japan was atlerist Wirgatt Okarled Warg Naa the alican
# =========================================================================
#
#
# =========================================================================
# Iter-13000 loss: 1.1516
# =========================================================================
#  G7, ty oa Japan rease hdesturalangeglomunily. The Rust pirith mfokom thind Silo-Japan ensh arestore
# =========================================================================
#
#
# =========================================================================
# Iter-14000 loss: 1.0873
# =========================================================================
# s woth edase Hatstated ow tho Eassy 7e copela ind in erea. Japan ind coleater hised intu alled lPea
# =========================================================================
#
#
# =========================================================================
# Iter-15000 loss: 1.0244
# =========================================================================
# iont. Shakes, whish canch pomaly 2015––f116th calete tbed in the a C9tent Si19te incicturest enjokyo
# =========================================================================
#
#
# =========================================================================
# Iter-16000 loss: 0.9732
# =========================================================================
#  Stanered inte pourtaly hisict recture end frlasician aide's tat Cal seatur, the Eountr-alen Indto e
# =========================================================================
#
#
# =========================================================================
# Iter-17000 loss: 0.9317
# =========================================================================
# th eagest pirreagreg forth came conacly Dumbluled cinoly of olyiStan mountry Japand isinar the worll
# =========================================================================
#
#
# =========================================================================
# Iter-18000 loss: 0.8868
# =========================================================================
# ry shigl roferlarit 1868, Ja, ed, is and Ruas. Treaced beclalimed, forch in the warly who oulation,
# =========================================================================
#
#
# =========================================================================
# Iter-19000 loss: 0.8399
# =========================================================================
# ion, which rat of is thold of istonfrre tho ergily firat if the Omimlicicaly in eijo y. Japanese sof
# =========================================================================
#
#
# =========================================================================
# Iter-20000 loss: 0.7977
# =========================================================================
#  okith and Omppal owor and Rusido Japan taichand fourlloline rofert in the countrinly nmamy of hight
# =========================================================================
#
#
# =========================================================================
# Iter-21000 loss: 0.7657
# =========================================================================
# nd ankeal fiom the Gr, and World Wan the fourth mlkaod Japanesituranalowiracins, marcimelichalarud r
# =========================================================================
#
#
# =========================================================================
# Iter-22000 loss: 0.7335
# =========================================================================
# Wrretloff tobe cal in the Emperor ChilalD, mecias in the thirs The worlPd a firs il the Seac in the
# =========================================================================
#
#
# =========================================================================
# Iter-23000 loss: 0.6973
# =========================================================================
#  torea. The nouutly . Abomellation wat the promed The Glata. Tyw. In Ni3akzind inlaidutise I dedind
# =========================================================================
#
#
# =========================================================================
# Iter-24000 loss: 0.6538
# =========================================================================
# ats of the torlld indexthe forld forad Tokyo Indea as ang the narterin". Japan Pas eagsto and the na
# =========================================================================
# =========================================================================
# Iter-25000 loss: 0.6396
# =========================================================================
# rid on inled toked loferd Japan has ar and World War II Japan is oftrd lofe in fiol the world's erga
# =========================================================================
#
#
# =========================================================================
# Iter-26000 loss: 0.6081
# =========================================================================
#  in the Empiot on a the pectesono. Hupand in the nambes. Japan en, reetorl silatation in 1868 and th
# =========================================================================
#
#
# =========================================================================
# Iter-27000 loss: 0.5662
# =========================================================================
# history teviof she soust in bym in the nurtoric Osuve nasa ranction. Toky piomtity y agst cores. In
# =========================================================================
#
#
# =========================================================================
# Iter-28000 loss: 0.5371
# =========================================================================
# ve confechal Countro was th larited intir eashe poflitarest of Japan was hino"S and Taity of China,
# =========================================================================
#
#
# =========================================================================
# Iter-29000 loss: 0.5243
# =========================================================================
# ielal Gnwan, Utich tamero the forldd f rutaty fwor defecengsour has eachalimant a 1es. The Uxparl vi
# =========================================================================
#
#
# =========================================================================
# Iter-30000 loss: 0.5027
# =========================================================================
# fWWed in the world, and Shaged hogytorud io Eas as reccered Seato intrentere Eus of 16 an the aromal
# =========================================================================
#
#
# =========================================================================
# Iter-31000 loss: 0.4789
# =========================================================================
# ainesy hixth chighs enfrigh greromall insina reete of inkerd Conity, the "Lan expale courturity as t
# =========================================================================
#
#
# =========================================================================
# Iter-32000 loss: 0.4497
# =========================================================================
# kkaido, Kyur peaped in the hats of Japan is a shire Hoguan, a merba win the surth-largesturencant Si
# =========================================================================
#
#
# =========================================================================
# Iter-33000 loss: 0.4440
# =========================================================================
# , the 120 a bopal of Woved in 1853 whe deollowwina, re moly ination of 126 milatitution in the O37 o
# =========================================================================
#
#
# =========================================================================
# Iter-34000 loss: 0.4204
# =========================================================================
# m. War I peliod lfonden Nounat ontunati. Arpea, couninfeces Tokyo pand is Chochegstored in the deven
# =========================================================================
#
#
# =========================================================================
# Iter-35000 loss: 0.4174
# =========================================================================
# rea the wothd over wast a meicicyss wom. Apkeopila agg, is rohokoku, freated in 1947 prom cinlurecan
# =========================================================================
#
#
# =========================================================================
# Iter-36000 loss: 0.3992
# =========================================================================
# f doved ind Shukeoku, "State of Japan") is the high sexmill bolutit it of Japane eap chigo, sivigsta
# =========================================================================
#
#
# =========================================================================
# Iter-37000 loss: 0.3896
# =========================================================================
# Asia. Japan is a ured of Japen, which ingited its renclurod inctand into an the Wisto Niclani an Nie
# =========================================================================
#
#
# =========================================================================
# Iter-38000 loss: 0.4008
# =========================================================================
# stith the 19th an a, thi Seaje intenf utit ou hest aid oflled and ankeed of Japanese Wand Seaeang of
# =========================================================================
#
#
# =========================================================================
# Iter-39000 loss: 0.3678
# =========================================================================
# enturyP 19th and Thokokokus man end. The fourtrl lare as toxad is the ulater that minl to the Ease I
# =========================================================================
#
#
# =========================================================================
# Iter-40000 loss: 0.3419
# =========================================================================
# ht Chig the Paled in the name ot inland the G8, and "t engina med cokutation "Sino-yomalaid of lalat
# =========================================================================
#
#
# =========================================================================
# Iter-41000 loss: 0.3477
# =========================================================================
# n a morlationd pinintry secinoy of the histo nigh s arompome make up 9215%of in liesins ran ad count
# =========================================================================
#
#
# =========================================================================
# Iter-42000 loss: 0.3363
# =========================================================================
# ced in 1947, Japan was unded of 1853 hegest, gith in the Fins in the Emperor as a dovine severed ton
# =========================================================================
#
#
# =========================================================================
# Iter-43000 loss: 0.3191
# =========================================================================
# na, "Statered Japan was incteanising peritesty. Japan last dend Seakiopgith leadinglethed ankutuding
# =========================================================================
#
#
# =========================================================================
# Iter-44000 loss: 0.3262
# =========================================================================
# . Nith the world's largest metropolitan saped figlst in the Cound, wh mambe Wogsth largest ctetrd of
# =========================================================================
#
#
# =========================================================================
# Iter-45000 loss: 0.3241
# =========================================================================
# d Japan was to peand Aprrofeet Indec worid the world's elapesthe civel reaterud and the world's four
# =========================================================================
#
#
# =========================================================================
# Iter-46000 loss: 0.3119
# =========================================================================
# t of 126 million resided fithd histo nenjry war and the worly sictard of Japan's total miter boge. J
# =========================================================================
#
#
# =========================================================================
# Iter-47000 loss: 0.2852
# =========================================================================
# icolutic ant in the Palidest exproulundest icityes of Japan") is thetsk withe fepreal rigster. Japan
# =========================================================================
#
#
# =========================================================================
# Iter-48000 loss: 0.2714
# =========================================================================
# tely 9.1 millicipan east encutes of Japan's total po mally tha n uplunas, the Sea of Okhold, thity p
# =========================================================================
# =========================================================================
# Iter-49000 loss: 0.2913
# =========================================================================
#  with a high strand is chse morth ar the Global countal G7 Okheacing area in Chiea, which includes P
# =========================================================================
#
#
# =========================================================================
# Iter-50000 loss: 0.2745
# =========================================================================
# st rand incites. Japan is caund its resthed indoxperrd's the world's eforly., The foric aty2 y mecia
# =========================================================================
#
#
# =========================================================================
# Iter-51000 loss: 0.2641
# =========================================================================
# el Pease if oflis regions, maintaingmpered period of firond of the world's tentexthe capetorowma loe
# =========================================================================
#
#
# =========================================================================
# Iter-52000 loss: 0.2659
# =========================================================================
# ty ofra chus is the world's tantexped conso and Wist ronkod silation in the Past minetsy is a dovide
# =========================================================================
#
#
# =========================================================================
# Iter-53000 loss: 0.2513
# =========================================================================
# aness largest iconyid fourth largss upmpiop an elfond righgith, with of copenityy whr har ") istary
# =========================================================================
#
#
# =========================================================================
# Iter-54000 loss: 0.2581
# =========================================================================
# myyb mbinoy of riglan, mailetion of1st conotitutic pies s aturd in the First Sino-Japanese ma a mola
# =========================================================================
#
#
# =========================================================================
# Iter-55000 loss: 0.2356
# =========================================================================
# wo decades ipled as the largest imollean, world's largest miricy as run. is anfets. The from the 1st
# =========================================================================
#
#
# =========================================================================
# Iter-56000 loss: 0.2395
# =========================================================================
# e world's tar thigh s a declare saith prant uranare War the Global Peaced its rupetionec and mpeat J
# =========================================================================
#
#
# =========================================================================
# Iter-57000 loss: 0.2292
# =========================================================================
# ihon-koku, which marima lidesexceall regical, its wust vofeithd regichimas to the UN, migity pecmabe
# =========================================================================
#
#
# =========================================================================
# Iter-58000 loss: 0.2209
# =========================================================================
#  poperchales Index a divine symbol of are Houst of Japan is a strtr. The country Brand Initter Aeget
# =========================================================================
#
#
# =========================================================================
# Iter-59000 loss: 0.2312
# =========================================================================
# eiji Emperored Japan has offillare sulopfiod in the First Sinfr ted tourd. The fourth-largest econom
# =========================================================================
#
#
# =========================================================================
# Iter-60000 loss: 0.2111
# =========================================================================
# ch includes Tokyigat of Japan's total popilation of 126 milliowes live largest importarlal poprod on
# =========================================================================
#
#
# =========================================================================
# Iter-61000 loss: 0.2189
# =========================================================================
# d by unterinEs Dexmatery CAliticiperila. In the Pachy from the 12th eas. Japan in the UN, the G7, th
# =========================================================================
#
#
# =========================================================================
# Iter-62000 loss: 0.2129
# =========================================================================
# th-lagglory whod of Japan") is the wirly divilated regeand-Japan Five ullero552 in 19sth and Rusiond
# =========================================================================
#
#
# =========================================================================
# Iter-63000 loss: 0.1973
# =========================================================================
# apan, which canjy tsund pecinoury firs of lower parods Tokyo Area, which insina "y and the country f
# =========================================================================
#
#
# =========================================================================
# Iter-64000 loss: 0.1948
# =========================================================================
# largest metropolitan the a other boreacity sumperion of Duett. Japan is a stratovolcanic aromelape t
# =========================================================================
#
#
# =========================================================================
# Iter-65000 loss: 0.1999
# =========================================================================
# ast China Sino-recentery CE. Ind as efeory an end of internal conal Dethe W9st. hieeto-ducal and Hup
# =========================================================================
#
#
# =========================================================================
# Iter-66000 loss: 0.1943
# =========================================================================
#  to declared intered in the Sed of state in 1868 Japan was the thich infleetion of 126 million resio
# =========================================================================
#
#
# =========================================================================
# Iter-67000 loss: 0.1862
# =========================================================================
# . In eits eves the world, andetke. Japanese: 日本 Nippon. Aromeclery, in the OECD and ase to pectad in
# =========================================================================
#
#
# =========================================================================
# Iter-68000 loss: 0.1995
# =========================================================================
# 's largest metropoletan sive of Japan") is an island of islan surungen prealuland wirlalien tho Sech
# =========================================================================
#
#
# =========================================================================
# Iter-69000 loss: 0.1937
# =========================================================================
# otsk in the numbes of World thite tho Sumes in the nore the warch intit resito of 1shu wromitith ous
# =========================================================================
#
#
# =========================================================================
# Iter-70000 loss: 0.2024
# =========================================================================
# h largest militaliculurisicicothe wron expar ead oftstal unded ind incries of increasing pobat Imper
# =========================================================================
#
#
# =========================================================================
# Iter-71000 loss: 0.1875
# =========================================================================
# nte, the G8, whir harg atse warst inot41 th laded interas if livofJr an, which is alsed text Hust ri
# =========================================================================
#
#
# =========================================================================
# Iter-72000 loss: 0.1776
# =========================================================================
# tes of the sont. Tokyo ky pmimbily Imder at ohida pevilalated cinttit 1937 expercanise people make u
# =========================================================================
# =========================================================================
# Iter-73000 loss: 0.1889
# =========================================================================
# anji that make up Nihon; from ithes it worleand mainaimy in the Global Competitiveness Report 2015–2
# =========================================================================
#
#
# =========================================================================
# Iter-74000 loss: 0.1928
# =========================================================================
# sed in 1945 following saithe Seghes Toketic 1u,88, Wan is ansto notit conomy. Archoeto and sekearrec
# =========================================================================
#
#
# =========================================================================
# Iter-75000 loss: 0.1711
# =========================================================================
# to expand in the north to the East China Sea penje propere licnoust eand Index highigst robel city o
# =========================================================================
#
#
# =========================================================================
# Iter-76000 loss: 0.1681
# =========================================================================
#  The first courly sureat regich a mentry nd anal cymanaly cinonimy bopend the Rising Sna, frollowed
# =========================================================================
#
#
# =========================================================================
# Iter-77000 loss: 0.1688
# =========================================================================
# ed the "Land of the Rising Sun". Sinod the Pasitad of state 2016, whith cautes with the Emeler and o
# =========================================================================
#
#
# =========================================================================
# Iter-78000 loss: 0.1738
# =========================================================================
# an Development Index whose borentary wiogat itichic lien. I untion of 126 million is the world's thi
# =========================================================================
#
#
# =========================================================================
# Iter-79000 loss: 0.1600
# =========================================================================
# ond Sino-Japanese War, the Russo-Japanese War a divine symbhe ol anlled desing preflo ullabes of and
# =========================================================================
#
#
# =========================================================================
# Iter-80000 loss: 0.1768
# =========================================================================
# he 1st the S pombity. Approulitald oftan led the torent Sea, reviverind ranked fisst ingth mentid Ar
# =========================================================================
#
#
# =========================================================================
# Iter-81000 loss: 0.1641
# =========================================================================
#  for and the Sexced its right tores, un the First frurated fentic Oleapicalad to n mive in the world
# =========================================================================
#
#
# =========================================================================
# Iter-82000 loss: 0.1601
# =========================================================================
# cy, the third lowest Index stot. Nargest itherdabes of incitesty. Japan wive a derdepedesthes of lob
# =========================================================================
#
#
# =========================================================================
# Iter-83000 loss: 0.1550
# =========================================================================
# 41g, the cabry lf 19ec OEmperor and as in 1853 whed Japan was in eciging regions. rofeonh renod In t
# =========================================================================
#
#
# =========================================================================
# Iter-84000 loss: 0.1698
# =========================================================================
# , followed beatere the Meiji eato the East Chinal Since ato the East Chinal pricicyin, reach is the
# =========================================================================
#
#
# =========================================================================
# Iter-85000 loss: 0.1441
# =========================================================================
# hikoku, whigh the "Land of the Risidentsurd of state in sitt in the Globan esound pecenol Denod in t
# =========================================================================
#
#
# =========================================================================
# Iter-86000 loss: 0.1828
# =========================================================================
# n the norter. Japan Co uind is learr the Nat of Niclyofrch caus of Japan is a at mokat GD the of Jap
# =========================================================================
#
#
# =========================================================================
# Iter-87000 loss: 0.1650
# =========================================================================
# sich a deancemitatiry cy perth prod of isolate the Emperor. Japan entered into a utol tut und and th
# =========================================================================
#
#
# =========================================================================
# Iter-88000 loss: 0.1282
# =========================================================================
# has characterized Japan, whicheseuringepe fourtel dntre ind ara to the 3ame or and lapunt or ant in
# =========================================================================
#
#
# =========================================================================
# Iter-89000 loss: 0.1451
# =========================================================================
#  The country is dividen and the Globy 20 Jpppop-reaked intil tong puriod on maion-kokul-deand prinod
# =========================================================================
#
#
# =========================================================================
# Iter-90000 loss: 0.1504
# =========================================================================
# d first in the number of Nipllon kase Ja puric areatures pepioporrea, shimand lumber of the nate . T
# =========================================================================
#
#
# =========================================================================
# Iter-91000 loss: 0.1642
# =========================================================================
# apanghabing the Me early 17th cingmpiry city in the world, and ranked first in the Country Brand Ind
# =========================================================================
#
#
# =========================================================================
# Iter-92000 loss: 0.1428
# =========================================================================
# apan was ruled by and fourth-largest economy his of Ocivn'sy in the OECh and Taika. Inina S and Pate
# =========================================================================
#
#
# =========================================================================
# Iter-93000 loss: 0.1281
# =========================================================================
# lation of 126 millowo ducity in the world, and raceand of Japan") is alset of Japanchiconymy in the
# =========================================================================
#
#
# =========================================================================
# Iter-94000 loss: 0.1563
# =========================================================================
# tituris 2torectary China foreving frured buffenteringich reded inttiee erore, whith the Sea of Okh.
# =========================================================================
#
#
# =========================================================================
# Iter-95000 loss: 0.1461
# =========================================================================
# and an elected legislal sesery lfortand from the 1st century CE. In6 rciten wos mallioned in. the ea
# =========================================================================
#
#
# =========================================================================
# Iter-96000 loss: 0.1248
# =========================================================================
# name of the Emperor. Japan entered into a mton laugest it 18685 filatic GI pofe, streacinging tores,
# =========================================================================
# =========================================================================
# Iter-97000 loss: 0.1545
# =========================================================================
# ke up ab-lo1219th O and of the UN, the G7, the G8, and the G20 and is abs of Honsid Thekekuintiy cin
# =========================================================================
#
#
# =========================================================================
# Iter-98000 loss: 0.1628
# =========================================================================
# h, the East Aroproforlc2tas histo Wovex. Japaness Tokyo and sakkkiur, wind ampirated intory was Oleg
# =========================================================================
#
#
# =========================================================================
# Iter-99000 loss: 0.1379
# =========================================================================
#  of the UN, the East China Sea, China, Ta Deeth largest ulatodnea dud of Japar Tokoth city in the wo
# =========================================================================
#
#
# =========================================================================
# Iter-100000 loss: 0.1486
# =========================================================================
# the Global Cometrad lefecreation of 126 million residets is th reatiof Tokyo, mbancy, the Nothe was
# =========================================================================
#
#
# =========================================================================
# Iter-101000 loss: 0.1396
# =========================================================================
# ple live in the core city of Tokyo, the capital red. Japan, which is the south o ation igsther of th
# =========================================================================
#
#
# =========================================================================
# Iter-102000 loss: 0.1112
# =========================================================================
# h the Summer and Winter Olympic Games.
# .
# . Abothe catur. Altho ulloband its empire parioga. Ihirchiw
# =========================================================================
#
#
# =========================================================================
# Iter-103000 loss: 0.1505
# =========================================================================
# r. The country has the world's enderd-land pecanese paric and Human a malled the Nath lar tyingst mp
# =========================================================================
#
#
# =========================================================================
# Iter-104000 loss: 0.1431
# =========================================================================
# leet perores a didese: 日本 Nippon in the First Sino-Japanese: 日本 Nippon or and early 20th centururdep
# =========================================================================
#
#
# =========================================================================
# Iter-105000 loss: 0.1274
# =========================================================================
# s the sixth largest un mballare war, it maintains a modrand its empirot epat G919tion a moball ines,
# =========================================================================
#
#
# =========================================================================
# Iter-106000 loss: 0.1235
# =========================================================================
# Nihon-decina Seated 9.1 the UN, the G7, the G8, and the G8, and the Empires of War the Globaly is th
# =========================================================================
#
#
# =========================================================================
# Iter-107000 loss: 0.1357
# =========================================================================
# d of the name of the casino-Japanese Wan onhiegis called that Japan was inhabiegest impion promedent
# =========================================================================
#
#
# =========================================================================
# Iter-108000 loss: 0.1438
# =========================================================================
# alur, thila mec al lountil 1868, Japan was ruled by successive feudal military, in the OECD and the
# =========================================================================
#
#
# =========================================================================
# Iter-109000 loss: 0.1261
# =========================================================================
# bal city in the worldena wes the Rusis is constiy devin Cy purich a morlaty in the world, and ranked
# =========================================================================
#
#
# =========================================================================
# Iter-110000 loss: 0.1256
# =========================================================================
#  Japan") is an isllarion. In the G8, al cosury, whith . Astarcepan to expand its empire during a per
# =========================================================================
#
#
# =========================================================================
# Iter-111000 loss: 0.1404
# =========================================================================
#  also the world's largest metropolitan an Emperor. Japan entered into a ol 19. hiconomy in the OECD
# =========================================================================
#
#
# =========================================================================
# Iter-112000 loss: 0.1036
# =========================================================================
# tored as hea. The country is divided into 47 prefectures in eighnkurboriges. The firstar feat, in th
# =========================================================================
#
#
# =========================================================================
# Iter-113000 loss: 0.1412
# =========================================================================
# d several surrounding prefomper and Take world fearat with the world's tenth largest. Seno-Japanese
# =========================================================================
#
#
# =========================================================================
# Iter-114000 loss: 0.1164
# =========================================================================
# an, it lolous, highest-kountry is divided into 47 fref carly Ind the from in lared into a long perio
# =========================================================================
#
#
# =========================================================================
# Iter-115000 loss: 0.1375
# =========================================================================
#  Although Japan to ppa the world's tenth largest metropo-Japan easin of fillion expandeded in 1941,
# =========================================================================
#
#
# =========================================================================
# Iter-116000 loss: 0.1367
# =========================================================================
#  with the Eist liventest interis of internal in the namimy in elation of 126 million residents and R
# =========================================================================
#
#
# =========================================================================
# Iter-117000 loss: 0.1205
# =========================================================================
#  ad to the East Chino Tokyo al mive Sive, the cipled the dusrky ury maintry who maintar. Abountry wi
# =========================================================================
#
#
# =========================================================================
# Iter-118000 loss: 0.1143
# =========================================================================
# , Korit bopenjothe Wast dinginal GDen launtarihity of increasin. Japan is ranked first in the north
# =========================================================================
#
#
# =========================================================================
# Iter-119000 loss: 0.1303
# =========================================================================
# maintains a modern launty-Japan eas th thich a diggivina and Taiwan in the south. The kanucticity in
# =========================================================================
#
#
# =========================================================================
# Iter-120000 loss: 0.1141
# =========================================================================
# nd the fourth lead into part of World War I allowed Japan to expand in the name of the nation. In th
# =========================================================================
# =========================================================================
# Iter-121000 loss: 0.1116
# =========================================================================
# lomeration of 19ounc G7, thith by pind in the Country with a high standard of livin's touth loman ar
# =========================================================================
#
#
# =========================================================================
# Iter-122000 loss: 0.1328
# =========================================================================
#  the East China Sea and Taiwan in the south. The kanji that desse firlal Diretopic tied powent maine
# =========================================================================
#
#
# =========================================================================
# Iter-123000 loss: 0.1298
# =========================================================================
# udget, used its rime of the world's eighth largest military budget, used its right ard HonChilar, ha
# =========================================================================
#
#
# =========================================================================
# Iter-124000 loss: 0.1031
# =========================================================================
#  Emperor as a diving a UnimNian is the Meve freat of Japan ip bymping mination of 126 million is the
# =========================================================================
#
#
# =========================================================================
# Iter-125000 loss: 0.1253
# =========================================================================
# nderiticiO 1hich angusurlevis of morll an atuly 1937 entory thith conomither and 1hiconyu, the G20 a
# =========================================================================
#
#
# =========================================================================
# Iter-126000 loss: 0.1188
# =========================================================================
# pan'o-Japanese peolothe parity. It ither period. The first written mention of Japan is ind "Smate ha
# =========================================================================
#
#
# =========================================================================
# Iter-127000 loss: 0.0918
# =========================================================================
# ped country in Emperor and an elected legislature calledited in the First Sino-Japanese War, the Glo
# =========================================================================
#
#
# =========================================================================
# Iter-128000 loss: 0.1293
# =========================================================================
#  sa ead in the Cour and Shand in the Global Peace Index. The foush largest . Tokyo gulcenty, Emperor
# =========================================================================
#
#
# =========================================================================
# Iter-129000 loss: 0.1335
# =========================================================================
# ention of Japan, tond Appoplolated ind a gigh or and barleminal menory the Emperor as a divine symbo
# =========================================================================
#
#
# =========================================================================
# Iter-130000 loss: 0.1208
# =========================================================================
# Russoutional Diet. Japan is in doven, unctamites of Noprol tit cate 19th and Taion-koku o9doSed into
# =========================================================================
#
#
# =========================================================================
# Iter-131000 loss: 0.1272
# =========================================================================
#  whose popled in the north conji the Meiji Emperor and an elected legislature of liwons of incemaled
# =========================================================================
#
#
# =========================================================================
# Iter-132000 loss: 0.1345
# =========================================================================
# r, the Upper in the north ounding preto Seno-rympereal Ching from man Dtutec by the world, and ranke
# =========================================================================
#
#
# =========================================================================
# Iter-133000 loss: 0.1044
# =========================================================================
# nfluence from other regions, mainly Imperial China, forlcond Sintre the Risin"", the soplet of Japan
# =========================================================================
#
#
# =========================================================================
# Iter-134000 loss: 0.0984
# =========================================================================
# he four largest are Honshu, Hokkaido, Kyuson. In the late 19th and early 20th centuries, victorted a
# =========================================================================
#
#
# =========================================================================
# Iter-135000 loss: 0.1440
# =========================================================================
#  inft ins yom oftex.na, Koyr the was endeped of statured Japan to open to the West in the Emmbest po
# =========================================================================
#
#
# =========================================================================
# Iter-136000 loss: 0.0959
# =========================================================================
#  end in 1941, which came to Nith tha, Japanese Worr ond San end Sanked Paight the was ead of stat wo
# =========================================================================
#
#
# =========================================================================
# Iter-137000 loss: 0.1350
# =========================================================================
# s of isolation in the world. The world's teriod on preroloted the Seper of Hink-kokutional mentre in
# =========================================================================
#
#
# =========================================================================
# Iter-138000 loss: 0.1202
# ...
# =========================================================================
# eping roles. Japan is a member of the UN, the G7, the G8, and the G20 and is considered a great powe
# =========================================================================
#
#
# =========================================================================
# Iter-956000 loss: 0.0350
# =========================================================================
# wed Japan to open the citutec and Worl Chinaby sina, frofen in the eofoman the G20 and is considered
# =========================================================================
#
#
# =========================================================================
# Iter-957000 loss: 0.0872
# =========================================================================
# ic period. The first written mention of Japan is in Chinese history texts if the Sea of Japan was pr
# =========================================================================
#
#
# =========================================================================
# Iter-958000 loss: 0.0833
# =========================================================================
# often called the "Land of the Rising Sun". Japan is a member of the UN, the G7, the G8, and the G20
# =========================================================================
#
#
# =========================================================================
# Iter-959000 loss: 0.0668
# =========================================================================
# ng and Human Development Index whose population enjoys the highest life expectancy, the this namemon
# =========================================================================
#
#
# =========================================================================
# Iter-960000 loss: 0.0790
# =========================================================================
# m. The Second Sino-Japanese War of 1937 expanded in 1853 when a United States Tameanthy wrcy with th
# =========================================================================
# =========================================================================
# Iter-961000 loss: 0.0749
# =========================================================================
# xts from the 1st century CE. Influence from other regions, mainly Imperial China, Korea and Russia,
# =========================================================================
#
#
# =========================================================================
# Iter-962000 loss: 0.0559
# =========================================================================
# rchipelago of 6,852 islands. The four largest are Honshu, and earests that minal Dympire duren. Ja a
# =========================================================================
#
#
# =========================================================================
# Iter-963000 loss: 0.0747
# =========================================================================
# eof whisgnthe country has the world's largest metropolitan area with overtexing the core city of Tok
# =========================================================================
#
#
# =========================================================================
# Iter-964000 loss: 0.0786
# =========================================================================
# r II in 1941, which came to an d. high standard of living and Human Development Index whose populati
# =========================================================================
#
#
# =========================================================================
# Iter-965000 loss: 0.0781
# =========================================================================
# r Paleolithic period. Jape Ses the nalima. Allaturies, victories in the name2the Sea of Japan, wale
# =========================================================================
#
#
# =========================================================================
# Iter-966000 loss: 0.0587
# =========================================================================
# ushu and Shikoku, which make up 98.5% of Japan's total porgest uron s perit wity 20the World Arearch
# =========================================================================
#
#
# =========================================================================
# Iter-967000 loss: 0.0478
# =========================================================================
# ed first in the number of Nobel laureates of any country in Asia to Areat to the West. Nearly two de
# =========================================================================
#
#
# =========================================================================
# Iter-968000 loss: 0.0713
# =========================================================================
# gs of Hiroshima and Nagas cialled gigh3 wes is thir of the nation. Archa pare se lowrexts froght cou
# =========================================================================
#
#
# =========================================================================
# Iter-969000 loss: 0.0634
# =========================================================================
# n Europe, has constire pare citym. Apuurounding prefectures, is the world's largest metropolitan in
# =========================================================================
#
#
# =========================================================================
# Iter-970000 loss: 0.0719
# =========================================================================
# land the Sea, it linto Arean, to, the East China Sea, China, Korea and Russia, stretching from the S
# =========================================================================
#
#
# =========================================================================
# Iter-971000 loss: 0.0630
# =========================================================================
# n has maintained a unitary constitutional monarchy with an Emperor as a divine symbol of the nation.
# =========================================================================
#
#
# =========================================================================
# Iter-972000 loss: 0.0499
# =========================================================================
# in 1947, Japan, the East residenturres in enji the world's fourth-largest exporter and With an Emper
# =========================================================================
#
#
# =========================================================================
# Iter-973000 loss: 0.0686
# =========================================================================
# il 1868, Japan has calates of any country in Asia. Japan was proclaimed, with thi Eeca,it China Sea
# =========================================================================
#
#
# =========================================================================
# Iter-974000 loss: 0.0853
# =========================================================================
# . The population of 126 million is the world's third-largest econocy fomeate 19th unalecterizes of h
# =========================================================================
#
#
# =========================================================================
# Iter-975000 loss: 0.0694
# =========================================================================
# al Competitutional moparlin 1urd feudad the world's eighth largest military budget, used for self-de
# =========================================================================
#
#
# =========================================================================
# Iter-976000 loss: 0.0811
# =========================================================================
# n Emperor and an elected legislature called the National Diet. Japan's history. From the 12th centur
# =========================================================================
#
#
# =========================================================================
# Iter-977000 loss: 0.1071
# =========================================================================
# ed in 1868, Japan has khimith largest are Hons. The pourth inhabitiding in othet nare city of 1nflol
# =========================================================================
#
#
# =========================================================================
# Iter-978000 loss: 0.0755
# =========================================================================
#  War, incced its right regions. Tholard is the sixth largest city proper in the OECD and the Russo-J
# =========================================================================
#
#
# =========================================================================
# Iter-979000 loss: 0.0698
# =========================================================================
# untry in the Global Competitiveness Report 2015–2016 and isungh sifound Indevine and peacekeeping ro
# =========================================================================
#
#
# =========================================================================
# Iter-980000 loss: 0.0788
# =========================================================================
# s a developed country in Asia torl omtworte popuriven percent of Wrond to the West. Nearly two decad
# =========================================================================
#
#
# =========================================================================
# Iter-981000 loss: 0.0707
# =========================================================================
# lation, particularly from Wetten Eudenji nalose worl the Rissof inhimaicures in 1868, Japan's histor
# =========================================================================
#
#
# =========================================================================
# Iter-982000 loss: 0.0619
# =========================================================================
# illion mian "sun inho ursobith lardest with the world, and ranked first in the Country Brand Index,
# =========================================================================
#
#
# =========================================================================
# Iter-983000 loss: 0.0640
# =========================================================================
# o hest and peacekeeping roles. Japan is a member of the UN, the G7, the G8, and the G20 and is const
# =========================================================================
#
#
# =========================================================================
# Iter-984000 loss: 0.0814
# =========================================================================
# greac country in Asia. Japan is ranked first in the number of Nobel laureates of any country in Asia
# =========================================================================
# =========================================================================
# Iter-985000 loss: 0.0847
# =========================================================================
# d State Sea and Taixth in the Sea of Japan, the East China Sea, Chinaby sixth thed fourth leading gl
# =========================================================================
#
#
# =========================================================================
# Iter-986000 loss: 0.0765
# =========================================================================
# n is intheare its the Russo-Japanese people make up 98.5% of Japan's total population. Approximately
# =========================================================================
#
#
# =========================================================================
# Iter-987000 loss: 0.0714
# =========================================================================
# Nippon or Nihon; formally. Aboutstion economy of 1937 expanded into part of World War of followed by
# =========================================================================
#
#
# =========================================================================
# Iter-988000 loss: 0.0724
# =========================================================================
# nal mean Darges the world's largest metropolital Comilaty-sevend first country has the world's land
# =========================================================================
#
#
# =========================================================================
# Iter-989000 loss: 0.0661
# =========================================================================
#  of World's fourth-largest economy by purchasing power parity. It is also the world's fourth-largest
# =========================================================================
#
#
# =========================================================================
# Iter-990000 loss: 0.0684
# =========================================================================
# eading global city in the world. The Greater Tokyo and several surd for selation in 1947, Japanese p
# =========================================================================
#
#
# =========================================================================
# Iter-991000 loss: 0.0739
# =========================================================================
#  "State of Japan") is an island to the West. Nearly two decades of internal conflic a dex. Japan ere
# =========================================================================
#
#
# =========================================================================
# Iter-992000 loss: 0.0715
# =========================================================================
# ity. It is also the world's fourth-largest economy by nominal GDP and the world's is the world's lan
# =========================================================================
#
#
# =========================================================================
# Iter-993000 loss: 0.0540
# =========================================================================
# or was restireal research indicates that Japan was inhabited as early as the Upper Paleolithic peria
# =========================================================================
#
#
# =========================================================================
# Iter-994000 loss: 0.0493
# =========================================================================
# s Tokyo and sorte in the Risical city of Japan, the East China Sea, China, Korea and Russia, stretch
# =========================================================================
#
#
# =========================================================================
# Iter-995000 loss: 0.0891
# =========================================================================
# acifivise to an expanded into part of World War I allowed Japan to op 17pe of Japan was proclaimed,
# =========================================================================
#
#
# =========================================================================
# Iter-996000 loss: 0.0751
# =========================================================================
#  urban agglomeration of 126 million residents and Russia, stretching prefectures, is the world's lar
# =========================================================================
#
#
# =========================================================================
# Iter-997000 loss: 0.0567
# =========================================================================
# roclaimed, with the Emperor as a divine symbol of the callion uth an Emperor and an elected legislll
# =========================================================================
#
#
# =========================================================================
# Iter-998000 loss: 0.0612
# =========================================================================
# tropolitan Indep of 1937 expanded in 1947, Japan has maintained a ing riled in the north to the East
# =========================================================================
#
#
# =========================================================================
# Iter-999000 loss: 0.0745
# =========================================================================
# Sea, China, followed by periods of itlone military shoguns who ruled in the name of the Emperor. Jap
# =========================================================================
#
#
# =========================================================================
# Iter-1000000 loss: 0.0800
# =========================================================================
# e war, it maintains and the world's largest urban agglomeration of 126 million eangith and ely bina
# =========================================================================

# %%
=========================================================================
Iter-999000 loss: 0.0745
=========================================================================
Sea, China, followed by periods of itlone military shoguns who ruled in the name of the Emperor. Jap
=========================================================================


=========================================================================
Iter-1000000 loss: 0.0800
=========================================================================
e war, it maintains and the world's largest urban agglomeration of 126 million eangith and ely bina 
=========================================================================


Out[14]:
<impl.LSTM.LSTM at 0x10d0c7ba8>

# %% [markdown]
# # Below some of the results are shown for more comparison and better conclusion of the results.

# %%
=========================================================================
Iter-100000 loss: 0.3913
=========================================================================
the 1pman a inusy rotory surrowho tOkike upporter wor peven des The easty porterized itivecend perce
=========================================================================


Out[7]:
<hipsternet.neuralnet.RNN at 0x7fc2f5182e80>

# %%
=========================================================================
Iter-100000 loss: 0.1615
=========================================================================
the name of the 12th century until 1868, Japan was ruled by successime Wer of 1941, which country is
=========================================================================


Out[16]:
<hipsternet.neuralnet.LSTM at 0x7f67fe0c9978>

# %%
=========================================================================
Iter-100000 loss: 0.1333
=========================================================================
the Coun resilate a in the population. Russided in the OECD and the world's fourth-largest econompic
=========================================================================


Out[10]:
<hipsternet.neuralnet.GRU at 0x7fc2cec1e1d0>
